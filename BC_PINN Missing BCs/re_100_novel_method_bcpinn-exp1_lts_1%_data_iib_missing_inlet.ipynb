# %%
import tensorflow as tf
import numpy as np
import time
import pandas as pd
import math
import pickle
from pathlib import Path
import matplotlib.pyplot as plt
import wandb

# set random seed
np.random.seed(1234)
tf.compat.v1.set_random_seed(1234)

tf.compat.v1.disable_eager_execution()

# %% [markdown]
# # Initializing wandb functionality

# %%
# !wandb login --relogin
# Copy and paste this api key: 822244d22c29151b0b6501c81c4e22a5c5a0843f

entity_name="vamsi_malineni6"
project_name="bc_pinn_ltd_1data_ib_missing_inlet"

wandb.init(entity=entity_name,project=project_name)
# Finish the dummy run started after first initializing
wandb.run.finish()

# # Delete the dummy run from the wandb workspace 
# api=wandb.Api()
# run_id=wandb.run.id
# run=ap.run(str(entity_name)+"/"+str(project_name)+"/"+str(run_id))
# run.delete()
# Out:
# 'wandb' is not recognized as an internal or external command,
# operable program or batch file.
# wandb: Currently logged in as: vamsi_malineni6. Use `wandb login --relogin` to force relogin
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221010_092219-1hkucq92</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/1hkucq92" target="_blank">northern-meadow-1</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.0, max…
# Synced <strong style="color:#cdcd00">northern-meadow-1</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/1hkucq92" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/1hkucq92</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221010_092219-1hkucq92\logs</code>

# %%
class bc_pinn_t0:
    # Initialize the class
    def __init__(self,domain,initial,boundary,domaindata,datalist,
                 ntrain,batch_size,layers,re,
                 load_model=False,filedr='',freeze=0,timestep=0,
                 savewandb='',saveloss=''):
        
        self.domain   = domain
        self.initial  = initial
        self.boundary = boundary
        self.datalist = datalist
        self.domain_data = domaindata
        
        self.freeze   = freeze
        self.time_step = timestep
        
        self.params_name = savewandb
        self.loss_name   = saveloss
        
        self.ntrain = ntrain
        self.batch_size= batch_size
        
        # Calling domain data for initializing the neural network before entering the Adam optimization
        self.xa=self.domain[:,0].reshape(self.domain[:,0].shape[0],1)
        self.ya=self.domain[:,1].reshape(self.domain[:,1].shape[0],1)
        self.ta=self.domain[:,2].reshape(self.domain[:,2].shape[0],1)
        self.ua=self.domain[:,3].reshape(self.domain[:,3].shape[0],1)
        self.va=self.domain[:,4].reshape(self.domain[:,4].shape[0],1)
        
        
        X = np.concatenate([self.xa,self.ya,self.ta], 1)

        self.lowb = X.min(0) 
        self.upb = X.max(0)
        
        # Calling boundary and initial conditions data as they dont change through the adam iterations
                
        self.x0=self.initial[:,0].reshape(self.initial[:, 0].shape[0], 1)
        self.y0=self.initial[:,1].reshape(self.initial[:, 1].shape[0], 1)
        self.t0=self.initial[:,2].reshape(self.initial[:, 2].shape[0], 1)
        self.u0=self.initial[:,3].reshape(self.initial[:, 3].shape[0], 1)
        self.v0=self.initial[:,4].reshape(self.initial[:, 4].shape[0], 1)
        
        self.xb=self.boundary[:,0].reshape(self.boundary[:, 0].shape[0], 1)
        self.yb=self.boundary[:,1].reshape(self.boundary[:, 1].shape[0], 1)
        self.tb=self.boundary[:,2].reshape(self.boundary[:, 2].shape[0], 1)
        self.ub=self.boundary[:,3].reshape(self.boundary[:, 3].shape[0], 1)
        self.vb=self.boundary[:,4].reshape(self.boundary[:, 4].shape[0], 1)
        
  
        self.layers = layers
        self.re = re

        # Initialize NN
        if load_model ==False:
            self.weights, self.biases = self.initialize_NN(self.layers)
        else:
            self.weights,self.biases = self.load_parameters(filedr,self.layers,self.freeze)
            
        

        # tf placeholders and graph
        
        self.sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        self.learning_rate = tf.compat.v1.placeholder(tf.float32, shape=[])
        
        # Initial conditions placeholders
        self.x_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.x0.shape[1]])
        self.y_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.y0.shape[1]])
        self.t_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.t0.shape[1]])
        self.u_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.u0.shape[1]])
        self.v_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.v0.shape[1]])
        
        # Boundary conditions placeholders
        self.x_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xb.shape[1]])
        self.y_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.yb.shape[1]])
        self.t_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.tb.shape[1]])
        self.u_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ub.shape[1]])
        self.v_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.vb.shape[1]])
        
        # Domain placeholders having the size of batch_size
        self.x_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.y_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.t_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        # Domain data placeholders 
        self.xdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.ydata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.tdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        self.udata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ua.shape[1]])
        self.vdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.va.shape[1]])
        
        # Initial conditions predictions
        self.u_ini_pred, self.v_ini_pred, self.p_ini_pred =\
            self.net_NS(self.x_ini_tf, self.y_ini_tf, self.t_ini_tf)
        
        # Boundary conditions predictions
        self.u_boundary_pred, self.v_boundary_pred, self.p_boundary_pred = \
            self.net_NS(self.x_boundary_tf, self.y_boundary_tf, self.t_boundary_tf)
        
        # Domain data predictions
        self.u_dom_pred,self.v_dom_pred,_=\
            self.net_NS(self.xdata_tf,self.ydata_tf,self.tdata_tf)
        
        # Domain predictions
        self.u_pred, self.v_pred, self.p_pred, self.f_u_pred, self.f_v_pred, self.f_e_pred = \
            self.net_f_NS(self.x_tf, self.y_tf, self.t_tf)

        alpha, beta = 1, 1

        # set loss function
        self.initial_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.u_ini_tf - self.u_ini_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.v_ini_tf - self.v_ini_pred))
        
        self.boundary_loss = beta * tf.reduce_mean(input_tensor=tf.square(self.u_boundary_tf - self.u_boundary_pred)) + \
                             beta * tf.reduce_mean(input_tensor=tf.square(self.v_boundary_tf - self.v_boundary_pred))

        self.domdata_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.udata_tf - self.u_dom_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.vdata_tf - self.v_dom_pred))

        self.residual_loss = tf.reduce_mean(input_tensor=tf.square(self.f_u_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_v_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_e_pred))

        
        
        self.loss =  self.initial_loss + self.boundary_loss + self.residual_loss + self.domdata_loss
        
        self.loss_i=[]
        self.loss_b=[]
        self.loss_r=[]
        self.loss_d=[]

        self.optimizer_Adam = tf.compat.v1.train.AdamOptimizer(self.learning_rate)
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)

        init = tf.compat.v1.global_variables_initializer()
        self.sess.run(init)
        

#===========================================================================================================#
#====================================Transfer Learning======================================================#
#===========================================================================================================#
    def save_parameters(self,fileDr):
        weights=self.sess.run(self.weights)
        biases= self.sess.run(self.biases)
        
                       
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\Missing BCs\exp1")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([weights,biases],f)
            print("Parameters are saved in pickle file")

    def load_parameters(self,fileDr,layers,freeze):
        tf_weights=[]
        tf_biases=[]
        num_layers=len(layers)
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\Missing BCs\exp1")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            weights,biases=pickle.load(f)
            assert num_layers == (len(weights)+1)
        
        # returns the weights and biases of the network as tf.variable, with few of the layers frozen for trainin
        for num in range(0,num_layers-1):
            if num<freeze:
                tf_weights.append ( tf.Variable (weights[num],trainable ='False'))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='False'))
            else:
                tf_weights.append ( tf.Variable (weights[num],trainable ='True'))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='True' ))
        
        print("Parameters are loaded succesffuly")
        
        return tf_weights,tf_biases
    
#===========================================================================================================#
#========================================saving loss values=================================================#
#===========================================================================================================#
    def save_loss(self,fileDr,tf_dict):
        self.loss_i.append(self.sess.run(self.initial_loss,tf_dict))
        self.loss_b.append(self.sess.run(self.boundary_loss,tf_dict))
        self.loss_r.append(self.sess.run(self.residual_loss,tf_dict))
        self.loss_d.append(self.sess.run(self.domdata_loss,tf_dict))
                       
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp38")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([self.loss_i,self.loss_b,self.loss_r,self.loss_d],f)
            print("Loss are saved in pickle file")
    
    def load_loss(self,fileDr):
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp38")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            initial,boundary,residual,datadomain=pickle.load(f)
        
        print("Losses are loaded successfully")
        
        return initial,boundary,residual,datadomain
    

    
#===========================================================================================================#
#===========================================================================================================#
#===========================================================================================================#
 

# initialize the weight and bias
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

# xavier used to initialize the weight
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

# generate the neural network
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = 2.0 * (X - self.lowb) / (self.upb - self.lowb) - 1.0
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
#             H = tf.tanh(tf.add(tf.matmul(H, W), b))
            H = tf.keras.activations.swish(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

# ###################without assume###############
    # supervised data driven
    def net_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        return u, v, p

    # unsupervised NS residual
    def net_f_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        u_t = tf.gradients(ys=u, xs=t)[0] 
        u_x = tf.gradients(ys=u, xs=x)[0] 
        u_y = tf.gradients(ys=u, xs=y)[0] 
        u_xx = tf.gradients(ys=u_x, xs=x)[0] 
        u_yy = tf.gradients(ys=u_y, xs=y)[0] 
        
        v_t = tf.gradients(ys=v, xs=t)[0] 
        v_x = tf.gradients(ys=v, xs=x)[0] 
        v_y = tf.gradients(ys=v, xs=y)[0] 
        v_xx = tf.gradients(ys=v_x, xs=x)[0] 
        v_yy = tf.gradients(ys=v_y, xs=y)[0] 

        p_x = tf.gradients(ys=p, xs=x)[0] 
        p_y = tf.gradients(ys=p, xs=y)[0] 

        f_u = u_t + (u * u_x + v * u_y) + p_x - (1/self.re) * (u_xx + u_yy)
        f_v = v_t + (u * v_x + v * v_y) + p_y - (1/self.re) * (v_xx + v_yy)
        f_e = u_x + v_y

        return u, v, p, f_u, f_v, f_e

#===========================================================================================================#
#===========================Predicting and finding error every 10 epochs====================================#
#===========================================================================================================#
   
    
    def predict(self, x_star, y_star, t_star):

        tf_dict = {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star}

        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)

        return u_star, v_star, p_star
    
    def load_testdata(self,time_step):
        
        # Converting the time_step from decimal to integer 0.1 --> 1
        ts=int(10*time_step)

        # Loading the complete list of data 
        data_list=self.datalist

        # Extracting the data for the given range of time steps [0,0.1] and so on
        dt=0.1
        times=[round(i,3) for i in np.arange(0,7+dt,dt)]

        # Finding the indexes of initial and final timestep from the times list
        t1=times.index(round((time_step-1.0),2))
        t2=times.index(time_step)

        temp=[]
        # Excluding INITIAL DATA from the collocation points, to make sure that the model is not overfitting on
        # initial points, as there is u,v data available for the model. 

        for i in range(t1,t2+1):
            if i<t2+1:
                temp.append(data_list[i])

        # data stores the final timestep data for the given time segment

        data=np.concatenate(temp[4:],axis=0)

        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]

        return X_star,Y_star
    
    def find_error(self,test_time_step):
        
        X_star,Y_star=self.load_testdata(test_time_step)
        u_pred,_,_ = self.predict(X_star[0],X_star[1],X_star[2])
        
        error_u = np.linalg.norm(Y_star[0] - u_pred, 2) / np.linalg.norm(Y_star[0], 2)
        

        return error_u
        
#===========================================================================================================#
#===========================ADAM TRAINING FUNCTION==========================================================#
#===========================================================================================================#
   
#IMPORTANT NOTES for a given TIME SEGMENT consisting of (5*10000=50000) points in the grid.

# (1) Randomly sampling 1000 datapoints every iteration from 38416 collocation points
#     effectively per epoch the model would see 25000 collocation points, which is 65% of sampled colloc points

# (2) Randomly sampling 250 datapoints every iteration from 19208 data points,
#     effectively per epoch the model would see 6250 data points. which is 32% of the sampled data points
 
# (3) The model would see 10000 initial conditions data points per iteration per epoch
#
# (4) The model would see 1584 boundary conditions points per iteration per epoch


    def Adam_train(self, epoch=5000, learning_rate=1e-3):
    
        start_time = time.time()
        
        iters = int(self.ntrain / self.batch_size)
        
        for it in range(epoch):
            
            for i in (range(iters)):
            
                idx=  np.random.choice(self.domain.shape[0],self.batch_size,replace=False)
                didx= np.random.choice(self.domain_data.shape[0],250,replace=False)
                
                self.data_domain=self.domain[idx,:]
                self.data_driven=self.domain_data[didx,:]
                
                xd=self.data_domain[:,0].reshape(self.data_domain[:, 0].shape[0], 1)
                yd=self.data_domain[:,1].reshape(self.data_domain[:, 1].shape[0], 1)
                td=self.data_domain[:,2].reshape(self.data_domain[:, 2].shape[0], 1)

                xdata=self.data_driven[:,0].reshape(self.data_driven[:, 0].shape[0], 1)
                ydata=self.data_driven[:,1].reshape(self.data_driven[:, 1].shape[0], 1)
                tdata=self.data_driven[:,2].reshape(self.data_driven[:, 2].shape[0], 1)
                udata=self.data_driven[:,3].reshape(self.data_driven[:, 3].shape[0], 1)
                vdata=self.data_driven[:,4].reshape(self.data_driven[:, 4].shape[0], 1)
                    
                Xd = np.concatenate([xd,yd,td], 1)
                
                # In contrast the model would see 10000 initial data points every iteration and every epoch
                # The model would see 1584 boundary conditions points every iteration and every epoch
                
                tf_dict = {self.x_ini_tf: self.x0, 
                           self.y_ini_tf: self.y0,
                           self.t_ini_tf: self.t0, 
                           self.u_ini_tf: self.u0,
                           self.v_ini_tf: self.v0, 
                           
                           self.x_boundary_tf: self.xb,
                           self.y_boundary_tf: self.yb, 
                           self.t_boundary_tf: self.tb,
                           self.u_boundary_tf: self.ub, 
                           self.v_boundary_tf: self.vb,
                           
                           self.x_tf: xd, 
                           self.y_tf: yd, 
                           self.t_tf: td,
                           
                           self.xdata_tf: xdata, 
                           self.ydata_tf: ydata, 
                           self.tdata_tf: tdata,
                           self.udata_tf: udata,
                           self.vdata_tf: vdata,
                           
                           self.learning_rate: learning_rate}

                self.sess.run(self.train_op_Adam, tf_dict)
            
            if it % 10 == 0:
                
                elapsed = time.time() - start_time
                
                t_loss= self.sess.run(self.loss, tf_dict)
                i_loss= self.sess.run(self.initial_loss,tf_dict)
                b_loss= self.sess.run(self.boundary_loss,tf_dict)
                r_loss= self.sess.run(self.residual_loss,tf_dict)
                d_loss= self.sess.run(self.domdata_loss,tf_dict)
                
                # Saving the loss values in a pickle file
#                 self.save_loss(self.loss_name,tf_dict)
                
                # Finding the error value at given timestep for every 10 epochs
                eu1= self.find_error(1)
                eu2= self.find_error(2)
                eu3= self.find_error(3)
                eu4= self.find_error(4)
                eu5= self.find_error(5)
                eu6= self.find_error(6)
                eu7= self.find_error(7)
                
                # Logging the loss values and error values to wandb workspace:
                log_dict={"Total_loss":t_loss,"Initial_loss":i_loss,\
                         "Boundary_loss":b_loss,"Residual_loss":r_loss,\
                         "Data_loss":d_loss,\
                         "time step 1":eu1,\
                         "time step 2":eu2,\
                         "time step 3":eu3,\
                         "time step 4":eu4,\
                         "time step 5":eu5,\
                         "time step 6":eu6,\
                         "time step 7":eu7
                         }
                         
                
                wandb.log(log_dict)
                
                print('epochs: %d, Loss: %.3e, Time: %.2f' %
                      (it, t_loss, elapsed))
                
                start_time = time.time()
            
            if it % 1000 == 0 and it > 0:
                self.save_parameters(self.params_name)

# %% [markdown]
# # This code snippet is for training for timesegments other than initial one

# %%
class bc_pinn_t:
    # Initialize the class
    def __init__(self,domain,initial,boundary,domaindata,prevtimedata,datalist,
                 ntrain,batch_size,layers,re,
                 load_model=False,filedr='',freeze=0,timestep=0
                 ,savewandb='',saveloss=''):
        
        self.domain   = domain
        self.initial  = initial
        self.boundary = boundary
        self.domain_data = domaindata
        self.prev_data = prevtimedata
        self.datalist = datalist
        
        self.freeze = freeze
        self.time_step = timestep
        
        self.params_name = savewandb
        self.loss_name   = saveloss
        
        self.ntrain = ntrain
        self.batch_size= batch_size
        #=========================================================================================================#
        
        # Calling domain data for initializing the neural network before entering the Adam optimization
        self.xa=self.domain[:,0].reshape(self.domain[:,0].shape[0],1)
        self.ya=self.domain[:,1].reshape(self.domain[:,1].shape[0],1)
        self.ta=self.domain[:,2].reshape(self.domain[:,2].shape[0],1)
        self.ua=self.domain[:,3].reshape(self.domain[:,3].shape[0],1)
        self.va=self.domain[:,4].reshape(self.domain[:,4].shape[0],1)
        
        # This creates an array of collocation points only for the domain
        X = np.concatenate([self.xa,self.ya,self.ta], 1)
        self.lowb = X.min(0) 
        self.upb = X.max(0)
        
        #=========================================================================================================#
        
        # Calling boundary and initial conditions data as they dont change through the adam iterations
                
        self.x0=self.initial[:,0].reshape(self.initial[:, 0].shape[0], 1)
        self.y0=self.initial[:,1].reshape(self.initial[:, 1].shape[0], 1)
        self.t0=self.initial[:,2].reshape(self.initial[:, 2].shape[0], 1)
        self.u0=self.initial[:,3].reshape(self.initial[:, 3].shape[0], 1)
        self.v0=self.initial[:,4].reshape(self.initial[:, 4].shape[0], 1)
        
        self.xb=self.boundary[:,0].reshape(self.boundary[:, 0].shape[0], 1)
        self.yb=self.boundary[:,1].reshape(self.boundary[:, 1].shape[0], 1)
        self.tb=self.boundary[:,2].reshape(self.boundary[:, 2].shape[0], 1)
        self.ub=self.boundary[:,3].reshape(self.boundary[:, 3].shape[0], 1)
        self.vb=self.boundary[:,4].reshape(self.boundary[:, 4].shape[0], 1)
        
  
        self.layers = layers
        self.re = re

        # Initialize NN
        if load_model ==False:
            self.weights, self.biases = self.initialize_NN(self.layers)
        else:
            self.weights,self.biases = self.load_parameters(filedr,self.layers,self.freeze)
            
        

        # tf placeholders and graph
        
        self.sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        self.learning_rate = tf.compat.v1.placeholder(tf.float32, shape=[])
        
        # Initial conditions placeholders
        self.x_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.x0.shape[1]])
        self.y_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.y0.shape[1]])
        self.t_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.t0.shape[1]])
        self.u_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.u0.shape[1]])
        self.v_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.v0.shape[1]])
        
        # Boundary conditions placeholders
        self.x_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xb.shape[1]])
        self.y_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.yb.shape[1]])
        self.t_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.tb.shape[1]])
        self.u_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ub.shape[1]])
        self.v_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.vb.shape[1]])
        
        # Domain placeholders having the size of batch_size
        self.x_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.y_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.t_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        # Domain data placeholders 
        self.xdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.ydata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.tdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        self.udata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ua.shape[1]])
        self.vdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.va.shape[1]])
        
        # Previous timestep placeholders
        self.xtime_tf = tf.compat.v1.placeholder(tf.float32)
        self.ytime_tf = tf.compat.v1.placeholder(tf.float32)
        self.ttime_tf = tf.compat.v1.placeholder(tf.float32)
        self.utime_tf = tf.compat.v1.placeholder(tf.float32)
        self.vtime_tf = tf.compat.v1.placeholder(tf.float32)
        
        
        # Initial conditions predictions
        self.u_ini_pred, self.v_ini_pred, self.p_ini_pred =\
            self.net_NS(self.x_ini_tf, self.y_ini_tf, self.t_ini_tf)
        
        # Boundary conditions predictions
        self.u_boundary_pred, self.v_boundary_pred, self.p_boundary_pred = \
            self.net_NS(self.x_boundary_tf, self.y_boundary_tf, self.t_boundary_tf)
        
        # Domain data predictions
        self.u_dom_pred,self.v_dom_pred,_=\
            self.net_NS(self.xdata_tf,self.ydata_tf,self.tdata_tf)
        
        # Domain residual predictions
        self.u_pred, self.v_pred, self.p_pred, self.f_u_pred, self.f_v_pred, self.f_e_pred = \
            self.net_f_NS(self.x_tf, self.y_tf, self.t_tf)
        
        # Previous time step predictions
        self.u_time_pred,self.v_time_pred,_=\
            self.net_NS(self.xtime_tf,self.ytime_tf,self.ttime_tf)
        
        
        alpha, beta = 1, 1

        # set loss function
        self.initial_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.u_ini_tf - self.u_ini_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.v_ini_tf - self.v_ini_pred))
        
        self.boundary_loss = beta * tf.reduce_mean(input_tensor=tf.square(self.u_boundary_tf - self.u_boundary_pred)) + \
                             beta * tf.reduce_mean(input_tensor=tf.square(self.v_boundary_tf - self.v_boundary_pred))

        self.domdata_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.udata_tf - self.u_dom_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.vdata_tf - self.v_dom_pred))
        
        self.prevtime_loss = alpha * tf.reduce_mean(input_tensor=tf.square(self.utime_tf - self.u_time_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.vtime_tf - self.v_time_pred))
        
        
        self.residual_loss = tf.reduce_mean(input_tensor=tf.square(self.f_u_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_v_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_e_pred))

        
        
        self.loss =  self.initial_loss + self.boundary_loss + self.residual_loss + self.domdata_loss + self.prevtime_loss
        
        self.loss_i=[]
        self.loss_b=[]
        self.loss_r=[]
        self.loss_d=[]
        self.loss_p=[]

        self.optimizer_Adam = tf.compat.v1.train.AdamOptimizer(self.learning_rate)
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)

        init = tf.compat.v1.global_variables_initializer()
        self.sess.run(init)
        

#===========================================================================================================#
#====================================Transfer Learning======================================================#
#===========================================================================================================#
    def save_parameters(self,fileDr):
        weights=self.sess.run(self.weights)
        biases= self.sess.run(self.biases)
        
                       
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\Missing BCs\exp1")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([weights,biases],f)
            print("Parameters are saved in pickle file")

    def load_parameters(self,fileDr,layers,freeze):
        tf_weights=[]
        tf_biases=[]
        num_layers=len(layers)
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\Missing BCs\exp1")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            weights,biases=pickle.load(f)
            assert num_layers == (len(weights)+1)
        
        # returns the weights and biases of the network as tf.variable
        for num in range(0,num_layers-1):
            if num<freeze:
                tf_weights.append ( tf.Variable (weights[num],trainable ='False'))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='False'))
            else:
                tf_weights.append ( tf.Variable (weights[num],trainable ='True' ))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='True' ))
        
        print("Parameters are loaded succesffuly")
        
        return tf_weights,tf_biases
    
#===========================================================================================================#
#========================================saving loss values=================================================#
#===========================================================================================================#
    def save_loss(self,fileDr,tf_dict):
        self.loss_i.append(self.sess.run(self.initial_loss,tf_dict))
        self.loss_b.append(self.sess.run(self.boundary_loss,tf_dict))
        self.loss_r.append(self.sess.run(self.residual_loss,tf_dict))
        self.loss_d.append(self.sess.run(self.domdata_loss,tf_dict))
        self.loss_p.append(self.sess.run(self.prevtime_loss,tf_dict))
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp38")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([self.loss_i,self.loss_b,self.loss_r,self.loss_d,self.loss_p],f)
            print("Loss are saved in pickle file")
    
    def load_loss(self,fileDr):
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp38")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            initial,boundary,residual,datadomain,prevtimeloss=pickle.load(f)
        
        print("Losses are loaded successfully")
        
        return initial,boundary,residual,datadomain,prevtimeloss
    
#===========================================================================================================#
#========================================Utility fucntions of NN============================================#
#===========================================================================================================#
 

# initialize the weight and bias
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

# xavier used to initialize the weight
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

# generate the neural network
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = 2.0 * (X - self.lowb) / (self.upb - self.lowb) - 1.0
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
#             H = tf.tanh(tf.add(tf.matmul(H, W), b))
            H = tf.keras.activations.swish(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
# ###################without assume###############
    # supervised data driven
    def net_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        return u, v, p

    # unsupervised NS residual
    def net_f_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        u_t = tf.gradients(ys=u, xs=t)[0] 
        u_x = tf.gradients(ys=u, xs=x)[0] 
        u_y = tf.gradients(ys=u, xs=y)[0] 
        u_xx = tf.gradients(ys=u_x, xs=x)[0] 
        u_yy = tf.gradients(ys=u_y, xs=y)[0] 
        
        v_t = tf.gradients(ys=v, xs=t)[0] 
        v_x = tf.gradients(ys=v, xs=x)[0] 
        v_y = tf.gradients(ys=v, xs=y)[0] 
        v_xx = tf.gradients(ys=v_x, xs=x)[0] 
        v_yy = tf.gradients(ys=v_y, xs=y)[0] 

        p_x = tf.gradients(ys=p, xs=x)[0] 
        p_y = tf.gradients(ys=p, xs=y)[0] 

        f_u = u_t + (u * u_x + v * u_y) + p_x - (1/self.re) * (u_xx + u_yy)
        f_v = v_t + (u * v_x + v * v_y) + p_y - (1/self.re) * (v_xx + v_yy)
        f_e = u_x + v_y

        return u, v, p, f_u, f_v, f_e
    
#===========================================================================================================#
#===========================Predicting and finding error every 10 epochs====================================#
#===========================================================================================================#
   

    def predict(self, x_star, y_star, t_star):

        tf_dict = {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star}

        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)

        return u_star, v_star, p_star
    
    def load_testdata(self,time_step):
        
        # Converting the time_step from decimal to integer 0.1 --> 1
        ts=int(10*time_step)

        # Loading the complete list of data 
        data_list=self.datalist

        # Extracting the data for the given range of time steps [0,0.1] and so on
        dt=0.1
        times=[round(i,3) for i in np.arange(0,7+dt,dt)]

        # Finding the indexes of initial and final timestep from the times list
        t1=times.index(round((time_step-1.0),2))
        t2=times.index(time_step)

        temp=[]
        # Excluding INITIAL DATA from the collocation points, to make sure that the model is not overfitting on
        # initial points, as there is u,v data available for the model. 

        for i in range(t1,t2+1):
            if i<t2+1:
                temp.append(data_list[i])

        # data stores the final timestep data for the given time segment

        data=np.concatenate(temp[4:],axis=0)

        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]

        return X_star,Y_star
    
    def find_error(self,test_time_step):
        
        X_star,Y_star=self.load_testdata(test_time_step)
        u_pred,_,_ = self.predict(X_star[0],X_star[1],X_star[2])
        
        error_u = np.linalg.norm(Y_star[0] - u_pred, 2) / np.linalg.norm(Y_star[0], 2)
        

        return error_u
        
    
    
    
#===========================================================================================================#
#===========================ADAM TRAINING FUNCTION==========================================================#
#===========================================================================================================#

    def Adam_train(self, epoch=5000, learning_rate=1e-3):

        start_time = time.time()
        
        iters = int(self.ntrain / self.batch_size)
        
        for it in range(epoch):
            
            for i in (range(iters)):
            
                # Randomly sampling ntrain datapoints in the spatio-temporal region
                idx=  np.random.choice(self.domain.shape[0],self.batch_size,replace=False)
                
                didx= np.random.choice(self.domain_data.shape[0],250,replace=False)
                
                # Should increase the batch size of prev data so that the model would be able to see more number of points
                # per iteration
                pidx= np.random.choice(self.prev_data.shape[0],(1000*self.time_step),replace=False)
                
                self.data_domain = self.domain[idx,:]
                self.data_driven = self.domain_data[didx,:]
                self.prev_batch  = self.prev_data[pidx,:]
                
                # Collocation points inside the domain without data
                xd=self.data_domain[:,0].reshape(self.data_domain[:, 0].shape[0], 1)
                yd=self.data_domain[:,1].reshape(self.data_domain[:, 1].shape[0], 1)
                td=self.data_domain[:,2].reshape(self.data_domain[:, 2].shape[0], 1)
                
                # Collocation points inside the domain with data
                xdata=self.data_driven[:,0].reshape(self.data_driven[:, 0].shape[0], 1)
                ydata=self.data_driven[:,1].reshape(self.data_driven[:, 1].shape[0], 1)
                tdata=self.data_driven[:,2].reshape(self.data_driven[:, 2].shape[0], 1)
                udata=self.data_driven[:,3].reshape(self.data_driven[:, 3].shape[0], 1)
                vdata=self.data_driven[:,4].reshape(self.data_driven[:, 4].shape[0], 1)
                
                # Points from the previous time steps with data
                xprev=self.prev_batch[:,0].reshape(self.prev_batch[:,0].shape[0],1)
                yprev=self.prev_batch[:,1].reshape(self.prev_batch[:,1].shape[0],1)
                tprev=self.prev_batch[:,2].reshape(self.prev_batch[:,2].shape[0],1)
                uprev=self.prev_batch[:,3].reshape(self.prev_batch[:,3].shape[0],1)
                vprev=self.prev_batch[:,4].reshape(self.prev_batch[:,4].shape[0],1)
                
                Xd = np.concatenate([xd,yd,td], 1)
        
                tf_dict = {self.x_ini_tf: self.x0, 
                           self.y_ini_tf: self.y0,
                           self.t_ini_tf: self.t0, 
                           self.u_ini_tf: self.u0,
                           self.v_ini_tf: self.v0, 
                           
                           self.x_boundary_tf: self.xb,
                           self.y_boundary_tf: self.yb, 
                           self.t_boundary_tf: self.tb,
                           self.u_boundary_tf: self.ub, 
                           self.v_boundary_tf: self.vb,
                           
                           self.x_tf: xd, 
                           self.y_tf: yd, 
                           self.t_tf: td,
                           
                           self.xdata_tf: xdata, 
                           self.ydata_tf: ydata, 
                           self.tdata_tf: tdata,
                           self.udata_tf: udata,
                           self.vdata_tf: vdata,
                           
                           self.xtime_tf: xprev,
                           self.ytime_tf: yprev,
                           self.ttime_tf: tprev,
                           self.utime_tf: uprev,
                           self.vtime_tf: vprev,
                           
                           self.learning_rate: learning_rate}

                self.sess.run(self.train_op_Adam, tf_dict)
            
            if it % 10 == 0:
                
                elapsed = time.time() - start_time
                
                t_loss= self.sess.run(self.loss, tf_dict)
                i_loss= self.sess.run(self.initial_loss,tf_dict)
                b_loss= self.sess.run(self.boundary_loss,tf_dict)
                r_loss= self.sess.run(self.residual_loss,tf_dict)
                d_loss= self.sess.run(self.domdata_loss,tf_dict)
                p_loss= self.sess.run(self.prevtime_loss,tf_dict)
                
                # Saving the loss values in a pickle file
#                 self.save_loss(self.loss_name,tf_dict)
                
                # Finding the error value at given timestep for every 10 epochs
                eu1= self.find_error(1)
                eu2= self.find_error(2)
                eu3= self.find_error(3)
                eu4= self.find_error(4)
                eu5= self.find_error(5)
                eu6= self.find_error(6)
                eu7= self.find_error(7)
#                 eo= self.find_error(0.1)
                
                # Logging the loss values and error values to wandb workspace:
                log_dict={"Total_loss":t_loss,"Initial_loss":i_loss,\
                         "Boundary_loss":b_loss,"Residual_loss":r_loss,\
                         "Data_loss":d_loss,"Previous_loss":p_loss,\
                          "time step 1":eu1,\
                          "time step 2":eu2,\
                          "time step 3":eu3,\
                          "time step 4":eu4,\
                          "time step 5":eu5,\
                          "time step 6":eu6,\
                          "time step 7":eu7
                         }
                
                wandb.log(log_dict)
                
                print('epochs: %d, Loss: %.3e, Time: %.2f' %
                      (it, t_loss, elapsed))
                
                start_time = time.time()
            
            if it % 10 == 0 and it > 0:
                self.save_parameters(self.params_name)

# %% [markdown]
# # Data loading functions

# %%
def load_complete_data():

    path=r"E:\Vamsi_oe20s302\Research work\Simulations and data\Unsteady trials\data\trials\Re100_data_true"

    uvel=pd.read_csv(path+r"/u_vel.csv")
    uvel=uvel.to_numpy()
    
    vvel=pd.read_csv(path+r"/v_vel.csv")
    vvel=vvel.to_numpy()
    
    press=pd.read_csv(path+r"/press.csv")
    press=press.to_numpy()
    
    xy=pd.read_csv(path+r"/xy.csv")
    xy=xy.to_numpy()
    
    time=pd.read_csv(path+r"/time.csv")
    time=time.to_numpy()
    time=time-time[0]

    N=xy.shape[0]
    TT = np.tile(time, (1,N)).T # N x T
    
    # stores the data for each time step as a list
    data_list=[]
    
    for i in range(TT.shape[1]):
        if i<N:
            t=TT[:,i:i+1]
            u=uvel[:,i:i+1]
            v=vvel[:,i:i+1]
            p=press[:,i:i+1]
            a=np.concatenate([xy,t,u,v,p],1)
            data_list.append(a)
    
    return data_list

# %%
def reduced_data(temp_datalist,min_max):
    
    xmax,xmin,ymax,ymin,tmax,tmin=min_max

    # Removing the boundary conditions 
    temp_data=[]
    for i in range(len(temp_datalist)):
        td=temp_datalist[i]
        td=td[:,:][td[:,0]>xmin]
        td=td[:,:][td[:,1]>ymin]
        td=td[:,:][td[:,0]<xmax]
        td=td[:,:][td[:,1]<ymax]
        temp_data.append(td)

    tot_num=temp_data[0].shape[0]
    # Choosing 1% of data 
    didx= np.random.choice(tot_num,int(tot_num/100),replace=False)

    data_datalist=[]
    for i in range(len(temp_data)):
        data_datalist.append(temp_data[i][didx,:])


    return data_datalist

# %%
def load_data(time_step):
    
    # Loading the complete list of data for all timesteps
    data_list=load_complete_data()
    
    # This creates a smaller dataset of timesteps untill 7 
    temp_datalist=[]
    for i in range(len(data_list)):
        if(np.unique(data_list[i][:,2])<7):
            temp_datalist.append(data_list[i])
        else:
            break
   

    
    # ================================================================================#
    # ================================================================================#
    # ================================================================================#

    # Should randomly sample from the above temp datalist 
    dt=0.1
    times=[round(i,3) for i in np.arange(0,7+dt,dt)]
    
    # Finding the indexes of initial and final timestep
    t1=times.index(round((time_step-1.0),2))
    t2=times.index(time_step)
    
    temp=[]
    for i in range(t1,t2+1):
        if i<t2+1:
            temp.append(temp_datalist[i])

    # data1 stores the initial time for the given timestep
    data1=temp[0]

    # data_b stores the data for boundary conditions
    data_b=np.concatenate(temp,axis=0)
    data_b=data_b[:,0:5]
    
    # data stores the collocation points inside the domain
    data=np.concatenate(temp[1:],axis=0)

    # Extracting x,y,t values from data
    xx=data_b[:,0:1]
    yy=data_b[:,1:2]
    tt=data_b[:,2:3]
    
    # Extracting unique values and there by maximum and minimum values of x 
    # and y
    ax=np.unique(xx)
    ay=np.unique(yy)
    at=np.unique(tt)
    
    xmin=min(ax)
    ymin=min(ay)
    tmin=min(at)
    
    xmax=max(ax)
    ymax=max(ay)
    tmax=max(at)
    
    min_max=[xmax,xmin,ymax,ymin,tmax,tmin]
    
    # +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
    # NOTE: All the following datasets are coming from temp_datalist
    # If you want to make any changes for the dataset play with temp_datalist
    # +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

    # here randomly select collocation points inside the domain
    # the selection is done per time step: for time step t>0 example,t=0.0125
    # There are 9600 collocation points available so randomly select points
    # whose u,v data you are going to use. So youll have to send another dataset
    # 
    # Now we have a list of data
    
    # This is only for data driven modelling part of the PINNs
    dlist = reduced_data(temp_datalist,min_max)
    
    temp_data=[]
    for i in range(t1,t2+1):
        if i<t2+1:
            temp_data.append(dlist[i])
    
    # data1 stores the initial time for the given timestep
    domain_data1=temp_data[0]
    
    # data stores the collocation points inside the domain
    domain_data=np.concatenate(temp_data[1:],axis=0)[:,0:5]


    #======================== domain ===================================#
    # Extracting only x,y,t to be sent for collocation points
    # Extracting u,v also for data driven methodology
    domain = data[:,0:5] 
    # Creating a domain dataset where only the points inside the boundary
    # is present
    domain=domain[:,:][domain[:,0]>xmin]
    domain=domain[:,:][domain[:,1]>ymin]
    domain=domain[:,:][domain[:,0]<xmax]
    domain=domain[:,:][domain[:,1]<ymax]

    #======================== initial ==================================#
    # Sending whole data x,y,t,u,v as the initial conditions data
    # Taking only the first set of 10000 points as initial conditions data
    data_t0 = data1[:,0:5]
    
    #======================== boundary =================================#
    # Creating a dataset comprising only boundary conditions data
    # excluding initial conditions
    
    # bc1_data consists of data across all y at x=xmin
#     bc1_data=data_b[:,:][data_b[:,0]==xmin]
#     bc1_data=bc1_data[:,:][bc1_data[:,2]>round(tmin,3)]

    # bc2_data consists of data across all y at x=xmax
    bc2_data=data_b[:,:][data_b[:,0]==xmax]
    bc2_data=bc2_data[:,:][bc2_data[:,2]>round(tmin,3)]

    # bc3_data consists of data across all x at y=ymin
    bc3_data=data_b[:,:][data_b[:,1]==ymin]
    bc3_data=bc3_data[:,:][bc3_data[:,2]>round(tmin,3)]

    # bc4_data consists of data across all x at y=ymax
    bc4_data=data_b[:,:][data_b[:,1]==ymax]
    bc4_data=bc4_data[:,:][bc4_data[:,2]>round(tmin,3)]

    
    # The boundary conditions data is arranged row wise
    # first 100 rows of bc1_data, second 100 rows of bc2_data and so on...
    data_sup_b_train = np.concatenate([bc2_data,bc3_data,bc4_data], 0)


    return domain,data_t0 ,data_sup_b_train,domain_data

# %%
def load_testdata(time_step):
    
    if time_step==0:
        
        data_list=load_complete_data()
        data=data_list[0]
        
        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]
        
    else:
        
        # Converting the time_step from decimal to integer 0.1 --> 1
        ts=int(10*time_step)

        # Loading the complete list of data 
        data_list=load_complete_data()

        # Extracting the data for the given range of time steps [0,0.1] and so on
        dt=0.1
        times=[round(i,3) for i in np.arange(0,7+dt,dt)]

        # Finding the indexes of initial and final timestep from the times list
        t1=times.index(round((time_step-1.0),2))
        t2=times.index(time_step)

        temp=[]

        for i in range(t1,t2+1):
            if i<t2+1:
                temp.append(data_list[i])

        # data stores the final timestep data for the given time segment
        
        # Change the value inside the temp to according to the index of time_step in the given timesegment you are choosing

        data=np.concatenate(temp[10:],axis=0)

        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]

    return X_star,Y_star

# %%
def load_train_data(timestep):
    data_list=load_complete_data()

    data=data_list[timestep]
    x_star=data[:,0].reshape(data[:,0].shape[0],1)
    y_star=data[:,1].reshape(data[:,1].shape[0],1)
    t_star=data[:,2].reshape(data[:,2].shape[0],1)

    X_star=[x_star,y_star,t_star]

    u_star=data[:,3].reshape(data[:,3].shape[0],1)
    v_star=data[:,4].reshape(data[:,4].shape[0],1)
    p_star=data[:,5].reshape(data[:,5].shape[0],1)

    Y_star=[u_star,v_star,p_star]

    return X_star,Y_star

# %%
# This snippet should be run for every time segment to obtain the predictions at each timestep in the specific timesegment

def time_segments(time_step):
    dt=0.1
    steps=[]
    for i in np.arange(round((time_step-1.0),3),round((time_step+dt),3),dt):
        steps.append(round(i,3))

    return steps

def return_indexes(time_step):
    idx=[]
    dt=0.1
    times=[round(i,3) for i in np.arange(0,7+dt,dt)]
    segs=time_segments(time_step)

    for i in range(len(segs)):
        idx.append(times.index(segs[i]))

    return idx

# %% [markdown]
# # Function to save the predictions of each timestep in previous timesegments

# %%
def read_prev_data(fileDr):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\Missing BCs\exp1")
    my_path=root_path/fileDr
    
    with open(my_path,'rb') as f:
        pdata=pickle.load(f)
    print("Previous predictions are loaded from pickle file")
    return pdata

# %%
def save_prev_data(idx,fileDr,t,model):
    if t == 1:
        prev_data=np.empty(shape=(1,5))

        for i in range(len(idx)):
            xi,_=load_train_data(idx[i])
            
            upredi,vpredi,ppredi=model.predict(xi[0],xi[1],xi[2])
            prev_data=np.append(prev_data,np.hstack((xi[0],xi[1],xi[2],upredi,vpredi)),axis=0)

        # Removing the first row of the array
        prev_data=np.delete(prev_data,(0),axis=0)
    
    else:
        # Reading from the previously stored data and appending 
        prev_data= read_prev_data(fileDr)
        
        # Appending the predictions for timesteps other than the first timestep 
        # for ex: excluding predictions for t=0.1 in the time segment [0.1,0.2]
        for i in range(1,len(idx)):
            xi,_=load_train_data(idx[i])
            
            upredi,vpredi,ppredi=model.predict(xi[0],xi[1],xi[2])
            prev_data=np.append(prev_data,np.hstack((xi[0],xi[1],xi[2],upredi,vpredi)),axis=0)
        
        
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_result\Missing BCs\exp1")
    my_path=root_path/fileDr
    
    with open(my_path,'wb') as f:
        pickle.dump(prev_data,f)
        print("Previous predictions are saved in pickle file")

# %% [markdown]
# # Run this Code segment to save the predictions at the final timestep of the segment

# %%
'''
Run this code to save the predictions of the model at the final timestep of 
the segment 
'''
def save_uv_values(model,fileDr,time_step):
    u=[]
    v=[]
    X_star,Y_star=load_testdata(time_step)
    print("Saving the predictions for time step:",np.unique(X_star[2]))
    u_pred, v_pred, p_pred = model.predict(X_star[0],X_star[1],X_star[2])
    
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\Missing BCs\exp1")
    my_path=root_path/fileDr
    
    with open(my_path,'wb') as f:
        pickle.dump([u_pred,v_pred,X_star[2]],f)
        print("Predictions are saved in pickle file")

# %%
def read_uv_values(fileDr):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\Missing BCs\exp1")
    my_path=root_path/fileDr
    
    with open(my_path,'rb') as f:
        u,v,t=pickle.load(f)
    print("Predictions are loaded")
    return u,v,t

# %% [markdown]
# # Commence the initial training using standard PINN

# %%
if __name__ == "__main__":
    '''
This code snippet starts the standard pinn training for the first time segment (0,1] and the predictions for the intermediate
time steps would be saved as a list of arrays in prev_data

Since we have already trained the datadriven model for the first time segment, the parameters of that model are being used,
and the predictions for each time step in the first time segment are being stored in a list of arrays.
    
    '''
    
    '''
Important thing to note here is that the model is just seeing 25000 points out of 10*100*100=100000 points per time segment in
one epoch, thats like 25% of the collocation points, essentially the model should be seeing the whole collocation points 
once per epoch in small batches, this feature is making the model less dependent on the collocation points!.
    '''
    N_train = 25000
    batch_size=1000
    Reynolds = 100
    
    layers = [3]+10*[100]+[3]
    
    time_step = 1
    
    datalist=load_complete_data()
    domain, initial, boundary, domain_data = load_data(time_step)

    # Enter the names of the files :
    '''
    load_params : name of the file from where you want to load the weights and biases initially
    params_name : name of the file where you want to save the weights and biases, incase of RESUMING TRAINING run this file
    loss_name   : name of the file where you want to save the loss components
    prev_name   : name of the file where you want to save the predictions of each time step in the segment
    '''
    
    params_name = 'params_exp38'
    loss_name   = 'Loss_re100_truly_sparse'
   


    with tf.device('/gpu:0'):
        
        # Loading the previously trained model
        model = bc_pinn_t0(domain,initial,boundary,domain_data,datalist,N_train,batch_size,
                           layers,re=Reynolds,
                           load_model=False,filedr='',
                           freeze= 0,timestep=time_step,
                           savewandb=params_name,saveloss=loss_name)
        
        wandb.init(entity=entity_name,project=project_name)
        name_run= str(time_step)
        wandb.run.name=name_run
        
        model.Adam_train(5000, 1e-3)
        model.Adam_train(600, 1e-4)

        # Saving the predictions at each time steps of the timesegment 
        idx=return_indexes(time_step)
        prev_name = 'prev_data_predictions_lts_exp38'
        save_prev_data(idx,prev_name,time_step,model)
        
        # Saving the u and v predictions of the final time steps of the timesegment
        pred_file = 'uv_preds_lts_exp38'
        save_uv_values(model,pred_file,time_step)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221010_092244-21eckujm</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/21eckujm" target="_blank">stoic-wildflower-2</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# epochs: 360, Loss: 3.810e-03, Time: 23.72
# epochs: 370, Loss: 3.219e-03, Time: 23.98
# epochs: 380, Loss: 3.378e-03, Time: 24.17
# epochs: 390, Loss: 4.124e-03, Time: 24.39
# epochs: 400, Loss: 3.266e-03, Time: 23.66
# epochs: 410, Loss: 2.717e-03, Time: 23.80
# epochs: 420, Loss: 3.837e-03, Time: 24.09
# epochs: 430, Loss: 3.456e-03, Time: 23.50
# epochs: 440, Loss: 2.884e-03, Time: 23.66
# epochs: 450, Loss: 4.294e-03, Time: 23.64
# epochs: 460, Loss: 3.625e-03, Time: 23.93
# epochs: 470, Loss: 3.505e-03, Time: 23.57
# epochs: 480, Loss: 3.669e-03, Time: 23.59
# epochs: 490, Loss: 3.411e-03, Time: 23.61
# epochs: 500, Loss: 3.121e-03, Time: 23.65
# epochs: 510, Loss: 3.639e-03, Time: 23.57
# epochs: 520, Loss: 3.092e-03, Time: 23.84
# epochs: 530, Loss: 3.995e-03, Time: 23.82
# epochs: 540, Loss: 3.275e-03, Time: 23.72
# epochs: 550, Loss: 3.484e-03, Time: 23.85
# epochs: 560, Loss: 3.902e-03, Time: 24.46
# epochs: 570, Loss: 3.842e-03, Time: 24.81
# epochs: 580, Loss: 3.123e-03, Time: 24.87
# epochs: 590, Loss: 3.398e-03, Time: 25.07
# Previous predictions are saved in pickle file
# Saving the predictions for time step: [1.]
# Predictions are saved in pickle file

# %% [markdown]
# # Start the training for the next timesegments

# %%
if __name__ == "__main__":

    
    N_train = 25000
    batch_size=1000
    Reynolds = 100
    layers = [3]+10*[100]+[3]
    
    fre = 5
    
    # Timesteps for loop :
    datalist=load_complete_data()
    timesteps=[round(i,3) for i in np.arange(2,8,1)]
    
    # Copy and paste this api key: 822244d22c29151b0b6501c81c4e22a5c5a0843f
#     !wandb login --relogin

    # Starting a new run for every timestep
#     wandb.run.finish()
    entity_name="vamsi_malineni6"
    project_name="bc_pinn_ltd_1data_ib_missing_inlet"
#     wandb.init(reinit=True)

        
    for i in timesteps:
        
        time_step = i
        
        # initializing wandb workspace
        wandb.init(entity=entity_name,project=project_name)
        
        # naming the run on wandb
        name_run= str(time_step)
        wandb.run.name=name_run
        
        # Loading the initial and the boundary conditions for the next timestep
        domain, initial, boundary, domain_data = load_data(time_step)

        # Loading the predictions of the final timestep of the first timesegment as the initial conditions of this time segment
        prediction_file='uv_preds_lts_exp38'
        u,v,t=read_uv_values(prediction_file)

        # Initial condition guided learning
        # Altering the initial conditions data, only uvt values are changed pressure values are untouched.
        initial[:,2]=t[:,0]
        initial[:,3]=u[:,0]
        initial[:,4]=v[:,0]

        # Loading the previous timesegment data
        prev_name='prev_data_predictions_lts_exp38'
        prevtimedata=read_prev_data(prev_name)

        # Enter the names of the files :
        '''
        params_name : name of the file where you want to save the weights and biases, LOAD THE MODEL EVERYTIME, SINCE ITS THE SAME
                      MODEL THAT IS BEING TRAINED OVER DIFFERNT TIMESEGMENTS, WITH FOCUS ON PREV TIME SEGMENTS                  
        loss_name   : name of the file where you want to save the loss components
        prev_name   : name of the file where you want to save the predictions of each time step in the segment
        '''

        params_name = 'params_exp38'
        loss_name   = 'Loss_re100_truly_sparse'

        # Start the Training process
        with tf.device('/gpu:0'):

            bc_pinn_model = bc_pinn_t (domain,initial,boundary,domain_data,prevtimedata,datalist,
                                       N_train,batch_size,
                                       layers,re=Reynolds,
                                       load_model=True,filedr=params_name,
                                       freeze = fre,timestep=time_step,
                                       savewandb=params_name,saveloss=loss_name)

            print("===============================================================================================")
            print("Commencing training for the timesegment:(",round((time_step-1),3),time_step,"] ")
            print("===============================================================================================")
            
            bc_pinn_model.Adam_train(1000, 1e-3)
            bc_pinn_model.Adam_train(1000, 1e-4)

        # Save the predictions of the final timestep of the current timesegment to be used for ICGL
        pred_file='uv_preds_lts_exp38'
        save_uv_values(bc_pinn_model,pred_file,time_step)

        # This code snippet appends the predictions at each time step for the previous time segment.
        idx=return_indexes(time_step)
        save_prev_data(idx,prev_name,time_step,bc_pinn_model)
        

        # Save the experiment run and finish the experiment in wandb 
        wandb.run.save()
        wandb.run.finish()
# Out:
# Finishing last run (ID:21eckujm) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>█▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Data_loss</td><td>█▃▂▂▂▂▂▂▂▂▂▁▁▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>█▄▂▃▂▂▄▂▃▃▂▂▂▂▂▃▂▃▂▃▂▂▁▂▂▂▂▂▃▂▁▂▁▂▂▂▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▃▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>█▅▃▃▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▂▂▁▁▁▂</td></tr><tr><td>time step 2</td><td>▁▃▇▇▇▇▆█▇█▆▆▆▆▆▆▆▆▆▆▇▇▇████████▇▇▆▆▆▆▆▆▆</td></tr><tr><td>time step 3</td><td>▁▁█▅▅▅▅▆▆▆▅▄▂▂▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▄▄▃▃▃▃▃▃</td></tr><tr><td>time step 4</td><td>▁▁▇▅▅▅▆▇██▆▅▁▁▁▁▂▁▂▁▁▁▁▁▂▂▃▂▂▃▄▄▄▃▃▃▃▃▃▃</td></tr><tr><td>time step 5</td><td>▁▁▆▄▅▅▆███▇▆▁▁▁▂▃▃▃▃▂▂▂▁▁▁▂▁▁▂▃▄▃▃▃▃▃▃▃▃</td></tr><tr><td>time step 6</td><td>▁▂▆▄▅▅▆███▇▆▂▁▁▃▄▄▅▄▃▃▃▂▁▁▁▁▁▂▃▃▃▃▂▃▃▃▃▂</td></tr><tr><td>time step 7</td><td>▁▂▅▄▅▅▆███▇▆▂▁▁▃▅▅▆▅▄▄▃▂▂▁▁▁▂▁▃▃▃▃▂▃▃▃▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>9e-05</td></tr><tr><td>Data_loss</td><td>0.00294</td></tr><tr><td>Initial_loss</td><td>0.00015</td></tr><tr><td>Residual_loss</td><td>0.00022</td></tr><tr><td>Total_loss</td><td>0.0034</td></tr><tr><td>time step 1</td><td>0.0529</td></tr><tr><td>time step 2</td><td>0.25906</td></tr><tr><td>time step 3</td><td>0.4225</td></tr><tr><td>time step 4</td><td>0.65711</td></tr><tr><td>time step 5</td><td>0.84467</td></tr><tr><td>time step 6</td><td>1.02713</td></tr><tr><td>time step 7</td><td>1.22578</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">stoic-wildflower-2</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/21eckujm" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/21eckujm</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221010_092244-21eckujm\logs</code>
# Successfully finished last run (ID:21eckujm). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.03342215220133463, max=1.0)…
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221010_150439-zsahv6qn</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/zsahv6qn" target="_blank">visionary-glade-3</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 1 2 ]
# ===============================================================================================
# epochs: 0, Loss: 1.987e-01, Time: 9.04
# epochs: 10, Loss: 2.081e-02, Time: 25.76
# Parameters are saved in pickle file
# epochs: 20, Loss: 1.205e-02, Time: 26.12
# Parameters are saved in pickle file
# epochs: 30, Loss: 8.792e-03, Time: 26.32
# Parameters are saved in pickle file
# epochs: 40, Loss: 7.444e-03, Time: 26.49
# Parameters are saved in pickle file
# epochs: 50, Loss: 6.376e-03, Time: 25.70
# Parameters are saved in pickle file
# epochs: 60, Loss: 6.392e-03, Time: 25.78
# Parameters are saved in pickle file
# epochs: 70, Loss: 5.781e-03, Time: 25.58
# Parameters are saved in pickle file
# epochs: 80, Loss: 6.848e-03, Time: 25.74
# Parameters are saved in pickle file
# epochs: 90, Loss: 6.135e-03, Time: 26.09
# Parameters are saved in pickle file
# epochs:
# Parameters are saved in pickle file
# epochs: 520, Loss: 3.629e-03, Time: 25.78
# Parameters are saved in pickle file
# epochs: 530, Loss: 4.622e-03, Time: 25.73
# Parameters are saved in pickle file
# epochs: 540, Loss: 3.639e-03, Time: 26.17
# Parameters are saved in pickle file
# epochs: 550, Loss: 6.771e-03, Time: 26.16
# Parameters are saved in pickle file
# epochs: 560, Loss: 5.665e-03, Time: 26.15
# Parameters are saved in pickle file
# epochs: 570, Loss: 3.446e-03, Time: 26.27
# Parameters are saved in pickle file
# epochs: 580, Loss: 4.091e-03, Time: 26.15
# Parameters are saved in pickle file
# epochs: 590, Loss: 3.489e-03, Time: 25.71
# Parameters are saved in pickle file
# epochs: 600, Loss: 4.015e-03, Time: 26.50
# Parameters are saved in pickle file
# epochs: 610, Loss: 5.543e-03, Time: 26.85
# Parameters are saved in pickle file
# epochs: 620, Loss: 4.556e-03, Time: 25.80
# Parameters are saved in pickle file
# epochs: 630, Loss: 5.078e-03, Time: 25.72
# Parameters are saved in pickle file
# epochs: 640, Loss: 4.071e-03, Time: 26.01
# Parameters are saved in pickle file
# epochs: 650, Loss: 3.256e-03, Time: 26.00
# Parameters are saved in pickle file
# epochs: 660, Loss: 3.774e-03, Time: 26.15
# Parameters are saved in pickle file
# epochs: 670, Loss: 4.131e-03, Time: 26.17
# Parameters are saved in pickle file
# epochs: 680, Loss: 5.390e-03, Time: 25.82
# Parameters are saved in pickle file
# epochs: 690, Loss: 4.312e-03, Time: 25.57
# Parameters are saved in pickle file
# epochs: 700, Loss: 5.770e-03, Time: 25.63
# Parameters are saved in pickle file
# epochs: 710, Loss: 3.456e-03, Time: 25.77
# Parameters are saved in pickle file
# epochs: 720, Loss: 3.399e-03, Time: 25.35
# Parameters are saved in pickle file
# epochs: 730, Loss: 4.042e-03, Time: 25.93
# Parameters are saved in pickle file
# epochs: 740, Loss: 3.825e-03, Time: 26.03
# Parameters are saved in pickle file
# epochs: 750, Loss: 4.127e-03, Time: 25.77
# Parameters are saved in pickle file
# epochs: 760, Loss: 3.640e-03, Time: 26.04
# Parameters are saved in pickle file
# epochs: 770, Loss: 3.318e-03, Time: 26.01
# Parameters are saved in pickle file
# epochs: 780, Loss: 3.558e-03, Time: 26.45
# Parameters are saved in pickle file
# epochs: 790, Loss: 4.464e-03, Time: 26.50
# Parameters are saved in pickle file
# epochs: 800, Loss: 5.372e-03, Time: 26.43
# Parameters are saved in pickle file
# epochs: 810, Loss: 3.078e-03, Time: 26.39
# Parameters are saved in pickle file
# epochs: 820, Loss: 4.080e-03, Time: 26.87
# Parameters are saved in pickle file
# epochs: 830, Loss: 4.628e-03, Time: 26.36
# Parameters are saved in pickle file
# epochs: 840, Loss: 4.267e-03, Time: 26.02
# Parameters are saved in pickle file
# epochs: 850, Loss: 3.490e-03, Time: 25.94
# Parameters are saved in pickle file
# epochs: 860, Loss: 4.560e-03, Time: 25.98
# Parameters are saved in pickle file
# epochs: 870, Loss: 3.631e-03, Time: 25.81
# Parameters are saved in pickle file
# epochs: 880, Loss: 4.071e-03, Time: 26.05
# Parameters are saved in pickle file
# epochs: 890, Loss: 4.402e-03, Time: 26.17
# Parameters are saved in pickle file
# epochs: 900, Loss: 4.891e-03, Time: 25.88
# Parameters are saved in pickle file
# epochs: 910, Loss: 3.925e-03, Time: 26.31
# Parameters are saved in pickle file
# epochs: 920, Loss: 4.675e-02, Time: 25.98
# Parameters are saved in pickle file
# epochs: 930, Loss: 1.602e-02, Time: 25.98
# Parameters are saved in pickle file
# epochs: 940, Loss: 1.160e-02, Time: 25.26
# Parameters are saved in pickle file
# epochs: 950, Loss: 1.171e-02, Time: 26.95
# Parameters are saved in pickle file
# epochs: 960, Loss: 9.711e-03, Time: 27.30
# Parameters are saved in pickle file
# epochs: 970, Loss: 6.945e-03, Time: 27.09
# Parameters are saved in pickle file
# epochs: 980, Loss: 6.220e-03, Time: 27.20
# Parameters are saved in pickle file
# epochs: 990, Loss: 8.239e-03, Time: 27.54
# Parameters are saved in pickle file
# epochs: 0, Loss: 4.219e-03, Time: 2.69
# epochs: 10, Loss: 3.837e-03, Time: 26.98
# Parameters are saved in pickle file
# epochs: 20, Loss: 3.654e-03, Time: 27.31
# Parameters are saved in pickle file
# epochs: 30, Loss: 3.498e-03, Time: 27.76
# Parameters are saved in pickle file
# epochs: 40, Loss: 4.171e-03, Time: 25.71
# Parameters are saved in pickle file
# epochs: 50, Loss: 3.776e-03, Time: 26.17
# Parameters are saved in pickle file
# epochs: 60, Loss: 2.882e-03, Time: 26.51
# Parameters are saved in pickle file
# epochs: 70, Loss: 2.924e-03, Time: 26.20
# Parameters are saved in pickle file
# epochs: 80, Loss: 3.083e-03, Time: 25.69
# Parameters are saved in pickle file
# epochs: 90, Loss: 3.664e-03, Time: 25.88
# Parameters are saved in pickle file
# epochs: 100, Loss: 3.325e-03, Time: 26.53
# Parameters are saved in pickle file
# epochs: 110, Loss: 3.077e-03, Time: 26.30
# Parameters are saved in pickle file
# epochs: 120, Loss: 2.993e-03, Time: 25.87
# Parameters are saved in pickle file
# epochs: 130, Loss: 3.280e-03, Time: 25.97
# Parameters are saved in pickle file
# epochs: 140, Loss: 2.617e-03, Time: 26.65
# Parameters are saved in pickle file
# epochs: 150, Loss: 2.945e-03, Time: 25.48
# Parameters are saved in pickle file
# epochs: 160, Loss: 3.012e-03, Time: 25.71
# Parameters are saved in pickle file
# epochs: 170, Loss: 3.052e-03, Time: 25.29
# Parameters are saved in pickle file
# epochs: 180, Loss: 2.662e-03, Time: 25.21
# Parameters are saved in pickle file
# epochs: 190, Loss: 2.790e-03, Time: 25.94
# Parameters are saved in pickle file
# epochs: 200, Loss: 2.085e-03, Time: 25.96
# Parameters are saved in pickle file
# epochs: 210, Loss: 2.905e-03, Time: 25.80
# Parameters are saved in pickle file
# epochs: 220, Loss: 3.153e-03, Time: 25.53
# Parameters are saved in pickle file
# epochs: 230, Loss: 2.889e-03, Time: 25.40
# Parameters are saved in pickle file
# epochs: 240, Loss: 2.528e-03, Time: 25.75
# Parameters are saved in pickle file
# epochs: 250, Loss: 2.741e-03, Time: 24.94
# Parameters are saved in pickle file
# epochs: 260, Loss: 2.230e-03, Time: 25.90
# Parameters are saved in pickle file
# epochs: 270, Loss: 2.830e-03, Time: 25.23
# Parameters are saved in pickle file
# epochs: 280, Loss: 2.520e-03, Time: 25.46
# Parameters are saved in pickle file
# epochs: 290, Loss: 2.721e-03, Time: 25.35
# Parameters are saved in pickle file
# epochs: 300, Loss: 2.760e-03, Time: 25.48
# Parameters are saved in pickle file
# epochs: 310, Loss: 2.456e-03, Time: 26.42
# Parameters are saved in pickle file
# epochs: 320, Loss: 2.461e-03, Time: 26.07
# Parameters are saved in pickle file
# epochs: 330, Loss: 3.029e-03, Time: 26.48
# Parameters are saved in pickle file
# epochs: 340, Loss: 2.742e-03, Time: 26.09
# Parameters are saved in pickle file
# epochs: 350, Loss: 2.989e-03, Time: 26.84
# Parameters are saved in pickle file
# epochs: 360, Loss: 2.555e-03, Time: 26.52
# Parameters are saved in pickle file
# epochs: 370, Loss: 2.544e-03, Time: 25.69
# Parameters are saved in pickle file
# epochs: 380, Loss: 2.402e-03, Time: 26.42
# Parameters are saved in pickle file
# epochs: 390, Loss: 2.458e-03, Time: 25.92
# Parameters are saved in pickle file
# epochs: 400, Loss: 2.495e-03, Time: 25.58
# Parameters are saved in pickle file
# epochs: 410, Loss: 2.031e-03, Time: 25.39
# Parameters are saved in pickle file
# epochs: 420, Loss: 2.916e-03, Time: 25.69
# Parameters are saved in pickle file
# epochs: 430, Loss: 2.654e-03, Time: 25.29
# Parameters are saved in pickle file
# epochs: 440, Loss: 2.625e-03, Time: 25.67
# Parameters are saved in pickle file
# epochs: 450, Loss: 2.585e-03, Time: 25.89
# Parameters are saved in pickle file
# epochs: 460, Loss: 2.365e-03, Time: 25.40
# Parameters are saved in pickle file
# epochs: 470, Loss: 2.340e-03, Time: 25.49
# Parameters are saved in pickle file
# epochs: 480, Loss: 2.082e-03, Time: 25.42
# Parameters are saved in pickle file
# epochs: 490, Loss: 2.959e-03, Time: 26.45
# Parameters are saved in pickle file
# epochs: 500, Loss: 2.301e-03, Time: 26.33
# Parameters are saved in pickle file
# epochs: 510, Loss: 2.429e-03, Time: 27.03
# Parameters are saved in pickle file
# epochs: 520, Loss: 2.195e-03, Time: 27.03
# Parameters are saved in pickle file
# epochs: 530, Loss: 2.182e-03, Time: 26.34
# Parameters are saved in pickle file
# epochs: 540, Loss: 3.042e-03, Time: 26.37
# Parameters are saved in pickle file
# epochs: 550, Loss: 2.269e-03, Time: 27.26
# Parameters are saved in pickle file
# epochs: 560, Loss: 2.198e-03, Time: 27.04
# Parameters are saved in pickle file
# epochs: 570, Loss: 2.181e-03, Time: 26.50
# Parameters are saved in pickle file
# epochs: 580, Loss: 2.125e-03, Time: 25.66
# Parameters are saved in pickle file
# epochs: 590, Loss: 1.914e-03, Time: 25.73
# Parameters are saved in pickle file
# epochs: 600, Loss: 2.457e-03, Time: 26.38
# Parameters are saved in pickle file
# epochs: 610, Loss: 1.899e-03, Time: 25.60
# Parameters are saved in pickle file
# epochs: 620, Loss: 1.994e-03, Time: 26.18
# Parameters are saved in pickle file
# epochs: 630, Loss: 2.209e-03, Time: 26.46
# Parameters are saved in pickle file
# epochs: 640, Loss: 2.435e-03, Time: 26.34
# Parameters are saved in pickle file
# epochs: 650, Loss: 2.197e-03, Time: 25.78
# Parameters are saved in pickle file
# epochs: 660, Loss: 2.894e-03, Time: 25.78
# Parameters are saved in pickle file
# epochs: 670, Loss: 1.676e-03, Time: 27.31
# Parameters are saved in pickle file
# epochs: 680, Loss: 2.386e-03, Time: 26.89
# Parameters are saved in pickle file
# epochs: 690, Loss: 2.422e-03, Time: 26.09
# Parameters are saved in pickle file
# epochs: 700, Loss: 1.659e-03, Time: 26.66
# Parameters are saved in pickle file
# epochs: 710, Loss: 1.850e-03, Time: 27.01
# Parameters are saved in pickle file
# epochs: 720, Loss: 2.563e-03, Time: 26.83
# Parameters are saved in pickle file
# epochs: 730, Loss: 2.463e-03, Time: 26.75
# Parameters are saved in pickle file
# epochs: 740, Loss: 2.508e-03, Time: 26.59
# Parameters are saved in pickle file
# epochs: 750, Loss: 2.178e-03, Time: 25.89
# Parameters are saved in pickle file
# epochs: 760, Loss: 2.487e-03, Time: 25.55
# Parameters are saved in pickle file
# epochs: 770, Loss: 2.246e-03, Time: 25.38
# Parameters are saved in pickle file
# epochs: 780, Loss: 2.396e-03, Time: 25.70
# Parameters are saved in pickle file
# epochs: 790, Loss: 2.587e-03, Time: 26.32
# Parameters are saved in pickle file
# epochs: 800, Loss: 1.920e-03, Time: 25.72
# Parameters are saved in pickle file
# epochs: 810, Loss: 2.152e-03, Time: 25.46
# Parameters are saved in pickle file
# epochs: 820, Loss: 1.966e-03, Time: 25.99
# Parameters are saved in pickle file
# epochs: 830, Loss: 3.316e-03, Time: 25.41
# Parameters are saved in pickle file
# epochs: 840, Loss: 2.336e-03, Time: 25.94
# Parameters are saved in pickle file
# epochs: 850, Loss: 2.533e-03, Time: 25.83
# Parameters are saved in pickle file
# epochs: 860, Loss: 2.663e-03, Time: 26.32
# Parameters are saved in pickle file
# epochs: 870, Loss: 2.881e-03, Time: 25.97
# Parameters are saved in pickle file
# epochs: 880, Loss: 2.571e-03, Time: 25.84
# Parameters are saved in pickle file
# epochs: 890, Loss: 2.453e-03, Time: 25.95
# Parameters are saved in pickle file
# epochs: 900, Loss: 2.459e-03, Time: 25.69
# Parameters are saved in pickle file
# epochs: 910, Loss: 2.379e-03, Time: 25.89
# Parameters are saved in pickle file
# epochs: 920, Loss: 2.009e-03, Time: 25.83
# Parameters are saved in pickle file
# epochs: 930, Loss: 1.882e-03, Time: 26.05
# Parameters are saved in pickle file
# epochs: 940, Loss: 2.011e-03, Time: 26.08
# Parameters are saved in pickle file
# epochs: 950, Loss: 2.114e-03, Time: 26.06
# Parameters are saved in pickle file
# epochs: 960, Loss: 2.128e-03, Time: 25.36
# Parameters are saved in pickle file
# epochs: 970, Loss: 1.988e-03, Time: 25.88
# Parameters are saved in pickle file
# epochs: 980, Loss: 2.246e-03, Time: 25.69
# Parameters are saved in pickle file
# epochs: 990, Loss: 1.816e-03, Time: 25.87
# Parameters are saved in pickle file
# Saving the predictions for time step: [2.]
# Predictions are saved in pickle file
# Previous predictions are loaded from pickle file
# wandb: WARNING Calling wandb.run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# Previous predictions are saved in pickle file
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>█▃▂▂▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Data_loss</td><td>█▄▄▄▅▃▄▃▄▄▄▃▃▃▃▂▂▂▃▆▄▃▃▃▃▃▃▂▂▂▂▂▂▁▂▂▃▃▁▁</td></tr><tr><td>Initial_loss</td><td>█▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Previous_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>▇▄▇▄▅▃▃▃▄▆█▇▆▄▂▃▃▄▄▅▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▃▃▂▃▂▂▂▂▂▃▃▂▂▂▂▂▂▂▃▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁</td></tr><tr><td>time step 1</td><td>█▁▂▂▂▂▂▂▂▂▃▂▂▃▂▂▂▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>time step 2</td><td>█▄▃▂▄▂▂▂▂▂▂▂▂▁▁▁▁▁▁▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 3</td><td>█▆▅▄▅▅▄▄▃▃▃▃▂▃▂▂▂▂▂▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▄</td></tr><tr><td>time step 4</td><td>█▇▅▄▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄</td></tr><tr><td>time step 5</td><td>▄▄▃▃▂▂▂▁▁▁▁▁▂▃▂▃▃▄▃▂▃▂▂▃▃▄▄▄▅▅▆▆▆▆▆▇▇▇██</td></tr><tr><td>time step 6</td><td>▂▃▂▂▁▁▁▁▁▁▂▃▄▆▄▆▇█▆▄▄▃▃▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>time step 7</td><td>▂▂▂▂▁▁▁▁▂▂▃▄▅▇▅▆▇█▆▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>7e-05</td></tr><tr><td>Data_loss</td><td>0.00157</td></tr><tr><td>Initial_loss</td><td>0.0</td></tr><tr><td>Previous_loss</td><td>3e-05</td></tr><tr><td>Residual_loss</td><td>0.00014</td></tr><tr><td>Total_loss</td><td>0.00182</td></tr><tr><td>time step 1</td><td>0.05277</td></tr><tr><td>time step 2</td><td>0.04314</td></tr><tr><td>time step 3</td><td>0.21244</td></tr><tr><td>time step 4</td><td>0.26511</td></tr><tr><td>time step 5</td><td>0.8195</td></tr><tr><td>time step 6</td><td>1.93192</td></tr><tr><td>time step 7</td><td>3.41018</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">visionary-glade-3</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/zsahv6qn" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/zsahv6qn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221010_150439-zsahv6qn\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.033523360888163246, max=1.0…
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221010_163322-1ahn5rte</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/1ahn5rte" target="_blank">denim-pine-4</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 2 3 ]
# ===============================================================================================
# epochs: 0, Loss: 1.173e-01, Time: 9.32
# epochs: 10, Loss: 1.762e-02, Time: 27.12
# Parameters are saved in pickle file
# epochs: 20, Loss: 9.960e-03, Time: 27.76
# Parameters are saved in pickle file
# epochs: 30, Loss: 7.325e-03, Time: 27.78
# Parameters are saved in pickle file
# epochs: 40, Loss: 7.177e-03, Time: 27.56
# Parameters are saved in pickle file
# epochs: 50, Loss: 1.006e-02, Time: 27.31
# Parameters are saved in pickle file
# epochs: 60, Loss: 8.859e-03, Time: 28.02
# Parameters are saved in pickle file
# epochs: 70, Loss: 6.879e-03, Time: 27.96
# Parameters are saved in pickle file
# epochs: 80, Loss: 5.574e-03, Time: 27.76
# Parameters are saved in pickle file
# epochs: 90, Loss: 6.987e-03, Time: 27.82
# Parameters are saved in pickle file
# epochs: 100, Loss: 5.106e-03, Time: 27.49
# Parameters are saved in pickle file
# epochs: 110, Loss: 5.237e-03, Time: 27.23
# Parameters are saved in pickle file
# epochs: 120, Loss: 8.191e-03, Time: 26.79
# Parameters are saved in pickle file
# epochs: 130, Loss: 5.451e-03, Time: 26.81
# Parameters are saved in pickle file
# epochs: 140, Loss: 5.269e-03, Time: 26.56
# Parameters are saved in pickle file
# epochs: 150, Loss: 6.463e-03, Time: 26.64
# Parameters are saved in pickle file
# epochs: 160, Loss: 4.496e-03, Time: 26.75
# Parameters are saved in pickle file
# epochs: 170, Loss: 5.707e-03, Time: 26.88
# Parameters are saved in pickle file
# epochs: 180, Loss: 3.957e-03, Time: 26.58
# Parameters are saved in pickle file
# epochs: 190, Loss: 4.393e-03, Time: 26.59
# Parameters are saved in pickle file
# epochs: 200, Loss: 3.765e-03, Time: 26.98
# Parameters are saved in pickle file
# epochs: 210, Loss: 4.788e-03, Time: 27.27
# Parameters are saved in pickle file
# epochs: 220, Loss: 5.459e-03, Time: 26.79
# Parameters are saved in pickle file
# epochs: 230, Loss: 4.297e-03, Time: 26.68
# Parameters are saved in pickle file
# epochs: 240, Loss: 4.367e-03, Time: 27.54
# Parameters are saved in pickle file
# epochs: 250, Loss: 4.562e-03, Time: 27.27
# Parameters are saved in pickle file
# epochs: 260, Loss: 5.690e-03, Time: 26.59
# Parameters are saved in pickle file
# epochs: 270, Loss: 4.142e-03, Time: 26.69
# Parameters are saved in pickle file
# epochs: 280, Loss: 5.992e-03, Time: 26.69
# Parameters are saved in pickle file
# epochs: 290, Loss: 5.350e-03, Time: 26.69
# Parameters are saved in pickle file
# epochs: 300, Loss: 3.356e-03, Time: 26.43
# Parameters are saved in pickle file
# epochs: 310, Loss: 4.609e-03, Time: 26.86
# Parameters are saved in pickle file
# epochs: 320, Loss: 4.234e-03, Time: 26.81
# Parameters are saved in pickle file
# epochs: 330, Loss: 3.931e-03, Time: 26.95
# Parameters are saved in pickle file
# epochs: 340, Loss: 2.669e-02, Time: 27.00
# Parameters are saved in pickle file
# epochs: 350, Loss: 1.261e-02, Time: 26.71
# Parameters are saved in pickle file
# epochs: 360, Loss: 8.883e-03, Time: 26.07
# Parameters are saved in pickle file
# epochs: 370, Loss: 7.727e-03, Time: 26.82
# Parameters are saved in pickle file
# epochs: 380, Loss: 5.901e-03, Time: 27.23
# Parameters are saved in pickle file
# epochs: 390, Loss: 7.160e-03, Time: 27.31
# Parameters are saved in pickle file
# epochs: 400, Loss: 5.556e-03, Time: 27.78
# Parameters are saved in pickle file
# epochs: 410, Loss: 5.428e-03, Time: 27.82
# Parameters are saved in pickle file
# epochs: 420, Loss: 9.050e-03, Time: 27.41
# Parameters are saved in pickle file
# epochs: 430, Loss: 7.109e-03, Time: 27.13
# Parameters are saved in pickle file
# epochs: 440, Loss: 4.519e-03, Time: 27.00
# Parameters are saved in pickle file
# epochs: 450, Loss: 5.484e-03, Time: 27.30
# Parameters are saved in pickle file
# epochs: 460, Loss: 4.373e-03, Time: 26.34
# Parameters are saved in pickle file
# epochs: 470, Loss: 5.609e-03, Time: 26.00
# Parameters are saved in pickle file
# epochs: 480, Loss: 4.162e-03, Time: 25.93
# Parameters are saved in pickle file
# epochs: 490, Loss: 4.729e-03, Time: 25.84
# Parameters are saved in pickle file
# epochs: 500, Loss: 4.726e-03, Time: 25.87
# Parameters are saved in pickle file
# epochs: 510, Loss: 4.633e-03, Time: 25.76
# Parameters are saved in pickle file
# epochs: 520, Loss: 5.812e-03, Time: 25.72
# Parameters are saved in pickle file
# epochs: 530, Loss: 5.632e-03, Time: 26.10
# Parameters are saved in pickle file
# epochs: 540, Loss: 4.652e-03, Time: 26.08
# Parameters are saved in pickle file
# epochs: 550, Loss: 5.956e-03, Time: 26.03
# Parameters are saved in pickle file
# epochs: 560, Loss: 4.942e-03, Time: 25.99
# Parameters are saved in pickle file
# epochs: 570, Loss: 4.237e-03, Time: 26.69
# Parameters are saved in pickle file
# epochs: 580, Loss: 4.680e-03, Time: 27.14
# Parameters are saved in pickle file
# epochs: 590, Loss: 3.434e-03, Time: 26.67
# Parameters are saved in pickle file
# epochs: 600, Loss: 4.856e-03, Time: 26.84
# Parameters are saved in pickle file
# epochs: 610, Loss: 3.395e-03, Time: 26.42
# Parameters are saved in pickle file
# epochs: 620, Loss: 3.364e-03, Time: 26.65
# Parameters are saved in pickle file
# epochs: 630, Loss: 3.009e-03, Time: 26.20
# Parameters are saved in pickle file
# epochs: 640, Loss: 4.828e-03, Time: 26.58
# Parameters are saved in pickle file
# epochs: 650, Loss: 4.002e-03, Time: 26.38
# Parameters are saved in pickle file
# epochs: 660, Loss: 3.476e-03, Time: 25.99
# Parameters are saved in pickle file
# epochs: 670, Loss: 4.536e-03, Time: 25.84
# Parameters are saved in pickle file
# epochs: 680, Loss: 2.966e-03, Time: 25.67
# Parameters are saved in pickle file
# epochs: 690, Loss: 3.900e-03, Time: 25.75
# Parameters are saved in pickle file
# epochs: 700, Loss: 4.060e-03, Time: 26.19
# Parameters are saved in pickle file
# epochs: 710, Loss: 3.304e-03, Time: 26.40
# Parameters are saved in pickle file
# epochs: 720, Loss: 4.103e-03, Time: 25.84
# Parameters are saved in pickle file
# epochs: 730, Loss: 4.244e-03, Time: 26.07
# Parameters are saved in pickle file
# epochs: 740, Loss: 3.765e-03, Time: 26.26
# Parameters are saved in pickle file
# epochs: 750, Loss: 3.348e-03, Time: 26.44
# Parameters are saved in pickle file
# epochs: 760, Loss: 3.171e-03, Time: 26.21
# Parameters are saved in pickle file
# epochs: 770, Loss: 3.306e-03, Time: 26.11
# Parameters are saved in pickle file
# epochs: 780, Loss: 2.889e-03, Time: 26.13
# Parameters are saved in pickle file
# epochs: 790, Loss: 2.125e-03, Time: 25.87
# Parameters are saved in pickle file
# epochs: 800, Loss: 3.340e-03, Time: 26.42
# Parameters are saved in pickle file
# epochs:
# Parameters are saved in pickle file
# epochs: 340, Loss: 1.188e-03, Time: 26.47
# Parameters are saved in pickle file
# epochs: 350, Loss: 1.365e-03, Time: 26.15
# Parameters are saved in pickle file
# epochs: 360, Loss: 1.329e-03, Time: 26.09
# Parameters are saved in pickle file
# epochs: 370, Loss: 1.198e-03, Time: 25.65
# Parameters are saved in pickle file
# epochs: 380, Loss: 1.193e-03, Time: 26.05
# Parameters are saved in pickle file
# epochs: 390, Loss: 1.175e-03, Time: 25.57
# Parameters are saved in pickle file
# epochs: 400, Loss: 1.251e-03, Time: 25.30
# Parameters are saved in pickle file
# epochs: 410, Loss: 1.038e-03, Time: 25.56
# Parameters are saved in pickle file
# epochs: 420, Loss: 1.352e-03, Time: 25.72
# Parameters are saved in pickle file
# epochs: 430, Loss: 1.572e-03, Time: 25.79
# Parameters are saved in pickle file
# epochs: 440, Loss: 1.275e-03, Time: 25.53
# Parameters are saved in pickle file
# epochs: 450, Loss: 1.110e-03, Time: 25.91
# Parameters are saved in pickle file
# epochs: 460, Loss: 1.256e-03, Time: 25.36
# Parameters are saved in pickle file
# epochs: 470, Loss: 1.277e-03, Time: 25.58
# Parameters are saved in pickle file
# epochs: 480, Loss: 1.199e-03, Time: 26.24
# Parameters are saved in pickle file
# epochs: 490, Loss: 1.213e-03, Time: 26.10
# Parameters are saved in pickle file
# epochs: 500, Loss: 1.341e-03, Time: 26.15
# Parameters are saved in pickle file
# epochs: 510, Loss: 1.027e-03, Time: 26.09
# Parameters are saved in pickle file
# epochs: 520, Loss: 9.427e-04, Time: 26.44
# Parameters are saved in pickle file
# epochs: 530, Loss: 1.176e-03, Time: 26.01
# Parameters are saved in pickle file
# epochs: 540, Loss: 1.510e-03, Time: 26.33
# Parameters are saved in pickle file
# epochs: 550, Loss: 1.040e-03, Time: 26.44
# Parameters are saved in pickle file
# epochs: 560, Loss: 1.484e-03, Time: 25.96
# Parameters are saved in pickle file
# epochs: 570, Loss: 1.428e-03, Time: 25.59
# Parameters are saved in pickle file
# epochs: 580, Loss: 1.238e-03, Time: 25.28
# Parameters are saved in pickle file
# epochs: 590, Loss: 1.350e-03, Time: 25.70
# Parameters are saved in pickle file
# epochs: 600, Loss: 1.159e-03, Time: 25.43
# Parameters are saved in pickle file
# epochs: 610, Loss: 1.101e-03, Time: 25.85
# Parameters are saved in pickle file
# epochs: 620, Loss: 1.076e-03, Time: 25.69
# Parameters are saved in pickle file
# epochs: 630, Loss: 1.072e-03, Time: 26.17
# Parameters are saved in pickle file
# epochs: 640, Loss: 1.050e-03, Time: 25.79
# Parameters are saved in pickle file
# epochs: 650, Loss: 1.111e-03, Time: 25.70
# Parameters are saved in pickle file
# epochs: 660, Loss: 1.200e-03, Time: 26.50
# Parameters are saved in pickle file
# epochs: 670, Loss: 1.254e-03, Time: 26.64
# Parameters are saved in pickle file
# epochs: 680, Loss: 1.152e-03, Time: 26.49
# Parameters are saved in pickle file
# epochs: 690, Loss: 9.324e-04, Time: 26.69
# Parameters are saved in pickle file
# epochs: 700, Loss: 1.147e-03, Time: 26.81
# Parameters are saved in pickle file
# epochs: 710, Loss: 1.461e-03, Time: 26.41
# Parameters are saved in pickle file
# epochs: 720, Loss: 1.551e-03, Time: 26.64
# Parameters are saved in pickle file
# epochs: 730, Loss: 8.514e-04, Time: 26.97
# Parameters are saved in pickle file
# epochs: 740, Loss: 1.051e-03, Time: 26.24
# Parameters are saved in pickle file
# epochs: 750, Loss: 1.135e-03, Time: 25.72
# Parameters are saved in pickle file
# epochs: 760, Loss: 1.233e-03, Time: 25.90
# Parameters are saved in pickle file
# epochs: 770, Loss: 9.926e-04, Time: 26.35
# Parameters are saved in pickle file
# epochs: 780, Loss: 1.295e-03, Time: 26.01
# Parameters are saved in pickle file
# epochs: 790, Loss: 9.434e-04, Time: 25.74
# Parameters are saved in pickle file
# epochs: 800, Loss: 1.380e-03, Time: 25.96
# Parameters are saved in pickle file
# epochs: 810, Loss: 1.217e-03, Time: 26.01
# Parameters are saved in pickle file
# epochs: 820, Loss: 1.052e-03, Time: 26.17
# Parameters are saved in pickle file
# epochs: 830, Loss: 1.181e-03, Time: 25.62
# Parameters are saved in pickle file
# epochs: 840, Loss: 1.248e-03, Time: 26.37
# Parameters are saved in pickle file
# epochs: 850, Loss: 1.109e-03, Time: 27.06
# Parameters are saved in pickle file
# epochs: 860, Loss: 1.002e-03, Time: 27.07
# Parameters are saved in pickle file
# epochs: 870, Loss: 1.084e-03, Time: 26.91
# Parameters are saved in pickle file
# epochs: 880, Loss: 9.270e-04, Time: 27.50
# Parameters are saved in pickle file
# epochs: 890, Loss: 1.162e-03, Time: 27.45
# Parameters are saved in pickle file
# epochs: 900, Loss: 1.330e-03, Time: 27.34
# Parameters are saved in pickle file
# epochs: 910, Loss: 9.961e-04, Time: 27.26
# Parameters are saved in pickle file
# epochs: 920, Loss: 1.481e-03, Time: 26.67
# Parameters are saved in pickle file
# epochs: 930, Loss: 1.179e-03, Time: 26.58
# Parameters are saved in pickle file
# epochs: 940, Loss: 9.050e-04, Time: 26.24
# Parameters are saved in pickle file
# epochs: 950, Loss: 1.183e-03, Time: 25.83
# Parameters are saved in pickle file
# epochs: 960, Loss: 1.255e-03, Time: 26.33
# Parameters are saved in pickle file
# epochs: 970, Loss: 1.417e-03, Time: 25.81
# Parameters are saved in pickle file
# epochs: 980, Loss: 1.369e-03, Time: 25.74
# Parameters are saved in pickle file
# epochs: 990, Loss: 1.200e-03, Time: 26.05
# Parameters are saved in pickle file
# Saving the predictions for time step: [3.]
# Predictions are saved in pickle file
# Previous predictions are loaded from pickle file
# Previous predictions are saved in pickle file
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>▄▂▂▂▂▁▁█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Data_loss</td><td>▇▃▃▄▃▄▃█▄▃▃▃▃▂▂▂▂▂▁▂▂▁▁▂▁▂▁▁▂▁▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>▅▂▂▁▁▁▁█▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Previous_loss</td><td>█▅▂▂▁▁▁▂▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>▆▆▄▅▅▃▄▇▃▅▄█▃▅▄▄▂▃▂▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▅▃▃▃▃▃▆▃▃▃▃▂▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>█▃▁▁▂▁▂▁▃▁▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>time step 2</td><td>█▅▃▃▃▂▂▄▃▁▂▂▂▁▂▂▂▁▂▁▁▁▁▁▂▁▂▁▂▁▂▂▂▁▂▂▂▁▂▂</td></tr><tr><td>time step 3</td><td>█▆▅▅▄▄▄█▄▄▄▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 4</td><td>▁▃▄▅▆▇█▇▇▇▆▆▆▆▇▇███▆▅▅▅▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>time step 5</td><td>▁▂▂▂▂▃▃▄▄▅▅▅▆▇▇████▇▆▆▆▆▆▅▅▅▅▅▅▅▅▅▅▅▅▅▆▆</td></tr><tr><td>time step 6</td><td>▁▂▂▂▃▃▄▄▄▅▅▅▆▇▇████▇▇▇▆▆▅▅▅▅▄▄▄▄▄▄▄▄▄▄▄▄</td></tr><tr><td>time step 7</td><td>▁▂▂▃▃▃▄▄▄▅▅▅▆▇▇█████▇▇▆▆▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>6e-05</td></tr><tr><td>Data_loss</td><td>0.00088</td></tr><tr><td>Initial_loss</td><td>1e-05</td></tr><tr><td>Previous_loss</td><td>8e-05</td></tr><tr><td>Residual_loss</td><td>0.00018</td></tr><tr><td>Total_loss</td><td>0.0012</td></tr><tr><td>time step 1</td><td>0.05214</td></tr><tr><td>time step 2</td><td>0.04298</td></tr><tr><td>time step 3</td><td>0.02714</td></tr><tr><td>time step 4</td><td>0.20416</td></tr><tr><td>time step 5</td><td>2.06181</td></tr><tr><td>time step 6</td><td>5.83372</td></tr><tr><td>time step 7</td><td>8.25853</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">denim-pine-4</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/1ahn5rte" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/1ahn5rte</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221010_163322-1ahn5rte\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.0337969700495402, max=1.0))…
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221010_180257-3n4k9q5u</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/3n4k9q5u" target="_blank">fanciful-eon-5</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 3 4 ]
# ===============================================================================================
# epochs: 0, Loss: 1.296e-01, Time: 9.11
# epochs: 10, Loss: 1.518e-02, Time: 26.59
# Parameters are saved in pickle file
# epochs: 20, Loss: 7.961e-03, Time: 27.29
# Parameters are saved in pickle file
# epochs: 30, Loss: 8.535e-03, Time: 26.38
# Parameters are saved in pickle file
# epochs: 40, Loss: 6.263e-03, Time: 26.28
# Parameters are saved in pickle file
# epochs: 50, Loss: 7.249e-03, Time: 26.41
# Parameters are saved in pickle file
# epochs: 60, Loss: 5.008e-03, Time: 26.57
# Parameters are saved in pickle file
# epochs: 70, Loss: 6.789e-03, Time: 26.54
# Parameters are saved in pickle file
# epochs: 80, Loss: 4.893e-03, Time: 26.36
# Parameters are saved in pickle file
# epochs: 90, Loss: 9.583e-03, Time: 26.52
# Parameters are saved in pickle file
# epochs: 100, Loss: 4.699e-03, Time: 26.27
# Parameters are saved in pickle file
# epochs: 110, Loss: 5.028e-03, Time: 26.59
# Parameters are saved in pickle file
# epochs: 120, Loss: 5.262e-03, Time: 26.77
# Parameters are saved in pickle file
# epochs: 130, Loss: 4.050e-03, Time: 26.48
# Parameters are saved in pickle file
# epochs: 140, Loss: 3.725e-03, Time: 26.17
# Parameters are saved in pickle file
# epochs: 150, Loss: 4.277e-03, Time: 26.52
# Parameters are saved in pickle file
# epochs: 160, Loss: 3.784e-03, Time: 26.30
# Parameters are saved in pickle file
# epochs: 170, Loss: 4.051e-03, Time: 26.19
# Parameters are saved in pickle file
# epochs: 180, Loss: 3.848e-03, Time: 25.99
# Parameters are saved in pickle file
# epochs: 190, Loss: 3.618e-03, Time: 26.67
# Parameters are saved in pickle file
# epochs: 200, Loss: 3.482e-03, Time: 26.14
# Parameters are saved in pickle file
# epochs: 210, Loss: 4.287e-03, Time: 26.78
# Parameters are saved in pickle file
# epochs: 220, Loss: 3.624e-03, Time: 27.53
# Parameters are saved in pickle file
# epochs: 230, Loss: 4.447e-03, Time: 27.77
# Parameters are saved in pickle file
# epochs: 240, Loss: 3.895e-03, Time: 27.44
# Parameters are saved in pickle file
# epochs: 250, Loss: 3.407e-03, Time: 27.41
# Parameters are saved in pickle file
# epochs: 260, Loss: 4.965e-03, Time: 27.40
# Parameters are saved in pickle file
# epochs: 270, Loss: 3.208e-03, Time: 27.27
# Parameters are saved in pickle file
# epochs: 280, Loss: 2.462e-03, Time: 27.38
# Parameters are saved in pickle file
# epochs: 290, Loss: 2.584e-03, Time: 27.10
# Parameters are saved in pickle file
# epochs: 300, Loss: 3.509e-03, Time: 26.66
# Parameters are saved in pickle file
# epochs: 310, Loss: 3.343e-03, Time: 26.23
# Parameters are saved in pickle file
# epochs: 320, Loss: 3.539e-03, Time: 26.24
# Parameters are saved in pickle file
# epochs: 330, Loss: 2.478e-03, Time: 26.47
# Parameters are saved in pickle file
# epochs: 340, Loss: 3.094e-03, Time: 26.57
# Parameters are saved in pickle file
# epochs: 350, Loss: 2.851e-03, Time: 26.52
# Parameters are saved in pickle file
# epochs: 360, Loss: 2.837e-03, Time: 26.25
# Parameters are saved in pickle file
# epochs: 370, Loss: 4.000e-03, Time: 26.26
# Parameters are saved in pickle file
# epochs: 380, Loss: 2.960e-03, Time: 26.21
# Parameters are saved in pickle file
# epochs: 390, Loss: 4.148e-03, Time: 26.12
# Parameters are saved in pickle file
# epochs: 400, Loss: 2.297e-03, Time: 26.37
# Parameters are saved in pickle file
# epochs: 410, Loss: 2.408e-03, Time: 26.37
# Parameters are saved in pickle file
# epochs: 420, Loss: 2.127e-03, Time: 26.37
# Parameters are saved in pickle file
# epochs: 430, Loss: 2.251e-03, Time: 26.42
# Parameters are saved in pickle file
# epochs: 440, Loss: 3.197e-03, Time: 26.30
# Parameters are saved in pickle file
# epochs: 450, Loss: 3.271e-03, Time: 26.49
# Parameters are saved in pickle file
# epochs: 460, Loss: 1.836e-03, Time: 26.52
# Parameters are saved in pickle file
# epochs: 470, Loss: 3.159e-03, Time: 26.79
# Parameters are saved in pickle file
# epochs: 480, Loss: 2.182e-03, Time: 26.45
# Parameters are saved in pickle file
# epochs: 490, Loss: 2.671e-03, Time: 26.07
# Parameters are saved in pickle file
# epochs: 500, Loss: 3.891e-03, Time: 26.20
# Parameters are saved in pickle file
# epochs: 510, Loss: 2.366e-03, Time: 26.31
# Parameters are saved in pickle file
# ...
# Parameters are saved in pickle file
# epochs: 330, Loss: 3.871e-03, Time: 28.29
# Parameters are saved in pickle file
# epochs: 340, Loss: 2.821e-03, Time: 28.13
# Parameters are saved in pickle file
# epochs: 350, Loss: 3.864e-03, Time: 28.68
# Parameters are saved in pickle file
# epochs: 360, Loss: 4.161e-03, Time: 28.63
# Parameters are saved in pickle file
# epochs: 370, Loss: 3.033e-03, Time: 28.35
# Parameters are saved in pickle file
# epochs: 380, Loss: 2.997e-03, Time: 28.16
# Parameters are saved in pickle file
# epochs: 390, Loss: 6.373e-03, Time: 27.95
# Parameters are saved in pickle file
# epochs: 400, Loss: 4.435e-03, Time: 29.73
# Parameters are saved in pickle file
# epochs: 410, Loss: 2.547e-03, Time: 29.42
# Parameters are saved in pickle file
# epochs: 420, Loss: 3.929e-03, Time: 29.64
# Parameters are saved in pickle file
# epochs: 430, Loss: 2.666e-03, Time: 29.96
# Parameters are saved in pickle file
# epochs: 440, Loss: 4.500e-03, Time: 29.76
# Parameters are saved in pickle file
# epochs: 450, Loss: 3.397e-03, Time: 29.65
# Parameters are saved in pickle file
# epochs: 460, Loss: 3.049e-03, Time: 29.33
# Parameters are saved in pickle file
# epochs: 470, Loss: 3.626e-03, Time: 29.59
# Parameters are saved in pickle file
# epochs: 480, Loss: 2.836e-03, Time: 29.41
# Parameters are saved in pickle file
# epochs: 490, Loss: 3.693e-03, Time: 28.32
# Parameters are saved in pickle file
# epochs: 500, Loss: 2.735e-03, Time: 28.21
# Parameters are saved in pickle file
# epochs: 510, Loss: 3.417e-03, Time: 28.23
# Parameters are saved in pickle file
# epochs: 520, Loss: 3.482e-03, Time: 28.55
# Parameters are saved in pickle file
# epochs: 530, Loss: 3.928e-03, Time: 28.30
# Parameters are saved in pickle file
# epochs: 540, Loss: 3.997e-03, Time: 28.39
# Parameters are saved in pickle file
# epochs: 550, Loss: 2.566e-03, Time: 28.05
# Parameters are saved in pickle file
# epochs: 560, Loss: 3.075e-03, Time: 28.53
# Parameters are saved in pickle file
# epochs: 570, Loss: 3.871e-03, Time: 28.41
# Parameters are saved in pickle file
# epochs: 580, Loss: 4.248e-03, Time: 28.34
# Parameters are saved in pickle file
# epochs: 590, Loss: 2.638e-03, Time: 28.03
# Parameters are saved in pickle file
# epochs: 600, Loss: 3.695e-03, Time: 28.55
# Parameters are saved in pickle file
# epochs: 610, Loss: 2.626e-03, Time: 28.42
# Parameters are saved in pickle file
# epochs: 620, Loss: 3.378e-03, Time: 28.27
# Parameters are saved in pickle file
# epochs: 630, Loss: 3.213e-03, Time: 28.83
# Parameters are saved in pickle file
# epochs: 640, Loss: 3.483e-03, Time: 28.57
# Parameters are saved in pickle file
# epochs: 650, Loss: 3.184e-03, Time: 28.34
# Parameters are saved in pickle file
# epochs: 660, Loss: 4.151e-03, Time: 28.73
# Parameters are saved in pickle file
# epochs: 670, Loss: 2.228e-03, Time: 28.19
# Parameters are saved in pickle file
# epochs: 680, Loss: 2.474e-03, Time: 27.92
# Parameters are saved in pickle file
# epochs: 690, Loss: 4.082e-03, Time: 27.98
# Parameters are saved in pickle file
# epochs: 700, Loss: 3.623e-03, Time: 27.85
# Parameters are saved in pickle file
# epochs: 710, Loss: 2.894e-03, Time: 27.97
# Parameters are saved in pickle file
# epochs: 720, Loss: 2.581e-03, Time: 28.22
# Parameters are saved in pickle file
# epochs: 730, Loss: 2.664e-03, Time: 28.78
# Parameters are saved in pickle file
# epochs: 740, Loss: 3.549e-03, Time: 28.11
# Parameters are saved in pickle file
# epochs: 750, Loss: 3.279e-03, Time: 28.28
# Parameters are saved in pickle file
# epochs: 760, Loss: 4.212e-03, Time: 29.28
# Parameters are saved in pickle file
# epochs: 770, Loss: 2.096e-03, Time: 29.07
# Parameters are saved in pickle file
# epochs: 780, Loss: 2.975e-03, Time: 29.10
# Parameters are saved in pickle file
# epochs: 790, Loss: 2.101e-03, Time: 29.58
# Parameters are saved in pickle file
# epochs: 800, Loss: 3.744e-03, Time: 29.32
# Parameters are saved in pickle file
# epochs: 810, Loss: 2.538e-02, Time: 29.74
# Parameters are saved in pickle file
# epochs: 820, Loss: 7.884e-03, Time: 29.34
# Parameters are saved in pickle file
# epochs: 830, Loss: 6.476e-03, Time: 29.10
# Parameters are saved in pickle file
# epochs: 840, Loss: 4.520e-03, Time: 28.77
# Parameters are saved in pickle file
# epochs: 850, Loss: 4.627e-03, Time: 28.46
# Parameters are saved in pickle file
# epochs: 860, Loss: 4.005e-03, Time: 27.96
# Parameters are saved in pickle file
# epochs: 870, Loss: 3.798e-03, Time: 27.91
# Parameters are saved in pickle file
# epochs: 880, Loss: 3.015e-03, Time: 28.24
# Parameters are saved in pickle file
# epochs: 890, Loss: 3.784e-03, Time: 28.21
# Parameters are saved in pickle file
# epochs: 900, Loss: 3.223e-03, Time: 28.31
# Parameters are saved in pickle file
# epochs: 910, Loss: 4.552e-03, Time: 28.18
# Parameters are saved in pickle file
# epochs: 920, Loss: 4.960e-03, Time: 28.36
# Parameters are saved in pickle file
# epochs: 930, Loss: 2.428e-03, Time: 28.21
# Parameters are saved in pickle file
# epochs: 940, Loss: 2.875e-03, Time: 28.05
# Parameters are saved in pickle file
# epochs: 950, Loss: 4.013e-03, Time: 28.20
# Parameters are saved in pickle file
# epochs: 960, Loss: 4.067e-03, Time: 28.63
# Parameters are saved in pickle file
# epochs: 970, Loss: 3.420e-03, Time: 29.00
# Parameters are saved in pickle file
# epochs: 980, Loss: 3.425e-03, Time: 28.05
# Parameters are saved in pickle file
# epochs: 990, Loss: 3.170e-03, Time: 28.20
# Parameters are saved in pickle file
# epochs: 0, Loss: 1.463e-03, Time: 2.85
# epochs: 10, Loss: 1.321e-03, Time: 28.37
# Parameters are saved in pickle file
# epochs: 20, Loss: 1.372e-03, Time: 27.67
# Parameters are saved in pickle file
# epochs: 30, Loss: 1.323e-03, Time: 28.16
# Parameters are saved in pickle file
# epochs: 40, Loss: 1.357e-03, Time: 28.15
# Parameters are saved in pickle file
# epochs: 50, Loss: 1.302e-03, Time: 27.77
# Parameters are saved in pickle file
# epochs: 60, Loss: 1.316e-03, Time: 28.01
# Parameters are saved in pickle file
# epochs: 70, Loss: 1.259e-03, Time: 27.84
# Parameters are saved in pickle file
# epochs: 80, Loss: 1.323e-03, Time: 27.84
# Parameters are saved in pickle file
# epochs: 90, Loss: 1.387e-03, Time: 28.20
# Parameters are saved in pickle file
# epochs: 100, Loss: 1.250e-03, Time: 28.27
# Parameters are saved in pickle file
# epochs: 110, Loss: 1.282e-03, Time: 28.79
# Parameters are saved in pickle file
# epochs: 120, Loss: 1.327e-03, Time: 29.70
# Parameters are saved in pickle file
# epochs: 130, Loss: 1.278e-03, Time: 29.85
# Parameters are saved in pickle file
# epochs: 140, Loss: 1.265e-03, Time: 29.75
# Parameters are saved in pickle file
# epochs: 150, Loss: 1.368e-03, Time: 29.53
# Parameters are saved in pickle file
# epochs: 160, Loss: 1.234e-03, Time: 29.92
# Parameters are saved in pickle file
# epochs: 170, Loss: 1.149e-03, Time: 29.87
# Parameters are saved in pickle file
# epochs: 180, Loss: 1.346e-03, Time: 29.54
# Parameters are saved in pickle file
# epochs: 190, Loss: 1.113e-03, Time: 29.16
# Parameters are saved in pickle file
# epochs: 200, Loss: 1.202e-03, Time: 28.66
# Parameters are saved in pickle file
# epochs: 210, Loss: 1.228e-03, Time: 28.42
# Parameters are saved in pickle file
# epochs: 220, Loss: 1.187e-03, Time: 28.24
# Parameters are saved in pickle file
# epochs: 230, Loss: 1.174e-03, Time: 28.22
# Parameters are saved in pickle file
# epochs: 240, Loss: 1.309e-03, Time: 28.33
# Parameters are saved in pickle file
# epochs: 250, Loss: 1.199e-03, Time: 28.29
# Parameters are saved in pickle file
# epochs: 260, Loss: 1.198e-03, Time: 28.39
# Parameters are saved in pickle file
# epochs: 270, Loss: 1.280e-03, Time: 28.25
# Parameters are saved in pickle file
# epochs: 280, Loss: 1.179e-03, Time: 28.69
# Parameters are saved in pickle file
# epochs: 290, Loss: 1.090e-03, Time: 28.92
# Parameters are saved in pickle file
# epochs: 300, Loss: 1.148e-03, Time: 28.83
# Parameters are saved in pickle file
# epochs: 310, Loss: 1.189e-03, Time: 29.11
# Parameters are saved in pickle file
# epochs: 320, Loss: 1.079e-03, Time: 29.10
# Parameters are saved in pickle file
# epochs: 330, Loss: 1.147e-03, Time: 29.79
# Parameters are saved in pickle file
# epochs: 340, Loss: 1.155e-03, Time: 28.92
# Parameters are saved in pickle file
# epochs: 350, Loss: 1.129e-03, Time: 29.13
# Parameters are saved in pickle file
# epochs: 360, Loss: 1.163e-03, Time: 28.93
# Parameters are saved in pickle file
# epochs: 370, Loss: 1.146e-03, Time: 28.86
# Parameters are saved in pickle file
# epochs: 380, Loss: 1.032e-03, Time: 27.94
# Parameters are saved in pickle file
# epochs: 390, Loss: 1.042e-03, Time: 28.46
# Parameters are saved in pickle file
# epochs: 400, Loss: 1.027e-03, Time: 28.42
# Parameters are saved in pickle file
# epochs: 410, Loss: 1.043e-03, Time: 28.35
# Parameters are saved in pickle file
# epochs: 420, Loss: 1.096e-03, Time: 28.28
# Parameters are saved in pickle file
# epochs: 430, Loss: 1.015e-03, Time: 28.94
# Parameters are saved in pickle file
# epochs: 440, Loss: 1.074e-03, Time: 28.30
# Parameters are saved in pickle file
# epochs: 450, Loss: 1.097e-03, Time: 28.68
# Parameters are saved in pickle file
# epochs: 460, Loss: 1.046e-03, Time: 27.92
# Parameters are saved in pickle file
# epochs: 470, Loss: 1.119e-03, Time: 28.77
# Parameters are saved in pickle file
# epochs: 480, Loss: 1.055e-03, Time: 28.49
# Parameters are saved in pickle file
# epochs: 490, Loss: 1.066e-03, Time: 28.65
# Parameters are saved in pickle file
# epochs: 500, Loss: 1.055e-03, Time: 28.39
# Parameters are saved in pickle file
# epochs: 510, Loss: 9.766e-04, Time: 28.91
# Parameters are saved in pickle file
# epochs: 520, Loss: 9.903e-04, Time: 28.88
# Parameters are saved in pickle file
# epochs: 530, Loss: 1.041e-03, Time: 28.36
# Parameters are saved in pickle file
# epochs: 540, Loss: 1.080e-03, Time: 28.18
# Parameters are saved in pickle file
# epochs: 550, Loss: 9.266e-04, Time: 28.58
# Parameters are saved in pickle file
# epochs: 560, Loss: 9.438e-04, Time: 28.19
# Parameters are saved in pickle file
# epochs: 570, Loss: 1.023e-03, Time: 28.04
# Parameters are saved in pickle file
# epochs: 580, Loss: 1.006e-03, Time: 27.69
# Parameters are saved in pickle file
# epochs: 590, Loss: 1.010e-03, Time: 28.03
# Parameters are saved in pickle file
# epochs: 600, Loss: 1.014e-03, Time: 28.16
# Parameters are saved in pickle file
# epochs: 610, Loss: 1.075e-03, Time: 27.89
# Parameters are saved in pickle file
# epochs: 620, Loss: 1.005e-03, Time: 27.96
# Parameters are saved in pickle file
# epochs: 630, Loss: 9.391e-04, Time: 28.13
# Parameters are saved in pickle file
# epochs: 640, Loss: 9.752e-04, Time: 28.12
# Parameters are saved in pickle file
# epochs: 650, Loss: 9.854e-04, Time: 28.33
# Parameters are saved in pickle file
# epochs: 660, Loss: 8.630e-04, Time: 28.59
# Parameters are saved in pickle file
# epochs: 670, Loss: 9.664e-04, Time: 28.48
# Parameters are saved in pickle file
# epochs: 680, Loss: 9.915e-04, Time: 28.67
# Parameters are saved in pickle file
# epochs: 690, Loss: 9.304e-04, Time: 28.30
# Parameters are saved in pickle file
# epochs: 700, Loss: 1.003e-03, Time: 28.00
# Parameters are saved in pickle file
# epochs: 710, Loss: 1.009e-03, Time: 28.20
# Parameters are saved in pickle file
# epochs: 720, Loss: 9.755e-04, Time: 28.40
# Parameters are saved in pickle file
# epochs: 730, Loss: 9.656e-04, Time: 28.30
# Parameters are saved in pickle file
# epochs: 740, Loss: 8.654e-04, Time: 27.90
# Parameters are saved in pickle file
# epochs: 750, Loss: 9.154e-04, Time: 28.05
# Parameters are saved in pickle file
# epochs: 760, Loss: 9.522e-04, Time: 28.10
# Parameters are saved in pickle file
# epochs: 770, Loss: 9.353e-04, Time: 27.64
# Parameters are saved in pickle file
# epochs: 780, Loss: 9.672e-04, Time: 28.09
# Parameters are saved in pickle file
# epochs: 790, Loss: 9.338e-04, Time: 28.30
# Parameters are saved in pickle file
# epochs: 800, Loss: 8.948e-04, Time: 28.20
# Parameters are saved in pickle file
# epochs: 810, Loss: 9.304e-04, Time: 28.44
# Parameters are saved in pickle file
# epochs: 820, Loss: 8.814e-04, Time: 28.19
# Parameters are saved in pickle file
# epochs: 830, Loss: 9.763e-04, Time: 29.31
# Parameters are saved in pickle file
# epochs: 840, Loss: 8.784e-04, Time: 29.88
# Parameters are saved in pickle file
# epochs: 850, Loss: 9.303e-04, Time: 30.15
# Parameters are saved in pickle file
# epochs: 860, Loss: 9.669e-04, Time: 29.80
# Parameters are saved in pickle file
# epochs: 870, Loss: 9.206e-04, Time: 29.66
# Parameters are saved in pickle file
# epochs: 880, Loss: 8.856e-04, Time: 29.45
# Parameters are saved in pickle file
# epochs: 890, Loss: 8.757e-04, Time: 30.47
# Parameters are saved in pickle file
# epochs: 900, Loss: 8.663e-04, Time: 30.01
# Parameters are saved in pickle file
# epochs: 910, Loss: 8.686e-04, Time: 29.56
# Parameters are saved in pickle file
# epochs: 920, Loss: 9.180e-04, Time: 28.13
# Parameters are saved in pickle file
# epochs: 930, Loss: 9.518e-04, Time: 28.43
# Parameters are saved in pickle file
# epochs: 940, Loss: 8.986e-04, Time: 28.18
# Parameters are saved in pickle file
# epochs: 950, Loss: 8.787e-04, Time: 27.99
# Parameters are saved in pickle file
# epochs: 960, Loss: 9.018e-04, Time: 28.14
# Parameters are saved in pickle file
# epochs: 970, Loss: 8.715e-04, Time: 28.51
# Parameters are saved in pickle file
# epochs: 980, Loss: 8.793e-04, Time: 28.37
# Parameters are saved in pickle file
# epochs: 990, Loss: 8.749e-04, Time: 27.79
# Parameters are saved in pickle file
# Saving the predictions for time step: [7.]
# Predictions are saved in pickle file
# Previous predictions are loaded from pickle file
# Previous predictions are saved in pickle file
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Data_loss</td><td>▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>▆▂▃▂▂▃▂▂▂▂▁▁▂▁▂▁█▁▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Previous_loss</td><td>█▃▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>▇▃▃▂▄▃▂▃▂▃▂▂▂▂▂▂█▂▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▃▂▂▂▂▂▂▁▂▂▁▂▁▂▁█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>█▃▃▃▂▂▃▂▂▁▁▂▁▁▂▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 2</td><td>█▄▂▂▂▂▂▁▁▁▁▂▁▁▂▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 3</td><td>█▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 4</td><td>█▆▄▄▆▃▃▄▂▄▄▄▃▂▄▂▃▂▃▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 5</td><td>▄▃▃▄▃▅▃▁▂▂▇▂▁▂▂▂█▃▃▂▂▁▁▂▁▁▂▂▁▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>time step 6</td><td>█▄▄▃▃▂▂▂▂▂▂▂▂▂▂▁▅▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 7</td><td>▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>6e-05</td></tr><tr><td>Data_loss</td><td>0.00024</td></tr><tr><td>Initial_loss</td><td>0.0</td></tr><tr><td>Previous_loss</td><td>0.00048</td></tr><tr><td>Residual_loss</td><td>9e-05</td></tr><tr><td>Total_loss</td><td>0.00087</td></tr><tr><td>time step 1</td><td>0.04813</td></tr><tr><td>time step 2</td><td>0.03875</td></tr><tr><td>time step 3</td><td>0.0245</td></tr><tr><td>time step 4</td><td>0.01735</td></tr><tr><td>time step 5</td><td>0.02773</td></tr><tr><td>time step 6</td><td>0.01852</td></tr><tr><td>time step 7</td><td>0.01612</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">apricot-surf-8</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/3cz10muq" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_ib_missing_inlet/runs/3cz10muq</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221010_224053-3cz10muq\logs</code>

# %% [markdown]
# # Run this code snippet to load the model

# %%
'''
This code snippet loads the bc pinn model, for some reason its not predicting well for time t=0 ?
'''

if __name__ == "__main__":

    
    N_train = 25000
    batch_size=1000
    Reynolds = 100
    layers = [3]+10*[100]+[3]
    
    # Enter the latest timestep for which the model has be previous trained on.
    time_step_test = 7

    # Loading the initial and the boundary conditions for the next timestep
    domain, initial, boundary,domain_data = load_data(time_step_test)
    datalist=load_complete_data()


    # Loading the predictions of the final timestep of the first timesegment as the initial conditions of this time segment
    prediction_file='uv_preds_lts_exp1'
    u,v,t=read_uv_values(prediction_file)

    # Initial condition guided learning
    # Altering the initial conditions data, only uvt values are changed pressure values are untouched.
    initial[:,2]=t[:,0]
    initial[:,3]=u[:,0]
    initial[:,4]=v[:,0]

    # Loading the previous timesegment data
    prev_name='prev_data_predictions_lts_exp1'
    prevtimedata=read_prev_data(prev_name)

    # Enter the names of the files :
    '''
    params_name : name of the file where you want to save the weights and biases, LOAD THE MODEL EVERYTIME, SINCE ITS THE SAME
                  MODEL THAT IS BEING TRAINED OVER DIFFERNT TIMESEGMENTS, WITH FOCUS ON PREV TIME SEGMENTS                  
    loss_name   : name of the file where you want to save the loss components
    prev_name   : name of the file where you want to save the predictions of each time step in the segment
    '''

    params_name = 'params_exp1'
    loss_name   = 'Loss_re100_truly_sparse'

    # Start the Training process
    with tf.device('/gpu:0'):

        bc_pinn_model_test = bc_pinn_t (domain,initial,boundary,domain_data,prevtimedata,datalist,
                                       N_train,batch_size,
                                       layers,re=Reynolds,
                                       load_model=True,filedr=params_name,
                                       freeze = 5,timestep=time_step_test,
                                       savewandb=params_name,saveloss=loss_name)
# Out:
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6

# %% [markdown]
# # Run this code snippet for checking

# %%
# Run this for Prediction for a network of 3 10*100 3 
def test_check_predictions(test_time_step,model,plot=False):
    '''
    This code works for specific time steps like 0,1,2,.... and not for intermediate timesteps like 0.1,0.2,0.3......
    '''

    X_star,Y_star=load_testdata(test_time_step)
    u_pred, v_pred, p_pred = model.predict(X_star[0],X_star[1],X_star[2])

    # # Error
    error_u = np.linalg.norm(Y_star[0] - u_pred, 2) / np.linalg.norm(Y_star[0], 2)
    error_v = np.linalg.norm(Y_star[1] - v_pred, 2) / np.linalg.norm(Y_star[1], 2)

    # Mean corrected pressure error
    p_predm=p_pred-np.mean(p_pred)
    p_truem=Y_star[2]-np.mean(Y_star[2])

    error_p = np.linalg.norm(p_truem - p_predm, 2) / np.linalg.norm(p_truem, 2)

    print("Errors at timestep:", np.unique(X_star[2]))
    print("------------------------------------------------")
    print('Error u: %e' % error_u)
    print('Error v: %e' % error_v)
    print('Error p: %e' % error_p)
    
    if plot == True:
        uplot=np.reshape(u_pred,(100,100))
        plt.imshow(uplot)
        plt.title("Predicted u_velocity")
        plt.colorbar()
#         plt.savefig('pred'+str(test_time_step))
        plt.show()

        upl=np.reshape(Y_star[0],(100,100))
        plt.imshow(upl)
        plt.title("Actual u_velocity")
        plt.colorbar()
#         plt.savefig('actual'+str(test_time_step))
        plt.show()
    return error_u,error_v

# %%
eu=[]
ev=[]
for i in np.arange(0,8,1):
    eua,eva=test_check_predictions(round(i,3),bc_pinn_model_test,plot=True)
    eu.append(eua)
    ev.append(eva)
# Out:
# Errors at timestep: [0.]
# ------------------------------------------------
# Error u: 1.497304e-02
# Error v: 6.609791e-02
# Error p: 9.816976e+00
# Errors at timestep: [1.]
# ------------------------------------------------
# Error u: 3.633293e-02
# Error v: 2.047841e-01
# Error p: 9.216539e+00
# Errors at timestep: [2.]
# ------------------------------------------------
# Error u: 3.665458e-02
# Error v: 2.125512e-01
# Error p: 5.196473e+00
# Errors at timestep: [3.]
# ------------------------------------------------
# Error u: 3.010152e-02
# Error v: 1.764793e-01
# Error p: 2.590811e+00
# Errors at timestep: [4.]
# ------------------------------------------------
# Error u: 1.758683e-02
# Error v: 7.317010e-02
# Error p: 5.302463e+00
# Errors at timestep: [5.]
# ------------------------------------------------
# Error u: 2.584470e-02
# Error v: 1.168999e-01
# Error p: 5.579278e+00
# Errors at timestep: [6.]
# ------------------------------------------------
# Error u: 1.757885e-02
# Error v: 9.435816e-02
# Error p: 6.603657e-01
# Errors at timestep: [7.]
# ------------------------------------------------
# Error u: 1.804408e-02
# Error v: 6.872885e-02
# Error p: 3.714218e-01

# %%
x=boundary[:,0:1]
y=boundary[:,1:2]
plt.scatter(x,y)
xd=domain[:,0:1]
yd=domain[:,1:2]
plt.scatter(xd,yd,s=0.01)

# %%
X_star,Y_star=load_testdata(6)
u_pred, v_pred, p_pred = bc_pinn_model_test.predict(X_star[0],X_star[1],X_star[2])
err=u_pred-Y_star[0]
err=np.reshape(err,(100,100))

plt.imshow(err)
plt.colorbar()

# %%
from scipy.interpolate import make_interp_spline as mis

nsfdata=pd.read_csv(r"C:\Users\user1\Desktop\NSFNET_basic.csv").to_numpy()
nsfdata2=pd.read_csv(r"C:\Users\user1\Desktop\NSFNET_dynamic.csv").to_numpy()
for i in range(nsfdata.shape[1]):
    nsfdata[i,0]=round(nsfdata[i,0],3)
    
for i in range(nsfdata2.shape[1]):
    nsfdata2[i,0]=round(nsfdata2[i,0],3)

t_nsf=nsfdata[:,0]
eu_nsf=nsfdata[:,1]
eu_nsf2=nsfdata2[:,1]

# Basic 
xyspline=mis(t_nsf,eu_nsf)
x=np.linspace(t_nsf.min(),t_nsf.max(),500)
y=xyspline(x)
plt.plot(x,y)
# Dynamic weights
xyspline3=mis(t_nsf,eu_nsf2)
y3=xyspline3(x)
plt.plot(x,y3)

# MY model
t=[i for i in np.arange(0,8,1)]
xyspline2=mis(t,eu)
y2=xyspline2(x)
plt.plot(x,y2)

plt.legend(['NSFNET Basic','NSFNET Dynamic','seq2seq model with 1% data from inside domain'])
plt.title("Comparison of relative l2 errors with NSFNET paper")
plt.xlabel("Time steps")
plt.ylabel("Relative l2 error")
plt.show()

# %%
from scipy.interpolate import make_interp_spline as mis

nsfdatav=pd.read_csv(r"C:\Users\user1\Desktop\vvel_basic.csv").to_numpy()
nsfdatav2=pd.read_csv(r"C:\Users\user1\Desktop\vvel_dynamic.csv").to_numpy()
for i in range(nsfdatav.shape[1]):
    nsfdatav[i,0]=round(nsfdatav[i,0],3)
    
for i in range(nsfdatav2.shape[1]):
    nsfdatav2[i,0]=round(nsfdatav2[i,0],3)

t_nsf=nsfdatav[:,0]
eu_nsf=nsfdatav[:,1]
eu_nsf2=nsfdatav2[:,1]

# Basic 
xyspline=mis(t_nsf,eu_nsf)
x=np.linspace(t_nsf.min(),t_nsf.max(),500)
y=xyspline(x)
plt.plot(x,y)
# Dynamic weights
xyspline3=mis(t_nsf,eu_nsf2)
y3=xyspline3(x)
plt.plot(x,y3)

# MY model
t=[i for i in np.arange(0,8,1)]
xyspline2=mis(t,ev)
y2=xyspline2(x)
plt.plot(x,y2)

plt.legend(['NSFNET no weights','NSFNET Dynamic weights','seq2seq model with 1% data from inside domain'])
plt.title("Comparison of v velocity relative l2 errors with NSFNET paper")
plt.xlabel("Time steps")
plt.ylabel("Relative l2 error")
plt.show()

# %% [markdown]
# # Run this code segment to save the errors

# %%
def save_error_data(file_name,eu):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\novel_method")
    my_path=root_path/file_name

    with open(my_path,'wb') as f:
        pickle.dump(eu,f)
        print("Errors are saved in pickle file")

# %%
def load_error_data(file_name):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_results\novel_method")
    my_path=root_path/file_name

    # returns the weights and biases of the network as np array
    with open(my_path,'rb') as f:
        eu_load=pickle.load(f)
    return eu_load

# %% [markdown]
# # Saving the errors

# %%
save_error_data('1data_long_training_ib_missing_inlet',eu)
# Out:
# Errors are saved in pickle file
