# %%
import tensorflow as tf
import numpy as np
import time
import pandas as pd
import math
import pickle
from pathlib import Path
import matplotlib.pyplot as plt
import wandb

# set random seed
np.random.seed(1234)
tf.compat.v1.set_random_seed(1234)

tf.compat.v1.disable_eager_execution()

# %% [markdown]
# # Initializing wandb functionality

# %%
# !wandb login --relogin
# Copy and paste this api key: 822244d22c29151b0b6501c81c4e22a5c5a0843f

entity_name="vamsi_malineni6"
project_name="bc_pinn_ltd_0data_ib_missing_inlet"

wandb.init(entity=entity_name,project=project_name)
# Finish the dummy run started after first initializing
wandb.run.finish()

# # Delete the dummy run from the wandb workspace 
# api=wandb.Api()
# run_id=wandb.run.id
# run=ap.run(str(entity_name)+"/"+str(project_name)+"/"+str(run_id))
# run.delete()
# Out:
# 'wandb' is not recognized as an internal or external command,
# operable program or batch file.
# wandb: Currently logged in as: vamsi_malineni6. Use `wandb login --relogin` to force relogin
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221013_091125-2ia3dnf4</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/2ia3dnf4" target="_blank">polar-disco-1</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.0, max…
# Synced <strong style="color:#cdcd00">polar-disco-1</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/2ia3dnf4" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/2ia3dnf4</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221013_091125-2ia3dnf4\logs</code>

# %%
class bc_pinn_t0:
    # Initialize the class
    def __init__(self,domain,initial,boundary,domaindata,datalist,
                 ntrain,batch_size,layers,re,
                 load_model=False,filedr='',freeze=0,timestep=0,
                 savewandb='',saveloss=''):
        
        self.domain   = domain
        self.initial  = initial
        self.boundary = boundary
        self.datalist = datalist
        self.domain_data = domaindata
        
        self.freeze   = freeze
        self.time_step = timestep
        
        self.params_name = savewandb
        self.loss_name   = saveloss
        
        self.ntrain = ntrain
        self.batch_size= batch_size
        
        # Calling domain data for initializing the neural network before entering the Adam optimization
        self.xa=self.domain[:,0].reshape(self.domain[:,0].shape[0],1)
        self.ya=self.domain[:,1].reshape(self.domain[:,1].shape[0],1)
        self.ta=self.domain[:,2].reshape(self.domain[:,2].shape[0],1)
        self.ua=self.domain[:,3].reshape(self.domain[:,3].shape[0],1)
        self.va=self.domain[:,4].reshape(self.domain[:,4].shape[0],1)
        
        
        X = np.concatenate([self.xa,self.ya,self.ta], 1)

        self.lowb = X.min(0) 
        self.upb = X.max(0)
        
        # Calling boundary and initial conditions data as they dont change through the adam iterations
                
        self.x0=self.initial[:,0].reshape(self.initial[:, 0].shape[0], 1)
        self.y0=self.initial[:,1].reshape(self.initial[:, 1].shape[0], 1)
        self.t0=self.initial[:,2].reshape(self.initial[:, 2].shape[0], 1)
        self.u0=self.initial[:,3].reshape(self.initial[:, 3].shape[0], 1)
        self.v0=self.initial[:,4].reshape(self.initial[:, 4].shape[0], 1)
        
        self.xb=self.boundary[:,0].reshape(self.boundary[:, 0].shape[0], 1)
        self.yb=self.boundary[:,1].reshape(self.boundary[:, 1].shape[0], 1)
        self.tb=self.boundary[:,2].reshape(self.boundary[:, 2].shape[0], 1)
        self.ub=self.boundary[:,3].reshape(self.boundary[:, 3].shape[0], 1)
        self.vb=self.boundary[:,4].reshape(self.boundary[:, 4].shape[0], 1)
        
  
        self.layers = layers
        self.re = re

        # Initialize NN
        if load_model ==False:
            self.weights, self.biases = self.initialize_NN(self.layers)
        else:
            self.weights,self.biases = self.load_parameters(filedr,self.layers,self.freeze)
            
        

        # tf placeholders and graph
        
        self.sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        self.learning_rate = tf.compat.v1.placeholder(tf.float32, shape=[])
        
        # Initial conditions placeholders
        self.x_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.x0.shape[1]])
        self.y_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.y0.shape[1]])
        self.t_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.t0.shape[1]])
        self.u_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.u0.shape[1]])
        self.v_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.v0.shape[1]])
        
        # Boundary conditions placeholders
        self.x_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xb.shape[1]])
        self.y_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.yb.shape[1]])
        self.t_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.tb.shape[1]])
        self.u_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ub.shape[1]])
        self.v_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.vb.shape[1]])
        
        # Domain placeholders having the size of batch_size
        self.x_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.y_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.t_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        # Domain data placeholders 
#         self.xdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
#         self.ydata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
#         self.tdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
#         self.udata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ua.shape[1]])
#         self.vdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.va.shape[1]])
        
        # Initial conditions predictions
        self.u_ini_pred, self.v_ini_pred, self.p_ini_pred =\
            self.net_NS(self.x_ini_tf, self.y_ini_tf, self.t_ini_tf)
        
        # Boundary conditions predictions
        self.u_boundary_pred, self.v_boundary_pred, self.p_boundary_pred = \
            self.net_NS(self.x_boundary_tf, self.y_boundary_tf, self.t_boundary_tf)
        
        # Domain data predictions
#         self.u_dom_pred,self.v_dom_pred,_=\
#             self.net_NS(self.xdata_tf,self.ydata_tf,self.tdata_tf)
        
        # Domain predictions
        self.u_pred, self.v_pred, self.p_pred, self.f_u_pred, self.f_v_pred, self.f_e_pred = \
            self.net_f_NS(self.x_tf, self.y_tf, self.t_tf)

        alpha, beta = 1, 1

        # set loss function
        self.initial_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.u_ini_tf - self.u_ini_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.v_ini_tf - self.v_ini_pred))
        
        self.boundary_loss = beta * tf.reduce_mean(input_tensor=tf.square(self.u_boundary_tf - self.u_boundary_pred)) + \
                             beta * tf.reduce_mean(input_tensor=tf.square(self.v_boundary_tf - self.v_boundary_pred))

#         self.domdata_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.udata_tf - self.u_dom_pred)) + \
#                              alpha * tf.reduce_mean(input_tensor=tf.square(self.vdata_tf - self.v_dom_pred))

        self.residual_loss = tf.reduce_mean(input_tensor=tf.square(self.f_u_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_v_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_e_pred))

        
        
        self.loss =  self.initial_loss + self.boundary_loss + self.residual_loss 
        
        self.loss_i=[]
        self.loss_b=[]
        self.loss_r=[]
#         self.loss_d=[]

        self.optimizer_Adam = tf.compat.v1.train.AdamOptimizer(self.learning_rate)
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)

        init = tf.compat.v1.global_variables_initializer()
        self.sess.run(init)
        

#===========================================================================================================#
#====================================Transfer Learning======================================================#
#===========================================================================================================#
    def save_parameters(self,fileDr):
        weights=self.sess.run(self.weights)
        biases= self.sess.run(self.biases)
        
                       
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\Missing BCs\exp2")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([weights,biases],f)
            print("Parameters are saved in pickle file")

    def load_parameters(self,fileDr,layers,freeze):
        tf_weights=[]
        tf_biases=[]
        num_layers=len(layers)
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\Missing BCs\exp2")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            weights,biases=pickle.load(f)
            assert num_layers == (len(weights)+1)
        
        # returns the weights and biases of the network as tf.variable, with few of the layers frozen for trainin
        for num in range(0,num_layers-1):
            if num<freeze:
                tf_weights.append ( tf.Variable (weights[num],trainable ='False'))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='False'))
            else:
                tf_weights.append ( tf.Variable (weights[num],trainable ='True'))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='True' ))
        
        print("Parameters are loaded succesffuly")
        
        return tf_weights,tf_biases
    
#===========================================================================================================#
#========================================saving loss values=================================================#
#===========================================================================================================#
    def save_loss(self,fileDr,tf_dict):
        self.loss_i.append(self.sess.run(self.initial_loss,tf_dict))
        self.loss_b.append(self.sess.run(self.boundary_loss,tf_dict))
        self.loss_r.append(self.sess.run(self.residual_loss,tf_dict))
        self.loss_d.append(self.sess.run(self.domdata_loss,tf_dict))
                       
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp39")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([self.loss_i,self.loss_b,self.loss_r,self.loss_d],f)
            print("Loss are saved in pickle file")
    
    def load_loss(self,fileDr):
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp39")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            initial,boundary,residual,datadomain=pickle.load(f)
        
        print("Losses are loaded successfully")
        
        return initial,boundary,residual,datadomain
    

    
#===========================================================================================================#
#===========================================================================================================#
#===========================================================================================================#
 

# initialize the weight and bias
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

# xavier used to initialize the weight
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

# generate the neural network
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = 2.0 * (X - self.lowb) / (self.upb - self.lowb) - 1.0
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
#             H = tf.tanh(tf.add(tf.matmul(H, W), b))
            H = tf.keras.activations.swish(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

# ###################without assume###############
    # supervised data driven
    def net_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        return u, v, p

    # unsupervised NS residual
    def net_f_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        u_t = tf.gradients(ys=u, xs=t)[0] 
        u_x = tf.gradients(ys=u, xs=x)[0] 
        u_y = tf.gradients(ys=u, xs=y)[0] 
        u_xx = tf.gradients(ys=u_x, xs=x)[0] 
        u_yy = tf.gradients(ys=u_y, xs=y)[0] 
        
        v_t = tf.gradients(ys=v, xs=t)[0] 
        v_x = tf.gradients(ys=v, xs=x)[0] 
        v_y = tf.gradients(ys=v, xs=y)[0] 
        v_xx = tf.gradients(ys=v_x, xs=x)[0] 
        v_yy = tf.gradients(ys=v_y, xs=y)[0] 

        p_x = tf.gradients(ys=p, xs=x)[0] 
        p_y = tf.gradients(ys=p, xs=y)[0] 

        f_u = u_t + (u * u_x + v * u_y) + p_x - (1/self.re) * (u_xx + u_yy)
        f_v = v_t + (u * v_x + v * v_y) + p_y - (1/self.re) * (v_xx + v_yy)
        f_e = u_x + v_y

        return u, v, p, f_u, f_v, f_e

#===========================================================================================================#
#===========================Predicting and finding error every 10 epochs====================================#
#===========================================================================================================#
   
    
    def predict(self, x_star, y_star, t_star):

        tf_dict = {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star}

        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)

        return u_star, v_star, p_star
    
    def load_testdata(self,time_step):
        
        # Converting the time_step from decimal to integer 0.1 --> 1
        ts=int(10*time_step)

        # Loading the complete list of data 
        data_list=self.datalist

        # Extracting the data for the given range of time steps [0,0.1] and so on
        dt=0.1
        times=[round(i,3) for i in np.arange(0,7+dt,dt)]

        # Finding the indexes of initial and final timestep from the times list
        t1=times.index(round((time_step-1.0),2))
        t2=times.index(time_step)

        temp=[]
        # Excluding INITIAL DATA from the collocation points, to make sure that the model is not overfitting on
        # initial points, as there is u,v data available for the model. 

        for i in range(t1,t2+1):
            if i<t2+1:
                temp.append(data_list[i])

        # data stores the final timestep data for the given time segment

        data=np.concatenate(temp[4:],axis=0)

        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]

        return X_star,Y_star
    
    def find_error(self,test_time_step):
        
        X_star,Y_star=self.load_testdata(test_time_step)
        u_pred,_,_ = self.predict(X_star[0],X_star[1],X_star[2])
        
        error_u = np.linalg.norm(Y_star[0] - u_pred, 2) / np.linalg.norm(Y_star[0], 2)
        

        return error_u
        
#===========================================================================================================#
#===========================ADAM TRAINING FUNCTION==========================================================#
#===========================================================================================================#
   
#IMPORTANT NOTES for a given TIME SEGMENT consisting of (5*10000=50000) points in the grid.

# (1) Randomly sampling 1000 datapoints every iteration from 38416 collocation points
#     effectively per epoch the model would see 25000 collocation points, which is 65% of sampled colloc points

# (2) Randomly sampling 250 datapoints every iteration from 19208 data points,
#     effectively per epoch the model would see 6250 data points. which is 32% of the sampled data points
 
# (3) The model would see 10000 initial conditions data points per iteration per epoch
#
# (4) The model would see 1584 boundary conditions points per iteration per epoch


    def Adam_train(self, epoch=5000, learning_rate=1e-3):
    
        start_time = time.time()
        
        iters = int(self.ntrain / self.batch_size)
        
        for it in range(epoch):
            
            for i in (range(iters)):
            
                idx=  np.random.choice(self.domain.shape[0],self.batch_size,replace=False)
#                 didx= np.random.choice(self.domain_data.shape[0],250,replace=False)
                
                self.data_domain=self.domain[idx,:]
#                 self.data_driven=self.domain_data[didx,:]
                
                xd=self.data_domain[:,0].reshape(self.data_domain[:, 0].shape[0], 1)
                yd=self.data_domain[:,1].reshape(self.data_domain[:, 1].shape[0], 1)
                td=self.data_domain[:,2].reshape(self.data_domain[:, 2].shape[0], 1)

#                 xdata=self.data_driven[:,0].reshape(self.data_driven[:, 0].shape[0], 1)
#                 ydata=self.data_driven[:,1].reshape(self.data_driven[:, 1].shape[0], 1)
#                 tdata=self.data_driven[:,2].reshape(self.data_driven[:, 2].shape[0], 1)
#                 udata=self.data_driven[:,3].reshape(self.data_driven[:, 3].shape[0], 1)
#                 vdata=self.data_driven[:,4].reshape(self.data_driven[:, 4].shape[0], 1)
                    
                Xd = np.concatenate([xd,yd,td], 1)
                
                # In contrast the model would see 10000 initial data points every iteration and every epoch
                # The model would see 1584 boundary conditions points every iteration and every epoch
                
                tf_dict = {self.x_ini_tf: self.x0, 
                           self.y_ini_tf: self.y0,
                           self.t_ini_tf: self.t0, 
                           self.u_ini_tf: self.u0,
                           self.v_ini_tf: self.v0, 
                           
                           self.x_boundary_tf: self.xb,
                           self.y_boundary_tf: self.yb, 
                           self.t_boundary_tf: self.tb,
                           self.u_boundary_tf: self.ub, 
                           self.v_boundary_tf: self.vb,
                           
                           self.x_tf: xd, 
                           self.y_tf: yd, 
                           self.t_tf: td,
                           
#                            self.xdata_tf: xdata, 
#                            self.ydata_tf: ydata, 
#                            self.tdata_tf: tdata,
#                            self.udata_tf: udata,
#                            self.vdata_tf: vdata,
                           
                           self.learning_rate: learning_rate}

                self.sess.run(self.train_op_Adam, tf_dict)
            
            if it % 10 == 0:
                
                elapsed = time.time() - start_time
                
                t_loss= self.sess.run(self.loss, tf_dict)
                i_loss= self.sess.run(self.initial_loss,tf_dict)
                b_loss= self.sess.run(self.boundary_loss,tf_dict)
                r_loss= self.sess.run(self.residual_loss,tf_dict)
#                 d_loss= self.sess.run(self.domdata_loss,tf_dict)
                
                # Saving the loss values in a pickle file
#                 self.save_loss(self.loss_name,tf_dict)
                
                # Finding the error value at given timestep for every 10 epochs
                eu1= self.find_error(1)
                eu2= self.find_error(2)
                eu3= self.find_error(3)
                eu4= self.find_error(4)
                eu5= self.find_error(5)
                eu6= self.find_error(6)
                eu7= self.find_error(7)
                
                # Logging the loss values and error values to wandb workspace:
                log_dict={"Total_loss":t_loss,"Initial_loss":i_loss,\
                         "Boundary_loss":b_loss,"Residual_loss":r_loss,\
#                          "Data_loss":d_loss,\
                         "time step 1":eu1,\
                         "time step 2":eu2,\
                         "time step 3":eu3,\
                         "time step 4":eu4,\
                         "time step 5":eu5,\
                         "time step 6":eu6,\
                         "time step 7":eu7
                         }
                         
                
                wandb.log(log_dict)
                
                print('epochs: %d, Loss: %.3e, Time: %.2f' %
                      (it, t_loss, elapsed))
                
                start_time = time.time()
            
            if it % 1000 == 0 and it > 0:
                self.save_parameters(self.params_name)

# %% [markdown]
# # This code snippet is for training for timesegments other than initial one

# %%
class bc_pinn_t:
    # Initialize the class
    def __init__(self,domain,initial,boundary,domaindata,prevtimedata,datalist,
                 ntrain,batch_size,layers,re,
                 load_model=False,filedr='',freeze=0,timestep=0
                 ,savewandb='',saveloss=''):
        
        self.domain   = domain
        self.initial  = initial
        self.boundary = boundary
        self.domain_data = domaindata
        self.prev_data = prevtimedata
        self.datalist = datalist
        
        self.freeze = freeze
        self.time_step = timestep
        
        self.params_name = savewandb
        self.loss_name   = saveloss
        
        self.ntrain = ntrain
        self.batch_size= batch_size
        #=========================================================================================================#
        
        # Calling domain data for initializing the neural network before entering the Adam optimization
        self.xa=self.domain[:,0].reshape(self.domain[:,0].shape[0],1)
        self.ya=self.domain[:,1].reshape(self.domain[:,1].shape[0],1)
        self.ta=self.domain[:,2].reshape(self.domain[:,2].shape[0],1)
        self.ua=self.domain[:,3].reshape(self.domain[:,3].shape[0],1)
        self.va=self.domain[:,4].reshape(self.domain[:,4].shape[0],1)
        
        # This creates an array of collocation points only for the domain
        X = np.concatenate([self.xa,self.ya,self.ta], 1)
        self.lowb = X.min(0) 
        self.upb = X.max(0)
        
        #=========================================================================================================#
        
        # Calling boundary and initial conditions data as they dont change through the adam iterations
                
        self.x0=self.initial[:,0].reshape(self.initial[:, 0].shape[0], 1)
        self.y0=self.initial[:,1].reshape(self.initial[:, 1].shape[0], 1)
        self.t0=self.initial[:,2].reshape(self.initial[:, 2].shape[0], 1)
        self.u0=self.initial[:,3].reshape(self.initial[:, 3].shape[0], 1)
        self.v0=self.initial[:,4].reshape(self.initial[:, 4].shape[0], 1)
        
        self.xb=self.boundary[:,0].reshape(self.boundary[:, 0].shape[0], 1)
        self.yb=self.boundary[:,1].reshape(self.boundary[:, 1].shape[0], 1)
        self.tb=self.boundary[:,2].reshape(self.boundary[:, 2].shape[0], 1)
        self.ub=self.boundary[:,3].reshape(self.boundary[:, 3].shape[0], 1)
        self.vb=self.boundary[:,4].reshape(self.boundary[:, 4].shape[0], 1)
        
  
        self.layers = layers
        self.re = re

        # Initialize NN
        if load_model ==False:
            self.weights, self.biases = self.initialize_NN(self.layers)
        else:
            self.weights,self.biases = self.load_parameters(filedr,self.layers,self.freeze)
            
        

        # tf placeholders and graph
        
        self.sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        self.learning_rate = tf.compat.v1.placeholder(tf.float32, shape=[])
        
        # Initial conditions placeholders
        self.x_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.x0.shape[1]])
        self.y_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.y0.shape[1]])
        self.t_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.t0.shape[1]])
        self.u_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.u0.shape[1]])
        self.v_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.v0.shape[1]])
        
        # Boundary conditions placeholders
        self.x_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xb.shape[1]])
        self.y_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.yb.shape[1]])
        self.t_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.tb.shape[1]])
        self.u_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ub.shape[1]])
        self.v_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.vb.shape[1]])
        
        # Domain placeholders having the size of batch_size
        self.x_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.y_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.t_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        # Domain data placeholders 
#         self.xdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
#         self.ydata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
#         self.tdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
#         self.udata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ua.shape[1]])
#         self.vdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.va.shape[1]])
        
        # Previous timestep placeholders
        self.xtime_tf = tf.compat.v1.placeholder(tf.float32)
        self.ytime_tf = tf.compat.v1.placeholder(tf.float32)
        self.ttime_tf = tf.compat.v1.placeholder(tf.float32)
        self.utime_tf = tf.compat.v1.placeholder(tf.float32)
        self.vtime_tf = tf.compat.v1.placeholder(tf.float32)
        
        
        # Initial conditions predictions
        self.u_ini_pred, self.v_ini_pred, self.p_ini_pred =\
            self.net_NS(self.x_ini_tf, self.y_ini_tf, self.t_ini_tf)
        
        # Boundary conditions predictions
        self.u_boundary_pred, self.v_boundary_pred, self.p_boundary_pred = \
            self.net_NS(self.x_boundary_tf, self.y_boundary_tf, self.t_boundary_tf)
        
        # Domain data predictions
#         self.u_dom_pred,self.v_dom_pred,_=\
#             self.net_NS(self.xdata_tf,self.ydata_tf,self.tdata_tf)
        
        # Domain residual predictions
        self.u_pred, self.v_pred, self.p_pred, self.f_u_pred, self.f_v_pred, self.f_e_pred = \
            self.net_f_NS(self.x_tf, self.y_tf, self.t_tf)
        
        # Previous time step predictions
        self.u_time_pred,self.v_time_pred,_=\
            self.net_NS(self.xtime_tf,self.ytime_tf,self.ttime_tf)
        
        
        alpha, beta = 1, 1

        # set loss function
        self.initial_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.u_ini_tf - self.u_ini_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.v_ini_tf - self.v_ini_pred))
        
        self.boundary_loss = beta * tf.reduce_mean(input_tensor=tf.square(self.u_boundary_tf - self.u_boundary_pred)) + \
                             beta * tf.reduce_mean(input_tensor=tf.square(self.v_boundary_tf - self.v_boundary_pred))

#         self.domdata_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.udata_tf - self.u_dom_pred)) + \
#                              alpha * tf.reduce_mean(input_tensor=tf.square(self.vdata_tf - self.v_dom_pred))
        
        self.prevtime_loss = alpha * tf.reduce_mean(input_tensor=tf.square(self.utime_tf - self.u_time_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.vtime_tf - self.v_time_pred))
        
        
        self.residual_loss = tf.reduce_mean(input_tensor=tf.square(self.f_u_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_v_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_e_pred))

        
        
        self.loss =  self.initial_loss + self.boundary_loss + self.residual_loss  + self.prevtime_loss
        
        self.loss_i=[]
        self.loss_b=[]
        self.loss_r=[]
#         self.loss_d=[]
        self.loss_p=[]

        self.optimizer_Adam = tf.compat.v1.train.AdamOptimizer(self.learning_rate)
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)

        init = tf.compat.v1.global_variables_initializer()
        self.sess.run(init)
        

#===========================================================================================================#
#====================================Transfer Learning======================================================#
#===========================================================================================================#
    def save_parameters(self,fileDr):
        weights=self.sess.run(self.weights)
        biases= self.sess.run(self.biases)
        
                       
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\Missing BCs\exp2")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([weights,biases],f)
            print("Parameters are saved in pickle file")

    def load_parameters(self,fileDr,layers,freeze):
        tf_weights=[]
        tf_biases=[]
        num_layers=len(layers)
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\Missing BCs\exp2")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            weights,biases=pickle.load(f)
            assert num_layers == (len(weights)+1)
        
        # returns the weights and biases of the network as tf.variable
        for num in range(0,num_layers-1):
            if num<freeze:
                tf_weights.append ( tf.Variable (weights[num],trainable ='False'))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='False'))
            else:
                tf_weights.append ( tf.Variable (weights[num],trainable ='True' ))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='True' ))
        
        print("Parameters are loaded succesffuly")
        
        return tf_weights,tf_biases
    
#===========================================================================================================#
#========================================saving loss values=================================================#
#===========================================================================================================#
    def save_loss(self,fileDr,tf_dict):
        self.loss_i.append(self.sess.run(self.initial_loss,tf_dict))
        self.loss_b.append(self.sess.run(self.boundary_loss,tf_dict))
        self.loss_r.append(self.sess.run(self.residual_loss,tf_dict))
        self.loss_d.append(self.sess.run(self.domdata_loss,tf_dict))
        self.loss_p.append(self.sess.run(self.prevtime_loss,tf_dict))
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp39")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([self.loss_i,self.loss_b,self.loss_r,self.loss_d,self.loss_p],f)
            print("Loss are saved in pickle file")
    
    def load_loss(self,fileDr):
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp39")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            initial,boundary,residual,datadomain,prevtimeloss=pickle.load(f)
        
        print("Losses are loaded successfully")
        
        return initial,boundary,residual,datadomain,prevtimeloss
    
#===========================================================================================================#
#========================================Utility fucntions of NN============================================#
#===========================================================================================================#
 

# initialize the weight and bias
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

# xavier used to initialize the weight
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

# generate the neural network
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = 2.0 * (X - self.lowb) / (self.upb - self.lowb) - 1.0
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
#             H = tf.tanh(tf.add(tf.matmul(H, W), b))
            H = tf.keras.activations.swish(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
# ###################without assume###############
    # supervised data driven
    def net_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        return u, v, p

    # unsupervised NS residual
    def net_f_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        u_t = tf.gradients(ys=u, xs=t)[0] 
        u_x = tf.gradients(ys=u, xs=x)[0] 
        u_y = tf.gradients(ys=u, xs=y)[0] 
        u_xx = tf.gradients(ys=u_x, xs=x)[0] 
        u_yy = tf.gradients(ys=u_y, xs=y)[0] 
        
        v_t = tf.gradients(ys=v, xs=t)[0] 
        v_x = tf.gradients(ys=v, xs=x)[0] 
        v_y = tf.gradients(ys=v, xs=y)[0] 
        v_xx = tf.gradients(ys=v_x, xs=x)[0] 
        v_yy = tf.gradients(ys=v_y, xs=y)[0] 

        p_x = tf.gradients(ys=p, xs=x)[0] 
        p_y = tf.gradients(ys=p, xs=y)[0] 

        f_u = u_t + (u * u_x + v * u_y) + p_x - (1/self.re) * (u_xx + u_yy)
        f_v = v_t + (u * v_x + v * v_y) + p_y - (1/self.re) * (v_xx + v_yy)
        f_e = u_x + v_y

        return u, v, p, f_u, f_v, f_e
    
#===========================================================================================================#
#===========================Predicting and finding error every 10 epochs====================================#
#===========================================================================================================#
   

    def predict(self, x_star, y_star, t_star):

        tf_dict = {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star}

        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)

        return u_star, v_star, p_star
    
    def load_testdata(self,time_step):
        
        # Converting the time_step from decimal to integer 0.1 --> 1
        ts=int(10*time_step)

        # Loading the complete list of data 
        data_list=self.datalist

        # Extracting the data for the given range of time steps [0,0.1] and so on
        dt=0.1
        times=[round(i,3) for i in np.arange(0,7+dt,dt)]

        # Finding the indexes of initial and final timestep from the times list
        t1=times.index(round((time_step-1.0),2))
        t2=times.index(time_step)

        temp=[]
        # Excluding INITIAL DATA from the collocation points, to make sure that the model is not overfitting on
        # initial points, as there is u,v data available for the model. 

        for i in range(t1,t2+1):
            if i<t2+1:
                temp.append(data_list[i])

        # data stores the final timestep data for the given time segment

        data=np.concatenate(temp[4:],axis=0)

        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]

        return X_star,Y_star
    
    def find_error(self,test_time_step):
        
        X_star,Y_star=self.load_testdata(test_time_step)
        u_pred,_,_ = self.predict(X_star[0],X_star[1],X_star[2])
        
        error_u = np.linalg.norm(Y_star[0] - u_pred, 2) / np.linalg.norm(Y_star[0], 2)
        

        return error_u
        
    
    
    
#===========================================================================================================#
#===========================ADAM TRAINING FUNCTION==========================================================#
#===========================================================================================================#

    def Adam_train(self, epoch=5000, learning_rate=1e-3):

        start_time = time.time()
        
        iters = int(self.ntrain / self.batch_size)
        
        for it in range(epoch):
            
            for i in (range(iters)):
            
                # Randomly sampling ntrain datapoints in the spatio-temporal region
                idx=  np.random.choice(self.domain.shape[0],self.batch_size,replace=False)
                
#                 didx= np.random.choice(self.domain_data.shape[0],250,replace=False)
                
                # Should increase the batch size of prev data so that the model would be able to see more number of points
                # per iteration
                pidx= np.random.choice(self.prev_data.shape[0],(1000*self.time_step),replace=False)
                
                self.data_domain = self.domain[idx,:]
#                 self.data_driven = self.domain_data[didx,:]
                self.prev_batch  = self.prev_data[pidx,:]
                
                # Collocation points inside the domain without data
                xd=self.data_domain[:,0].reshape(self.data_domain[:, 0].shape[0], 1)
                yd=self.data_domain[:,1].reshape(self.data_domain[:, 1].shape[0], 1)
                td=self.data_domain[:,2].reshape(self.data_domain[:, 2].shape[0], 1)
                
                # Collocation points inside the domain with data
#                 xdata=self.data_driven[:,0].reshape(self.data_driven[:, 0].shape[0], 1)
#                 ydata=self.data_driven[:,1].reshape(self.data_driven[:, 1].shape[0], 1)
#                 tdata=self.data_driven[:,2].reshape(self.data_driven[:, 2].shape[0], 1)
#                 udata=self.data_driven[:,3].reshape(self.data_driven[:, 3].shape[0], 1)
#                 vdata=self.data_driven[:,4].reshape(self.data_driven[:, 4].shape[0], 1)
                
                # Points from the previous time steps with data
                xprev=self.prev_batch[:,0].reshape(self.prev_batch[:,0].shape[0],1)
                yprev=self.prev_batch[:,1].reshape(self.prev_batch[:,1].shape[0],1)
                tprev=self.prev_batch[:,2].reshape(self.prev_batch[:,2].shape[0],1)
                uprev=self.prev_batch[:,3].reshape(self.prev_batch[:,3].shape[0],1)
                vprev=self.prev_batch[:,4].reshape(self.prev_batch[:,4].shape[0],1)
                
                Xd = np.concatenate([xd,yd,td], 1)
        
                tf_dict = {self.x_ini_tf: self.x0, 
                           self.y_ini_tf: self.y0,
                           self.t_ini_tf: self.t0, 
                           self.u_ini_tf: self.u0,
                           self.v_ini_tf: self.v0, 
                           
                           self.x_boundary_tf: self.xb,
                           self.y_boundary_tf: self.yb, 
                           self.t_boundary_tf: self.tb,
                           self.u_boundary_tf: self.ub, 
                           self.v_boundary_tf: self.vb,
                           
                           self.x_tf: xd, 
                           self.y_tf: yd, 
                           self.t_tf: td,
                           
#                            self.xdata_tf: xdata, 
#                            self.ydata_tf: ydata, 
#                            self.tdata_tf: tdata,
#                            self.udata_tf: udata,
#                            self.vdata_tf: vdata,
                           
                           self.xtime_tf: xprev,
                           self.ytime_tf: yprev,
                           self.ttime_tf: tprev,
                           self.utime_tf: uprev,
                           self.vtime_tf: vprev,
                           
                           self.learning_rate: learning_rate}

                self.sess.run(self.train_op_Adam, tf_dict)
            
            if it % 10 == 0:
                
                elapsed = time.time() - start_time
                
                t_loss= self.sess.run(self.loss, tf_dict)
                i_loss= self.sess.run(self.initial_loss,tf_dict)
                b_loss= self.sess.run(self.boundary_loss,tf_dict)
                r_loss= self.sess.run(self.residual_loss,tf_dict)
#                 d_loss= self.sess.run(self.domdata_loss,tf_dict)
                p_loss= self.sess.run(self.prevtime_loss,tf_dict)
                
                # Saving the loss values in a pickle file
#                 self.save_loss(self.loss_name,tf_dict)
                
                # Finding the error value at given timestep for every 10 epochs
                eu1= self.find_error(1)
                eu2= self.find_error(2)
                eu3= self.find_error(3)
                eu4= self.find_error(4)
                eu5= self.find_error(5)
                eu6= self.find_error(6)
                eu7= self.find_error(7)
#                 eo= self.find_error(0.1)
                
                # Logging the loss values and error values to wandb workspace:
                log_dict={"Total_loss":t_loss,"Initial_loss":i_loss,\
                         "Boundary_loss":b_loss,"Residual_loss":r_loss,\
#                          "Data_loss":d_loss,\
                          "Previous_loss":p_loss,\
                          "time step 1":eu1,\
                          "time step 2":eu2,\
                          "time step 3":eu3,\
                          "time step 4":eu4,\
                          "time step 5":eu5,\
                          "time step 6":eu6,\
                          "time step 7":eu7
                         }
                
                wandb.log(log_dict)
                
                print('epochs: %d, Loss: %.3e, Time: %.2f' %
                      (it, t_loss, elapsed))
                
                start_time = time.time()
            
            if it % 10 == 0 and it > 0:
                self.save_parameters(self.params_name)

# %% [markdown]
# # Data loading functions

# %%
def load_complete_data():

    path=r"E:\Vamsi_oe20s302\Research work\Simulations and data\Unsteady trials\data\trials\Re100_data_true"

    uvel=pd.read_csv(path+r"/u_vel.csv")
    uvel=uvel.to_numpy()
    
    vvel=pd.read_csv(path+r"/v_vel.csv")
    vvel=vvel.to_numpy()
    
    press=pd.read_csv(path+r"/press.csv")
    press=press.to_numpy()
    
    xy=pd.read_csv(path+r"/xy.csv")
    xy=xy.to_numpy()
    
    time=pd.read_csv(path+r"/time.csv")
    time=time.to_numpy()
    time=time-time[0]

    N=xy.shape[0]
    TT = np.tile(time, (1,N)).T # N x T
    
    # stores the data for each time step as a list
    data_list=[]
    
    for i in range(TT.shape[1]):
        if i<N:
            t=TT[:,i:i+1]
            u=uvel[:,i:i+1]
            v=vvel[:,i:i+1]
            p=press[:,i:i+1]
            a=np.concatenate([xy,t,u,v,p],1)
            data_list.append(a)
    
    return data_list

# %%
def reduced_data(temp_datalist,min_max):
    
    xmax,xmin,ymax,ymin,tmax,tmin=min_max

    # Removing the boundary conditions 
    temp_data=[]
    for i in range(len(temp_datalist)):
        td=temp_datalist[i]
        td=td[:,:][td[:,0]>xmin]
        td=td[:,:][td[:,1]>ymin]
        td=td[:,:][td[:,0]<xmax]
        td=td[:,:][td[:,1]<ymax]
        temp_data.append(td)

    tot_num=temp_data[0].shape[0]
    # Choosing 1% of data 
    didx= np.random.choice(tot_num,int(tot_num/100),replace=False)

    data_datalist=[]
    for i in range(len(temp_data)):
        data_datalist.append(temp_data[i][didx,:])


    return data_datalist

# %%
def load_data(time_step):
    
    # Loading the complete list of data for all timesteps
    data_list=load_complete_data()
    
    # This creates a smaller dataset of timesteps untill 7 
    temp_datalist=[]
    for i in range(len(data_list)):
        if(np.unique(data_list[i][:,2])<7):
            temp_datalist.append(data_list[i])
        else:
            break
   

    
    # ================================================================================#
    # ================================================================================#
    # ================================================================================#

    # Should randomly sample from the above temp datalist 
    dt=0.1
    times=[round(i,3) for i in np.arange(0,7+dt,dt)]
    
    # Finding the indexes of initial and final timestep
    t1=times.index(round((time_step-1.0),2))
    t2=times.index(time_step)
    
    temp=[]
    for i in range(t1,t2+1):
        if i<t2+1:
            temp.append(temp_datalist[i])

    # data1 stores the initial time for the given timestep
    data1=temp[0]

    # data_b stores the data for boundary conditions
    data_b=np.concatenate(temp,axis=0)
    data_b=data_b[:,0:5]
    
    # data stores the collocation points inside the domain
    data=np.concatenate(temp[1:],axis=0)

    # Extracting x,y,t values from data
    xx=data_b[:,0:1]
    yy=data_b[:,1:2]
    tt=data_b[:,2:3]
    
    # Extracting unique values and there by maximum and minimum values of x 
    # and y
    ax=np.unique(xx)
    ay=np.unique(yy)
    at=np.unique(tt)
    
    xmin=min(ax)
    ymin=min(ay)
    tmin=min(at)
    
    xmax=max(ax)
    ymax=max(ay)
    tmax=max(at)
    
    min_max=[xmax,xmin,ymax,ymin,tmax,tmin]
    
    # +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
    # NOTE: All the following datasets are coming from temp_datalist
    # If you want to make any changes for the dataset play with temp_datalist
    # +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

    # here randomly select collocation points inside the domain
    # the selection is done per time step: for time step t>0 example,t=0.0125
    # There are 9600 collocation points available so randomly select points
    # whose u,v data you are going to use. So youll have to send another dataset
    # 
    # Now we have a list of data
    
    # This is only for data driven modelling part of the PINNs
    dlist = reduced_data(temp_datalist,min_max)
    
    temp_data=[]
    for i in range(t1,t2+1):
        if i<t2+1:
            temp_data.append(dlist[i])
    
    # data1 stores the initial time for the given timestep
    domain_data1=temp_data[0]
    
    # data stores the collocation points inside the domain
    domain_data=np.concatenate(temp_data[1:],axis=0)[:,0:5]


    #======================== domain ===================================#
    # Extracting only x,y,t to be sent for collocation points
    # Extracting u,v also for data driven methodology
    domain = data[:,0:5] 
    # Creating a domain dataset where only the points inside the boundary
    # is present
    domain=domain[:,:][domain[:,0]>xmin]
    domain=domain[:,:][domain[:,1]>ymin]
    domain=domain[:,:][domain[:,0]<xmax]
    domain=domain[:,:][domain[:,1]<ymax]

    #======================== initial ==================================#
    # Sending whole data x,y,t,u,v as the initial conditions data
    # Taking only the first set of 10000 points as initial conditions data
    data_t0 = data1[:,0:5]
    
    #======================== boundary =================================#
    # Creating a dataset comprising only boundary conditions data
    # excluding initial conditions
    
    # bc1_data consists of data across all y at x=xmin
#     bc1_data=data_b[:,:][data_b[:,0]==xmin]
#     bc1_data=bc1_data[:,:][bc1_data[:,2]>round(tmin,3)]

    # bc2_data consists of data across all y at x=xmax
    bc2_data=data_b[:,:][data_b[:,0]==xmax]
    bc2_data=bc2_data[:,:][bc2_data[:,2]>round(tmin,3)]

    # bc3_data consists of data across all x at y=ymin
    bc3_data=data_b[:,:][data_b[:,1]==ymin]
    bc3_data=bc3_data[:,:][bc3_data[:,2]>round(tmin,3)]

    # bc4_data consists of data across all x at y=ymax
    bc4_data=data_b[:,:][data_b[:,1]==ymax]
    bc4_data=bc4_data[:,:][bc4_data[:,2]>round(tmin,3)]

    
    # The boundary conditions data is arranged row wise
    # first 100 rows of bc1_data, second 100 rows of bc2_data and so on...
    data_sup_b_train = np.concatenate([bc2_data,bc3_data,bc4_data], 0)


    return domain,data_t0 ,data_sup_b_train,domain_data

# %%
def load_testdata(time_step):
    
    if time_step==0:
        
        data_list=load_complete_data()
        data=data_list[0]
        
        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]
        
    else:
        
        # Converting the time_step from decimal to integer 0.1 --> 1
        ts=int(10*time_step)

        # Loading the complete list of data 
        data_list=load_complete_data()

        # Extracting the data for the given range of time steps [0,0.1] and so on
        dt=0.1
        times=[round(i,3) for i in np.arange(0,7+dt,dt)]

        # Finding the indexes of initial and final timestep from the times list
        t1=times.index(round((time_step-1.0),2))
        t2=times.index(time_step)

        temp=[]

        for i in range(t1,t2+1):
            if i<t2+1:
                temp.append(data_list[i])

        # data stores the final timestep data for the given time segment
        
        # Change the value inside the temp to according to the index of time_step in the given timesegment you are choosing

        data=np.concatenate(temp[10:],axis=0)

        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]

    return X_star,Y_star

# %%
def load_train_data(timestep):
    data_list=load_complete_data()

    data=data_list[timestep]
    x_star=data[:,0].reshape(data[:,0].shape[0],1)
    y_star=data[:,1].reshape(data[:,1].shape[0],1)
    t_star=data[:,2].reshape(data[:,2].shape[0],1)

    X_star=[x_star,y_star,t_star]

    u_star=data[:,3].reshape(data[:,3].shape[0],1)
    v_star=data[:,4].reshape(data[:,4].shape[0],1)
    p_star=data[:,5].reshape(data[:,5].shape[0],1)

    Y_star=[u_star,v_star,p_star]

    return X_star,Y_star

# %%
# This snippet should be run for every time segment to obtain the predictions at each timestep in the specific timesegment

def time_segments(time_step):
    dt=0.1
    steps=[]
    for i in np.arange(round((time_step-1.0),3),round((time_step+dt),3),dt):
        steps.append(round(i,3))

    return steps

def return_indexes(time_step):
    idx=[]
    dt=0.1
    times=[round(i,3) for i in np.arange(0,7+dt,dt)]
    segs=time_segments(time_step)

    for i in range(len(segs)):
        idx.append(times.index(segs[i]))

    return idx

# %% [markdown]
# # Function to save the predictions of each timestep in previous timesegments

# %%
def read_prev_data(fileDr):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\Missing BCs\exp2")
    my_path=root_path/fileDr
    
    with open(my_path,'rb') as f:
        pdata=pickle.load(f)
    print("Previous predictions are loaded from pickle file")
    return pdata

# %%
def save_prev_data(idx,fileDr,t,model):
    if t == 1:
        prev_data=np.empty(shape=(1,5))

        for i in range(len(idx)):
            xi,_=load_train_data(idx[i])
            
            upredi,vpredi,ppredi=model.predict(xi[0],xi[1],xi[2])
            prev_data=np.append(prev_data,np.hstack((xi[0],xi[1],xi[2],upredi,vpredi)),axis=0)

        # Removing the first row of the array
        prev_data=np.delete(prev_data,(0),axis=0)
    
    else:
        # Reading from the previously stored data and appending 
        prev_data= read_prev_data(fileDr)
        
        # Appending the predictions for timesteps other than the first timestep 
        # for ex: excluding predictions for t=0.1 in the time segment [0.1,0.2]
        for i in range(1,len(idx)):
            xi,_=load_train_data(idx[i])
            
            upredi,vpredi,ppredi=model.predict(xi[0],xi[1],xi[2])
            prev_data=np.append(prev_data,np.hstack((xi[0],xi[1],xi[2],upredi,vpredi)),axis=0)
        
        
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\Missing BCs\exp2")
    my_path=root_path/fileDr
    
    with open(my_path,'wb') as f:
        pickle.dump(prev_data,f)
        print("Previous predictions are saved in pickle file")

# %% [markdown]
# # Run this Code segment to save the predictions at the final timestep of the segment

# %%
'''
Run this code to save the predictions of the model at the final timestep of 
the segment 
'''
def save_uv_values(model,fileDr,time_step):
    u=[]
    v=[]
    X_star,Y_star=load_testdata(time_step)
    print("Saving the predictions for time step:",np.unique(X_star[2]))
    u_pred, v_pred, p_pred = model.predict(X_star[0],X_star[1],X_star[2])
    
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\Missing BCs\exp2")
    my_path=root_path/fileDr
    
    with open(my_path,'wb') as f:
        pickle.dump([u_pred,v_pred,X_star[2]],f)
        print("Predictions are saved in pickle file")

# %%
def read_uv_values(fileDr):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\Missing BCs\exp2")
    my_path=root_path/fileDr
    
    with open(my_path,'rb') as f:
        u,v,t=pickle.load(f)
    print("Predictions are loaded")
    return u,v,t

# %% [markdown]
# # Commence the initial training using standard PINN

# %%
if __name__ == "__main__":
    '''
This code snippet starts the standard pinn training for the first time segment (0,1] and the predictions for the intermediate
time steps would be saved as a list of arrays in prev_data

Since we have already trained the datadriven model for the first time segment, the parameters of that model are being used,
and the predictions for each time step in the first time segment are being stored in a list of arrays.
    
    '''
    
    '''
Important thing to note here is that the model is just seeing 25000 points out of 10*100*100=100000 points per time segment in
one epoch, thats like 25% of the collocation points, essentially the model should be seeing the whole collocation points 
once per epoch in small batches, this feature is making the model less dependent on the collocation points!.
    '''
    N_train = 25000
    batch_size=1000
    Reynolds = 100
    
    layers = [3]+10*[100]+[3]
    
    time_step = 1
    
    datalist=load_complete_data()
    domain, initial, boundary, domain_data = load_data(time_step)

    # Enter the names of the files :
    '''
    load_params : name of the file from where you want to load the weights and biases initially
    params_name : name of the file where you want to save the weights and biases, incase of RESUMING TRAINING run this file
    loss_name   : name of the file where you want to save the loss components
    prev_name   : name of the file where you want to save the predictions of each time step in the segment
    '''
    
    params_name = 'params_exp2'
    loss_name   = 'Loss_re100_truly_sparse'
   


    with tf.device('/gpu:0'):
        
        # Loading the previously trained model
        model = bc_pinn_t0(domain,initial,boundary,domain_data,datalist,N_train,batch_size,
                           layers,re=Reynolds,
                           load_model=False,filedr='',
                           freeze= 0,timestep=time_step,
                           savewandb=params_name,saveloss=loss_name)
        
        wandb.init(entity=entity_name,project=project_name)
        name_run= str(time_step)
        wandb.run.name=name_run
        
        model.Adam_train(5000, 1e-3)
        model.Adam_train(600, 1e-4)

        # Saving the predictions at each time steps of the timesegment 
        idx=return_indexes(time_step)
        prev_name = 'prev_data_predictions_lts_exp2'
        save_prev_data(idx,prev_name,time_step,model)
        
        # Saving the u and v predictions of the final time steps of the timesegment
        pred_file = 'uv_preds_lts_exp2'
        save_uv_values(model,pred_file,time_step)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221013_091210-sft5m4fo</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/sft5m4fo" target="_blank">lively-valley-2</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# epochs: 400, Loss: 2.051e-04, Time: 23.77
# epochs: 410, Loss: 2.045e-04, Time: 23.48
# epochs: 420, Loss: 2.053e-04, Time: 23.56
# epochs: 430, Loss: 2.053e-04, Time: 23.54
# epochs: 440, Loss: 2.144e-04, Time: 23.73
# epochs: 450, Loss: 2.027e-04, Time: 23.64
# epochs: 460, Loss: 2.044e-04, Time: 24.08
# epochs: 470, Loss: 2.036e-04, Time: 23.75
# epochs: 480, Loss: 2.005e-04, Time: 23.78
# epochs: 490, Loss: 2.010e-04, Time: 23.69
# epochs: 500, Loss: 2.027e-04, Time: 23.28
# epochs: 510, Loss: 2.041e-04, Time: 23.39
# epochs: 520, Loss: 2.073e-04, Time: 23.47
# epochs: 530, Loss: 2.005e-04, Time: 23.72
# epochs: 540, Loss: 1.997e-04, Time: 23.74
# epochs: 550, Loss: 2.067e-04, Time: 23.34
# epochs: 560, Loss: 1.997e-04, Time: 23.64
# epochs: 570, Loss: 2.016e-04, Time: 23.62
# epochs: 580, Loss: 1.975e-04, Time: 23.72
# epochs: 590, Loss: 2.033e-04, Time: 23.40
# Previous predictions are saved in pickle file
# Saving the predictions for time step: [1.]
# Predictions are saved in pickle file

# %% [markdown]
# # Start the training for the next timesegments

# %%
if __name__ == "__main__":

    
    N_train = 25000
    batch_size=1000
    Reynolds = 100
    layers = [3]+10*[100]+[3]
    
    fre = 5
    
    # Timesteps for loop :
    datalist=load_complete_data()
    timesteps=[round(i,3) for i in np.arange(2,8,1)]
    
    # Copy and paste this api key: 822244d22c29151b0b6501c81c4e22a5c5a0843f
#     !wandb login --relogin

    # Starting a new run for every timestep
#     wandb.run.finish()
    entity_name="vamsi_malineni6"
    project_name="bc_pinn_ltd_0data_ib_missing_inlet"
#     wandb.init(reinit=True)

        
    for i in timesteps:
        
        time_step = i
        
        # initializing wandb workspace
        wandb.init(entity=entity_name,project=project_name)
        
        # naming the run on wandb
        name_run= str(time_step)
        wandb.run.name=name_run
        
        # Loading the initial and the boundary conditions for the next timestep
        domain, initial, boundary, domain_data = load_data(time_step)

        # Loading the predictions of the final timestep of the first timesegment as the initial conditions of this time segment
        prediction_file='uv_preds_lts_exp2'
        u,v,t=read_uv_values(prediction_file)

        # Initial condition guided learning
        # Altering the initial conditions data, only uvt values are changed pressure values are untouched.
        initial[:,2]=t[:,0]
        initial[:,3]=u[:,0]
        initial[:,4]=v[:,0]

        # Loading the previous timesegment data
        prev_name='prev_data_predictions_lts_exp2'
        prevtimedata=read_prev_data(prev_name)

        # Enter the names of the files :
        '''
        params_name : name of the file where you want to save the weights and biases, LOAD THE MODEL EVERYTIME, SINCE ITS THE SAME
                      MODEL THAT IS BEING TRAINED OVER DIFFERNT TIMESEGMENTS, WITH FOCUS ON PREV TIME SEGMENTS                  
        loss_name   : name of the file where you want to save the loss components
        prev_name   : name of the file where you want to save the predictions of each time step in the segment
        '''

        params_name = 'params_exp2'
        loss_name   = 'Loss_re100_truly_sparse'

        # Start the Training process
        with tf.device('/gpu:0'):

            bc_pinn_model = bc_pinn_t (domain,initial,boundary,domain_data,prevtimedata,datalist,
                                       N_train,batch_size,
                                       layers,re=Reynolds,
                                       load_model=True,filedr=params_name,
                                       freeze = fre,timestep=time_step,
                                       savewandb=params_name,saveloss=loss_name)

            print("===============================================================================================")
            print("Commencing training for the timesegment:(",round((time_step-1),3),time_step,"] ")
            print("===============================================================================================")
            
            bc_pinn_model.Adam_train(1000, 1e-3)
            bc_pinn_model.Adam_train(1000, 1e-4)

        # Save the predictions of the final timestep of the current timesegment to be used for ICGL
        pred_file='uv_preds_lts_exp2'
        save_uv_values(bc_pinn_model,pred_file,time_step)

        # This code snippet appends the predictions at each time step for the previous time segment.
        idx=return_indexes(time_step)
        save_prev_data(idx,prev_name,time_step,bc_pinn_model)
        

        # Save the experiment run and finish the experiment in wandb 
        wandb.run.save()
        wandb.run.finish()
# Out:
# Finishing last run (ID:sft5m4fo) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>█▅▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>█▃▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>▄█▂▃▂▃▂▃▁▁▂▂▆▂▄▇▄▂▂▇▃▅▁▃▂▁▁▁▂▂▁▂▁▂▂▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▆▃▂▂▃▂▂▂▂▂▂▃▂▂▃▂▂▂▃▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>██▄▂▁▁▃▃▄▄▅▅▄▅▅▅▅▄▃▄▃▃▃▁▁▂▂▂▃▃▄▄▄▄▄▄▄▄▄▄</td></tr><tr><td>time step 2</td><td>▂▃▃▁▁▁▁▂▂▂▂▂▂▁▂▂▆▆▄▂▄▆▆██▆▅▆▅▃▃▃▂▂▂▂▂▂▂▂</td></tr><tr><td>time step 3</td><td>▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▃▂▁▂▅▆▆▇█▇██▇▆▅▅▄▃▄▃▃▃▂▂</td></tr><tr><td>time step 4</td><td>▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▁▃▅▅▆▆▇▇███▇▆▆▅▄▅▄▃▃▃▃</td></tr><tr><td>time step 5</td><td>▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▃▅▅▅▆▆▇███▇▇▇▆▅▅▄▄▄▄▃</td></tr><tr><td>time step 6</td><td>▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▃▅▅▅▆▆▇▇██▇▇▇▆▅▆▅▄▄▄▃</td></tr><tr><td>time step 7</td><td>▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▃▄▄▅▅▆▇▇██▇▇▇▆▆▆▅▄▄▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>5e-05</td></tr><tr><td>Initial_loss</td><td>0.00014</td></tr><tr><td>Residual_loss</td><td>1e-05</td></tr><tr><td>Total_loss</td><td>0.0002</td></tr><tr><td>time step 1</td><td>0.17088</td></tr><tr><td>time step 2</td><td>0.19766</td></tr><tr><td>time step 3</td><td>0.31968</td></tr><tr><td>time step 4</td><td>0.67946</td></tr><tr><td>time step 5</td><td>1.17628</td></tr><tr><td>time step 6</td><td>1.71964</td></tr><tr><td>time step 7</td><td>2.28978</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lively-valley-2</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/sft5m4fo" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/sft5m4fo</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221013_091210-sft5m4fo\logs</code>
# Successfully finished last run (ID:sft5m4fo). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.033394416173299156, max=1.0…
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221013_131858-3m8framy</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/3m8framy" target="_blank">celestial-flower-3</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 1 2 ]
# ===============================================================================================
# epochs: 0, Loss: 8.388e-02, Time: 8.88
# epochs: 10, Loss: 1.724e-02, Time: 25.88
# Parameters are saved in pickle file
# epochs: 20, Loss: 1.000e-02, Time: 26.44
# Parameters are saved in pickle file
# epochs: 30, Loss: 7.146e-03, Time: 25.66
# Parameters are saved in pickle file
# epochs: 40, Loss: 5.667e-03, Time: 25.66
# Parameters are saved in pickle file
# epochs: 50, Loss: 5.491e-03, Time: 25.80
# Parameters are saved in pickle file
# epochs: 60, Loss: 4.085e-03, Time: 25.79
# Parameters are saved in pickle file
# epochs: 70, Loss: 5.505e-03, Time: 26.18
# Parameters are saved in pickle file
# epochs: 80, Loss: 3.251e-03, Time: 25.49
# Parameters are saved in pickle file
# epochs: 90, Loss: 2.641e-03, Time: 26.00
# Parameters are saved in pickle file
# epochs: 100, Loss: 2.774e-03, Time: 25.40
# Parameters are saved in pickle file
# epochs: 110, Loss: 2.159e-03, Time: 25.89
# Parameters are saved in pickle file
# epochs: 120, Loss: 1.741e-03, Time: 25.56
# Parameters are saved in pickle file
# epochs: 130, Loss: 2.800e-03, Time: 24.65
# Parameters are saved in pickle file
# epochs: 140, Loss: 1.524e-03, Time: 25.08
# Parameters are saved in pickle file
# epochs: 150, Loss: 1.192e-03, Time: 25.58
# Parameters are saved in pickle file
# epochs: 160, Loss: 1.014e-03, Time: 25.60
# Parameters are saved in pickle file
# epochs: 170, Loss: 1.345e-03, Time: 24.99
# Parameters are saved in pickle file
# epochs: 180, Loss: 9.416e-04, Time: 25.32
# Parameters are saved in pickle file
# epochs: 190, Loss: 1.569e-03, Time: 25.68
# Parameters are saved in pickle file
# epochs: 200, Loss: 8.602e-04, Time: 25.61
# Parameters are saved in pickle file
# epochs: 210, Loss: 7.413e-04, Time: 25.63
# Parameters are saved in pickle file
# epochs: 220, Loss: 1.025e-03, Time: 25.50
# Parameters are saved in pickle file
# epochs: 230, Loss: 1.440e-03, Time: 25.66
# Parameters are saved in pickle file
# epochs: 240, Loss: 9.725e-04, Time: 25.77
# Parameters are saved in pickle file
# epochs: 250, Loss: 9.418e-04, Time: 25.20
# Parameters are saved in pickle file
# epochs: 260, Loss: 6.010e-04, Time: 25.81
# Parameters are saved in pickle file
# epochs: 270, Loss: 5.269e-03, Time: 26.12
# Parameters are saved in pickle file
# epochs: 280, Loss: 6.012e-04, Time: 25.96
# Parameters are saved in pickle file
# epochs: 290, Loss: 1.166e-03, Time: 25.25
# Parameters are saved in pickle file
# epochs: 300, Loss: 6.282e-04, Time: 25.30
# Parameters are saved in pickle file
# epochs: 310, Loss: 1.078e-03, Time: 25.93
# Parameters are saved in pickle file
# epochs: 320, Loss: 5.403e-04, Time: 25.69
# Parameters are saved in pickle file
# epochs: 330, Loss: 1.443e-03, Time: 24.87
# Parameters are saved in pickle file
# epochs: 340, Loss: 1.021e-03, Time: 25.39
# Parameters are saved in pickle file
# epochs: 350, Loss: 4.207e-04, Time: 25.31
# Parameters are saved in pickle file
# epochs: 360, Loss: 1.129e-03, Time: 25.22
# Parameters are saved in pickle file
# epochs: 370, Loss: 1.399e-03, Time: 24.45
# Parameters are saved in pickle file
# epochs: 380, Loss: 5.932e-04, Time: 25.51
# Parameters are saved in pickle file
# epochs: 390, Loss: 5.165e-04, Time: 26.23
# Parameters are saved in pickle file
# epochs: 400, Loss: 2.330e-03, Time: 26.37
# Parameters are saved in pickle file
# epochs: 410, Loss: 7.645e-04, Time: 26.05
# Parameters are saved in pickle file
# epochs: 420, Loss: 9.525e-04, Time: 26.19
# Parameters are saved in pickle file
# epochs: 430, Loss: 5.506e-04, Time: 26.45
# Parameters are saved in pickle file
# epochs: 440, Loss: 1.366e-03, Time: 26.94
# Parameters are saved in pickle file
# epochs: 450, Loss: 6.714e-04, Time: 26.51
# Parameters are saved in pickle file
# epochs: 460, Loss: 9.394e-04, Time: 25.65
# Parameters are saved in pickle file
# epochs: 470, Loss: 7.475e-04, Time: 24.82
# Parameters are saved in pickle file
# epochs: 480, Loss: 7.217e-04, Time: 24.87
# Parameters are saved in pickle file
# epochs: 490, Loss: 8.164e-04, Time: 24.84
# Parameters are saved in pickle file
# epochs: 500, Loss: 1.455e-03, Time: 24.90
# Parameters are saved in pickle file
# epochs: 510, Loss: 5.240e-04, Time: 25.35
# Parameters are saved in pickle file
# epochs: 520, Loss: 2.217e-03, Time: 25.17
# Parameters are saved in pickle file
# epochs: 530, Loss: 6.616e-04, Time: 25.13
# Parameters are saved in pickle file
# epochs: 540, Loss: 4.323e-04, Time: 24.96
# Parameters are saved in pickle file
# epochs: 550, Loss: 5.014e-04, Time: 24.70
# Parameters are saved in pickle file
# epochs: 560, Loss: 4.451e-04, Time: 24.72
# Parameters are saved in pickle file
# epochs: 570, Loss: 7.460e-04, Time: 25.14
# Parameters are saved in pickle file
# epochs: 580, Loss: 1.001e-03, Time: 24.76
# Parameters are saved in pickle file
# epochs: 590, Loss: 3.200e-04, Time: 24.96
# Parameters are saved in pickle file
# epochs: 600, Loss: 8.565e-04, Time: 24.73
# Parameters are saved in pickle file
# epochs: 610, Loss: 4.190e-04, Time: 25.26
# Parameters are saved in pickle file
# epochs: 620, Loss: 8.402e-04, Time: 24.83
# Parameters are saved in pickle file
# epochs: 630, Loss: 1.395e-03, Time: 25.10
# Parameters are saved in pickle file
# epochs: 640, Loss: 1.036e-03, Time: 25.20
# Parameters are saved in pickle file
# epochs: 650, Loss: 7.248e-04, Time: 24.55
# Parameters are saved in pickle file
# epochs: 660, Loss: 4.039e-04, Time: 25.39
# Parameters are saved in pickle file
# epochs: 670, Loss: 5.041e-04, Time: 25.43
# Parameters are saved in pickle file
# epochs: 680, Loss: 4.165e-04, Time: 26.21
# Parameters are saved in pickle file
# epochs: 690, Loss: 8.031e-04, Time: 25.57
# Parameters are saved in pickle file
# epochs: 700, Loss: 1.781e-03, Time: 25.02
# Parameters are saved in pickle file
# epochs: 710, Loss: 3.015e-04, Time: 26.18
# Parameters are saved in pickle file
# epochs: 720, Loss: 6.207e-04, Time: 25.82
# Parameters are saved in pickle file
# epochs: 730, Loss: 2.487e-04, Time: 25.74
# Parameters are saved in pickle file
# epochs: 740, Loss: 2.884e-04, Time: 26.36
# Parameters are saved in pickle file
# epochs: 750, Loss: 3.234e-04, Time: 27.61
# Parameters are saved in pickle file
# epochs: 760, Loss: 9.264e-04, Time: 26.94
# Parameters are saved in pickle file
# epochs: 770, Loss: 8.222e-04, Time: 26.98
# Parameters are saved in pickle file
# epochs: 780, Loss: 3.958e-04, Time: 27.35
# Parameters are saved in pickle file
# epochs: 790, Loss: 3.755e-04, Time: 26.85
# Parameters are saved in pickle file
# epochs: 800, Loss: 9.111e-04, Time: 27.45
# Parameters are saved in pickle file
# epochs: 810, Loss: 2.389e-04, Time: 27.25
# Parameters are saved in pickle file
# epochs: 820, Loss: 4.600e-04, Time: 27.50
# Parameters are saved in pickle file
# epochs: 830, Loss: 3.295e-04, Time: 26.30
# Parameters are saved in pickle file
# epochs: 840, Loss: 3.694e-04, Time: 26.42
# Parameters are saved in pickle file
# epochs: 850, Loss: 5.785e-04, Time: 25.28
# Parameters are saved in pickle file
# epochs: 860, Loss: 2.846e-04, Time: 24.85
# Parameters are saved in pickle file
# epochs: 870, Loss: 2.582e-04, Time: 25.05
# Parameters are saved in pickle file
# epochs: 880, Loss: 8.143e-04, Time: 25.26
# Parameters are saved in pickle file
# epochs: 890, Loss: 1.241e-03, Time: 25.65
# Parameters are saved in pickle file
# epochs: 900, Loss: 3.693e-04, Time: 24.78
# Parameters are saved in pickle file
# epochs: 910, Loss: 3.931e-04, Time: 25.09
# Parameters are saved in pickle file
# epochs: 920, Loss: 5.097e-04, Time: 25.21
# Parameters are saved in pickle file
# epochs: 930, Loss: 7.236e-04, Time: 25.26
# Parameters are saved in pickle file
# epochs: 940, Loss: 2.486e-04, Time: 25.33
# Parameters are saved in pickle file
# epochs: 950, Loss: 4.907e-04, Time: 26.14
# Parameters are saved in pickle file
# epochs: 960, Loss: 2.811e-04, Time: 26.16
# Parameters are saved in pickle file
# epochs: 970, Loss: 3.846e-04, Time: 25.77
# Parameters are saved in pickle file
# epochs: 980, Loss: 3.106e-04, Time: 25.42
# Parameters are saved in pickle file
# epochs: 990, Loss: 2.347e-04, Time: 25.18
# Parameters are saved in pickle file
# epochs: 0, Loss: 2.267e-04, Time: 2.54
# epochs: 10, Loss: 1.641e-04, Time: 25.27
# Parameters are saved in pickle file
# epochs: 20, Loss: 1.499e-04, Time: 24.88
# Parameters are saved in pickle file
# epochs: 30, Loss: 1.444e-04, Time: 25.01
# Parameters are saved in pickle file
# epochs: 40, Loss: 1.404e-04, Time: 24.96
# Parameters are saved in pickle file
# epochs: 50, Loss: 1.403e-04, Time: 25.50
# Parameters are saved in pickle file
# epochs: 60, Loss: 1.321e-04, Time: 24.90
# Parameters are saved in pickle file
# epochs: 70, Loss: 1.314e-04, Time: 24.92
# Parameters are saved in pickle file
# epochs: 80, Loss: 1.305e-04, Time: 25.40
# Parameters are saved in pickle file
# epochs: 90, Loss: 1.276e-04, Time: 25.02
# Parameters are saved in pickle file
# epochs: 100, Loss: 1.241e-04, Time: 26.17
# Parameters are saved in pickle file
# epochs: 110, Loss: 1.224e-04, Time: 25.82
# Parameters are saved in pickle file
# epochs: 120, Loss: 1.224e-04, Time: 25.81
# Parameters are saved in pickle file
# epochs: 130, Loss: 1.214e-04, Time: 26.52
# Parameters are saved in pickle file
# epochs: 140, Loss: 1.186e-04, Time: 26.30
# Parameters are saved in pickle file
# epochs: 150, Loss: 1.150e-04, Time: 26.57
# Parameters are saved in pickle file
# epochs: 160, Loss: 1.189e-04, Time: 26.21
# Parameters are saved in pickle file
# epochs: 170, Loss: 1.105e-04, Time: 25.54
# Parameters are saved in pickle file
# epochs: 180, Loss: 1.120e-04, Time: 25.97
# Parameters are saved in pickle file
# epochs: 190, Loss: 1.119e-04, Time: 25.68
# Parameters are saved in pickle file
# epochs: 200, Loss: 1.108e-04, Time: 25.40
# Parameters are saved in pickle file
# epochs: 210, Loss: 1.117e-04, Time: 24.63
# Parameters are saved in pickle file
# epochs: 220, Loss: 1.045e-04, Time: 24.92
# Parameters are saved in pickle file
# epochs: 230, Loss: 1.096e-04, Time: 25.09
# Parameters are saved in pickle file
# epochs: 240, Loss: 1.032e-04, Time: 24.83
# Parameters are saved in pickle file
# epochs: 250, Loss: 1.054e-04, Time: 25.18
# Parameters are saved in pickle file
# epochs: 260, Loss: 1.008e-04, Time: 24.54
# Parameters are saved in pickle file
# epochs: 270, Loss: 9.994e-05, Time: 25.13
# Parameters are saved in pickle file
# epochs: 280, Loss: 1.095e-04, Time: 25.56
# Parameters are saved in pickle file
# epochs: 290, Loss: 9.760e-05, Time: 25.79
# Parameters are saved in pickle file
# epochs: 300, Loss: 1.025e-04, Time: 25.72
# Parameters are saved in pickle file
# epochs: 310, Loss: 1.025e-04, Time: 26.32
# Parameters are saved in pickle file
# epochs: 320, Loss: 1.015e-04, Time: 26.47
# Parameters are saved in pickle file
# epochs: 330, Loss: 9.370e-05, Time: 25.94
# Parameters are saved in pickle file
# epochs: 340, Loss: 1.004e-04, Time: 25.77
# Parameters are saved in pickle file
# epochs: 350, Loss: 9.546e-05, Time: 26.02
# Parameters are saved in pickle file
# epochs: 360, Loss: 9.273e-05, Time: 26.20
# Parameters are saved in pickle file
# epochs: 370, Loss: 8.994e-05, Time: 25.73
# Parameters are saved in pickle file
# epochs: 380, Loss: 9.246e-05, Time: 24.79
# Parameters are saved in pickle file
# epochs: 390, Loss: 9.145e-05, Time: 25.32
# Parameters are saved in pickle file
# epochs: 400, Loss: 9.012e-05, Time: 24.87
# Parameters are saved in pickle file
# epochs: 410, Loss: 9.269e-05, Time: 24.76
# Parameters are saved in pickle file
# epochs: 420, Loss: 8.540e-05, Time: 25.71
# Parameters are saved in pickle file
# epochs: 430, Loss: 8.516e-05, Time: 25.20
# Parameters are saved in pickle file
# epochs: 440, Loss: 8.454e-05, Time: 24.89
# Parameters are saved in pickle file
# epochs: 450, Loss: 8.678e-05, Time: 24.89
# Parameters are saved in pickle file
# epochs: 460, Loss: 8.825e-05, Time: 24.81
# Parameters are saved in pickle file
# epochs: 470, Loss: 8.652e-05, Time: 24.73
# Parameters are saved in pickle file
# epochs: 480, Loss: 8.477e-05, Time: 24.80
# Parameters are saved in pickle file
# epochs: 490, Loss: 8.500e-05, Time: 25.40
# Parameters are saved in pickle file
# epochs: 500, Loss: 8.001e-05, Time: 25.50
# Parameters are saved in pickle file
# epochs: 510, Loss: 8.098e-05, Time: 25.63
# Parameters are saved in pickle file
# epochs: 520, Loss: 8.581e-05, Time: 25.35
# Parameters are saved in pickle file
# epochs: 530, Loss: 8.177e-05, Time: 25.32
# Parameters are saved in pickle file
# epochs: 540, Loss: 8.161e-05, Time: 25.20
# Parameters are saved in pickle file
# epochs: 550, Loss: 8.090e-05, Time: 25.33
# Parameters are saved in pickle file
# epochs: 560, Loss: 9.087e-05, Time: 25.59
# Parameters are saved in pickle file
# epochs: 570, Loss: 8.209e-05, Time: 24.90
# Parameters are saved in pickle file
# epochs: 580, Loss: 7.916e-05, Time: 25.02
# Parameters are saved in pickle file
# epochs: 590, Loss: 8.425e-05, Time: 24.96
# Parameters are saved in pickle file
# epochs: 600, Loss: 8.233e-05, Time: 25.49
# Parameters are saved in pickle file
# epochs: 610, Loss: 7.950e-05, Time: 25.11
# Parameters are saved in pickle file
# epochs: 620, Loss: 8.088e-05, Time: 24.35
# Parameters are saved in pickle file
# epochs: 630, Loss: 8.013e-05, Time: 24.87
# Parameters are saved in pickle file
# epochs: 640, Loss: 8.314e-05, Time: 24.83
# Parameters are saved in pickle file
# epochs: 650, Loss: 7.895e-05, Time: 24.73
# Parameters are saved in pickle file
# epochs: 660, Loss: 7.375e-05, Time: 24.89
# Parameters are saved in pickle file
# epochs: 670, Loss: 7.319e-05, Time: 25.34
# Parameters are saved in pickle file
# epochs: 680, Loss: 8.292e-05, Time: 25.35
# Parameters are saved in pickle file
# epochs: 690, Loss: 7.784e-05, Time: 25.28
# Parameters are saved in pickle file
# epochs: 700, Loss: 8.033e-05, Time: 24.60
# Parameters are saved in pickle file
# epochs: 710, Loss: 7.545e-05, Time: 25.29
# Parameters are saved in pickle file
# epochs: 720, Loss: 7.497e-05, Time: 25.15
# Parameters are saved in pickle file
# epochs: 730, Loss: 7.427e-05, Time: 24.89
# Parameters are saved in pickle file
# epochs: 740, Loss: 7.729e-05, Time: 24.45
# Parameters are saved in pickle file
# epochs: 750, Loss: 7.585e-05, Time: 24.85
# Parameters are saved in pickle file
# epochs: 760, Loss: 7.110e-05, Time: 26.11
# Parameters are saved in pickle file
# epochs: 770, Loss: 7.833e-05, Time: 25.35
# Parameters are saved in pickle file
# epochs: 780, Loss: 7.551e-05, Time: 24.83
# Parameters are saved in pickle file
# epochs: 790, Loss: 7.675e-05, Time: 24.90
# Parameters are saved in pickle file
# epochs: 800, Loss: 7.620e-05, Time: 24.63
# Parameters are saved in pickle file
# epochs: 810, Loss: 7.478e-05, Time: 24.75
# Parameters are saved in pickle file
# epochs: 820, Loss: 7.167e-05, Time: 24.81
# Parameters are saved in pickle file
# epochs: 830, Loss: 7.177e-05, Time: 24.77
# Parameters are saved in pickle file
# epochs: 840, Loss: 7.237e-05, Time: 25.91
# Parameters are saved in pickle file
# epochs: 850, Loss: 6.757e-05, Time: 26.54
# Parameters are saved in pickle file
# epochs: 860, Loss: 8.966e-05, Time: 26.64
# Parameters are saved in pickle file
# epochs: 870, Loss: 6.830e-05, Time: 26.40
# Parameters are saved in pickle file
# epochs: 880, Loss: 6.883e-05, Time: 26.32
# Parameters are saved in pickle file
# epochs: 890, Loss: 7.590e-05, Time: 26.25
# Parameters are saved in pickle file
# epochs: 900, Loss: 6.718e-05, Time: 26.62
# Parameters are saved in pickle file
# epochs: 910, Loss: 6.586e-05, Time: 26.65
# Parameters are saved in pickle file
# epochs: 920, Loss: 7.033e-05, Time: 26.84
# Parameters are saved in pickle file
# epochs: 930, Loss: 6.962e-05, Time: 25.71
# Parameters are saved in pickle file
# epochs: 940, Loss: 6.789e-05, Time: 24.63
# Parameters are saved in pickle file
# epochs: 950, Loss: 6.670e-05, Time: 25.12
# Parameters are saved in pickle file
# epochs: 960, Loss: 6.513e-05, Time: 25.12
# Parameters are saved in pickle file
# epochs: 970, Loss: 6.930e-05, Time: 24.64
# Parameters are saved in pickle file
# epochs: 980, Loss: 9.561e-05, Time: 25.22
# Parameters are saved in pickle file
# epochs: 990, Loss: 6.425e-05, Time: 25.76
# Parameters are saved in pickle file
# Saving the predictions for time step: [2.]
# Predictions are saved in pickle file
# Previous predictions are loaded from pickle file
# wandb: WARNING Calling wandb.run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# Previous predictions are saved in pickle file
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Previous_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>██▆▄▂▃▄▂▄▃▂▂▂▃▂▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>▁▅▆▆▆██▆█▅▆▇▇▆▇▅█▆▅▇▇▇▇▇▆▇▇▇▇▇▇▇▆▇▇▇▇▇▇▇</td></tr><tr><td>time step 2</td><td>█▃▂▁▁▁▃▂▃▃▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>time step 3</td><td>▁▁▂▃▄▄▃▄▄▄▃▂▂▂▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>time step 4</td><td>▂▁▁▁▂▂▃▃▃▄▄▃▃▃▄▅▄▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>time step 5</td><td>▃▁▁▁▂▂▃▃▄▄▄▃▄▄▄▅▅▅▆▇▇▆▇▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>time step 6</td><td>▃▁▁▁▂▃▃▄▄▄▅▄▄▄▅▅▅▅▆▇▇▇▇▇▇▇▇▇▇▇▇▇████████</td></tr><tr><td>time step 7</td><td>▃▁▁▁▂▃▃▄▄▄▅▄▄▄▅▅▅▅▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>5e-05</td></tr><tr><td>Initial_loss</td><td>0.0</td></tr><tr><td>Previous_loss</td><td>0.0</td></tr><tr><td>Residual_loss</td><td>1e-05</td></tr><tr><td>Total_loss</td><td>6e-05</td></tr><tr><td>time step 1</td><td>0.17087</td></tr><tr><td>time step 2</td><td>0.17485</td></tr><tr><td>time step 3</td><td>0.33309</td></tr><tr><td>time step 4</td><td>3.77808</td></tr><tr><td>time step 5</td><td>10.41613</td></tr><tr><td>time step 6</td><td>18.62207</td></tr><tr><td>time step 7</td><td>26.80243</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">celestial-flower-3</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/3m8framy" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/3m8framy</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221013_131858-3m8framy\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.033339556058247885, max=1.0…
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221013_144537-omxuoacx</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/omxuoacx" target="_blank">worthy-star-4</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 2 3 ]
# ===============================================================================================
# epochs: 0, Loss: 5.443e-02, Time: 8.78
# epochs: 10, Loss: 5.150e-03, Time: 25.67
# Parameters are saved in pickle file
# epochs: 20, Loss: 2.845e-03, Time: 26.92
# Parameters are saved in pickle file
# epochs: 30, Loss: 2.081e-03, Time: 26.82
# Parameters are saved in pickle file
# epochs: 40, Loss: 2.043e-03, Time: 27.06
# Parameters are saved in pickle file
# epochs: 50, Loss: 1.467e-03, Time: 26.57
# Parameters are saved in pickle file
# epochs: 60, Loss: 1.537e-03, Time: 26.87
# Parameters are saved in pickle file
# epochs: 70, Loss: 1.151e-03, Time: 26.76
# Parameters are saved in pickle file
# epochs: 80, Loss: 8.935e-04, Time: 26.96
# Parameters are saved in pickle file
# epochs: 90, Loss: 9.393e-04, Time: 26.65
# Parameters are saved in pickle file
# epochs: 100, Loss: 1.043e-03, Time: 26.81
# Parameters are saved in pickle file
# epochs: 110, Loss: 6.048e-04, Time: 26.84
# Parameters are saved in pickle file
# epochs: 120, Loss: 7.507e-04, Time: 26.40
# Parameters are saved in pickle file
# epochs: 130, Loss: 7.333e-04, Time: 26.64
# Parameters are saved in pickle file
# epochs: 140, Loss: 1.258e-03, Time: 26.67
# Parameters are saved in pickle file
# epochs: 150, Loss: 1.527e-03, Time: 26.57
# Parameters are saved in pickle file
# epochs: 160, Loss: 5.849e-04, Time: 26.42
# Parameters are saved in pickle file
# epochs: 170, Loss: 7.415e-04, Time: 26.36
# Parameters are saved in pickle file
# epochs: 180, Loss: 4.758e-04, Time: 26.39
# Parameters are saved in pickle file
# epochs: 190, Loss: 7.300e-04, Time: 26.39
# Parameters are saved in pickle file
# epochs: 200, Loss: 8.669e-04, Time: 27.00
# Parameters are saved in pickle file
# epochs: 210, Loss: 8.815e-04, Time: 26.08
# Parameters are saved in pickle file
# epochs: 220, Loss: 6.277e-04, Time: 26.46
# Parameters are saved in pickle file
# epochs: 230, Loss: 5.858e-04, Time: 26.25
# Parameters are saved in pickle file
# epochs: 240, Loss: 8.846e-04, Time: 26.48
# Parameters are saved in pickle file
# epochs: 250, Loss: 7.487e-04, Time: 26.00
# Parameters are saved in pickle file
# epochs: 260, Loss: 4.690e-04, Time: 26.36
# Parameters are saved in pickle file
# epochs: 270, Loss: 5.222e-04, Time: 25.91
# Parameters are saved in pickle file
# epochs: 280, Loss: 7.160e-04, Time: 25.68
# Parameters are saved in pickle file
# epochs: 290, Loss: 9.982e-04, Time: 26.17
# Parameters are saved in pickle file
# epochs: 300, Loss: 2.595e-03, Time: 25.67
# Parameters are saved in pickle file
# epochs: 310, Loss: 2.105e-03, Time: 25.93
# Parameters are saved in pickle file
# epochs: 320, Loss: 1.490e-03, Time: 25.83
# Parameters are saved in pickle file
# epochs: 330, Loss: 2.094e-03, Time: 26.59
# Parameters are saved in pickle file
# epochs: 340, Loss: 1.105e-03, Time: 26.72
# Parameters are saved in pickle file
# epochs: 350, Loss: 2.559e-03, Time: 26.14
# Parameters are saved in pickle file
# epochs: 360, Loss: 1.236e-03, Time: 26.19
# Parameters are saved in pickle file
# epochs: 370, Loss: 8.763e-04, Time: 26.47
# Parameters are saved in pickle file
# epochs: 380, Loss: 1.014e-03, Time: 26.70
# Parameters are saved in pickle file
# epochs: 390, Loss: 1.072e-03, Time: 27.10
# Parameters are saved in pickle file
# epochs: 400, Loss: 1.173e-03, Time: 27.55
# Parameters are saved in pickle file
# epochs: 410, Loss: 9.942e-04, Time: 27.47
# Parameters are saved in pickle file
# epochs: 420, Loss: 8.705e-04, Time: 26.41
# Parameters are saved in pickle file
# epochs: 430, Loss: 1.089e-03, Time: 26.53
# Parameters are saved in pickle file
# epochs: 440, Loss: 1.271e-03, Time: 26.41
# Parameters are saved in pickle file
# epochs: 450, Loss: 6.893e-04, Time: 26.21
# Parameters are saved in pickle file
# epochs: 460, Loss: 6.563e-04, Time: 26.36
# Parameters are saved in pickle file
# epochs: 470, Loss: 5.790e-04, Time: 26.29
# Parameters are saved in pickle file
# epochs: 480, Loss: 7.774e-04, Time: 25.72
# Parameters are saved in pickle file
# epochs: 490, Loss: 7.144e-04, Time: 25.87
# Parameters are saved in pickle file
# epochs: 500, Loss: 5.265e-04, Time: 25.56
# Parameters are saved in pickle file
# epochs: 510, Loss: 5.093e-04, Time: 25.51
# Parameters are saved in pickle file
# epochs: 520, Loss: 3.794e-04, Time: 25.37
# Parameters are saved in pickle file
# epochs: 530, Loss: 8.328e-04, Time: 25.60
# Parameters are saved in pickle file
# epochs: 540, Loss: 8.101e-04, Time: 25.87
# Parameters are saved in pickle file
# epochs: 550, Loss: 8.523e-04, Time: 25.69
# Parameters are saved in pickle file
# epochs: 560, Loss: 4.151e-04, Time: 25.65
# Parameters are saved in pickle file
# epochs: 570, Loss: 2.676e-04, Time: 26.57
# Parameters are saved in pickle file
# epochs: 580, Loss: 3.931e-04, Time: 26.73
# Parameters are saved in pickle file
# epochs: 590, Loss: 4.254e-04, Time: 26.78
# Parameters are saved in pickle file
# epochs: 600, Loss: 5.623e-04, Time: 27.09
# Parameters are saved in pickle file
# epochs: 610, Loss: 8.423e-04, Time: 26.75
# Parameters are saved in pickle file
# epochs: 620, Loss: 4.208e-04, Time: 27.04
# Parameters are saved in pickle file
# epochs: 630, Loss: 3.825e-04, Time: 26.49
# Parameters are saved in pickle file
# epochs: 640, Loss: 4.692e-04, Time: 26.82
# Parameters are saved in pickle file
# epochs: 650, Loss: 3.066e-04, Time: 26.94
# Parameters are saved in pickle file
# epochs: 660, Loss: 7.032e-04, Time: 25.92
# Parameters are saved in pickle file
# epochs: 670, Loss: 6.766e-04, Time: 25.54
# Parameters are saved in pickle file
# epochs: 680, Loss: 3.243e-04, Time: 25.72
# Parameters are saved in pickle file
# epochs: 690, Loss: 4.087e-04, Time: 25.69
# Parameters are saved in pickle file
# epochs: 700, Loss: 5.738e-04, Time: 25.65
# Parameters are saved in pickle file
# epochs: 710, Loss: 2.406e-03, Time: 25.67
# Parameters are saved in pickle file
# epochs: 720, Loss: 3.404e-04, Time: 26.15
# Parameters are saved in pickle file
# epochs: 730, Loss: 2.790e-04, Time: 25.70
# Parameters are saved in pickle file
# epochs: 740, Loss: 6.696e-04, Time: 25.56
# Parameters are saved in pickle file
# epochs: 750, Loss: 6.903e-04, Time: 25.52
# Parameters are saved in pickle file
# epochs: 760, Loss: 5.259e-04, Time: 25.76
# Parameters are saved in pickle file
# epochs: 770, Loss: 3.683e-04, Time: 25.57
# Parameters are saved in pickle file
# epochs: 780, Loss: 5.290e-04, Time: 26.39
# Parameters are saved in pickle file
# epochs: 790, Loss: 5.995e-04, Time: 26.84
# Parameters are saved in pickle file
# epochs: 800, Loss: 5.075e-04, Time: 26.63
# Parameters are saved in pickle file
# epochs: 810, Loss: 7.797e-04, Time: 26.76
# Parameters are saved in pickle file
# epochs: 820, Loss: 1.480e-03, Time: 27.05
# Parameters are saved in pickle file
# epochs: 830, Loss: 1.588e-03, Time: 26.50
# Parameters are saved in pickle file
# epochs: 840, Loss: 1.175e-03, Time: 26.82
# Parameters are saved in pickle file
# epochs: 850, Loss: 1.816e-04, Time: 26.67
# Parameters are saved in pickle file
# epochs: 860, Loss: 7.731e-04, Time: 26.45
# Parameters are saved in pickle file
# epochs: 870, Loss: 5.500e-04, Time: 26.68
# Parameters are saved in pickle file
# epochs: 880, Loss: 3.475e-04, Time: 26.50
# Parameters are saved in pickle file
# epochs: 890, Loss: 2.086e-04, Time: 26.93
# Parameters are saved in pickle file
# epochs: 900, Loss: 4.144e-04, Time: 25.73
# Parameters are saved in pickle file
# epochs: 910, Loss: 3.583e-04, Time: 25.05
# Parameters are saved in pickle file
# epochs: 920, Loss: 3.072e-04, Time: 25.79
# Parameters are saved in pickle file
# epochs: 930, Loss: 1.934e-04, Time: 25.90
# Parameters are saved in pickle file
# epochs: 940, Loss: 2.627e-04, Time: 26.34
# Parameters are saved in pickle file
# epochs: 950, Loss: 7.395e-04, Time: 26.36
# Parameters are saved in pickle file
# epochs: 960, Loss: 6.145e-04, Time: 26.68
# Parameters are saved in pickle file
# epochs: 970, Loss: 3.886e-04, Time: 26.93
# Parameters are saved in pickle file
# epochs: 980, Loss: 1.451e-03, Time: 25.82
# Parameters are saved in pickle file
# epochs: 990, Loss: 3.450e-04, Time: 26.27
# Parameters are saved in pickle file
# epochs: 0, Loss: 1.306e-04, Time: 2.65
# epochs: 10, Loss: 1.173e-04, Time: 26.34
# Parameters are saved in pickle file
# epochs: 20, Loss: 1.169e-04, Time: 26.18
# Parameters are saved in pickle file
# epochs: 30, Loss: 1.107e-04, Time: 25.16
# Parameters are saved in pickle file
# epochs: 40, Loss: 1.112e-04, Time: 25.29
# Parameters are saved in pickle file
# epochs: 50, Loss: 1.090e-04, Time: 26.06
# Parameters are saved in pickle file
# epochs: 60, Loss: 1.067e-04, Time: 25.57
# Parameters are saved in pickle file
# epochs: 70, Loss: 1.057e-04, Time: 25.36
# Parameters are saved in pickle file
# epochs: 80, Loss: 1.023e-04, Time: 25.74
# Parameters are saved in pickle file
# epochs: 90, Loss: 1.016e-04, Time: 25.47
# Parameters are saved in pickle file
# epochs: 100, Loss: 1.016e-04, Time: 25.17
# Parameters are saved in pickle file
# epochs: 110, Loss: 1.004e-04, Time: 25.57
# Parameters are saved in pickle file
# epochs: 120, Loss: 9.866e-05, Time: 25.98
# Parameters are saved in pickle file
# epochs: 130, Loss: 9.976e-05, Time: 25.62
# Parameters are saved in pickle file
# epochs: 140, Loss: 1.011e-04, Time: 25.57
# Parameters are saved in pickle file
# epochs: 150, Loss: 9.689e-05, Time: 25.43
# Parameters are saved in pickle file
# epochs: 160, Loss: 9.648e-05, Time: 25.36
# Parameters are saved in pickle file
# epochs: 170, Loss: 9.624e-05, Time: 25.85
# Parameters are saved in pickle file
# epochs: 180, Loss: 9.135e-05, Time: 25.52
# Parameters are saved in pickle file
# epochs: 190, Loss: 9.354e-05, Time: 25.68
# Parameters are saved in pickle file
# epochs: 200, Loss: 8.869e-05, Time: 25.58
# Parameters are saved in pickle file
# epochs: 210, Loss: 9.230e-05, Time: 25.88
# Parameters are saved in pickle file
# epochs: 220, Loss: 1.084e-04, Time: 25.17
# Parameters are saved in pickle file
# epochs: 230, Loss: 9.118e-05, Time: 25.11
# Parameters are saved in pickle file
# epochs: 240, Loss: 1.030e-04, Time: 25.16
# Parameters are saved in pickle file
# epochs: 250, Loss: 8.564e-05, Time: 25.75
# Parameters are saved in pickle file
# epochs: 260, Loss: 8.909e-05, Time: 25.34
# Parameters are saved in pickle file
# epochs: 270, Loss: 8.572e-05, Time: 24.85
# Parameters are saved in pickle file
# epochs: 280, Loss: 8.344e-05, Time: 25.53
# Parameters are saved in pickle file
# epochs: 290, Loss: 8.899e-05, Time: 25.33
# Parameters are saved in pickle file
# epochs: 300, Loss: 8.261e-05, Time: 25.39
# Parameters are saved in pickle file
# epochs: 310, Loss: 8.324e-05, Time: 26.52
# Parameters are saved in pickle file
# epochs: 320, Loss: 8.455e-05, Time: 27.10
# Parameters are saved in pickle file
# epochs: 330, Loss: 8.059e-05, Time: 27.07
# Parameters are saved in pickle file
# epochs: 340, Loss: 7.830e-05, Time: 26.57
# Parameters are saved in pickle file
# epochs: 350, Loss: 7.832e-05, Time: 26.57
# Parameters are saved in pickle file
# epochs: 360, Loss: 7.678e-05, Time: 26.77
# Parameters are saved in pickle file
# epochs: 370, Loss: 8.077e-05, Time: 27.15
# Parameters are saved in pickle file
# epochs: 380, Loss: 7.688e-05, Time: 26.97
# Parameters are saved in pickle file
# epochs: 390, Loss: 8.992e-05, Time: 26.48
# Parameters are saved in pickle file
# epochs: 400, Loss: 8.316e-05, Time: 25.66
# Parameters are saved in pickle file
# epochs: 410, Loss: 7.537e-05, Time: 25.71
# Parameters are saved in pickle file
# epochs: 420, Loss: 8.042e-05, Time: 25.93
# Parameters are saved in pickle file
# epochs: 430, Loss: 7.718e-05, Time: 25.76
# Parameters are saved in pickle file
# epochs: 440, Loss: 7.900e-05, Time: 25.54
# Parameters are saved in pickle file
# epochs: 450, Loss: 7.244e-05, Time: 25.53
# Parameters are saved in pickle file
# epochs: 460, Loss: 7.615e-05, Time: 25.80
# Parameters are saved in pickle file
# epochs: 470, Loss: 7.203e-05, Time: 25.32
# Parameters are saved in pickle file
# epochs: 480, Loss: 7.691e-05, Time: 25.47
# Parameters are saved in pickle file
# epochs: 490, Loss: 7.254e-05, Time: 25.62
# Parameters are saved in pickle file
# epochs: 500, Loss: 7.975e-05, Time: 26.39
# Parameters are saved in pickle file
# epochs: 510, Loss: 7.774e-05, Time: 26.40
# Parameters are saved in pickle file
# epochs: 520, Loss: 7.513e-05, Time: 26.11
# Parameters are saved in pickle file
# epochs: 530, Loss: 7.848e-05, Time: 26.29
# Parameters are saved in pickle file
# epochs: 540, Loss: 7.440e-05, Time: 25.82
# Parameters are saved in pickle file
# epochs: 550, Loss: 6.947e-05, Time: 26.53
# Parameters are saved in pickle file
# epochs: 560, Loss: 7.123e-05, Time: 25.98
# Parameters are saved in pickle file
# epochs: 570, Loss: 7.020e-05, Time: 26.00
# Parameters are saved in pickle file
# epochs: 580, Loss: 6.752e-05, Time: 26.27
# Parameters are saved in pickle file
# epochs: 590, Loss: 6.901e-05, Time: 26.13
# Parameters are saved in pickle file
# epochs: 600, Loss: 6.805e-05, Time: 25.92
# Parameters are saved in pickle file
# epochs: 610, Loss: 7.123e-05, Time: 25.36
# Parameters are saved in pickle file
# epochs: 620, Loss: 6.695e-05, Time: 25.33
# Parameters are saved in pickle file
# epochs: 630, Loss: 6.870e-05, Time: 25.48
# Parameters are saved in pickle file
# epochs: 640, Loss: 6.686e-05, Time: 25.55
# Parameters are saved in pickle file
# epochs: 650, Loss: 6.843e-05, Time: 25.45
# Parameters are saved in pickle file
# epochs: 660, Loss: 7.122e-05, Time: 25.54
# Parameters are saved in pickle file
# epochs: 670, Loss: 6.734e-05, Time: 25.38
# Parameters are saved in pickle file
# epochs: 680, Loss: 6.500e-05, Time: 25.61
# Parameters are saved in pickle file
# epochs: 690, Loss: 6.726e-05, Time: 25.75
# Parameters are saved in pickle file
# epochs: 700, Loss: 6.357e-05, Time: 25.46
# Parameters are saved in pickle file
# epochs: 710, Loss: 6.614e-05, Time: 25.90
# Parameters are saved in pickle file
# epochs: 720, Loss: 6.663e-05, Time: 25.48
# Parameters are saved in pickle file
# epochs: 730, Loss: 6.747e-05, Time: 25.80
# Parameters are saved in pickle file
# epochs: 740, Loss: 6.522e-05, Time: 25.80
# Parameters are saved in pickle file
# epochs: 750, Loss: 6.443e-05, Time: 25.80
# Parameters are saved in pickle file
# epochs: 760, Loss: 6.214e-05, Time: 26.06
# Parameters are saved in pickle file
# epochs: 770, Loss: 6.634e-05, Time: 25.97
# Parameters are saved in pickle file
# epochs: 780, Loss: 6.575e-05, Time: 25.27
# Parameters are saved in pickle file
# epochs: 790, Loss: 6.374e-05, Time: 24.92
# Parameters are saved in pickle file
# epochs: 800, Loss: 7.554e-05, Time: 25.21
# Parameters are saved in pickle file
# epochs: 810, Loss: 6.231e-05, Time: 24.93
# Parameters are saved in pickle file
# epochs: 820, Loss: 6.369e-05, Time: 25.78
# Parameters are saved in pickle file
# epochs: 830, Loss: 8.106e-05, Time: 25.67
# Parameters are saved in pickle file
# epochs: 840, Loss: 6.496e-05, Time: 25.35
# Parameters are saved in pickle file
# epochs: 850, Loss: 6.113e-05, Time: 25.23
# Parameters are saved in pickle file
# epochs: 860, Loss: 5.917e-05, Time: 25.25
# Parameters are saved in pickle file
# epochs: 870, Loss: 6.013e-05, Time: 25.36
# Parameters are saved in pickle file
# epochs: 880, Loss: 6.092e-05, Time: 25.65
# Parameters are saved in pickle file
# epochs: 890, Loss: 5.988e-05, Time: 25.56
# Parameters are saved in pickle file
# epochs: 900, Loss: 6.344e-05, Time: 25.48
# Parameters are saved in pickle file
# epochs: 910, Loss: 6.717e-05, Time: 25.76
# Parameters are saved in pickle file
# epochs: 920, Loss: 6.474e-05, Time: 25.70
# Parameters are saved in pickle file
# epochs: 930, Loss: 6.273e-05, Time: 25.81
# Parameters are saved in pickle file
# epochs: 940, Loss: 6.308e-05, Time: 25.47
# Parameters are saved in pickle file
# epochs: 950, Loss: 7.044e-05, Time: 25.50
# Parameters are saved in pickle file
# epochs: 960, Loss: 6.266e-05, Time: 25.43
# Parameters are saved in pickle file
# epochs: 970, Loss: 5.783e-05, Time: 25.18
# Parameters are saved in pickle file
# epochs: 980, Loss: 6.028e-05, Time: 25.52
# Parameters are saved in pickle file
# epochs: 990, Loss: 5.992e-05, Time: 25.28
# Parameters are saved in pickle file
# Saving the predictions for time step: [3.]
# Predictions are saved in pickle file
# Previous predictions are loaded from pickle file
# Previous predictions are saved in pickle file
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>█▃▂▂▂▂█▅▄▃▂▁▁▂▆▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>█▃▂▃▃▃▂▂▁▁▁▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Previous_loss</td><td>█▂▂▂▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>▄▃▁▃▃▃▄█▂▂▂▂▃▃▇▂▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▃▂▃▂▂▄▄▂▂▂▂▂▂▄▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>▁▄▃▅▄▆▇▆▅▄▇▂▆▄▃▇█▃▆▇▅▅▅▅▅▄▅▅▅▅▅▅▅▅▅▅▅▅▅▄</td></tr><tr><td>time step 2</td><td>▄▆▅█▃▇▅▄▁▃▃▃▆▄▄▂▄▂▃▁▃▃▃▄▄▄▄▃▃▄▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>time step 3</td><td>▂▁▁▂▂▂▅▇██▄▂▂▂▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>time step 4</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▃▃▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇█████</td></tr><tr><td>time step 5</td><td>▁▂▂▂▂▂▁▁▁▁▁▂▂▂▂▃▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇███████</td></tr><tr><td>time step 6</td><td>▁▂▂▂▂▂▁▁▁▁▁▂▂▂▂▃▃▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>time step 7</td><td>▁▂▂▂▂▂▁▁▁▁▁▂▂▂▂▃▃▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇███████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>4e-05</td></tr><tr><td>Initial_loss</td><td>0.0</td></tr><tr><td>Previous_loss</td><td>1e-05</td></tr><tr><td>Residual_loss</td><td>1e-05</td></tr><tr><td>Total_loss</td><td>6e-05</td></tr><tr><td>time step 1</td><td>0.17062</td></tr><tr><td>time step 2</td><td>0.17475</td></tr><tr><td>time step 3</td><td>0.17472</td></tr><tr><td>time step 4</td><td>1.30837</td></tr><tr><td>time step 5</td><td>17.75476</td></tr><tr><td>time step 6</td><td>56.78392</td></tr><tr><td>time step 7</td><td>107.74821</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">worthy-star-4</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/omxuoacx" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/omxuoacx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221013_144537-omxuoacx\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.033333595593770346, max=1.0…
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20221013_161356-kwzdn7d3</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/kwzdn7d3" target="_blank">efficient-wave-5</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 3 4 ]
# ===============================================================================================
# epochs: 0, Loss: 5.419e-02, Time: 8.93
# epochs: 10, Loss: 5.729e-03, Time: 25.81
# Parameters are saved in pickle file
# epochs: 20, Loss: 3.159e-03, Time: 26.53
# Parameters are saved in pickle file
# epochs: 30, Loss: 2.098e-03, Time: 25.89
# Parameters are saved in pickle file
# epochs: 40, Loss: 1.718e-03, Time: 25.90
# Parameters are saved in pickle file
# epochs: 50, Loss: 1.605e-03, Time: 25.99
# Parameters are saved in pickle file
# epochs: 60, Loss: 1.531e-03, Time: 27.34
# Parameters are saved in pickle file
# epochs: 70, Loss: 1.673e-03, Time: 28.20
# Parameters are saved in pickle file
# epochs: 80, Loss: 1.012e-03, Time: 27.46
# Parameters are saved in pickle file
# epochs: 90, Loss: 1.032e-03, Time: 27.23
# Parameters are saved in pickle file
# epochs: 100, Loss: 9.056e-04, Time: 27.33
# Parameters are saved in pickle file
# epochs: 110, Loss: 1.197e-03, Time: 27.64
# Parameters are saved in pickle file
# epochs: 120, Loss: 1.090e-03, Time: 28.07
# Parameters are saved in pickle file
# epochs: 130, Loss: 7.426e-04, Time: 28.36
# Parameters are saved in pickle file
# epochs: 140, Loss: 1.204e-03, Time: 27.34
# Parameters are saved in pickle file
# epochs: 150, Loss: 6.078e-04, Time: 26.69
# Parameters are saved in pickle file
# epochs: 160, Loss: 5.607e-04, Time: 26.28
# Parameters are saved in pickle file
# epochs: 170, Loss: 6.699e-04, Time: 26.19
# Parameters are saved in pickle file
# epochs: 180, Loss: 8.672e-04, Time: 26.23
# Parameters are saved in pickle file
# epochs: 190, Loss: 5.729e-04, Time: 26.28
# Parameters are saved in pickle file
# epochs: 200, Loss: 6.709e-04, Time: 26.04
# Parameters are saved in pickle file
# epochs: 210, Loss: 4.949e-04, Time: 26.20
# Parameters are saved in pickle file
# epochs: 220, Loss: 1.542e-03, Time: 26.12
# Parameters are saved in pickle file
# epochs: 230, Loss: 6.401e-04, Time: 26.43
# Parameters are saved in pickle file
# epochs: 240, Loss: 5.055e-04, Time: 26.42
# Parameters are saved in pickle file
# epochs: 250, Loss: 8.234e-04, Time: 26.59
# Parameters are saved in pickle file
# epochs: 260, Loss: 5.744e-04, Time: 25.89
# Parameters are saved in pickle file
# epochs: 270, Loss: 6.955e-04, Time: 25.93
# Parameters are saved in pickle file
# epochs: 280, Loss: 6.676e-04, Time: 25.76
# Parameters are saved in pickle file
# epochs: 290, Loss: 6.512e-04, Time: 26.59
# Parameters are saved in pickle file
# epochs: 300, Loss: 4.256e-04, Time: 26.19
# Parameters are saved in pickle file
# epochs: 310, Loss: 4.217e-04, Time: 26.25
# Parameters are saved in pickle file
# epochs: 320, Loss: 4.350e-04, Time: 26.05
# Parameters are saved in pickle file
# epochs: 330, Loss: 4.193e-04, Time: 26.17
# Parameters are saved in pickle file
# epochs: 340, Loss: 8.412e-04, Time: 25.85
# Parameters are saved in pickle file
# epochs: 350, Loss: 4.261e-04, Time: 25.84
# Parameters are saved in pickle file
# epochs: 360, Loss: 5.543e-04, Time: 25.93
# Parameters are saved in pickle file
# epochs: 370, Loss: 7.572e-04, Time: 25.91
# Parameters are saved in pickle file
# epochs: 380, Loss: 4.646e-04, Time: 26.09
# Parameters are saved in pickle file
# epochs: 390, Loss: 1.147e-03, Time: 25.99
# Parameters are saved in pickle file
# epochs: 400, Loss: 5.011e-04, Time: 26.27
# Parameters are saved in pickle file
# epochs: 410, Loss: 2.353e-03, Time: 26.43
# Parameters are saved in pickle file
# epochs: 420, Loss: 7.489e-04, Time: 26.09
# Parameters are saved in pickle file
# epochs: 430, Loss: 5.829e-04, Time: 27.26
# Parameters are saved in pickle file
# epochs: 440, Loss: 3.901e-04, Time: 26.56
# Parameters are saved in pickle file
# epochs: 450, Loss: 1.162e-03, Time: 27.36
# Parameters are saved in pickle file
# epochs: 460, Loss: 8.474e-04, Time: 27.44
# Parameters are saved in pickle file
# epochs: 470, Loss: 1.409e-03, Time: 27.19
# Parameters are saved in pickle file
# epochs: 480, Loss: 6.708e-04, Time: 26.51
# Parameters are saved in pickle file
# epochs: 490, Loss: 8.904e-04, Time: 27.14
# Parameters are saved in pickle file
# epochs: 500, Loss: 5.566e-04, Time: 26.98
# Parameters are saved in pickle file
# epochs: 510, Loss: 6.915e-04, Time: 26.79
# Parameters are saved in pickle file
# epochs: 520, Loss: 9.843e-04, Time: 27.19
# Parameters are saved in pickle file
# epochs: 530, Loss: 4.675e-04, Time: 27.15
# Parameters are saved in pickle file
# epochs: 540, Loss: 1.171e-03, Time: 26.87
# Parameters are saved in pickle file
# epochs: 550, Loss: 5.832e-04, Time: 27.00
# Parameters are saved in pickle file
# epochs: 560, Loss: 3.085e-04, Time: 26.42
# ...
# Parameters are saved in pickle file
# epochs: 310, Loss: 7.130e-04, Time: 27.09
# Parameters are saved in pickle file
# epochs: 320, Loss: 1.080e-03, Time: 27.46
# Parameters are saved in pickle file
# epochs: 330, Loss: 3.442e-04, Time: 27.46
# Parameters are saved in pickle file
# epochs: 340, Loss: 7.384e-04, Time: 27.72
# Parameters are saved in pickle file
# epochs: 350, Loss: 8.006e-04, Time: 28.63
# Parameters are saved in pickle file
# epochs: 360, Loss: 9.809e-04, Time: 28.07
# Parameters are saved in pickle file
# epochs: 370, Loss: 5.041e-04, Time: 27.99
# Parameters are saved in pickle file
# epochs: 380, Loss: 4.861e-04, Time: 27.66
# Parameters are saved in pickle file
# epochs: 390, Loss: 5.506e-04, Time: 27.79
# Parameters are saved in pickle file
# epochs: 400, Loss: 1.264e-03, Time: 27.81
# Parameters are saved in pickle file
# epochs: 410, Loss: 5.220e-04, Time: 28.07
# Parameters are saved in pickle file
# epochs: 420, Loss: 1.049e-03, Time: 27.80
# Parameters are saved in pickle file
# epochs: 430, Loss: 2.004e-03, Time: 28.37
# Parameters are saved in pickle file
# epochs: 440, Loss: 2.736e-03, Time: 27.38
# Parameters are saved in pickle file
# epochs: 450, Loss: 8.899e-04, Time: 27.48
# Parameters are saved in pickle file
# epochs: 460, Loss: 5.927e-04, Time: 27.37
# Parameters are saved in pickle file
# epochs: 470, Loss: 5.774e-04, Time: 27.61
# Parameters are saved in pickle file
# epochs: 480, Loss: 6.362e-04, Time: 27.17
# Parameters are saved in pickle file
# epochs: 490, Loss: 5.207e-04, Time: 27.67
# Parameters are saved in pickle file
# epochs: 500, Loss: 6.267e-04, Time: 27.65
# Parameters are saved in pickle file
# epochs: 510, Loss: 7.025e-04, Time: 27.91
# Parameters are saved in pickle file
# epochs: 520, Loss: 3.889e-04, Time: 27.89
# Parameters are saved in pickle file
# epochs: 530, Loss: 1.163e-03, Time: 27.65
# Parameters are saved in pickle file
# epochs: 540, Loss: 3.601e-04, Time: 27.41
# Parameters are saved in pickle file
# epochs: 550, Loss: 7.939e-04, Time: 27.51
# Parameters are saved in pickle file
# epochs: 560, Loss: 7.615e-04, Time: 27.67
# Parameters are saved in pickle file
# epochs: 570, Loss: 5.396e-04, Time: 27.30
# Parameters are saved in pickle file
# epochs: 580, Loss: 5.436e-04, Time: 27.74
# Parameters are saved in pickle file
# epochs: 590, Loss: 1.031e-03, Time: 27.89
# Parameters are saved in pickle file
# epochs: 600, Loss: 1.502e-03, Time: 27.60
# Parameters are saved in pickle file
# epochs: 610, Loss: 3.641e-04, Time: 27.47
# Parameters are saved in pickle file
# epochs: 620, Loss: 8.165e-04, Time: 27.85
# Parameters are saved in pickle file
# epochs: 630, Loss: 3.938e-03, Time: 27.52
# Parameters are saved in pickle file
# epochs: 640, Loss: 2.779e-04, Time: 27.49
# Parameters are saved in pickle file
# epochs: 650, Loss: 7.684e-04, Time: 27.28
# Parameters are saved in pickle file
# epochs: 660, Loss: 2.738e-04, Time: 27.78
# Parameters are saved in pickle file
# epochs: 670, Loss: 4.550e-04, Time: 27.88
# Parameters are saved in pickle file
# epochs: 680, Loss: 6.606e-04, Time: 27.52
# Parameters are saved in pickle file
# epochs: 690, Loss: 1.296e-03, Time: 27.57
# Parameters are saved in pickle file
# epochs: 700, Loss: 5.939e-04, Time: 27.61
# Parameters are saved in pickle file
# epochs: 710, Loss: 2.823e-04, Time: 27.32
# Parameters are saved in pickle file
# epochs: 720, Loss: 4.279e-04, Time: 28.81
# Parameters are saved in pickle file
# epochs: 730, Loss: 4.286e-04, Time: 29.05
# Parameters are saved in pickle file
# epochs: 740, Loss: 4.300e-04, Time: 29.59
# Parameters are saved in pickle file
# epochs: 750, Loss: 6.534e-04, Time: 29.74
# Parameters are saved in pickle file
# epochs: 760, Loss: 1.088e-03, Time: 29.32
# Parameters are saved in pickle file
# epochs: 770, Loss: 2.957e-04, Time: 28.79
# Parameters are saved in pickle file
# epochs: 780, Loss: 9.893e-04, Time: 29.19
# Parameters are saved in pickle file
# epochs: 790, Loss: 9.110e-04, Time: 29.42
# Parameters are saved in pickle file
# epochs: 800, Loss: 5.191e-04, Time: 28.87
# Parameters are saved in pickle file
# epochs: 810, Loss: 1.304e-03, Time: 28.58
# Parameters are saved in pickle file
# epochs: 820, Loss: 3.248e-04, Time: 27.81
# Parameters are saved in pickle file
# epochs: 830, Loss: 7.932e-04, Time: 28.23
# Parameters are saved in pickle file
# epochs: 840, Loss: 8.988e-04, Time: 27.27
# Parameters are saved in pickle file
# epochs: 850, Loss: 6.060e-04, Time: 27.51
# Parameters are saved in pickle file
# epochs: 860, Loss: 9.980e-04, Time: 27.57
# Parameters are saved in pickle file
# epochs: 870, Loss: 7.017e-04, Time: 27.98
# Parameters are saved in pickle file
# epochs: 880, Loss: 2.836e-04, Time: 27.44
# Parameters are saved in pickle file
# epochs: 890, Loss: 5.887e-04, Time: 27.77
# Parameters are saved in pickle file
# epochs: 900, Loss: 5.725e-04, Time: 28.02
# Parameters are saved in pickle file
# epochs: 910, Loss: 4.723e-04, Time: 27.69
# Parameters are saved in pickle file
# epochs: 920, Loss: 3.685e-04, Time: 27.52
# Parameters are saved in pickle file
# epochs: 930, Loss: 2.917e-04, Time: 27.82
# Parameters are saved in pickle file
# epochs: 940, Loss: 1.412e-03, Time: 27.74
# Parameters are saved in pickle file
# epochs: 950, Loss: 1.791e-03, Time: 27.31
# Parameters are saved in pickle file
# epochs: 960, Loss: 1.073e-03, Time: 27.60
# Parameters are saved in pickle file
# epochs: 970, Loss: 4.233e-04, Time: 27.59
# Parameters are saved in pickle file
# epochs: 980, Loss: 5.135e-04, Time: 28.24
# Parameters are saved in pickle file
# epochs: 990, Loss: 5.619e-04, Time: 27.88
# Parameters are saved in pickle file
# epochs: 0, Loss: 1.621e-04, Time: 2.73
# epochs: 10, Loss: 1.395e-04, Time: 27.52
# Parameters are saved in pickle file
# epochs: 20, Loss: 1.328e-04, Time: 27.53
# Parameters are saved in pickle file
# epochs: 30, Loss: 1.327e-04, Time: 26.94
# Parameters are saved in pickle file
# epochs: 40, Loss: 1.324e-04, Time: 27.38
# Parameters are saved in pickle file
# epochs: 50, Loss: 1.299e-04, Time: 27.46
# Parameters are saved in pickle file
# epochs: 60, Loss: 1.331e-04, Time: 27.74
# Parameters are saved in pickle file
# epochs: 70, Loss: 1.308e-04, Time: 27.42
# Parameters are saved in pickle file
# epochs: 80, Loss: 1.263e-04, Time: 27.46
# Parameters are saved in pickle file
# epochs: 90, Loss: 1.226e-04, Time: 27.39
# Parameters are saved in pickle file
# epochs: 100, Loss: 1.315e-04, Time: 28.26
# Parameters are saved in pickle file
# epochs: 110, Loss: 1.268e-04, Time: 27.78
# Parameters are saved in pickle file
# epochs: 120, Loss: 1.322e-04, Time: 27.91
# Parameters are saved in pickle file
# epochs: 130, Loss: 1.233e-04, Time: 27.78
# Parameters are saved in pickle file
# epochs: 140, Loss: 1.234e-04, Time: 27.80
# Parameters are saved in pickle file
# epochs: 150, Loss: 1.274e-04, Time: 27.80
# Parameters are saved in pickle file
# epochs: 160, Loss: 1.164e-04, Time: 28.07
# Parameters are saved in pickle file
# epochs: 170, Loss: 1.217e-04, Time: 28.02
# Parameters are saved in pickle file
# epochs: 180, Loss: 1.189e-04, Time: 27.70
# Parameters are saved in pickle file
# epochs: 190, Loss: 1.224e-04, Time: 27.56
# Parameters are saved in pickle file
# epochs: 200, Loss: 1.489e-04, Time: 27.32
# Parameters are saved in pickle file
# epochs: 210, Loss: 1.140e-04, Time: 27.24
# Parameters are saved in pickle file
# epochs: 220, Loss: 1.161e-04, Time: 27.45
# Parameters are saved in pickle file
# epochs: 230, Loss: 1.173e-04, Time: 27.75
# Parameters are saved in pickle file
# epochs: 240, Loss: 1.145e-04, Time: 27.67
# Parameters are saved in pickle file
# epochs: 250, Loss: 1.248e-04, Time: 27.26
# Parameters are saved in pickle file
# epochs: 260, Loss: 1.204e-04, Time: 27.04
# Parameters are saved in pickle file
# epochs: 270, Loss: 1.114e-04, Time: 27.77
# Parameters are saved in pickle file
# epochs: 280, Loss: 1.118e-04, Time: 28.59
# Parameters are saved in pickle file
# epochs: 290, Loss: 1.193e-04, Time: 28.65
# Parameters are saved in pickle file
# epochs: 300, Loss: 1.104e-04, Time: 28.37
# Parameters are saved in pickle file
# epochs: 310, Loss: 1.112e-04, Time: 28.36
# Parameters are saved in pickle file
# epochs: 320, Loss: 1.107e-04, Time: 28.00
# Parameters are saved in pickle file
# epochs: 330, Loss: 1.092e-04, Time: 28.28
# Parameters are saved in pickle file
# epochs: 340, Loss: 1.098e-04, Time: 28.52
# Parameters are saved in pickle file
# epochs: 350, Loss: 1.249e-04, Time: 28.75
# Parameters are saved in pickle file
# epochs: 360, Loss: 1.100e-04, Time: 28.02
# Parameters are saved in pickle file
# epochs: 370, Loss: 1.117e-04, Time: 27.67
# Parameters are saved in pickle file
# epochs: 380, Loss: 1.095e-04, Time: 27.91
# Parameters are saved in pickle file
# epochs: 390, Loss: 1.057e-04, Time: 27.89
# Parameters are saved in pickle file
# epochs: 400, Loss: 1.020e-04, Time: 27.41
# Parameters are saved in pickle file
# epochs: 410, Loss: 1.015e-04, Time: 27.39
# Parameters are saved in pickle file
# epochs: 420, Loss: 1.036e-04, Time: 27.70
# Parameters are saved in pickle file
# epochs: 430, Loss: 9.950e-05, Time: 27.86
# Parameters are saved in pickle file
# epochs: 440, Loss: 1.046e-04, Time: 27.77
# Parameters are saved in pickle file
# epochs: 450, Loss: 1.045e-04, Time: 28.05
# Parameters are saved in pickle file
# epochs: 460, Loss: 9.996e-05, Time: 28.58
# Parameters are saved in pickle file
# epochs: 470, Loss: 9.607e-05, Time: 29.14
# Parameters are saved in pickle file
# epochs: 480, Loss: 1.007e-04, Time: 28.55
# Parameters are saved in pickle file
# epochs: 490, Loss: 1.066e-04, Time: 28.78
# Parameters are saved in pickle file
# epochs: 500, Loss: 1.047e-04, Time: 29.08
# Parameters are saved in pickle file
# epochs: 510, Loss: 1.107e-04, Time: 28.98
# Parameters are saved in pickle file
# epochs: 520, Loss: 1.046e-04, Time: 28.74
# Parameters are saved in pickle file
# epochs: 530, Loss: 1.012e-04, Time: 29.12
# Parameters are saved in pickle file
# epochs: 540, Loss: 1.124e-04, Time: 29.24
# Parameters are saved in pickle file
# epochs: 550, Loss: 9.538e-05, Time: 27.96
# Parameters are saved in pickle file
# epochs: 560, Loss: 9.472e-05, Time: 27.49
# Parameters are saved in pickle file
# epochs: 570, Loss: 9.236e-05, Time: 27.64
# Parameters are saved in pickle file
# epochs: 580, Loss: 1.110e-04, Time: 28.12
# Parameters are saved in pickle file
# epochs: 590, Loss: 1.017e-04, Time: 27.30
# Parameters are saved in pickle file
# epochs: 600, Loss: 9.714e-05, Time: 27.56
# Parameters are saved in pickle file
# epochs: 610, Loss: 9.228e-05, Time: 28.00
# Parameters are saved in pickle file
# epochs: 620, Loss: 1.027e-04, Time: 28.04
# Parameters are saved in pickle file
# epochs: 630, Loss: 9.829e-05, Time: 27.48
# Parameters are saved in pickle file
# epochs: 640, Loss: 1.002e-04, Time: 27.59
# Parameters are saved in pickle file
# epochs: 650, Loss: 9.935e-05, Time: 28.30
# Parameters are saved in pickle file
# epochs: 660, Loss: 9.506e-05, Time: 27.81
# Parameters are saved in pickle file
# epochs: 670, Loss: 9.131e-05, Time: 27.97
# Parameters are saved in pickle file
# epochs: 680, Loss: 1.059e-04, Time: 27.65
# Parameters are saved in pickle file
# epochs: 690, Loss: 1.002e-04, Time: 28.05
# Parameters are saved in pickle file
# epochs: 700, Loss: 9.327e-05, Time: 27.50
# Parameters are saved in pickle file
# epochs: 710, Loss: 9.172e-05, Time: 27.48
# Parameters are saved in pickle file
# epochs: 720, Loss: 1.066e-04, Time: 27.75
# Parameters are saved in pickle file
# epochs: 730, Loss: 9.393e-05, Time: 27.58
# Parameters are saved in pickle file
# epochs: 740, Loss: 9.251e-05, Time: 27.80
# Parameters are saved in pickle file
# epochs: 750, Loss: 8.807e-05, Time: 28.02
# Parameters are saved in pickle file
# epochs: 760, Loss: 9.159e-05, Time: 27.66
# Parameters are saved in pickle file
# epochs: 770, Loss: 8.893e-05, Time: 27.67
# Parameters are saved in pickle file
# epochs: 780, Loss: 8.698e-05, Time: 27.59
# Parameters are saved in pickle file
# epochs: 790, Loss: 9.503e-05, Time: 27.48
# Parameters are saved in pickle file
# epochs: 800, Loss: 8.737e-05, Time: 27.68
# Parameters are saved in pickle file
# epochs: 810, Loss: 8.639e-05, Time: 27.73
# Parameters are saved in pickle file
# epochs: 820, Loss: 8.814e-05, Time: 27.44
# Parameters are saved in pickle file
# epochs: 830, Loss: 8.573e-05, Time: 28.30
# Parameters are saved in pickle file
# epochs: 840, Loss: 9.027e-05, Time: 28.66
# Parameters are saved in pickle file
# epochs: 850, Loss: 8.903e-05, Time: 29.17
# Parameters are saved in pickle file
# epochs: 860, Loss: 9.451e-05, Time: 28.74
# Parameters are saved in pickle file
# epochs: 870, Loss: 9.227e-05, Time: 28.55
# Parameters are saved in pickle file
# epochs: 880, Loss: 8.086e-05, Time: 28.18
# Parameters are saved in pickle file
# epochs: 890, Loss: 8.832e-05, Time: 28.43
# Parameters are saved in pickle file
# epochs: 900, Loss: 9.015e-05, Time: 28.43
# Parameters are saved in pickle file
# epochs: 910, Loss: 9.558e-05, Time: 28.70
# Parameters are saved in pickle file
# epochs: 920, Loss: 8.409e-05, Time: 28.57
# Parameters are saved in pickle file
# epochs: 930, Loss: 8.922e-05, Time: 27.43
# Parameters are saved in pickle file
# epochs: 940, Loss: 8.834e-05, Time: 27.33
# Parameters are saved in pickle file
# epochs: 950, Loss: 8.171e-05, Time: 27.43
# Parameters are saved in pickle file
# epochs: 960, Loss: 8.221e-05, Time: 27.66
# Parameters are saved in pickle file
# epochs: 970, Loss: 8.660e-05, Time: 28.02
# Parameters are saved in pickle file
# epochs: 980, Loss: 8.445e-05, Time: 27.37
# Parameters are saved in pickle file
# epochs: 990, Loss: 8.340e-05, Time: 27.05
# Parameters are saved in pickle file
# Saving the predictions for time step: [7.]
# Predictions are saved in pickle file
# Previous predictions are loaded from pickle file
# Previous predictions are saved in pickle file
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>█▂▃▁▁▁▁▂▁▂▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Previous_loss</td><td>█▄▇▂▂▂▂▂▂▂▂▂▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>▇▇▄▆▂▅▃▅▃▅▃▅▂▃▂▂█▄▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▄▄▃▂▂▂▂▂▂▂▂▁▂▁▁▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>▁▆▁▅▇▇▇▅▅█▆█▇▆▇▆███▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>time step 2</td><td>▁▆▃▅▆▅▅▅▅▇▅▆▇▆▆▆█▇█▅▆▆▆▆▆▆▆▆▆▆▆▆▇▆▇▆▆▆▆▆</td></tr><tr><td>time step 3</td><td>▁▆▂▆▅▅▆▇▅▄▂▆▇▄▅▇▇██▆▆▆▆▅▆▆▆▆▅▆▆▅▆▆▆▅▆▆▆▆</td></tr><tr><td>time step 4</td><td>▁▇▃▄▇▄▂▅▄█▅▆▆█▇▆▇▇▅▄▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>time step 5</td><td>▄▄▅▄▄▄▅▅▂▆▁▃▅▄▅▄▃▅▃█▄▄▄▄▅▄▄▄▄▄▄▄▄▄▅▄▄▄▄▄</td></tr><tr><td>time step 6</td><td>█▁▅▆▄▅▆▆▄▃▅▄▄▄▄▅▄▄▆▅▄▅▅▄▄▄▅▅▄▄▅▅▅▅▅▅▄▄▄▄</td></tr><tr><td>time step 7</td><td>▃▁▂▂▃▄▅▅▅▆▆▆▇▇▇▇▇████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>4e-05</td></tr><tr><td>Initial_loss</td><td>0.0</td></tr><tr><td>Previous_loss</td><td>3e-05</td></tr><tr><td>Residual_loss</td><td>1e-05</td></tr><tr><td>Total_loss</td><td>8e-05</td></tr><tr><td>time step 1</td><td>0.1708</td></tr><tr><td>time step 2</td><td>0.17471</td></tr><tr><td>time step 3</td><td>0.17461</td></tr><tr><td>time step 4</td><td>0.1773</td></tr><tr><td>time step 5</td><td>0.19751</td></tr><tr><td>time step 6</td><td>0.1766</td></tr><tr><td>time step 7</td><td>0.17719</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">silvery-dragon-8</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/28onv8fk" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_0data_ib_missing_inlet/runs/28onv8fk</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221013_204813-28onv8fk\logs</code>

# %% [markdown]
# # Run this code snippet to load the model

# %%
'''
This code snippet loads the bc pinn model, for some reason its not predicting well for time t=0 ?
'''

if __name__ == "__main__":

    
    N_train = 25000
    batch_size=1000
    Reynolds = 100
    layers = [3]+10*[100]+[3]
    
    # Enter the latest timestep for which the model has be previous trained on.
    time_step_test = 7

    # Loading the initial and the boundary conditions for the next timestep
    domain, initial, boundary,domain_data = load_data(time_step_test)
    datalist=load_complete_data()


    # Loading the predictions of the final timestep of the first timesegment as the initial conditions of this time segment
    prediction_file='uv_preds_lts_exp2'
    u,v,t=read_uv_values(prediction_file)

    # Initial condition guided learning
    # Altering the initial conditions data, only uvt values are changed pressure values are untouched.
    initial[:,2]=t[:,0]
    initial[:,3]=u[:,0]
    initial[:,4]=v[:,0]

    # Loading the previous timesegment data
    prev_name='prev_data_predictions_lts_exp2'
    prevtimedata=read_prev_data(prev_name)

    # Enter the names of the files :
    '''
    params_name : name of the file where you want to save the weights and biases, LOAD THE MODEL EVERYTIME, SINCE ITS THE SAME
                  MODEL THAT IS BEING TRAINED OVER DIFFERNT TIMESEGMENTS, WITH FOCUS ON PREV TIME SEGMENTS                  
    loss_name   : name of the file where you want to save the loss components
    prev_name   : name of the file where you want to save the predictions of each time step in the segment
    '''

    params_name = 'params_exp2'
    loss_name   = 'Loss_re100_truly_sparse'

    # Start the Training process
    with tf.device('/gpu:0'):

        bc_pinn_model_test = bc_pinn_t (domain,initial,boundary,domain_data,prevtimedata,datalist,
                                       N_train,batch_size,
                                       layers,re=Reynolds,
                                       load_model=True,filedr=params_name,
                                       freeze = 5,timestep=time_step_test,
                                       savewandb=params_name,saveloss=loss_name)
# Out:
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6

# %% [markdown]
# # Run this code snippet for checking

# %%
# Run this for Prediction for a network of 3 10*100 3 
def test_check_predictions(test_time_step,model,plot=False):
    '''
    This code works for specific time steps like 0,1,2,.... and not for intermediate timesteps like 0.1,0.2,0.3......
    '''

    X_star,Y_star=load_testdata(test_time_step)
    u_pred, v_pred, p_pred = model.predict(X_star[0],X_star[1],X_star[2])

    # # Error
    error_u = np.linalg.norm(Y_star[0] - u_pred, 2) / np.linalg.norm(Y_star[0], 2)
    error_v = np.linalg.norm(Y_star[1] - v_pred, 2) / np.linalg.norm(Y_star[1], 2)

    # Mean corrected pressure error
    p_predm=p_pred-np.mean(p_pred)
    p_truem=Y_star[2]-np.mean(Y_star[2])

    error_p = np.linalg.norm(p_truem - p_predm, 2) / np.linalg.norm(p_truem, 2)

    print("Errors at timestep:", np.unique(X_star[2]))
    print("------------------------------------------------")
    print('Error u: %e' % error_u)
    print('Error v: %e' % error_v)
    print('Error p: %e' % error_p)
    
    if plot == True:
        uplot=np.reshape(u_pred,(100,100))
        plt.imshow(uplot)
        plt.title("Predicted u_velocity")
        plt.colorbar()
#         plt.savefig('pred'+str(test_time_step))
        plt.show()

        upl=np.reshape(Y_star[0],(100,100))
        plt.imshow(upl)
        plt.title("Actual u_velocity")
        plt.colorbar()
#         plt.savefig('actual'+str(test_time_step))
        plt.show()
    return error_u,error_v

# %%
eu=[]
ev=[]
for i in np.arange(0,8,1):
    eua,eva=test_check_predictions(round(i,3),bc_pinn_model_test,plot=True)
    eu.append(eua)
    ev.append(eva)
# Out:
# Errors at timestep: [0.]
# ------------------------------------------------
# Error u: 1.049110e-02
# Error v: 4.757209e-02
# Error p: 3.718852e+00
# Errors at timestep: [1.]
# ------------------------------------------------
# Error u: 1.927580e-01
# Error v: 8.904895e-01
# Error p: 4.180834e+00
# Errors at timestep: [2.]
# ------------------------------------------------
# Error u: 1.887498e-01
# Error v: 8.523658e-01
# Error p: 1.905713e+00
# Errors at timestep: [3.]
# ------------------------------------------------
# Error u: 1.883210e-01
# Error v: 8.982567e-01
# Error p: 2.693884e+00
# Errors at timestep: [4.]
# ------------------------------------------------
# Error u: 1.926551e-01
# Error v: 8.776875e-01
# Error p: 2.634102e+00
# Errors at timestep: [5.]
# ------------------------------------------------
# Error u: 2.296562e-01
# Error v: 8.846160e-01
# Error p: 1.678146e+00
# Errors at timestep: [6.]
# ------------------------------------------------
# Error u: 1.936859e-01
# Error v: 9.231450e-01
# Error p: 1.000572e+00
# Errors at timestep: [7.]
# ------------------------------------------------
# Error u: 1.953320e-01
# Error v: 8.878199e-01
# Error p: 1.238013e+00

# %%
X_star,Y_star=load_testdata(6)
u_pred, v_pred, p_pred = bc_pinn_model_test.predict(X_star[0],X_star[1],X_star[2])
err=u_pred-Y_star[0]
err=np.reshape(err,(100,100))

plt.imshow(err)
plt.colorbar()

# %%
from scipy.interpolate import make_interp_spline as mis

nsfdata=pd.read_csv(r"C:\Users\user1\Desktop\NSFNET_basic.csv").to_numpy()
nsfdata2=pd.read_csv(r"C:\Users\user1\Desktop\NSFNET_dynamic.csv").to_numpy()
for i in range(nsfdata.shape[1]):
    nsfdata[i,0]=round(nsfdata[i,0],3)
    
for i in range(nsfdata2.shape[1]):
    nsfdata2[i,0]=round(nsfdata2[i,0],3)

t_nsf=nsfdata[:,0]
eu_nsf=nsfdata[:,1]
eu_nsf2=nsfdata2[:,1]

# Basic 
xyspline=mis(t_nsf,eu_nsf)
x=np.linspace(t_nsf.min(),t_nsf.max(),500)
y=xyspline(x)
plt.plot(x,y)
# Dynamic weights
xyspline3=mis(t_nsf,eu_nsf2)
y3=xyspline3(x)
plt.plot(x,y3)

# MY model
t=[i for i in np.arange(0,8,1)]
xyspline2=mis(t,eu)
y2=xyspline2(x)
plt.plot(x,y2)

plt.legend(['NSFNET Basic','NSFNET Dynamic','seq2seq model with 1% data from inside domain'])
plt.title("Comparison of relative l2 errors with NSFNET paper")
plt.xlabel("Time steps")
plt.ylabel("Relative l2 error")
plt.show()

# %%
from scipy.interpolate import make_interp_spline as mis

nsfdatav=pd.read_csv(r"C:\Users\user1\Desktop\vvel_basic.csv").to_numpy()
nsfdatav2=pd.read_csv(r"C:\Users\user1\Desktop\vvel_dynamic.csv").to_numpy()
for i in range(nsfdatav.shape[1]):
    nsfdatav[i,0]=round(nsfdatav[i,0],3)
    
for i in range(nsfdatav2.shape[1]):
    nsfdatav2[i,0]=round(nsfdatav2[i,0],3)

t_nsf=nsfdatav[:,0]
eu_nsf=nsfdatav[:,1]
eu_nsf2=nsfdatav2[:,1]

# Basic 
xyspline=mis(t_nsf,eu_nsf)
x=np.linspace(t_nsf.min(),t_nsf.max(),500)
y=xyspline(x)
plt.plot(x,y)
# Dynamic weights
xyspline3=mis(t_nsf,eu_nsf2)
y3=xyspline3(x)
plt.plot(x,y3)

# MY model
t=[i for i in np.arange(0,8,1)]
xyspline2=mis(t,ev)
y2=xyspline2(x)
plt.plot(x,y2)

plt.legend(['NSFNET no weights','NSFNET Dynamic weights','seq2seq model with 1% data from inside domain'])
plt.title("Comparison of v velocity relative l2 errors with NSFNET paper")
plt.xlabel("Time steps")
plt.ylabel("Relative l2 error")
plt.show()

# %% [markdown]
# # Run this code segment to save the errors

# %%
def save_error_data(file_name,eu):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\Missing BCs")
    my_path=root_path/file_name

    with open(my_path,'wb') as f:
        pickle.dump(eu,f)
        print("Errors are saved in pickle file")

# %%
def load_error_data(file_name):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_results\Missing BCs")
    my_path=root_path/file_name

    # returns the weights and biases of the network as np array
    with open(my_path,'rb') as f:
        eu_load=pickle.load(f)
    return eu_load

# %% [markdown]
# # Saving the errors

# %%
save_error_data('1data_lt_ib_missing_inlet',eu)
# Out:
# Errors are saved in pickle file
