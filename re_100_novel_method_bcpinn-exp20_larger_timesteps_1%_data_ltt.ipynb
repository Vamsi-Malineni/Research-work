# %%
import tensorflow as tf
import numpy as np
import time
import pandas as pd
import math
import pickle
from pathlib import Path
import matplotlib.pyplot as plt
import wandb

# set random seed
np.random.seed(1234)
tf.compat.v1.set_random_seed(1234)

tf.compat.v1.disable_eager_execution()

# %% [markdown]
# # Initializing wandb functionality

# %%
# !wandb login --relogin
# Copy and paste this api key: 822244d22c29151b0b6501c81c4e22a5c5a0843f

entity_name="vamsi_malineni6"
project_name="bc_pinn_ltd_1data_longer_training"

wandb.init(entity=entity_name,project=project_name)
# Finish the dummy run started after first initializing
wandb.run.finish()

# # Delete the dummy run from the wandb workspace 
# api=wandb.Api()
# run_id=wandb.run.id
# run=ap.run(str(entity_name)+"/"+str(project_name)+"/"+str(run_id))
# run.delete()
# Out:
# 'wandb' is not recognized as an internal or external command,
# operable program or batch file.
# wandb: Currently logged in as: vamsi_malineni6. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20220916_230119-3kl2gp9m</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/3kl2gp9m" target="_blank">fancy-durian-5</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.0, max…
# Synced <strong style="color:#cdcd00">fancy-durian-5</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/3kl2gp9m" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/3kl2gp9m</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220916_230119-3kl2gp9m\logs</code>

# %%
class bc_pinn_t0:
    # Initialize the class
    def __init__(self,domain,initial,boundary,domaindata,datalist,
                 ntrain,batch_size,layers,re,
                 load_model=False,filedr='',freeze=0,timestep=0,
                 savewandb='',saveloss=''):
        
        self.domain   = domain
        self.initial  = initial
        self.boundary = boundary
        self.datalist = datalist
        self.domain_data = domaindata
        
        self.freeze   = freeze
        self.time_step = timestep
        
        self.params_name = savewandb
        self.loss_name   = saveloss
        
        self.ntrain = ntrain
        self.batch_size= batch_size
        
        # Calling domain data for initializing the neural network before entering the Adam optimization
        self.xa=self.domain[:,0].reshape(self.domain[:,0].shape[0],1)
        self.ya=self.domain[:,1].reshape(self.domain[:,1].shape[0],1)
        self.ta=self.domain[:,2].reshape(self.domain[:,2].shape[0],1)
        self.ua=self.domain[:,3].reshape(self.domain[:,3].shape[0],1)
        self.va=self.domain[:,4].reshape(self.domain[:,4].shape[0],1)
        
        
        X = np.concatenate([self.xa,self.ya,self.ta], 1)

        self.lowb = X.min(0) 
        self.upb = X.max(0)
        
        # Calling boundary and initial conditions data as they dont change through the adam iterations
                
        self.x0=self.initial[:,0].reshape(self.initial[:, 0].shape[0], 1)
        self.y0=self.initial[:,1].reshape(self.initial[:, 1].shape[0], 1)
        self.t0=self.initial[:,2].reshape(self.initial[:, 2].shape[0], 1)
        self.u0=self.initial[:,3].reshape(self.initial[:, 3].shape[0], 1)
        self.v0=self.initial[:,4].reshape(self.initial[:, 4].shape[0], 1)
        
        self.xb=self.boundary[:,0].reshape(self.boundary[:, 0].shape[0], 1)
        self.yb=self.boundary[:,1].reshape(self.boundary[:, 1].shape[0], 1)
        self.tb=self.boundary[:,2].reshape(self.boundary[:, 2].shape[0], 1)
        self.ub=self.boundary[:,3].reshape(self.boundary[:, 3].shape[0], 1)
        self.vb=self.boundary[:,4].reshape(self.boundary[:, 4].shape[0], 1)
        
  
        self.layers = layers
        self.re = re

        # Initialize NN
        if load_model ==False:
            self.weights, self.biases = self.initialize_NN(self.layers)
        else:
            self.weights,self.biases = self.load_parameters(filedr,self.layers,self.freeze)
            
        

        # tf placeholders and graph
        
        self.sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        self.learning_rate = tf.compat.v1.placeholder(tf.float32, shape=[])
        
        # Initial conditions placeholders
        self.x_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.x0.shape[1]])
        self.y_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.y0.shape[1]])
        self.t_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.t0.shape[1]])
        self.u_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.u0.shape[1]])
        self.v_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.v0.shape[1]])
        
        # Boundary conditions placeholders
        self.x_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xb.shape[1]])
        self.y_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.yb.shape[1]])
        self.t_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.tb.shape[1]])
        self.u_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ub.shape[1]])
        self.v_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.vb.shape[1]])
        
        # Domain placeholders having the size of batch_size
        self.x_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.y_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.t_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        # Domain data placeholders 
        self.xdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.ydata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.tdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        self.udata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ua.shape[1]])
        self.vdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.va.shape[1]])
        
        # Initial conditions predictions
        self.u_ini_pred, self.v_ini_pred, self.p_ini_pred =\
            self.net_NS(self.x_ini_tf, self.y_ini_tf, self.t_ini_tf)
        
        # Boundary conditions predictions
        self.u_boundary_pred, self.v_boundary_pred, self.p_boundary_pred = \
            self.net_NS(self.x_boundary_tf, self.y_boundary_tf, self.t_boundary_tf)
        
        # Domain data predictions
        self.u_dom_pred,self.v_dom_pred,_=\
            self.net_NS(self.xdata_tf,self.ydata_tf,self.tdata_tf)
        
        # Domain predictions
        self.u_pred, self.v_pred, self.p_pred, self.f_u_pred, self.f_v_pred, self.f_e_pred = \
            self.net_f_NS(self.x_tf, self.y_tf, self.t_tf)

        alpha, beta = 1, 1

        # set loss function
        self.initial_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.u_ini_tf - self.u_ini_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.v_ini_tf - self.v_ini_pred))
        
        self.boundary_loss = beta * tf.reduce_mean(input_tensor=tf.square(self.u_boundary_tf - self.u_boundary_pred)) + \
                             beta * tf.reduce_mean(input_tensor=tf.square(self.v_boundary_tf - self.v_boundary_pred))

        self.domdata_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.udata_tf - self.u_dom_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.vdata_tf - self.v_dom_pred))

        self.residual_loss = tf.reduce_mean(input_tensor=tf.square(self.f_u_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_v_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_e_pred))

        
        
        self.loss =  self.initial_loss + self.boundary_loss + self.residual_loss + self.domdata_loss
        
        self.loss_i=[]
        self.loss_b=[]
        self.loss_r=[]
        self.loss_d=[]

        self.optimizer_Adam = tf.compat.v1.train.AdamOptimizer(self.learning_rate)
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)

        init = tf.compat.v1.global_variables_initializer()
        self.sess.run(init)
        

#===========================================================================================================#
#====================================Transfer Learning======================================================#
#===========================================================================================================#
    def save_parameters(self,fileDr):
        weights=self.sess.run(self.weights)
        biases= self.sess.run(self.biases)
        
                       
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp20")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([weights,biases],f)
            print("Parameters are saved in pickle file")

    def load_parameters(self,fileDr,layers,freeze):
        tf_weights=[]
        tf_biases=[]
        num_layers=len(layers)
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp20")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            weights,biases=pickle.load(f)
            assert num_layers == (len(weights)+1)
        
        # returns the weights and biases of the network as tf.variable, with few of the layers frozen for trainin
        for num in range(0,num_layers-1):
            if num<freeze:
                tf_weights.append ( tf.Variable (weights[num],trainable ='False'))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='False'))
            else:
                tf_weights.append ( tf.Variable (weights[num],trainable ='True'))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='True' ))
        
        print("Parameters are loaded succesffuly")
        
        return tf_weights,tf_biases
    
#===========================================================================================================#
#========================================saving loss values=================================================#
#===========================================================================================================#
    def save_loss(self,fileDr,tf_dict):
        self.loss_i.append(self.sess.run(self.initial_loss,tf_dict))
        self.loss_b.append(self.sess.run(self.boundary_loss,tf_dict))
        self.loss_r.append(self.sess.run(self.residual_loss,tf_dict))
        self.loss_d.append(self.sess.run(self.domdata_loss,tf_dict))
                       
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp20")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([self.loss_i,self.loss_b,self.loss_r,self.loss_d],f)
            print("Loss are saved in pickle file")
    
    def load_loss(self,fileDr):
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp20")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            initial,boundary,residual,datadomain=pickle.load(f)
        
        print("Losses are loaded successfully")
        
        return initial,boundary,residual,datadomain
    

    
#===========================================================================================================#
#===========================================================================================================#
#===========================================================================================================#
 

# initialize the weight and bias
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

# xavier used to initialize the weight
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

# generate the neural network
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = 2.0 * (X - self.lowb) / (self.upb - self.lowb) - 1.0
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
#             H = tf.tanh(tf.add(tf.matmul(H, W), b))
            H = tf.keras.activations.swish(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

# ###################without assume###############
    # supervised data driven
    def net_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        return u, v, p

    # unsupervised NS residual
    def net_f_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        u_t = tf.gradients(ys=u, xs=t)[0] 
        u_x = tf.gradients(ys=u, xs=x)[0] 
        u_y = tf.gradients(ys=u, xs=y)[0] 
        u_xx = tf.gradients(ys=u_x, xs=x)[0] 
        u_yy = tf.gradients(ys=u_y, xs=y)[0] 
        
        v_t = tf.gradients(ys=v, xs=t)[0] 
        v_x = tf.gradients(ys=v, xs=x)[0] 
        v_y = tf.gradients(ys=v, xs=y)[0] 
        v_xx = tf.gradients(ys=v_x, xs=x)[0] 
        v_yy = tf.gradients(ys=v_y, xs=y)[0] 

        p_x = tf.gradients(ys=p, xs=x)[0] 
        p_y = tf.gradients(ys=p, xs=y)[0] 

        f_u = u_t + (u * u_x + v * u_y) + p_x - (1/self.re) * (u_xx + u_yy)
        f_v = v_t + (u * v_x + v * v_y) + p_y - (1/self.re) * (v_xx + v_yy)
        f_e = u_x + v_y

        return u, v, p, f_u, f_v, f_e

#===========================================================================================================#
#===========================Predicting and finding error every 10 epochs====================================#
#===========================================================================================================#
   
    
    def predict(self, x_star, y_star, t_star):

        tf_dict = {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star}

        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)

        return u_star, v_star, p_star
    
    def load_testdata(self,time_step):
        
        # Converting the time_step from decimal to integer 0.1 --> 1
        ts=int(10*time_step)

        # Loading the complete list of data 
        data_list=self.datalist

        # Extracting the data for the given range of time steps [0,0.1] and so on
        dt=0.1
        times=[round(i,3) for i in np.arange(0,7+dt,dt)]

        # Finding the indexes of initial and final timestep from the times list
        t1=times.index(round((time_step-1.0),2))
        t2=times.index(time_step)

        temp=[]
        # Excluding INITIAL DATA from the collocation points, to make sure that the model is not overfitting on
        # initial points, as there is u,v data available for the model. 

        for i in range(t1,t2+1):
            if i<t2+1:
                temp.append(data_list[i])

        # data stores the final timestep data for the given time segment

        data=np.concatenate(temp[4:],axis=0)

        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]

        return X_star,Y_star
    
    def find_error(self,test_time_step):
        
        X_star,Y_star=self.load_testdata(test_time_step)
        u_pred,_,_ = self.predict(X_star[0],X_star[1],X_star[2])
        
        error_u = np.linalg.norm(Y_star[0] - u_pred, 2) / np.linalg.norm(Y_star[0], 2)
        

        return error_u
        
#===========================================================================================================#
#===========================ADAM TRAINING FUNCTION==========================================================#
#===========================================================================================================#
   
#IMPORTANT NOTES for a given TIME SEGMENT consisting of (5*10000=50000) points in the grid.

# (1) Randomly sampling 1000 datapoints every iteration from 38416 collocation points
#     effectively per epoch the model would see 25000 collocation points, which is 65% of sampled colloc points

# (2) Randomly sampling 250 datapoints every iteration from 19208 data points,
#     effectively per epoch the model would see 6250 data points. which is 32% of the sampled data points
 
# (3) The model would see 10000 initial conditions data points per iteration per epoch
#
# (4) The model would see 1584 boundary conditions points per iteration per epoch


    def Adam_train(self, epoch=5000, learning_rate=1e-3):
    
        start_time = time.time()
        
        iters = int(self.ntrain / self.batch_size)
        
        for it in range(epoch):
            
            for i in (range(iters)):
            
                idx=  np.random.choice(self.domain.shape[0],self.batch_size,replace=False)
                didx= np.random.choice(self.domain_data.shape[0],250,replace=False)
                
                self.data_domain=self.domain[idx,:]
                self.data_driven=self.domain_data[didx,:]
                
                xd=self.data_domain[:,0].reshape(self.data_domain[:, 0].shape[0], 1)
                yd=self.data_domain[:,1].reshape(self.data_domain[:, 1].shape[0], 1)
                td=self.data_domain[:,2].reshape(self.data_domain[:, 2].shape[0], 1)

                xdata=self.data_driven[:,0].reshape(self.data_driven[:, 0].shape[0], 1)
                ydata=self.data_driven[:,1].reshape(self.data_driven[:, 1].shape[0], 1)
                tdata=self.data_driven[:,2].reshape(self.data_driven[:, 2].shape[0], 1)
                udata=self.data_driven[:,3].reshape(self.data_driven[:, 3].shape[0], 1)
                vdata=self.data_driven[:,4].reshape(self.data_driven[:, 4].shape[0], 1)
                    
                Xd = np.concatenate([xd,yd,td], 1)
                
                # In contrast the model would see 10000 initial data points every iteration and every epoch
                # The model would see 1584 boundary conditions points every iteration and every epoch
                
                tf_dict = {self.x_ini_tf: self.x0, 
                           self.y_ini_tf: self.y0,
                           self.t_ini_tf: self.t0, 
                           self.u_ini_tf: self.u0,
                           self.v_ini_tf: self.v0, 
                           
                           self.x_boundary_tf: self.xb,
                           self.y_boundary_tf: self.yb, 
                           self.t_boundary_tf: self.tb,
                           self.u_boundary_tf: self.ub, 
                           self.v_boundary_tf: self.vb,
                           
                           self.x_tf: xd, 
                           self.y_tf: yd, 
                           self.t_tf: td,
                           
                           self.xdata_tf: xdata, 
                           self.ydata_tf: ydata, 
                           self.tdata_tf: tdata,
                           self.udata_tf: udata,
                           self.vdata_tf: vdata,
                           
                           self.learning_rate: learning_rate}

                self.sess.run(self.train_op_Adam, tf_dict)
            
            if it % 10 == 0:
                
                elapsed = time.time() - start_time
                
                t_loss= self.sess.run(self.loss, tf_dict)
                i_loss= self.sess.run(self.initial_loss,tf_dict)
                b_loss= self.sess.run(self.boundary_loss,tf_dict)
                r_loss= self.sess.run(self.residual_loss,tf_dict)
                d_loss= self.sess.run(self.domdata_loss,tf_dict)
                
                # Saving the loss values in a pickle file
#                 self.save_loss(self.loss_name,tf_dict)
                
                # Finding the error value at given timestep for every 10 epochs
                eu1= self.find_error(1)
                eu2= self.find_error(2)
                eu3= self.find_error(3)
                eu4= self.find_error(4)
                eu5= self.find_error(5)
                eu6= self.find_error(6)
                eu7= self.find_error(7)
                
                # Logging the loss values and error values to wandb workspace:
                log_dict={"Total_loss":t_loss,"Initial_loss":i_loss,\
                         "Boundary_loss":b_loss,"Residual_loss":r_loss,\
                         "Data_loss":d_loss,\
                         "time step 1":eu1,\
                         "time step 2":eu2,\
                         "time step 3":eu3,\
                         "time step 4":eu4,\
                         "time step 5":eu5,\
                         "time step 6":eu6,\
                         "time step 7":eu7
                         }
                         
                
                wandb.log(log_dict)
                
                print('epochs: %d, Loss: %.3e, Time: %.2f' %
                      (it, t_loss, elapsed))
                
                start_time = time.time()
            
            if it % 1000 == 0 and it > 0:
                self.save_parameters(self.params_name)

# %% [markdown]
# # This code snippet is for training for timesegments other than initial one

# %%
class bc_pinn_t:
    # Initialize the class
    def __init__(self,domain,initial,boundary,domaindata,prevtimedata,datalist,
                 ntrain,batch_size,layers,re,
                 load_model=False,filedr='',freeze=0,timestep=0
                 ,savewandb='',saveloss=''):
        
        self.domain   = domain
        self.initial  = initial
        self.boundary = boundary
        self.domain_data = domaindata
        self.prev_data = prevtimedata
        self.datalist = datalist
        
        self.freeze = freeze
        self.time_step = timestep
        
        self.params_name = savewandb
        self.loss_name   = saveloss
        
        self.ntrain = ntrain
        self.batch_size= batch_size
        #=========================================================================================================#
        
        # Calling domain data for initializing the neural network before entering the Adam optimization
        self.xa=self.domain[:,0].reshape(self.domain[:,0].shape[0],1)
        self.ya=self.domain[:,1].reshape(self.domain[:,1].shape[0],1)
        self.ta=self.domain[:,2].reshape(self.domain[:,2].shape[0],1)
        self.ua=self.domain[:,3].reshape(self.domain[:,3].shape[0],1)
        self.va=self.domain[:,4].reshape(self.domain[:,4].shape[0],1)
        
        # This creates an array of collocation points only for the domain
        X = np.concatenate([self.xa,self.ya,self.ta], 1)
        self.lowb = X.min(0) 
        self.upb = X.max(0)
        
        #=========================================================================================================#
        
        # Calling boundary and initial conditions data as they dont change through the adam iterations
                
        self.x0=self.initial[:,0].reshape(self.initial[:, 0].shape[0], 1)
        self.y0=self.initial[:,1].reshape(self.initial[:, 1].shape[0], 1)
        self.t0=self.initial[:,2].reshape(self.initial[:, 2].shape[0], 1)
        self.u0=self.initial[:,3].reshape(self.initial[:, 3].shape[0], 1)
        self.v0=self.initial[:,4].reshape(self.initial[:, 4].shape[0], 1)
        
        self.xb=self.boundary[:,0].reshape(self.boundary[:, 0].shape[0], 1)
        self.yb=self.boundary[:,1].reshape(self.boundary[:, 1].shape[0], 1)
        self.tb=self.boundary[:,2].reshape(self.boundary[:, 2].shape[0], 1)
        self.ub=self.boundary[:,3].reshape(self.boundary[:, 3].shape[0], 1)
        self.vb=self.boundary[:,4].reshape(self.boundary[:, 4].shape[0], 1)
        
  
        self.layers = layers
        self.re = re

        # Initialize NN
        if load_model ==False:
            self.weights, self.biases = self.initialize_NN(self.layers)
        else:
            self.weights,self.biases = self.load_parameters(filedr,self.layers,self.freeze)
            
        

        # tf placeholders and graph
        
        self.sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        self.learning_rate = tf.compat.v1.placeholder(tf.float32, shape=[])
        
        # Initial conditions placeholders
        self.x_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.x0.shape[1]])
        self.y_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.y0.shape[1]])
        self.t_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.t0.shape[1]])
        self.u_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.u0.shape[1]])
        self.v_ini_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.v0.shape[1]])
        
        # Boundary conditions placeholders
        self.x_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xb.shape[1]])
        self.y_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.yb.shape[1]])
        self.t_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.tb.shape[1]])
        self.u_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ub.shape[1]])
        self.v_boundary_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.vb.shape[1]])
        
        # Domain placeholders having the size of batch_size
        self.x_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.y_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.t_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        # Domain data placeholders 
        self.xdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.xa.shape[1]])
        self.ydata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ya.shape[1]])
        self.tdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ta.shape[1]])
        
        self.udata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.ua.shape[1]])
        self.vdata_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.va.shape[1]])
        
        # Previous timestep placeholders
        self.xtime_tf = tf.compat.v1.placeholder(tf.float32)
        self.ytime_tf = tf.compat.v1.placeholder(tf.float32)
        self.ttime_tf = tf.compat.v1.placeholder(tf.float32)
        self.utime_tf = tf.compat.v1.placeholder(tf.float32)
        self.vtime_tf = tf.compat.v1.placeholder(tf.float32)
        
        
        # Initial conditions predictions
        self.u_ini_pred, self.v_ini_pred, self.p_ini_pred =\
            self.net_NS(self.x_ini_tf, self.y_ini_tf, self.t_ini_tf)
        
        # Boundary conditions predictions
        self.u_boundary_pred, self.v_boundary_pred, self.p_boundary_pred = \
            self.net_NS(self.x_boundary_tf, self.y_boundary_tf, self.t_boundary_tf)
        
        # Domain data predictions
        self.u_dom_pred,self.v_dom_pred,_=\
            self.net_NS(self.xdata_tf,self.ydata_tf,self.tdata_tf)
        
        # Domain residual predictions
        self.u_pred, self.v_pred, self.p_pred, self.f_u_pred, self.f_v_pred, self.f_e_pred = \
            self.net_f_NS(self.x_tf, self.y_tf, self.t_tf)
        
        # Previous time step predictions
        self.u_time_pred,self.v_time_pred,_=\
            self.net_NS(self.xtime_tf,self.ytime_tf,self.ttime_tf)
        
        
        alpha, beta = 1, 1

        # set loss function
        self.initial_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.u_ini_tf - self.u_ini_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.v_ini_tf - self.v_ini_pred))
        
        self.boundary_loss = beta * tf.reduce_mean(input_tensor=tf.square(self.u_boundary_tf - self.u_boundary_pred)) + \
                             beta * tf.reduce_mean(input_tensor=tf.square(self.v_boundary_tf - self.v_boundary_pred))

        self.domdata_loss  = alpha * tf.reduce_mean(input_tensor=tf.square(self.udata_tf - self.u_dom_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.vdata_tf - self.v_dom_pred))
        
        self.prevtime_loss = alpha * tf.reduce_mean(input_tensor=tf.square(self.utime_tf - self.u_time_pred)) + \
                             alpha * tf.reduce_mean(input_tensor=tf.square(self.vtime_tf - self.v_time_pred))
        
        
        self.residual_loss = tf.reduce_mean(input_tensor=tf.square(self.f_u_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_v_pred)) + \
                             tf.reduce_mean(input_tensor=tf.square(self.f_e_pred))

        
        
        self.loss =  self.initial_loss + self.boundary_loss + self.residual_loss + self.domdata_loss + self.prevtime_loss
        
        self.loss_i=[]
        self.loss_b=[]
        self.loss_r=[]
        self.loss_d=[]
        self.loss_p=[]

        self.optimizer_Adam = tf.compat.v1.train.AdamOptimizer(self.learning_rate)
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)

        init = tf.compat.v1.global_variables_initializer()
        self.sess.run(init)
        

#===========================================================================================================#
#====================================Transfer Learning======================================================#
#===========================================================================================================#
    def save_parameters(self,fileDr):
        weights=self.sess.run(self.weights)
        biases= self.sess.run(self.biases)
        
                       
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp20")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([weights,biases],f)
            print("Parameters are saved in pickle file")

    def load_parameters(self,fileDr,layers,freeze):
        tf_weights=[]
        tf_biases=[]
        num_layers=len(layers)
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp20")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            weights,biases=pickle.load(f)
            assert num_layers == (len(weights)+1)
        
        # returns the weights and biases of the network as tf.variable
        for num in range(0,num_layers-1):
            if num<freeze:
                tf_weights.append ( tf.Variable (weights[num],trainable ='False'))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='False'))
            else:
                tf_weights.append ( tf.Variable (weights[num],trainable ='True' ))
                tf_biases.append  ( tf.Variable (biases[num],trainable ='True' ))
        
        print("Parameters are loaded succesffuly")
        
        return tf_weights,tf_biases
    
#===========================================================================================================#
#========================================saving loss values=================================================#
#===========================================================================================================#
    def save_loss(self,fileDr,tf_dict):
        self.loss_i.append(self.sess.run(self.initial_loss,tf_dict))
        self.loss_b.append(self.sess.run(self.boundary_loss,tf_dict))
        self.loss_r.append(self.sess.run(self.residual_loss,tf_dict))
        self.loss_d.append(self.sess.run(self.domdata_loss,tf_dict))
        self.loss_p.append(self.sess.run(self.prevtime_loss,tf_dict))
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp20")
        my_path=root_path/fileDr
        
        with open(my_path,'wb') as f:
            pickle.dump([self.loss_i,self.loss_b,self.loss_r,self.loss_d,self.loss_p],f)
            print("Loss are saved in pickle file")
    
    def load_loss(self,fileDr):
        
        root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_params\novel_method\exp20")
        my_path=root_path/fileDr
        
        # returns the weights and biases of the network as np array
        with open(my_path,'rb') as f:
            initial,boundary,residual,datadomain,prevtimeloss=pickle.load(f)
        
        print("Losses are loaded successfully")
        
        return initial,boundary,residual,datadomain,prevtimeloss
    
#===========================================================================================================#
#========================================Utility fucntions of NN============================================#
#===========================================================================================================#
 

# initialize the weight and bias
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

# xavier used to initialize the weight
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

# generate the neural network
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = 2.0 * (X - self.lowb) / (self.upb - self.lowb) - 1.0
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
#             H = tf.tanh(tf.add(tf.matmul(H, W), b))
            H = tf.keras.activations.swish(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
# ###################without assume###############
    # supervised data driven
    def net_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        return u, v, p

    # unsupervised NS residual
    def net_f_NS(self, x, y, t):

        u_v_p = self.neural_net(tf.concat([x, y, t], 1), self.weights, self.biases)
        u = u_v_p[:, 0:1]
        v = u_v_p[:, 1:2]
        p = u_v_p[:, 2:3]

        u_t = tf.gradients(ys=u, xs=t)[0] 
        u_x = tf.gradients(ys=u, xs=x)[0] 
        u_y = tf.gradients(ys=u, xs=y)[0] 
        u_xx = tf.gradients(ys=u_x, xs=x)[0] 
        u_yy = tf.gradients(ys=u_y, xs=y)[0] 
        
        v_t = tf.gradients(ys=v, xs=t)[0] 
        v_x = tf.gradients(ys=v, xs=x)[0] 
        v_y = tf.gradients(ys=v, xs=y)[0] 
        v_xx = tf.gradients(ys=v_x, xs=x)[0] 
        v_yy = tf.gradients(ys=v_y, xs=y)[0] 

        p_x = tf.gradients(ys=p, xs=x)[0] 
        p_y = tf.gradients(ys=p, xs=y)[0] 

        f_u = u_t + (u * u_x + v * u_y) + p_x - (1/self.re) * (u_xx + u_yy)
        f_v = v_t + (u * v_x + v * v_y) + p_y - (1/self.re) * (v_xx + v_yy)
        f_e = u_x + v_y

        return u, v, p, f_u, f_v, f_e
    
#===========================================================================================================#
#===========================Predicting and finding error every 10 epochs====================================#
#===========================================================================================================#
   

    def predict(self, x_star, y_star, t_star):

        tf_dict = {self.x_tf: x_star, self.y_tf: y_star, self.t_tf: t_star}

        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)

        return u_star, v_star, p_star
    
    def load_testdata(self,time_step):
        
        # Converting the time_step from decimal to integer 0.1 --> 1
        ts=int(10*time_step)

        # Loading the complete list of data 
        data_list=self.datalist

        # Extracting the data for the given range of time steps [0,0.1] and so on
        dt=0.1
        times=[round(i,3) for i in np.arange(0,7+dt,dt)]

        # Finding the indexes of initial and final timestep from the times list
        t1=times.index(round((time_step-1.0),2))
        t2=times.index(time_step)

        temp=[]
        # Excluding INITIAL DATA from the collocation points, to make sure that the model is not overfitting on
        # initial points, as there is u,v data available for the model. 

        for i in range(t1,t2+1):
            if i<t2+1:
                temp.append(data_list[i])

        # data stores the final timestep data for the given time segment

        data=np.concatenate(temp[4:],axis=0)

        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]

        return X_star,Y_star
    
    def find_error(self,test_time_step):
        
        X_star,Y_star=self.load_testdata(test_time_step)
        u_pred,_,_ = self.predict(X_star[0],X_star[1],X_star[2])
        
        error_u = np.linalg.norm(Y_star[0] - u_pred, 2) / np.linalg.norm(Y_star[0], 2)
        

        return error_u
        
    
    
    
#===========================================================================================================#
#===========================ADAM TRAINING FUNCTION==========================================================#
#===========================================================================================================#

    def Adam_train(self, epoch=5000, learning_rate=1e-3):

        start_time = time.time()
        
        iters = int(self.ntrain / self.batch_size)
        
        for it in range(epoch):
            
            for i in (range(iters)):
            
                # Randomly sampling ntrain datapoints in the spatio-temporal region
                idx=  np.random.choice(self.domain.shape[0],self.batch_size,replace=False)
                
                didx= np.random.choice(self.domain_data.shape[0],250,replace=False)
                
                # Should increase the batch size of prev data so that the model would be able to see more number of points
                # per iteration
                pidx= np.random.choice(self.prev_data.shape[0],1000,replace=False)
                
                self.data_domain = self.domain[idx,:]
                self.data_driven = self.domain_data[didx,:]
                self.prev_batch  = self.prev_data[pidx,:]
                
                # Collocation points inside the domain without data
                xd=self.data_domain[:,0].reshape(self.data_domain[:, 0].shape[0], 1)
                yd=self.data_domain[:,1].reshape(self.data_domain[:, 1].shape[0], 1)
                td=self.data_domain[:,2].reshape(self.data_domain[:, 2].shape[0], 1)
                
                # Collocation points inside the domain with data
                xdata=self.data_driven[:,0].reshape(self.data_driven[:, 0].shape[0], 1)
                ydata=self.data_driven[:,1].reshape(self.data_driven[:, 1].shape[0], 1)
                tdata=self.data_driven[:,2].reshape(self.data_driven[:, 2].shape[0], 1)
                udata=self.data_driven[:,3].reshape(self.data_driven[:, 3].shape[0], 1)
                vdata=self.data_driven[:,4].reshape(self.data_driven[:, 4].shape[0], 1)
                
                # Points from the previous time steps with data
                xprev=self.prev_batch[:,0].reshape(self.prev_batch[:,0].shape[0],1)
                yprev=self.prev_batch[:,1].reshape(self.prev_batch[:,1].shape[0],1)
                tprev=self.prev_batch[:,2].reshape(self.prev_batch[:,2].shape[0],1)
                uprev=self.prev_batch[:,3].reshape(self.prev_batch[:,3].shape[0],1)
                vprev=self.prev_batch[:,4].reshape(self.prev_batch[:,4].shape[0],1)
                
                Xd = np.concatenate([xd,yd,td], 1)
        
                tf_dict = {self.x_ini_tf: self.x0, 
                           self.y_ini_tf: self.y0,
                           self.t_ini_tf: self.t0, 
                           self.u_ini_tf: self.u0,
                           self.v_ini_tf: self.v0, 
                           
                           self.x_boundary_tf: self.xb,
                           self.y_boundary_tf: self.yb, 
                           self.t_boundary_tf: self.tb,
                           self.u_boundary_tf: self.ub, 
                           self.v_boundary_tf: self.vb,
                           
                           self.x_tf: xd, 
                           self.y_tf: yd, 
                           self.t_tf: td,
                           
                           self.xdata_tf: xdata, 
                           self.ydata_tf: ydata, 
                           self.tdata_tf: tdata,
                           self.udata_tf: udata,
                           self.vdata_tf: vdata,
                           
                           self.xtime_tf: xprev,
                           self.ytime_tf: yprev,
                           self.ttime_tf: tprev,
                           self.utime_tf: uprev,
                           self.vtime_tf: vprev,
                           
                           self.learning_rate: learning_rate}

                self.sess.run(self.train_op_Adam, tf_dict)
            
            if it % 10 == 0:
                
                elapsed = time.time() - start_time
                
                t_loss= self.sess.run(self.loss, tf_dict)
                i_loss= self.sess.run(self.initial_loss,tf_dict)
                b_loss= self.sess.run(self.boundary_loss,tf_dict)
                r_loss= self.sess.run(self.residual_loss,tf_dict)
                d_loss= self.sess.run(self.domdata_loss,tf_dict)
                p_loss= self.sess.run(self.prevtime_loss,tf_dict)
                
                # Saving the loss values in a pickle file
#                 self.save_loss(self.loss_name,tf_dict)
                
                # Finding the error value at given timestep for every 10 epochs
                eu1= self.find_error(1)
                eu2= self.find_error(2)
                eu3= self.find_error(3)
                eu4= self.find_error(4)
                eu5= self.find_error(5)
                eu6= self.find_error(6)
                eu7= self.find_error(7)
#                 eo= self.find_error(0.1)
                
                # Logging the loss values and error values to wandb workspace:
                log_dict={"Total_loss":t_loss,"Initial_loss":i_loss,\
                         "Boundary_loss":b_loss,"Residual_loss":r_loss,\
                         "Data_loss":d_loss,"Previous_loss":p_loss,\
                          "time step 1":eu1,\
                          "time step 2":eu2,\
                          "time step 3":eu3,\
                          "time step 4":eu4,\
                          "time step 5":eu5,\
                          "time step 6":eu6,\
                          "time step 7":eu7
                         }
                
                wandb.log(log_dict)
                
                print('epochs: %d, Loss: %.3e, Time: %.2f' %
                      (it, t_loss, elapsed))
                
                start_time = time.time()
            
            if it % 10 == 0 and it > 0:
                self.save_parameters(self.params_name)

# %% [markdown]
# # Data loading functions

# %%
def load_complete_data():

    path=r"E:\Vamsi_oe20s302\Research work\Simulations and data\Unsteady trials\data\trials\Re100_data_true"

    uvel=pd.read_csv(path+r"/u_vel.csv")
    uvel=uvel.to_numpy()
    
    vvel=pd.read_csv(path+r"/v_vel.csv")
    vvel=vvel.to_numpy()
    
    press=pd.read_csv(path+r"/press.csv")
    press=press.to_numpy()
    
    xy=pd.read_csv(path+r"/xy.csv")
    xy=xy.to_numpy()
    
    time=pd.read_csv(path+r"/time.csv")
    time=time.to_numpy()
    time=time-time[0]

    N=xy.shape[0]
    TT = np.tile(time, (1,N)).T # N x T
    
    # stores the data for each time step as a list
    data_list=[]
    
    for i in range(TT.shape[1]):
        if i<N:
            t=TT[:,i:i+1]
            u=uvel[:,i:i+1]
            v=vvel[:,i:i+1]
            p=press[:,i:i+1]
            a=np.concatenate([xy,t,u,v,p],1)
            data_list.append(a)
    
    return data_list

# %%
def reduced_data(temp_datalist,min_max):
    
    xmax,xmin,ymax,ymin,tmax,tmin=min_max

    # Removing the boundary conditions 
    temp_data=[]
    for i in range(len(temp_datalist)):
        td=temp_datalist[i]
        td=td[:,:][td[:,0]>xmin]
        td=td[:,:][td[:,1]>ymin]
        td=td[:,:][td[:,0]<xmax]
        td=td[:,:][td[:,1]<ymax]
        temp_data.append(td)

    tot_num=temp_data[0].shape[0]
    # Choosing 1% of data 
    didx= np.random.choice(tot_num,int(tot_num/100),replace=False)

    data_datalist=[]
    for i in range(len(temp_data)):
        data_datalist.append(temp_data[i][didx,:])


    return data_datalist

# %%
def load_data(time_step):
    
    # Loading the complete list of data for all timesteps
    data_list=load_complete_data()
    
    # This creates a smaller dataset of timesteps untill 7 
    temp_datalist=[]
    for i in range(len(data_list)):
        if(np.unique(data_list[i][:,2])<7):
            temp_datalist.append(data_list[i])
        else:
            break
   

    
    # ================================================================================#
    # ================================================================================#
    # ================================================================================#

    # Should randomly sample from the above temp datalist 
    dt=0.1
    times=[round(i,3) for i in np.arange(0,7+dt,dt)]
    
    # Finding the indexes of initial and final timestep
    t1=times.index(round((time_step-1.0),2))
    t2=times.index(time_step)
    
    temp=[]
    for i in range(t1,t2+1):
        if i<t2+1:
            temp.append(temp_datalist[i])

    # data1 stores the initial time for the given timestep
    data1=temp[0]

    # data_b stores the data for boundary conditions
    data_b=np.concatenate(temp,axis=0)
    data_b=data_b[:,0:5]
    
    # data stores the collocation points inside the domain
    data=np.concatenate(temp[1:],axis=0)

    # Extracting x,y,t values from data
    xx=data_b[:,0:1]
    yy=data_b[:,1:2]
    tt=data_b[:,2:3]
    
    # Extracting unique values and there by maximum and minimum values of x 
    # and y
    ax=np.unique(xx)
    ay=np.unique(yy)
    at=np.unique(tt)
    
    xmin=min(ax)
    ymin=min(ay)
    tmin=min(at)
    
    xmax=max(ax)
    ymax=max(ay)
    tmax=max(at)
    
    min_max=[xmax,xmin,ymax,ymin,tmax,tmin]
    
    # +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
    # NOTE: All the following datasets are coming from temp_datalist
    # If you want to make any changes for the dataset play with temp_datalist
    # +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

    # here randomly select collocation points inside the domain
    # the selection is done per time step: for time step t>0 example,t=0.0125
    # There are 9600 collocation points available so randomly select points
    # whose u,v data you are going to use. So youll have to send another dataset
    # 
    # Now we have a list of data
    
    # This is only for data driven modelling part of the PINNs
    dlist = reduced_data(temp_datalist,min_max)
    
    temp_data=[]
    for i in range(t1,t2+1):
        if i<t2+1:
            temp_data.append(dlist[i])
    
    # data1 stores the initial time for the given timestep
    domain_data1=temp_data[0]
    
    # data stores the collocation points inside the domain
    domain_data=np.concatenate(temp_data[1:],axis=0)[:,0:5]


    #======================== domain ===================================#
    # Extracting only x,y,t to be sent for collocation points
    # Extracting u,v also for data driven methodology
    domain = data[:,0:5] 
    # Creating a domain dataset where only the points inside the boundary
    # is present
    domain=domain[:,:][domain[:,0]>xmin]
    domain=domain[:,:][domain[:,1]>ymin]
    domain=domain[:,:][domain[:,0]<xmax]
    domain=domain[:,:][domain[:,1]<ymax]

    #======================== initial ==================================#
    # Sending whole data x,y,t,u,v as the initial conditions data
    # Taking only the first set of 10000 points as initial conditions data
    data_t0 = data1[:,0:5]
    
    #======================== boundary =================================#
    # Creating a dataset comprising only boundary conditions data
    # excluding initial conditions
    
    # bc1_data consists of data across all y at x=xmin
    bc1_data=data_b[:,:][data_b[:,0]==xmin]
    bc1_data=bc1_data[:,:][bc1_data[:,2]>round(tmin,3)]

    # bc2_data consists of data across all y at x=xmax
    bc2_data=data_b[:,:][data_b[:,0]==xmax]
    bc2_data=bc2_data[:,:][bc2_data[:,2]>round(tmin,3)]

    # bc3_data consists of data across all x at y=ymin
    bc3_data=data_b[:,:][data_b[:,1]==ymin]
    bc3_data=bc3_data[:,:][bc3_data[:,2]>round(tmin,3)]

    # bc4_data consists of data across all x at y=ymax
    bc4_data=data_b[:,:][data_b[:,1]==ymax]
    bc4_data=bc4_data[:,:][bc4_data[:,2]>round(tmin,3)]

    
    # The boundary conditions data is arranged row wise
    # first 100 rows of bc1_data, second 100 rows of bc2_data and so on...
    data_sup_b_train = np.concatenate([bc1_data,bc2_data,bc3_data,bc4_data], 0)


    return domain,data_t0 ,data_sup_b_train,domain_data

# %%
def load_testdata(time_step):
    
    if time_step==0:
        
        data_list=load_complete_data()
        data=data_list[0]
        
        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]
        
    else:
        
        # Converting the time_step from decimal to integer 0.1 --> 1
        ts=int(10*time_step)

        # Loading the complete list of data 
        data_list=load_complete_data()

        # Extracting the data for the given range of time steps [0,0.1] and so on
        dt=0.1
        times=[round(i,3) for i in np.arange(0,7+dt,dt)]

        # Finding the indexes of initial and final timestep from the times list
        t1=times.index(round((time_step-1.0),2))
        t2=times.index(time_step)

        temp=[]

        for i in range(t1,t2+1):
            if i<t2+1:
                temp.append(data_list[i])

        # data stores the final timestep data for the given time segment
        
        # Change the value inside the temp to according to the index of time_step in the given timesegment you are choosing

        data=np.concatenate(temp[10:],axis=0)

        x_star=data[:,0].reshape(data[:,0].shape[0],1)
        y_star=data[:,1].reshape(data[:,1].shape[0],1)
        t_star=data[:,2].reshape(data[:,2].shape[0],1)

        X_star=[x_star,y_star,t_star]

        u_star=data[:,3].reshape(data[:,3].shape[0],1)
        v_star=data[:,4].reshape(data[:,4].shape[0],1)
        p_star=data[:,5].reshape(data[:,5].shape[0],1)

        Y_star=[u_star,v_star,p_star]

    return X_star,Y_star

# %%
def load_train_data(timestep):
    data_list=load_complete_data()

    data=data_list[timestep]
    x_star=data[:,0].reshape(data[:,0].shape[0],1)
    y_star=data[:,1].reshape(data[:,1].shape[0],1)
    t_star=data[:,2].reshape(data[:,2].shape[0],1)

    X_star=[x_star,y_star,t_star]

    u_star=data[:,3].reshape(data[:,3].shape[0],1)
    v_star=data[:,4].reshape(data[:,4].shape[0],1)
    p_star=data[:,5].reshape(data[:,5].shape[0],1)

    Y_star=[u_star,v_star,p_star]

    return X_star,Y_star

# %%
# This snippet should be run for every time segment to obtain the predictions at each timestep in the specific timesegment

def time_segments(time_step):
    dt=0.1
    steps=[]
    for i in np.arange(round((time_step-1.0),3),round((time_step+dt),3),dt):
        steps.append(round(i,3))

    return steps

def return_indexes(time_step):
    idx=[]
    dt=0.1
    times=[round(i,3) for i in np.arange(0,7+dt,dt)]
    segs=time_segments(time_step)

    for i in range(len(segs)):
        idx.append(times.index(segs[i]))

    return idx

# %% [markdown]
# # Function to save the predictions of each timestep in previous timesegments

# %%
def read_prev_data(fileDr):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\novel_method\exp20")
    my_path=root_path/fileDr
    
    with open(my_path,'rb') as f:
        pdata=pickle.load(f)
    print("Previous predictions are loaded from pickle file")
    return pdata

# %%
def save_prev_data(idx,fileDr,t,model):
    if t == 1:
        prev_data=np.empty(shape=(1,5))

        for i in range(len(idx)):
            xi,_=load_train_data(idx[i])
            
            upredi,vpredi,ppredi=model.predict(xi[0],xi[1],xi[2])
            prev_data=np.append(prev_data,np.hstack((xi[0],xi[1],xi[2],upredi,vpredi)),axis=0)

        # Removing the first row of the array
        prev_data=np.delete(prev_data,(0),axis=0)
    
    else:
        # Reading from the previously stored data and appending 
        prev_data= read_prev_data(fileDr)
        
        # Appending the predictions for timesteps other than the first timestep 
        # for ex: excluding predictions for t=0.1 in the time segment [0.1,0.2]
        for i in range(1,len(idx)):
            xi,_=load_train_data(idx[i])
            
            upredi,vpredi,ppredi=model.predict(xi[0],xi[1],xi[2])
            prev_data=np.append(prev_data,np.hstack((xi[0],xi[1],xi[2],upredi,vpredi)),axis=0)
        
        
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\novel_method\exp20")
    my_path=root_path/fileDr
    
    with open(my_path,'wb') as f:
        pickle.dump(prev_data,f)
        print("Previous predictions are saved in pickle file")

# %% [markdown]
# # Run this Code segment to save the predictions at the final timestep of the segment

# %%
'''
Run this code to save the predictions of the model at the final timestep of 
the segment 
'''
def save_uv_values(model,fileDr,time_step):
    u=[]
    v=[]
    X_star,Y_star=load_testdata(time_step)
    print("Saving the predictions for time step:",np.unique(X_star[2]))
    u_pred, v_pred, p_pred = model.predict(X_star[0],X_star[1],X_star[2])
    
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\novel_method\exp20")
    my_path=root_path/fileDr
    
    with open(my_path,'wb') as f:
        pickle.dump([u_pred,v_pred,X_star[2]],f)
        print("Predictions are saved in pickle file")

# %%
def read_uv_values(fileDr):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\novel_method\exp20")
    my_path=root_path/fileDr
    
    with open(my_path,'rb') as f:
        u,v,t=pickle.load(f)
    print("Predictions are loaded")
    return u,v,t

# %% [markdown]
# # Commence the initial training using standard PINN

# %%
if __name__ == "__main__":
    '''
This code snippet starts the standard pinn training for the first time segment (0,1] and the predictions for the intermediate
time steps would be saved as a list of arrays in prev_data

Since we have already trained the datadriven model for the first time segment, the parameters of that model are being used,
and the predictions for each time step in the first time segment are being stored in a list of arrays.
    
    '''
    
    '''
Important thing to note here is that the model is just seeing 25000 points out of 10*100*100=100000 points per time segment in
one epoch, thats like 25% of the collocation points, essentially the model should be seeing the whole collocation points 
once per epoch in small batches, this feature is making the model less dependent on the collocation points!.
    '''
    N_train = 25000
    batch_size=1000
    Reynolds = 100
    
    layers = [3]+10*[100]+[3]
    
    time_step = 1
    
    datalist=load_complete_data()
    domain, initial, boundary, domain_data = load_data(time_step)

    # Enter the names of the files :
    '''
    load_params : name of the file from where you want to load the weights and biases initially
    params_name : name of the file where you want to save the weights and biases, incase of RESUMING TRAINING run this file
    loss_name   : name of the file where you want to save the loss components
    prev_name   : name of the file where you want to save the predictions of each time step in the segment
    '''
    
    params_name = 'params_exp20'
    loss_name   = 'Loss_re100_truly_sparse'
   


    with tf.device('/gpu:0'):
        
        # Loading the previously trained model
        model = bc_pinn_t0(domain,initial,boundary,domain_data,datalist,N_train,batch_size,
                           layers,re=Reynolds,
                           load_model=False,filedr='',
                           freeze= 0,timestep=time_step,
                           savewandb=params_name,saveloss=loss_name)
        
        wandb.init(entity=entity_name,project=project_name)
        name_run= str(time_step)
        wandb.run.name=name_run
        
        model.Adam_train(5000, 1e-3)
        model.Adam_train(600, 1e-4)

        # Saving the predictions at each time steps of the timesegment 
        idx=return_indexes(time_step)
        prev_name = 'prev_data_predictions_lts_exp20'
        save_prev_data(idx,prev_name,time_step,model)
        
        # Saving the u and v predictions of the final time steps of the timesegment
        pred_file = 'uv_preds_lts_exp20'
        save_uv_values(model,pred_file,time_step)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20220916_230159-k7u42qbj</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/k7u42qbj" target="_blank">helpful-plasma-6</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# epochs: 0, Loss: 2.385e-01, Time: 26.53
# epochs: 10, Loss: 2.006e-01, Time: 28.73
# epochs: 20, Loss: 1.577e-01, Time: 28.44
# epochs: 30, Loss: 1.470e-01, Time: 26.78
# epochs: 40, Loss: 1.436e-01, Time: 27.03
# epochs: 50, Loss: 1.491e-01, Time: 27.24
# epochs: 60, Loss: 1.325e-01, Time: 27.44
# epochs: 70, Loss: 1.404e-01, Time: 27.11
# epochs: 80, Loss: 1.338e-01, Time: 26.94
# epochs: 90, Loss: 1.337e-01, Time: 27.24
# epochs: 100, Loss: 1.056e-01, Time: 27.09
# epochs: 110, Loss: 7.671e-02, Time: 26.77
# epochs: 120, Loss: 6.609e-02, Time: 26.83
# epochs: 130, Loss: 6.219e-02, Time: 26.94
# epochs: 140, Loss: 6.048e-02, Time: 27.27
# epochs: 150, Loss: 5.931e-02, Time: 27.05
# epochs: 160, Loss: 4.859e-02, Time: 26.99
# epochs: 170, Loss: 4.607e-02, Time: 27.40
# epochs: 180, Loss: 4.540e-02, Time: 27.06
# epochs: 190, Loss: 3.649e-02, Time: 26.78
# epochs: 200, Loss: 3.040e-02, Time: 26.98
# epochs: 210, Loss: 3.039e-02, Time: 27.21
# epochs: 220, Loss: 2.524e-02, Time: 27.40
# epochs: 230, Loss: 2.522e-02, Time: 27.06
# epochs: 240, Loss: 2.434e-02, Time: 26.98
# epochs: 250, Loss: 2.600e-02, Time: 27.14
# epochs: 260, Loss: 2.429e-02, Time: 26.94
# epochs: 270, Loss: 2.219e-02, Time: 26.68
# epochs: 280, Loss: 1.980e-02, Time: 26.72
# epochs: 290, Loss: 1.757e-02, Time: 26.95
# epochs: 300, Loss: 1.922e-02, Time: 27.03
# epochs: 310, Loss: 2.029e-02, Time: 27.13
# epochs: 320, Loss: 1.717e-02, Time: 26.91
# epochs: 330, Loss: 2.134e-02, Time: 27.37
# epochs: 340, Loss: 1.948e-02, Time: 27.27
# epochs: 350, Loss: 2.100e-02, Time: 26.39
# epochs: 360, Loss: 1.806e-02, Time: 27.15
# epochs: 370, Loss: 1.940e-02, Time: 27.12
# epochs: 380, Loss: 2.052e-02, Time: 27.43
# epochs: 390, Loss: 1.922e-02, Time: 27.50
# epochs: 400, Loss: 1.749e-02, Time: 27.02
# epochs: 410, Loss: 1.979e-02, Time: 27.29
# epochs: 420, Loss: 1.484e-02, Time: 27.15
# epochs: 430, Loss: 1.931e-02, Time: 26.79
# epochs: 440, Loss: 2.574e-02, Time: 26.96
# epochs: 450, Loss: 2.011e-02, Time: 26.93
# epochs: 460, Loss: 1.876e-02, Time: 27.41
# epochs: 470, Loss: 1.665e-02, Time: 27.00
# epochs: 480, Loss: 1.662e-02, Time: 27.04
# epochs: 490, Loss: 1.796e-02, Time: 27.40
# epochs: 500, Loss: 1.498e-02, Time: 26.77
# epochs: 510, Loss: 1.647e-02, Time: 24.81
# epochs: 520, Loss: 1.657e-02, Time: 26.75
# epochs: 530, Loss: 1.802e-02, Time: 27.25
# epochs: 540, Loss: 1.775e-02, Time: 27.09
# epochs: 550, Loss: 1.344e-02, Time: 26.89
# epochs: 560, Loss: 1.453e-02, Time: 27.21
# epochs: 570, Loss: 1.549e-02, Time: 27.27
# epochs: 580, Loss: 1.894e-02, Time: 26.82
# epochs: 590, Loss: 1.481e-02, Time: 26.56
# epochs: 600, Loss: 1.613e-02, Time: 26.84
# epochs: 610, Loss: 1.709e-02, Time: 26.92
# epochs: 620, Loss: 1.757e-02, Time: 27.29
# epochs: 630, Loss: 1.514e-02, Time: 26.89
# epochs: 640, Loss: 1.664e-02, Time: 27.06
# epochs: 650, Loss: 1.414e-02, Time: 27.33
# epochs: 660, Loss: 1.390e-02, Time: 27.26
# epochs: 670, Loss: 1.678e-02, Time: 26.71
# epochs: 680, Loss: 1.462e-02, Time: 26.85
# epochs: 690, Loss: 1.626e-02, Time: 27.13
# epochs: 700, Loss: 1.465e-02, Time: 27.45
# epochs: 710, Loss: 1.343e-02, Time: 27.07
# epochs: 720, Loss: 1.888e-02, Time: 27.21
# epochs: 730, Loss: 1.287e-02, Time: 27.35
# epochs: 740, Loss: 1.397e-02, Time: 26.81
# epochs: 750, Loss: 1.349e-02, Time: 26.52
# epochs: 760, Loss: 1.484e-02, Time: 26.82
# epochs: 770, Loss: 1.406e-02, Time: 27.10
# epochs: 780, Loss: 1.365e-02, Time: 27.31
# epochs: 790, Loss: 1.349e-02, Time: 26.96
# epochs: 800, Loss: 1.635e-02, Time: 26.95
# epochs: 810, Loss: 1.462e-02, Time: 27.35
# epochs: 820, Loss: 1.344e-02, Time: 27.16
# epochs: 830, Loss: 1.301e-02, Time: 26.83
# epochs: 840, Loss: 1.402e-02, Time: 26.83
# epochs: 850, Loss: 1.292e-02, Time: 27.24
# epochs: 860, Loss: 1.633e-02, Time: 27.65
# epochs: 870, Loss: 1.542e-02, Time: 27.11
# epochs: 880, Loss: 1.292e-02, Time: 27.40
# epochs: 890, Loss: 1.270e-02, Time: 27.47
# epochs: 900, Loss: 1.573e-02, Time: 26.87
# epochs: 910, Loss: 1.406e-02, Time: 26.53
# epochs: 920, Loss: 1.417e-02, Time: 26.86
# epochs: 930, Loss: 1.244e-02, Time: 26.96
# epochs: 940, Loss: 1.346e-02, Time: 27.09
# epochs: 950, Loss: 1.616e-02, Time: 27.00
# epochs: 960, Loss: 1.389e-02, Time: 26.85
# epochs: 970, Loss: 1.299e-02, Time: 27.12
# epochs: 980, Loss: 1.512e-02, Time: 27.49
# epochs: 990, Loss: 1.424e-02, Time: 26.90
# epochs: 1000, Loss: 1.389e-02, Time: 26.89
# Parameters are saved in pickle file
# epochs: 1010, Loss: 1.396e-02, Time: 27.73
# epochs: 1020, Loss: 1.429e-02, Time: 27.44
# epochs: 1030, Loss: 1.236e-02, Time: 27.39
# epochs: 1040, Loss: 1.577e-02, Time: 27.11
# epochs: 1050, Loss: 1.453e-02, Time: 27.37
# epochs: 1060, Loss: 1.379e-02, Time: 27.35
# epochs: 1070, Loss: 1.355e-02, Time: 27.04
# epochs: 1080, Loss: 1.405e-02, Time: 26.84
# epochs: 1090, Loss: 1.307e-02, Time: 27.15
# epochs: 1100, Loss: 1.327e-02, Time: 27.38
# epochs: 1110, Loss: 1.370e-02, Time: 27.19
# epochs: 1120, Loss: 1.297e-02, Time: 27.27
# epochs: 1130, Loss: 1.756e-02, Time: 27.64
# epochs: 1140, Loss: 1.535e-02, Time: 27.14
# epochs: 1150, Loss: 1.536e-02, Time: 27.09
# epochs: 1160, Loss: 1.214e-02, Time: 26.77
# epochs: 1170, Loss: 1.312e-02, Time: 27.31
# epochs: 1180, Loss: 1.708e-02, Time: 27.46
# epochs: 1190, Loss: 1.518e-02, Time: 27.01
# epochs: 1200, Loss: 1.285e-02, Time: 27.31
# epochs: 1210, Loss: 1.506e-02, Time: 27.50
# epochs: 1220, Loss: 1.463e-02, Time: 26.97
# epochs: 1230, Loss: 1.471e-02, Time: 26.75
# epochs: 1240, Loss: 1.362e-02, Time: 26.64
# epochs: 1250, Loss: 1.469e-02, Time: 27.16
# epochs: 1260, Loss: 1.422e-02, Time: 27.38
# epochs: 1270, Loss: 1.281e-02, Time: 26.93
# epochs: 1280, Loss: 1.470e-02, Time: 26.99
# epochs: 1290, Loss: 1.291e-02, Time: 27.27
# epochs: 1300, Loss: 1.348e-02, Time: 27.40
# epochs: 1310, Loss: 1.349e-02, Time: 27.04
# epochs: 1320, Loss: 1.466e-02, Time: 26.82
# epochs: 1330, Loss: 1.402e-02, Time: 27.15
# epochs: 1340, Loss: 1.167e-02, Time: 27.40
# epochs: 1350, Loss: 1.224e-02, Time: 27.35
# epochs: 1360, Loss: 1.399e-02, Time: 27.11
# epochs: 1370, Loss: 1.680e-02, Time: 27.35
# epochs: 1380, Loss: 1.590e-02, Time: 27.37
# epochs: 1390, Loss: 1.463e-02, Time: 26.93
# epochs: 1400, Loss: 1.397e-02, Time: 26.72
# epochs: 1410, Loss: 1.366e-02, Time: 27.14
# epochs: 1420, Loss: 1.338e-02, Time: 27.49
# epochs: 1430, Loss: 1.310e-02, Time: 27.11
# epochs: 1440, Loss: 1.131e-02, Time: 27.20
# epochs: 1450, Loss: 1.273e-02, Time: 27.45
# epochs: 1460, Loss: 1.333e-02, Time: 27.31
# epochs: 1470, Loss: 1.287e-02, Time: 26.94
# epochs: 1480, Loss: 1.176e-02, Time: 26.88
# epochs: 1490, Loss: 1.274e-02, Time: 27.11
# epochs: 1500, Loss: 1.195e-02, Time: 27.40
# epochs: 1510, Loss: 1.135e-02, Time: 27.14
# epochs: 1520, Loss: 1.129e-02, Time: 26.93
# epochs: 1530, Loss: 1.322e-02, Time: 27.30
# epochs: 1540, Loss: 1.124e-02, Time: 27.17
# epochs: 1550, Loss: 1.117e-02, Time: 26.87
# epochs: 1560, Loss: 1.160e-02, Time: 27.01
# epochs: 1570, Loss: 1.367e-02, Time: 27.06
# epochs: 1580, Loss: 1.099e-02, Time: 27.35
# epochs: 1590, Loss: 1.116e-02, Time: 26.99
# epochs: 1600, Loss: 1.095e-02, Time: 27.05
# epochs: 1610, Loss: 1.375e-02, Time: 27.31
# epochs: 1620, Loss: 1.179e-02, Time: 27.32
# epochs: 1630, Loss: 1.433e-02, Time: 26.92
# epochs: 1640, Loss: 1.060e-02, Time: 26.86
# epochs: 1650, Loss: 1.128e-02, Time: 27.06
# epochs: 1660, Loss: 1.200e-02, Time: 27.48
# epochs: 1670, Loss: 1.044e-02, Time: 27.33
# epochs: 1680, Loss: 1.506e-02, Time: 27.32
# epochs: 1690, Loss: 1.153e-02, Time: 27.50
# epochs: 1700, Loss: 1.203e-02, Time: 26.97
# epochs: 1710, Loss: 1.161e-02, Time: 26.73
# epochs: 1720, Loss: 1.047e-02, Time: 26.83
# epochs: 1730, Loss: 1.081e-02, Time: 26.93
# epochs: 1740, Loss: 9.800e-03, Time: 27.24
# epochs: 1750, Loss: 9.697e-03, Time: 27.10
# epochs: 1760, Loss: 1.113e-02, Time: 26.82
# epochs: 1770, Loss: 1.125e-02, Time: 27.24
# epochs: 1780, Loss: 9.902e-03, Time: 27.50
# epochs: 1790, Loss: 1.041e-02, Time: 26.96
# epochs: 1800, Loss: 1.035e-02, Time: 26.83
# epochs: 1810, Loss: 1.080e-02, Time: 27.09
# epochs: 1820, Loss: 1.011e-02, Time: 27.43
# epochs: 1830, Loss: 1.084e-02, Time: 27.44
# epochs: 1840, Loss: 1.031e-02, Time: 27.02
# epochs: 1850, Loss: 1.438e-02, Time: 27.43
# epochs: 1860, Loss: 1.089e-02, Time: 27.50
# epochs: 1870, Loss: 9.677e-03, Time: 26.83
# epochs: 1880, Loss: 9.411e-03, Time: 26.70
# epochs: 1890, Loss: 1.462e-02, Time: 26.89
# epochs: 1900, Loss: 1.332e-02, Time: 27.24
# epochs: 1910, Loss: 9.539e-03, Time: 27.40
# epochs: 1920, Loss: 9.835e-03, Time: 27.01
# epochs: 1930, Loss: 9.309e-03, Time: 27.17
# epochs: 1940, Loss: 9.789e-03, Time: 27.52
# epochs: 1950, Loss: 1.065e-02, Time: 26.98
# epochs: 1960, Loss: 1.023e-02, Time: 26.81
# epochs: 1970, Loss: 9.105e-03, Time: 26.95
# epochs: 1980, Loss: 1.057e-02, Time: 27.25
# epochs: 1990, Loss: 8.824e-03, Time: 27.55
# epochs: 2000, Loss: 9.468e-03, Time: 27.03
# Parameters are saved in pickle file
# epochs: 2010, Loss: 1.162e-02, Time: 27.33
# epochs: 2020, Loss: 8.787e-03, Time: 27.48
# epochs: 2030, Loss: 8.695e-03, Time: 27.06
# epochs: 2040, Loss: 1.018e-02, Time: 26.76
# epochs: 2050, Loss: 1.231e-02, Time: 27.08
# epochs: 2060, Loss: 9.241e-03, Time: 27.53
# epochs: 2070, Loss: 1.028e-02, Time: 27.32
# epochs: 2080, Loss: 9.177e-03, Time: 27.06
# epochs: 2090, Loss: 1.084e-02, Time: 27.43
# epochs: 2100, Loss: 1.016e-02, Time: 27.23
# epochs: 2110, Loss: 9.313e-03, Time: 26.18
# epochs: 2120, Loss: 1.032e-02, Time: 25.49
# epochs: 2130, Loss: 8.783e-03, Time: 27.07
# epochs: 2140, Loss: 9.156e-03, Time: 27.35
# epochs: 2150, Loss: 1.053e-02, Time: 27.17
# epochs: 2160, Loss: 6.557e-03, Time: 27.48
# epochs: 2170, Loss: 1.141e-02, Time: 27.53
# epochs: 2180, Loss: 1.164e-02, Time: 27.09
# epochs: 2190, Loss: 9.762e-03, Time: 27.02
# epochs: 2200, Loss: 7.280e-03, Time: 26.70
# epochs: 2210, Loss: 9.652e-03, Time: 27.03
# epochs: 2220, Loss: 9.856e-03, Time: 27.27
# epochs: 2230, Loss: 9.422e-03, Time: 26.84
# epochs: 2240, Loss: 7.201e-03, Time: 26.98
# epochs: 2250, Loss: 7.619e-03, Time: 27.38
# epochs: 2260, Loss: 7.113e-03, Time: 27.28
# epochs: 2270, Loss: 7.806e-03, Time: 27.24
# epochs: 2280, Loss: 7.351e-03, Time: 27.02
# epochs: 2290, Loss: 1.034e-02, Time: 27.20
# epochs: 2300, Loss: 8.185e-03, Time: 27.52
# epochs: 2310, Loss: 8.485e-03, Time: 27.24
# epochs: 2320, Loss: 7.125e-03, Time: 27.45
# epochs: 2330, Loss: 9.406e-03, Time: 27.59
# epochs: 2340, Loss: 9.097e-03, Time: 27.09
# epochs: 2350, Loss: 1.097e-02, Time: 27.57
# epochs: 2360, Loss: 8.080e-03, Time: 26.54
# epochs: 2370, Loss: 1.073e-02, Time: 27.26
# epochs: 2380, Loss: 9.186e-03, Time: 27.30
# epochs: 2390, Loss: 8.658e-03, Time: 27.18
# epochs: 2400, Loss: 8.353e-03, Time: 27.44
# epochs: 2410, Loss: 9.779e-03, Time: 27.32
# epochs: 2420, Loss: 7.982e-03, Time: 27.11
# epochs: 2430, Loss: 9.422e-03, Time: 27.51
# epochs: 2440, Loss: 7.577e-03, Time: 26.68
# epochs: 2450, Loss: 1.054e-02, Time: 27.26
# epochs: 2460, Loss: 8.144e-03, Time: 27.38
# epochs: 2470, Loss: 1.452e-02, Time: 27.20
# epochs: 2480, Loss: 6.726e-03, Time: 27.42
# epochs: 2490, Loss: 9.475e-03, Time: 27.45
# epochs: 2500, Loss: 7.401e-03, Time: 27.08
# epochs: 2510, Loss: 1.022e-02, Time: 27.30
# epochs: 2520, Loss: 8.694e-03, Time: 26.74
# epochs: 2530, Loss: 1.104e-02, Time: 27.09
# epochs: 2540, Loss: 8.255e-03, Time: 27.16
# epochs: 2550, Loss: 7.784e-03, Time: 27.05
# epochs: 2560, Loss: 9.749e-03, Time: 27.28
# epochs: 2570, Loss: 6.560e-03, Time: 27.33
# epochs: 2580, Loss: 8.940e-03, Time: 27.34
# epochs: 2590, Loss: 9.048e-03, Time: 27.53
# epochs: 2600, Loss: 7.725e-03, Time: 26.42
# epochs: 2610, Loss: 8.814e-03, Time: 27.33
# epochs: 2620, Loss: 6.665e-03, Time: 27.58
# epochs: 2630, Loss: 8.996e-03, Time: 27.19
# epochs: 2640, Loss: 9.302e-03, Time: 27.47
# epochs: 2650, Loss: 8.845e-03, Time: 27.78
# epochs: 2660, Loss: 7.707e-03, Time: 27.23
# epochs: 2670, Loss: 8.905e-03, Time: 27.31
# epochs: 2680, Loss: 6.542e-03, Time: 26.83
# epochs: 2690, Loss: 8.134e-03, Time: 27.15
# epochs: 2700, Loss: 7.555e-03, Time: 27.44
# epochs: 2710, Loss: 7.447e-03, Time: 27.07
# epochs: 2720, Loss: 7.857e-03, Time: 27.46
# epochs: 2730, Loss: 9.097e-03, Time: 27.51
# epochs: 2740, Loss: 6.625e-03, Time: 27.32
# epochs: 2750, Loss: 1.194e-02, Time: 27.69
# epochs: 2760, Loss: 8.111e-03, Time: 26.96
# epochs: 2770, Loss: 8.539e-03, Time: 27.41
# epochs: 2780, Loss: 6.861e-03, Time: 27.50
# epochs: 2790, Loss: 7.153e-03, Time: 27.39
# epochs: 2800, Loss: 6.439e-03, Time: 27.81
# epochs: 2810, Loss: 8.225e-03, Time: 27.31
# epochs: 2820, Loss: 6.680e-03, Time: 27.14
# epochs: 2830, Loss: 8.569e-03, Time: 27.68
# epochs: 2840, Loss: 8.407e-03, Time: 26.61
# epochs: 2850, Loss: 6.874e-03, Time: 27.28
# epochs: 2860, Loss: 8.131e-03, Time: 27.26
# epochs: 2870, Loss: 8.734e-03, Time: 27.43
# epochs: 2880, Loss: 6.297e-03, Time: 27.48
# epochs: 2890, Loss: 8.044e-03, Time: 26.97
# epochs: 2900, Loss: 6.221e-03, Time: 27.17
# epochs: 2910, Loss: 7.178e-03, Time: 27.58
# epochs: 2920, Loss: 5.699e-03, Time: 26.77
# epochs: 2930, Loss: 6.288e-03, Time: 27.28
# epochs: 2940, Loss: 6.040e-03, Time: 27.30
# epochs: 2950, Loss: 7.341e-03, Time: 27.47
# epochs: 2960, Loss: 4.760e-03, Time: 27.57
# epochs: 2970, Loss: 6.934e-03, Time: 27.11
# epochs: 2980, Loss: 7.044e-03, Time: 27.24
# epochs: 2990, Loss: 5.055e-03, Time: 27.52
# epochs: 3000, Loss: 6.638e-03, Time: 26.71
# Parameters are saved in pickle file
# epochs: 3010, Loss: 6.763e-03, Time: 27.36
# epochs: 3020, Loss: 5.502e-03, Time: 27.29
# epochs: 3030, Loss: 6.405e-03, Time: 27.48
# epochs: 3040, Loss: 5.632e-03, Time: 27.60
# epochs: 3050, Loss: 5.850e-03, Time: 27.20
# epochs: 3060, Loss: 6.264e-03, Time: 27.41
# epochs: 3070, Loss: 6.731e-03, Time: 27.69
# epochs: 3080, Loss: 7.640e-03, Time: 26.82
# epochs: 3090, Loss: 5.113e-03, Time: 27.38
# epochs: 3100, Loss: 4.050e-03, Time: 27.38
# epochs: 3110, Loss: 4.827e-03, Time: 27.56
# epochs: 3120, Loss: 7.133e-03, Time: 27.35
# epochs: 3130, Loss: 3.867e-03, Time: 27.35
# epochs: 3140, Loss: 4.738e-03, Time: 27.37
# epochs: 3150, Loss: 4.296e-03, Time: 27.25
# epochs: 3160, Loss: 4.359e-03, Time: 27.02
# epochs: 3170, Loss: 5.844e-03, Time: 26.95
# epochs: 3180, Loss: 4.710e-03, Time: 27.00
# epochs: 3190, Loss: 6.323e-03, Time: 27.49
# epochs: 3200, Loss: 5.044e-03, Time: 27.26
# epochs: 3210, Loss: 4.469e-03, Time: 27.08
# epochs: 3220, Loss: 7.659e-03, Time: 27.48
# epochs: 3230, Loss: 5.065e-03, Time: 27.64
# epochs: 3240, Loss: 3.776e-03, Time: 26.93
# epochs: 3250, Loss: 4.029e-03, Time: 27.31
# epochs: 3260, Loss: 5.708e-03, Time: 27.46
# epochs: 3270, Loss: 3.990e-03, Time: 27.70
# epochs: 3280, Loss: 4.640e-03, Time: 27.33
# epochs: 3290, Loss: 4.175e-03, Time: 27.24
# epochs: 3300, Loss: 5.364e-03, Time: 27.62
# epochs: 3310, Loss: 9.955e-03, Time: 27.10
# epochs: 3320, Loss: 3.651e-03, Time: 27.00
# epochs: 3330, Loss: 4.617e-03, Time: 27.11
# epochs: 3340, Loss: 4.241e-03, Time: 27.30
# epochs: 3350, Loss: 4.420e-03, Time: 27.51
# epochs: 3360, Loss: 3.266e-03, Time: 27.19
# epochs: 3370, Loss: 4.941e-03, Time: 27.41
# epochs: 3380, Loss: 3.826e-03, Time: 27.76
# epochs: 3390, Loss: 4.397e-03, Time: 27.15
# epochs: 3400, Loss: 3.604e-03, Time: 27.09
# epochs: 3410, Loss: 4.731e-03, Time: 27.18
# epochs: 3420, Loss: 2.953e-03, Time: 27.50
# epochs: 3430, Loss: 3.951e-03, Time: 27.75
# epochs: 3440, Loss: 3.108e-03, Time: 27.09
# epochs: 3450, Loss: 4.696e-03, Time: 27.50
# epochs: 3460, Loss: 3.209e-03, Time: 27.48
# epochs: 3470, Loss: 5.904e-03, Time: 27.13
# epochs: 3480, Loss: 3.296e-03, Time: 26.91
# epochs: 3490, Loss: 3.919e-03, Time: 26.95
# epochs: 3500, Loss: 2.090e-03, Time: 27.33
# epochs: 3510, Loss: 2.426e-03, Time: 27.58
# epochs: 3520, Loss: 2.569e-03, Time: 27.26
# epochs: 3530, Loss: 3.274e-03, Time: 27.36
# epochs: 3540, Loss: 3.569e-03, Time: 27.83
# epochs: 3550, Loss: 2.360e-03, Time: 27.26
# epochs: 3560, Loss: 3.463e-03, Time: 27.09
# epochs: 3570, Loss: 3.219e-03, Time: 27.45
# epochs: 3580, Loss: 2.073e-03, Time: 27.77
# epochs: 3590, Loss: 2.843e-03, Time: 27.31
# epochs: 3600, Loss: 2.470e-03, Time: 27.31
# epochs: 3610, Loss: 3.096e-03, Time: 27.70
# epochs: 3620, Loss: 1.803e-02, Time: 27.26
# epochs: 3630, Loss: 4.055e-03, Time: 26.91
# epochs: 3640, Loss: 2.789e-03, Time: 27.03
# epochs: 3650, Loss: 2.699e-03, Time: 27.18
# epochs: 3660, Loss: 2.450e-03, Time: 27.48
# epochs: 3670, Loss: 2.183e-03, Time: 27.18
# epochs: 3680, Loss: 2.620e-03, Time: 27.31
# epochs: 3690, Loss: 1.894e-03, Time: 27.36
# epochs: 3700, Loss: 1.814e-03, Time: 27.32
# epochs: 3710, Loss: 2.383e-03, Time: 26.22
# epochs: 3720, Loss: 2.152e-03, Time: 25.79
# epochs: 3730, Loss: 3.740e-03, Time: 27.40
# epochs: 3740, Loss: 2.503e-03, Time: 27.49
# epochs: 3750, Loss: 2.280e-03, Time: 27.23
# epochs: 3760, Loss: 1.938e-03, Time: 27.53
# epochs: 3770, Loss: 2.106e-03, Time: 27.75
# epochs: 3780, Loss: 2.314e-03, Time: 27.29
# epochs: 3790, Loss: 2.137e-03, Time: 27.39
# epochs: 3800, Loss: 1.020e-02, Time: 26.70
# epochs: 3810, Loss: 6.470e-03, Time: 27.03
# epochs: 3820, Loss: 5.599e-03, Time: 27.55
# epochs: 3830, Loss: 5.222e-03, Time: 27.02
# epochs: 3840, Loss: 4.354e-03, Time: 27.38
# epochs: 3850, Loss: 3.890e-03, Time: 27.54
# epochs: 3860, Loss: 3.438e-03, Time: 27.32
# epochs: 3870, Loss: 3.760e-03, Time: 27.52
# epochs: 3880, Loss: 3.867e-03, Time: 26.80
# epochs: 3890, Loss: 3.234e-03, Time: 27.20
# epochs: 3900, Loss: 3.685e-03, Time: 27.52
# epochs: 3910, Loss: 2.884e-03, Time: 27.14
# epochs: 3920, Loss: 3.400e-03, Time: 27.65
# epochs: 3930, Loss: 4.063e-03, Time: 27.55
# epochs: 3940, Loss: 3.029e-03, Time: 27.27
# epochs: 3950, Loss: 2.800e-03, Time: 27.39
# epochs: 3960, Loss: 3.884e-03, Time: 26.58
# epochs: 3970, Loss: 3.324e-03, Time: 27.29
# epochs: 3980, Loss: 2.509e-03, Time: 27.43
# epochs: 3990, Loss: 2.984e-03, Time: 27.35
# epochs: 4000, Loss: 2.367e-03, Time: 27.64
# Parameters are saved in pickle file
# epochs: 4010, Loss: 2.677e-03, Time: 27.45
# epochs: 4020, Loss: 2.263e-03, Time: 27.30
# epochs: 4030, Loss: 2.743e-03, Time: 27.85
# epochs: 4040, Loss: 1.924e-03, Time: 26.99
# epochs: 4050, Loss: 3.980e-03, Time: 27.38
# epochs: 4060, Loss: 2.537e-03, Time: 27.38
# epochs: 4070, Loss: 3.247e-03, Time: 27.46
# epochs: 4080, Loss: 2.911e-03, Time: 27.75
# epochs: 4090, Loss: 2.610e-03, Time: 27.16
# epochs: 4100, Loss: 2.680e-03, Time: 27.05
# epochs: 4110, Loss: 1.897e-03, Time: 27.28
# epochs: 4120, Loss: 2.078e-03, Time: 26.83
# epochs: 4130, Loss: 1.994e-03, Time: 27.08
# epochs: 4140, Loss: 3.492e-03, Time: 27.15
# epochs: 4150, Loss: 2.520e-03, Time: 26.95
# epochs: 4160, Loss: 3.490e-03, Time: 27.35
# epochs: 4170, Loss: 1.758e-03, Time: 27.35
# epochs: 4180, Loss: 4.022e-03, Time: 27.33
# epochs: 4190, Loss: 2.389e-03, Time: 27.61
# epochs: 4200, Loss: 5.146e-03, Time: 26.80
# epochs: 4210, Loss: 2.134e-03, Time: 27.42
# epochs: 4220, Loss: 2.248e-03, Time: 27.54
# epochs: 4230, Loss: 1.858e-03, Time: 27.53
# epochs: 4240, Loss: 2.084e-03, Time: 27.67
# epochs: 4250, Loss: 3.611e-03, Time: 27.30
# epochs: 4260, Loss: 2.006e-03, Time: 27.41
# epochs: 4270, Loss: 1.689e-03, Time: 27.71
# epochs: 4280, Loss: 2.542e-03, Time: 26.59
# epochs: 4290, Loss: 1.827e-03, Time: 27.47
# epochs: 4300, Loss: 3.167e-03, Time: 27.36
# epochs: 4310, Loss: 2.072e-03, Time: 27.49
# epochs: 4320, Loss: 2.046e-03, Time: 27.62
# epochs: 4330, Loss: 2.859e-03, Time: 27.20
# epochs: 4340, Loss: 2.311e-03, Time: 27.60
# epochs: 4350, Loss: 3.272e-03, Time: 27.62
# epochs: 4360, Loss: 2.278e-03, Time: 26.70
# epochs: 4370, Loss: 2.226e-03, Time: 27.40
# epochs: 4380, Loss: 1.925e-03, Time: 27.32
# epochs: 4390, Loss: 2.428e-03, Time: 27.64
# epochs: 4400, Loss: 2.059e-03, Time: 27.43
# epochs: 4410, Loss: 2.192e-03, Time: 27.33
# epochs: 4420, Loss: 2.078e-03, Time: 27.49
# epochs: 4430, Loss: 2.778e-03, Time: 27.22
# epochs: 4440, Loss: 2.431e-03, Time: 26.99
# epochs: 4450, Loss: 2.233e-03, Time: 27.06
# epochs: 4460, Loss: 1.896e-03, Time: 27.09
# epochs: 4470, Loss: 3.640e-03, Time: 27.57
# epochs: 4480, Loss: 2.276e-03, Time: 27.26
# epochs: 4490, Loss: 1.812e-03, Time: 27.29
# epochs: 4500, Loss: 2.874e-03, Time: 27.53
# epochs: 4510, Loss: 2.933e-03, Time: 27.25
# epochs: 4520, Loss: 2.515e-03, Time: 26.93
# epochs: 4530, Loss: 1.614e-03, Time: 27.08
# epochs: 4540, Loss: 1.943e-03, Time: 27.13
# epochs: 4550, Loss: 3.383e-03, Time: 27.55
# epochs: 4560, Loss: 5.580e-03, Time: 27.32
# epochs: 4570, Loss: 1.592e-03, Time: 27.35
# epochs: 4580, Loss: 2.588e-03, Time: 27.57
# epochs: 4590, Loss: 1.289e-03, Time: 27.33
# epochs: 4600, Loss: 1.580e-03, Time: 26.81
# epochs: 4610, Loss: 2.017e-03, Time: 26.98
# epochs: 4620, Loss: 1.663e-03, Time: 27.15
# epochs: 4630, Loss: 2.616e-03, Time: 27.55
# epochs: 4640, Loss: 1.999e-03, Time: 27.42
# epochs: 4650, Loss: 1.893e-03, Time: 27.29
# epochs: 4660, Loss: 2.404e-03, Time: 27.64
# epochs: 4670, Loss: 1.626e-03, Time: 27.37
# epochs: 4680, Loss: 2.005e-03, Time: 27.13
# epochs: 4690, Loss: 2.026e-03, Time: 27.17
# epochs: 4700, Loss: 2.370e-03, Time: 27.58
# epochs: 4710, Loss: 1.701e-03, Time: 27.67
# epochs: 4720, Loss: 1.368e-03, Time: 27.27
# epochs: 4730, Loss: 1.661e-03, Time: 27.43
# epochs: 4740, Loss: 3.721e-03, Time: 27.37
# epochs: 4750, Loss: 1.507e-03, Time: 26.98
# epochs: 4760, Loss: 1.925e-03, Time: 27.05
# epochs: 4770, Loss: 2.152e-03, Time: 27.21
# epochs: 4780, Loss: 1.872e-03, Time: 27.45
# epochs: 4790, Loss: 1.683e-03, Time: 27.50
# epochs: 4800, Loss: 1.927e-03, Time: 27.46
# epochs: 4810, Loss: 1.862e-03, Time: 27.80
# epochs: 4820, Loss: 1.751e-03, Time: 27.42
# epochs: 4830, Loss: 2.240e-03, Time: 26.99
# epochs: 4840, Loss: 2.465e-03, Time: 26.90
# epochs: 4850, Loss: 1.289e-03, Time: 27.37
# epochs: 4860, Loss: 4.233e-03, Time: 27.76
# epochs: 4870, Loss: 1.876e-03, Time: 27.27
# epochs: 4880, Loss: 1.594e-03, Time: 27.40
# epochs: 4890, Loss: 1.340e-03, Time: 27.50
# epochs: 4900, Loss: 2.117e-03, Time: 27.33
# epochs: 4910, Loss: 1.868e-03, Time: 27.08
# epochs: 4920, Loss: 2.692e-03, Time: 27.08
# epochs: 4930, Loss: 1.354e-03, Time: 27.36
# epochs: 4940, Loss: 2.453e-03, Time: 27.55
# epochs: 4950, Loss: 2.253e-03, Time: 27.16
# epochs: 4960, Loss: 2.390e-03, Time: 27.32
# epochs: 4970, Loss: 9.789e-04, Time: 27.84
# epochs: 4980, Loss: 1.323e-03, Time: 27.35
# epochs: 4990, Loss: 1.446e-03, Time: 26.96
# epochs: 0, Loss: 8.291e-04, Time: 2.71
# epochs: 10, Loss: 7.557e-04, Time: 27.53
# epochs: 20, Loss: 7.431e-04, Time: 27.69
# epochs: 30, Loss: 7.772e-04, Time: 27.25
# epochs: 40, Loss: 6.872e-04, Time: 27.48
# epochs: 50, Loss: 7.278e-04, Time: 27.23
# epochs: 60, Loss: 7.453e-04, Time: 26.96
# epochs: 70, Loss: 6.913e-04, Time: 26.90
# epochs: 80, Loss: 5.807e-04, Time: 27.01
# epochs: 90, Loss: 7.087e-04, Time: 27.19
# epochs: 100, Loss: 9.286e-04, Time: 27.59
# epochs: 110, Loss: 7.648e-04, Time: 27.13
# epochs: 120, Loss: 6.159e-04, Time: 27.14
# epochs: 130, Loss: 6.375e-04, Time: 27.56
# epochs: 140, Loss: 6.211e-04, Time: 27.63
# epochs: 150, Loss: 5.953e-04, Time: 27.19
# epochs: 160, Loss: 6.716e-04, Time: 27.18
# epochs: 170, Loss: 7.243e-04, Time: 27.58
# epochs: 180, Loss: 6.308e-04, Time: 27.65
# epochs: 190, Loss: 5.736e-04, Time: 27.24
# epochs: 200, Loss: 6.707e-04, Time: 27.55
# epochs: 210, Loss: 6.882e-04, Time: 27.81
# epochs: 220, Loss: 6.519e-04, Time: 27.11
# epochs: 230, Loss: 6.607e-04, Time: 27.05
# epochs: 240, Loss: 6.344e-04, Time: 27.32
# epochs: 250, Loss: 6.763e-04, Time: 27.84
# epochs: 260, Loss: 5.760e-04, Time: 27.16
# epochs: 270, Loss: 6.362e-04, Time: 27.26
# epochs: 280, Loss: 6.472e-04, Time: 27.57
# epochs: 290, Loss: 6.039e-04, Time: 27.46
# epochs: 300, Loss: 7.324e-04, Time: 27.28
# epochs: 310, Loss: 6.348e-04, Time: 25.46
# epochs: 320, Loss: 6.464e-04, Time: 27.12
# epochs: 330, Loss: 6.451e-04, Time: 27.06
# epochs: 340, Loss: 5.677e-04, Time: 27.27
# epochs: 350, Loss: 5.589e-04, Time: 27.51
# epochs: 360, Loss: 5.846e-04, Time: 27.21
# epochs: 370, Loss: 5.860e-04, Time: 27.24
# epochs: 380, Loss: 5.698e-04, Time: 27.58
# epochs: 390, Loss: 5.861e-04, Time: 27.38
# epochs: 400, Loss: 5.522e-04, Time: 26.79
# epochs: 410, Loss: 5.589e-04, Time: 27.04
# epochs: 420, Loss: 5.904e-04, Time: 27.28
# epochs: 430, Loss: 5.784e-04, Time: 27.57
# epochs: 440, Loss: 5.663e-04, Time: 27.44
# epochs: 450, Loss: 5.590e-04, Time: 27.51
# epochs: 460, Loss: 5.573e-04, Time: 27.85
# epochs: 470, Loss: 5.460e-04, Time: 27.28
# epochs: 480, Loss: 6.044e-04, Time: 27.15
# epochs: 490, Loss: 6.039e-04, Time: 27.31
# epochs: 500, Loss: 5.231e-04, Time: 27.64
# epochs: 510, Loss: 5.668e-04, Time: 27.58
# epochs: 520, Loss: 5.844e-04, Time: 27.31
# epochs: 530, Loss: 5.572e-04, Time: 27.41
# epochs: 540, Loss: 5.477e-04, Time: 27.40
# epochs: 550, Loss: 5.323e-04, Time: 27.11
# epochs: 560, Loss: 5.517e-04, Time: 27.07
# epochs: 570, Loss: 6.138e-04, Time: 27.26
# epochs: 580, Loss: 5.114e-04, Time: 27.51
# epochs: 590, Loss: 5.384e-04, Time: 27.35
# Previous predictions are saved in pickle file
# Saving the predictions for time step: [1.]
# Predictions are saved in pickle file

# %% [markdown]
# # Start the training for the next timesegments

# %%
if __name__ == "__main__":

    
    N_train = 25000
    batch_size=1000
    Reynolds = 100
    layers = [3]+10*[100]+[3]
    
    fre = 5
    
    # Timesteps for loop :
    datalist=load_complete_data()
    timesteps=[round(i,3) for i in np.arange(2,8,1)]
    
    # Copy and paste this api key: 822244d22c29151b0b6501c81c4e22a5c5a0843f
#     !wandb login --relogin

    # Starting a new run for every timestep
#     wandb.run.finish()
    entity_name="vamsi_malineni6"
    project_name="bc_pinn_ltd_1data_longer_training"
#     wandb.init(reinit=True)

        
    for i in timesteps:
        
        time_step = i
        
        # initializing wandb workspace
        wandb.init(entity=entity_name,project=project_name)
        
        # naming the run on wandb
        name_run= str(time_step)
        wandb.run.name=name_run
        
        # Loading the initial and the boundary conditions for the next timestep
        domain, initial, boundary, domain_data = load_data(time_step)

        # Loading the predictions of the final timestep of the first timesegment as the initial conditions of this time segment
        prediction_file='uv_preds_lts_exp20'
        u,v,t=read_uv_values(prediction_file)

        # Initial condition guided learning
        # Altering the initial conditions data, only uvt values are changed pressure values are untouched.
        initial[:,2]=t[:,0]
        initial[:,3]=u[:,0]
        initial[:,4]=v[:,0]

        # Loading the previous timesegment data
        prev_name='prev_data_predictions_lts_exp20'
        prevtimedata=read_prev_data(prev_name)

        # Enter the names of the files :
        '''
        params_name : name of the file where you want to save the weights and biases, LOAD THE MODEL EVERYTIME, SINCE ITS THE SAME
                      MODEL THAT IS BEING TRAINED OVER DIFFERNT TIMESEGMENTS, WITH FOCUS ON PREV TIME SEGMENTS                  
        loss_name   : name of the file where you want to save the loss components
        prev_name   : name of the file where you want to save the predictions of each time step in the segment
        '''

        params_name = 'params_exp20'
        loss_name   = 'Loss_re100_truly_sparse'

        # Start the Training process
        with tf.device('/gpu:0'):

            bc_pinn_model = bc_pinn_t (domain,initial,boundary,domain_data,prevtimedata,datalist,
                                       N_train,batch_size,
                                       layers,re=Reynolds,
                                       load_model=True,filedr=params_name,
                                       freeze = fre,timestep=time_step,
                                       savewandb=params_name,saveloss=loss_name)

            print("===============================================================================================")
            print("Commencing training for the timesegment:(",round((time_step-1),3),time_step,"] ")
            print("===============================================================================================")
            
            bc_pinn_model.Adam_train(1000, 1e-3)
            bc_pinn_model.Adam_train(1000, 1e-4)

        # Save the predictions of the final timestep of the current timesegment to be used for ICGL
        pred_file='uv_preds_lts_exp20'
        save_uv_values(bc_pinn_model,pred_file,time_step)

        # This code snippet appends the predictions at each time step for the previous time segment.
        idx=return_indexes(time_step)
        save_prev_data(idx,prev_name,time_step,bc_pinn_model)
        

        # Save the experiment run and finish the experiment in wandb 
        wandb.run.save()
        wandb.run.finish()
# Out:
# Finishing last run (ID:k7u42qbj) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>█▅▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Data_loss</td><td>█▅▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>▂█▅▅▅▃▄▃▄▃▃▃▂▂▂▃▂▇▂▂▄▃▂▂▂▂▂▃▂▂▂▂▃▂▂▂▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▄▂▂▂▂▂▂▂▂▂▂▁▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>█▇▄▄▄▄▄▄▄▄▄▄▄▄▄▄▃▄▃▃▃▃▃▃▂▂▂▃▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>time step 2</td><td>▁▂█▄▃▃▃▃▃▃▃▄▃▃▃▃▃▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄</td></tr><tr><td>time step 3</td><td>▁▅█▄▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>time step 4</td><td>▁▆█▃▂▂▂▂▁▁▁▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▃▃▄</td></tr><tr><td>time step 5</td><td>▁██▂▁▂▂▂▂▁▂▂▂▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▃▃▄▅▇</td></tr><tr><td>time step 6</td><td>▂▇▆▁▁▁▂▂▂▁▁▂▂▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▄▄▅▇█</td></tr><tr><td>time step 7</td><td>▁▅▄▂▂▁▂▂▁▁▁▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▄▄▅▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>0.00013</td></tr><tr><td>Data_loss</td><td>0.00021</td></tr><tr><td>Initial_loss</td><td>0.00015</td></tr><tr><td>Residual_loss</td><td>5e-05</td></tr><tr><td>Total_loss</td><td>0.00054</td></tr><tr><td>time step 1</td><td>0.01652</td></tr><tr><td>time step 2</td><td>0.21448</td></tr><tr><td>time step 3</td><td>0.31687</td></tr><tr><td>time step 4</td><td>0.80101</td></tr><tr><td>time step 5</td><td>1.45284</td></tr><tr><td>time step 6</td><td>2.26609</td></tr><tr><td>time step 7</td><td>3.24532</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">helpful-plasma-6</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/k7u42qbj" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/k7u42qbj</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220916_230159-k7u42qbj\logs</code>
# Successfully finished last run (ID:k7u42qbj). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.03333337306976318, max=1.0)…
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20220917_032014-desiehdj</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/desiehdj" target="_blank">fragrant-shadow-7</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 1 2 ]
# ===============================================================================================
# epochs: 0, Loss: 2.614e-01, Time: 27.49
# epochs: 10, Loss: 2.841e-02, Time: 29.61
# Parameters are saved in pickle file
# epochs: 20, Loss: 1.259e-02, Time: 31.19
# Parameters are saved in pickle file
# epochs: 30, Loss: 7.613e-03, Time: 29.40
# Parameters are saved in pickle file
# epochs: 40, Loss: 6.775e-03, Time: 28.40
# Parameters are saved in pickle file
# epochs: 50, Loss: 5.863e-03, Time: 29.01
# Parameters are saved in pickle file
# epochs: 60, Loss: 7.379e-03, Time: 29.88
# Parameters are saved in pickle file
# epochs: 70, Loss: 5.008e-03, Time: 29.43
# Parameters are saved in pickle file
# epochs: 80, Loss: 5.426e-03, Time: 29.31
# Parameters are saved in pickle file
# epochs: 90, Loss: 4.585e-03, Time: 29.14
# Parameters are saved in pickle file
# epochs: 100, Loss: 4.662e-03, Time: 29.24
# Parameters are saved in pickle file
# epochs: 110, Loss: 4.811e-03, Time: 28.66
# Parameters are saved in pickle file
# epochs: 120, Loss: 3.696e-03, Time: 28.75
# Parameters are saved in pickle file
# epochs: 130, Loss: 4.037e-03, Time: 29.42
# Parameters are saved in pickle file
# epochs: 140, Loss: 3.823e-03, Time: 28.63
# Parameters are saved in pickle file
# epochs: 150, Loss: 3.682e-03, Time: 29.61
# Parameters are saved in pickle file
# epochs: 160, Loss: 4.667e-03, Time: 29.09
# Parameters are saved in pickle file
# epochs: 170, Loss: 3.591e-03, Time: 29.87
# Parameters are saved in pickle file
# epochs: 180, Loss: 4.131e-03, Time: 28.48
# Parameters are saved in pickle file
# epochs: 190, Loss: 3.207e-03, Time: 28.99
# Parameters are saved in pickle file
# epochs: 200, Loss: 3.561e-03, Time: 29.72
# Parameters are saved in pickle file
# epochs: 210, Loss: 3.854e-03, Time: 29.56
# Parameters are saved in pickle file
# epochs: 220, Loss: 5.073e-03, Time: 29.86
# Parameters are saved in pickle file
# epochs: 230, Loss: 3.742e-03, Time: 29.18
# Parameters are saved in pickle file
# epochs: 240, Loss: 4.187e-03, Time: 29.21
# Parameters are saved in pickle file
# epochs: 250, Loss: 2.541e-03, Time: 28.72
# Parameters are saved in pickle file
# epochs: 260, Loss: 2.612e-03, Time: 29.25
# Parameters are saved in pickle file
# epochs: 270, Loss: 3.335e-03, Time: 29.34
# Parameters are saved in pickle file
# epochs: 280, Loss: 2.963e-03, Time: 29.08
# Parameters are saved in pickle file
# epochs: 290, Loss: 3.214e-03, Time: 29.03
# Parameters are saved in pickle file
# epochs: 300, Loss: 2.441e-03, Time: 29.18
# Parameters are saved in pickle file
# epochs: 310, Loss: 3.737e-03, Time: 29.17
# Parameters are saved in pickle file
# epochs: 320, Loss: 3.898e-03, Time: 28.47
# Parameters are saved in pickle file
# epochs: 330, Loss: 2.772e-03, Time: 29.59
# Parameters are saved in pickle file
# epochs: 340, Loss: 2.975e-03, Time: 29.42
# Parameters are saved in pickle file
# epochs: 350, Loss: 2.493e-03, Time: 29.23
# Parameters are saved in pickle file
# epochs: 360, Loss: 2.069e-03, Time: 29.41
# Parameters are saved in pickle file
# epochs: 370, Loss: 2.920e-03, Time: 29.85
# Parameters are saved in pickle file
# epochs: 380, Loss: 3.716e-03, Time: 28.97
# Parameters are saved in pickle file
# epochs: 390, Loss: 2.568e-03, Time: 28.52
# Parameters are saved in pickle file
# epochs: 400, Loss: 3.311e-03, Time: 29.40
# Parameters are saved in pickle file
# epochs: 410, Loss: 3.920e-03, Time: 29.88
# Parameters are saved in pickle file
# epochs: 420, Loss: 3.146e-03, Time: 29.97
# Parameters are saved in pickle file
# epochs: 430, Loss: 3.311e-03, Time: 29.82
# Parameters are saved in pickle file
# epochs: 440, Loss: 3.801e-03, Time: 28.92
# Parameters are saved in pickle file
# epochs: 450, Loss: 2.609e-03, Time: 29.34
# Parameters are saved in pickle file
# epochs: 460, Loss: 3.440e-03, Time: 28.85
# Parameters are saved in pickle file
# epochs: 470, Loss: 2.225e-03, Time: 28.68
# Parameters are saved in pickle file
# epochs: 480, Loss: 2.408e-03, Time: 29.65
# Parameters are saved in pickle file
# epochs: 490, Loss: 3.774e-03, Time: 29.01
# Parameters are saved in pickle file
# epochs: 500, Loss: 2.567e-03, Time: 29.61
# Parameters are saved in pickle file
# epochs: 510, Loss: 3.662e-03, Time: 28.87
# Parameters are saved in pickle file
# epochs: 520, Loss: 3.191e-03, Time: 29.27
# Parameters are saved in pickle file
# epochs: 530, Loss: 2.899e-03, Time: 28.60
# Parameters are saved in pickle file
# epochs: 540, Loss: 2.105e-03, Time: 29.29
# Parameters are saved in pickle file
# epochs: 550, Loss: 2.787e-03, Time: 29.87
# Parameters are saved in pickle file
# epochs: 560, Loss: 2.392e-03, Time: 28.87
# Parameters are saved in pickle file
# epochs: 570, Loss: 2.503e-03, Time: 30.07
# Parameters are saved in pickle file
# epochs: 580, Loss: 5.020e-03, Time: 29.28
# Parameters are saved in pickle file
# epochs: 590, Loss: 1.944e-03, Time: 30.02
# Parameters are saved in pickle file
# epochs: 600, Loss: 2.701e-03, Time: 28.60
# Parameters are saved in pickle file
# epochs: 610, Loss: 2.468e-03, Time: 29.23
# Parameters are saved in pickle file
# epochs: 620, Loss: 1.885e-03, Time: 29.47
# Parameters are saved in pickle file
# epochs: 630, Loss: 3.328e-03, Time: 28.96
# Parameters are saved in pickle file
# epochs: 640, Loss: 2.305e-03, Time: 29.61
# Parameters are saved in pickle file
# epochs: 650, Loss: 2.053e-03, Time: 28.90
# Parameters are saved in pickle file
# epochs: 660, Loss: 2.396e-03, Time: 29.64
# Parameters are saved in pickle file
# epochs: 670, Loss: 2.943e-03, Time: 28.69
# Parameters are saved in pickle file
# epochs: 680, Loss: 2.556e-03, Time: 28.91
# Parameters are saved in pickle file
# epochs: 690, Loss: 2.316e-03, Time: 29.29
# Parameters are saved in pickle file
# epochs: 700, Loss: 3.683e-03, Time: 28.98
# Parameters are saved in pickle file
# epochs: 710, Loss: 1.479e-03, Time: 29.62
# Parameters are saved in pickle file
# epochs: 720, Loss: 3.201e-03, Time: 29.10
# Parameters are saved in pickle file
# epochs: 730, Loss: 5.988e-03, Time: 29.21
# Parameters are saved in pickle file
# epochs: 740, Loss: 1.688e-03, Time: 28.65
# Parameters are saved in pickle file
# epochs: 750, Loss: 1.701e-03, Time: 29.09
# Parameters are saved in pickle file
# epochs: 760, Loss: 2.200e-03, Time: 29.55
# Parameters are saved in pickle file
# epochs: 770, Loss: 2.371e-03, Time: 29.25
# Parameters are saved in pickle file
# epochs: 780, Loss: 3.026e-03, Time: 29.91
# Parameters are saved in pickle file
# epochs: 790, Loss: 2.453e-03, Time: 29.60
# Parameters are saved in pickle file
# epochs: 800, Loss: 3.845e-03, Time: 29.31
# Parameters are saved in pickle file
# epochs: 810, Loss: 1.861e-03, Time: 28.76
# Parameters are saved in pickle file
# epochs: 820, Loss: 2.354e-03, Time: 29.86
# Parameters are saved in pickle file
# epochs: 830, Loss: 2.329e-03, Time: 28.91
# Parameters are saved in pickle file
# epochs: 840, Loss: 2.054e-03, Time: 29.27
# Parameters are saved in pickle file
# epochs: 850, Loss: 1.389e-03, Time: 28.99
# Parameters are saved in pickle file
# epochs: 860, Loss: 3.087e-03, Time: 29.44
# Parameters are saved in pickle file
# epochs: 870, Loss: 1.690e-03, Time: 29.00
# Parameters are saved in pickle file
# epochs: 880, Loss: 1.254e-03, Time: 28.82
# Parameters are saved in pickle file
# epochs: 890, Loss: 5.236e-03, Time: 29.38
# Parameters are saved in pickle file
# epochs: 900, Loss: 1.482e-03, Time: 29.25
# Parameters are saved in pickle file
# epochs: 910, Loss: 1.714e-03, Time: 29.56
# Parameters are saved in pickle file
# epochs: 920, Loss: 1.858e-03, Time: 29.00
# Parameters are saved in pickle file
# epochs: 930, Loss: 1.782e-03, Time: 29.56
# Parameters are saved in pickle file
# epochs: 940, Loss: 1.304e-03, Time: 29.03
# Parameters are saved in pickle file
# epochs: 950, Loss: 1.617e-03, Time: 28.63
# Parameters are saved in pickle file
# epochs: 960, Loss: 3.932e-03, Time: 29.63
# Parameters are saved in pickle file
# epochs: 970, Loss: 1.396e-03, Time: 29.03
# Parameters are saved in pickle file
# epochs: 980, Loss: 2.454e-03, Time: 29.22
# Parameters are saved in pickle file
# epochs: 990, Loss: 2.538e-03, Time: 29.33
# Parameters are saved in pickle file
# epochs: 0, Loss: 1.238e-03, Time: 3.22
# epochs: 10, Loss: 8.323e-04, Time: 28.79
# Parameters are saved in pickle file
# epochs: 20, Loss: 8.108e-04, Time: 28.64
# Parameters are saved in pickle file
# epochs: 30, Loss: 1.007e-03, Time: 29.38
# Parameters are saved in pickle file
# epochs: 40, Loss: 1.063e-03, Time: 29.35
# Parameters are saved in pickle file
# epochs: 50, Loss: 7.763e-04, Time: 29.57
# Parameters are saved in pickle file
# epochs: 60, Loss: 6.935e-04, Time: 29.39
# Parameters are saved in pickle file
# epochs: 70, Loss: 7.378e-04, Time: 29.53
# Parameters are saved in pickle file
# epochs: 80, Loss: 7.162e-04, Time: 28.23
# Parameters are saved in pickle file
# epochs: 90, Loss: 7.188e-04, Time: 27.66
# Parameters are saved in pickle file
# epochs: 100, Loss: 7.637e-04, Time: 29.58
# Parameters are saved in pickle file
# epochs: 110, Loss: 7.291e-04, Time: 29.46
# Parameters are saved in pickle file
# epochs: 120, Loss: 7.630e-04, Time: 29.39
# Parameters are saved in pickle file
# epochs: 130, Loss: 7.783e-04, Time: 29.49
# Parameters are saved in pickle file
# epochs: 140, Loss: 6.857e-04, Time: 29.33
# Parameters are saved in pickle file
# epochs: 150, Loss: 7.435e-04, Time: 29.75
# Parameters are saved in pickle file
# epochs: 160, Loss: 7.692e-04, Time: 28.60
# Parameters are saved in pickle file
# epochs: 170, Loss: 7.421e-04, Time: 28.97
# Parameters are saved in pickle file
# epochs: 180, Loss: 6.842e-04, Time: 29.65
# Parameters are saved in pickle file
# epochs: 190, Loss: 6.717e-04, Time: 29.18
# Parameters are saved in pickle file
# epochs: 200, Loss: 6.836e-04, Time: 30.15
# Parameters are saved in pickle file
# epochs: 210, Loss: 6.651e-04, Time: 29.16
# Parameters are saved in pickle file
# epochs: 220, Loss: 7.186e-04, Time: 29.48
# Parameters are saved in pickle file
# epochs: 230, Loss: 7.449e-04, Time: 28.57
# Parameters are saved in pickle file
# epochs: 240, Loss: 7.006e-04, Time: 29.14
# Parameters are saved in pickle file
# epochs: 250, Loss: 6.578e-04, Time: 29.73
# Parameters are saved in pickle file
# epochs: 260, Loss: 6.832e-04, Time: 29.10
# Parameters are saved in pickle file
# epochs: 270, Loss: 6.647e-04, Time: 29.39
# Parameters are saved in pickle file
# epochs: 280, Loss: 6.157e-04, Time: 28.83
# Parameters are saved in pickle file
# epochs: 290, Loss: 7.177e-04, Time: 29.50
# Parameters are saved in pickle file
# epochs: 300, Loss: 5.855e-04, Time: 28.64
# Parameters are saved in pickle file
# epochs: 310, Loss: 6.115e-04, Time: 28.85
# Parameters are saved in pickle file
# epochs: 320, Loss: 5.861e-04, Time: 29.60
# Parameters are saved in pickle file
# epochs: 330, Loss: 7.235e-04, Time: 29.27
# Parameters are saved in pickle file
# epochs: 340, Loss: 6.427e-04, Time: 29.34
# Parameters are saved in pickle file
# epochs: 350, Loss: 7.206e-04, Time: 28.95
# Parameters are saved in pickle file
# epochs: 360, Loss: 6.190e-04, Time: 29.87
# Parameters are saved in pickle file
# epochs: 370, Loss: 5.113e-04, Time: 28.72
# Parameters are saved in pickle file
# epochs: 380, Loss: 5.551e-04, Time: 29.01
# Parameters are saved in pickle file
# epochs: 390, Loss: 5.840e-04, Time: 29.68
# Parameters are saved in pickle file
# epochs: 400, Loss: 5.633e-04, Time: 29.36
# Parameters are saved in pickle file
# epochs: 410, Loss: 5.613e-04, Time: 30.11
# Parameters are saved in pickle file
# epochs: 420, Loss: 6.348e-04, Time: 29.39
# Parameters are saved in pickle file
# epochs: 430, Loss: 5.720e-04, Time: 29.20
# Parameters are saved in pickle file
# epochs: 440, Loss: 6.445e-04, Time: 28.57
# Parameters are saved in pickle file
# epochs: 450, Loss: 6.015e-04, Time: 29.20
# Parameters are saved in pickle file
# epochs: 460, Loss: 5.999e-04, Time: 29.44
# Parameters are saved in pickle file
# epochs: 470, Loss: 5.196e-04, Time: 29.66
# Parameters are saved in pickle file
# epochs: 480, Loss: 5.095e-04, Time: 29.39
# Parameters are saved in pickle file
# epochs: 490, Loss: 5.573e-04, Time: 29.42
# Parameters are saved in pickle file
# epochs: 500, Loss: 6.010e-04, Time: 29.05
# Parameters are saved in pickle file
# epochs: 510, Loss: 5.897e-04, Time: 28.76
# Parameters are saved in pickle file
# epochs: 520, Loss: 5.849e-04, Time: 29.42
# Parameters are saved in pickle file
# epochs: 530, Loss: 6.029e-04, Time: 29.29
# Parameters are saved in pickle file
# epochs: 540, Loss: 6.482e-04, Time: 29.46
# Parameters are saved in pickle file
# epochs: 550, Loss: 5.241e-04, Time: 28.97
# Parameters are saved in pickle file
# epochs: 560, Loss: 5.501e-04, Time: 29.31
# Parameters are saved in pickle file
# epochs: 570, Loss: 5.413e-04, Time: 29.13
# Parameters are saved in pickle file
# epochs: 580, Loss: 5.065e-04, Time: 28.68
# Parameters are saved in pickle file
# epochs: 590, Loss: 4.559e-04, Time: 29.36
# Parameters are saved in pickle file
# epochs: 600, Loss: 5.704e-04, Time: 29.23
# Parameters are saved in pickle file
# epochs: 610, Loss: 5.061e-04, Time: 29.32
# Parameters are saved in pickle file
# epochs: 620, Loss: 5.375e-04, Time: 28.93
# Parameters are saved in pickle file
# epochs: 630, Loss: 5.378e-04, Time: 29.24
# Parameters are saved in pickle file
# epochs: 640, Loss: 5.993e-04, Time: 29.01
# Parameters are saved in pickle file
# epochs: 650, Loss: 4.991e-04, Time: 28.48
# Parameters are saved in pickle file
# epochs: 660, Loss: 6.053e-04, Time: 29.45
# Parameters are saved in pickle file
# epochs: 670, Loss: 5.029e-04, Time: 29.63
# Parameters are saved in pickle file
# epochs: 680, Loss: 5.383e-04, Time: 29.28
# Parameters are saved in pickle file
# epochs: 690, Loss: 5.506e-04, Time: 29.61
# Parameters are saved in pickle file
# epochs: 700, Loss: 4.815e-04, Time: 29.50
# Parameters are saved in pickle file
# epochs: 710, Loss: 4.901e-04, Time: 28.91
# Parameters are saved in pickle file
# epochs: 720, Loss: 5.197e-04, Time: 28.88
# Parameters are saved in pickle file
# epochs: 730, Loss: 5.132e-04, Time: 29.36
# Parameters are saved in pickle file
# epochs: 740, Loss: 4.634e-04, Time: 29.09
# Parameters are saved in pickle file
# epochs: 750, Loss: 4.981e-04, Time: 29.50
# Parameters are saved in pickle file
# epochs: 760, Loss: 5.844e-04, Time: 29.03
# Parameters are saved in pickle file
# epochs: 770, Loss: 5.102e-04, Time: 29.21
# Parameters are saved in pickle file
# epochs: 780, Loss: 4.934e-04, Time: 29.19
# Parameters are saved in pickle file
# epochs: 790, Loss: 5.122e-04, Time: 28.76
# Parameters are saved in pickle file
# epochs: 800, Loss: 4.565e-04, Time: 29.43
# Parameters are saved in pickle file
# epochs: 810, Loss: 5.281e-04, Time: 29.33
# Parameters are saved in pickle file
# epochs: 820, Loss: 4.962e-04, Time: 29.65
# Parameters are saved in pickle file
# epochs: 830, Loss: 6.051e-04, Time: 29.60
# Parameters are saved in pickle file
# epochs: 840, Loss: 5.278e-04, Time: 29.72
# Parameters are saved in pickle file
# epochs: 850, Loss: 5.142e-04, Time: 28.76
# Parameters are saved in pickle file
# epochs: 860, Loss: 4.832e-04, Time: 28.54
# Parameters are saved in pickle file
# epochs: 870, Loss: 5.606e-04, Time: 29.41
# Parameters are saved in pickle file
# epochs: 880, Loss: 4.930e-04, Time: 29.19
# Parameters are saved in pickle file
# epochs: 890, Loss: 4.403e-04, Time: 29.37
# Parameters are saved in pickle file
# epochs: 900, Loss: 5.008e-04, Time: 29.20
# Parameters are saved in pickle file
# epochs: 910, Loss: 4.456e-04, Time: 29.29
# Parameters are saved in pickle file
# epochs: 920, Loss: 4.913e-04, Time: 28.68
# Parameters are saved in pickle file
# epochs: 930, Loss: 4.314e-04, Time: 28.78
# Parameters are saved in pickle file
# epochs: 940, Loss: 4.634e-04, Time: 29.42
# Parameters are saved in pickle file
# epochs: 950, Loss: 5.077e-04, Time: 29.19
# Parameters are saved in pickle file
# epochs: 960, Loss: 4.768e-04, Time: 29.73
# Parameters are saved in pickle file
# epochs: 970, Loss: 4.859e-04, Time: 29.25
# Parameters are saved in pickle file
# epochs: 980, Loss: 5.077e-04, Time: 29.38
# Parameters are saved in pickle file
# epochs: 990, Loss: 4.469e-04, Time: 28.87
# Parameters are saved in pickle file
# Saving the predictions for time step: [2.]
# Predictions are saved in pickle file
# Previous predictions are loaded from pickle file
# wandb: WARNING Calling wandb.run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# Previous predictions are saved in pickle file
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Data_loss</td><td>█▅▅▄▃▃▃▃▃▃▃▂▃▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Previous_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>█▃▃▂▄▂▄▂▄▂▄▃▃▄▁▂▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 2</td><td>█▆▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 3</td><td>▁▆▄▃▂▃▃▃▃▄▄▄▄▄▄▄▄▄▄▅▅▅▆▆▇▇▇▇████████████</td></tr><tr><td>time step 4</td><td>██▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂</td></tr><tr><td>time step 5</td><td>▆▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▃▅▅▆▆▆▇▇▇▇▇▇██████████</td></tr><tr><td>time step 6</td><td>▃▄▃▂▁▁▁▁▂▂▂▂▂▂▂▂▂▃▃▅▅▆▆▇▇▇██████████████</td></tr><tr><td>time step 7</td><td>▃▄▂▁▁▁▁▂▂▃▃▃▃▃▃▃▃▄▄▅▅▆▆▇▇███████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>0.00013</td></tr><tr><td>Data_loss</td><td>0.00021</td></tr><tr><td>Initial_loss</td><td>0.0</td></tr><tr><td>Previous_loss</td><td>3e-05</td></tr><tr><td>Residual_loss</td><td>7e-05</td></tr><tr><td>Total_loss</td><td>0.00045</td></tr><tr><td>time step 1</td><td>0.01617</td></tr><tr><td>time step 2</td><td>0.01531</td></tr><tr><td>time step 3</td><td>0.21888</td></tr><tr><td>time step 4</td><td>0.2448</td></tr><tr><td>time step 5</td><td>0.61181</td></tr><tr><td>time step 6</td><td>1.32432</td></tr><tr><td>time step 7</td><td>2.03141</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fragrant-shadow-7</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/desiehdj" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/desiehdj</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220917_032014-desiehdj\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.033510502179463705, max=1.0…
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20220917_050030-2blt9zrr</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/2blt9zrr" target="_blank">smart-monkey-8</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 2 3 ]
# ===============================================================================================
# epochs: 0, Loss: 1.429e-01, Time: 27.38
# epochs: 10, Loss: 9.643e-03, Time: 29.65
# Parameters are saved in pickle file
# epochs: 20, Loss: 6.314e-03, Time: 33.47
# Parameters are saved in pickle file
# epochs: 30, Loss: 4.300e-03, Time: 30.74
# Parameters are saved in pickle file
# epochs: 40, Loss: 3.829e-03, Time: 30.41
# Parameters are saved in pickle file
# epochs: 50, Loss: 5.193e-03, Time: 30.26
# Parameters are saved in pickle file
# epochs: 60, Loss: 4.563e-03, Time: 29.62
# Parameters are saved in pickle file
# epochs: 70, Loss: 3.441e-03, Time: 30.40
# Parameters are saved in pickle file
# epochs: 80, Loss: 3.402e-03, Time: 30.07
# Parameters are saved in pickle file
# epochs: 90, Loss: 3.417e-03, Time: 30.40
# Parameters are saved in pickle file
# epochs: 100, Loss: 3.361e-03, Time: 31.23
# Parameters are saved in pickle file
# epochs: 110, Loss: 3.347e-03, Time: 30.13
# Parameters are saved in pickle file
# epochs: 120, Loss: 3.928e-03, Time: 30.44
# Parameters are saved in pickle file
# epochs: 130, Loss: 3.691e-03, Time: 29.47
# Parameters are saved in pickle file
# epochs: 140, Loss: 4.366e-03, Time: 30.39
# Parameters are saved in pickle file
# epochs: 150, Loss: 2.533e-03, Time: 29.98
# Parameters are saved in pickle file
# epochs: 160, Loss: 1.984e-03, Time: 30.47
# Parameters are saved in pickle file
# epochs: 170, Loss: 2.034e-03, Time: 30.56
# Parameters are saved in pickle file
# epochs: 180, Loss: 1.966e-03, Time: 29.66
# Parameters are saved in pickle file
# epochs: 190, Loss: 1.816e-03, Time: 29.75
# Parameters are saved in pickle file
# epochs: 200, Loss: 2.691e-03, Time: 30.10
# Parameters are saved in pickle file
# epochs: 210, Loss: 2.982e-03, Time: 30.20
# Parameters are saved in pickle file
# epochs: 220, Loss: 3.550e-03, Time: 30.14
# Parameters are saved in pickle file
# epochs: 230, Loss: 2.624e-03, Time: 30.79
# Parameters are saved in pickle file
# epochs: 240, Loss: 2.935e-03, Time: 30.45
# Parameters are saved in pickle file
# epochs: 250, Loss: 3.530e-03, Time: 29.70
# Parameters are saved in pickle file
# epochs: 260, Loss: 1.705e-03, Time: 29.41
# Parameters are saved in pickle file
# epochs: 270, Loss: 2.974e-03, Time: 30.54
# Parameters are saved in pickle file
# epochs: 280, Loss: 2.301e-03, Time: 30.03
# Parameters are saved in pickle file
# epochs: 290, Loss: 1.469e-03, Time: 29.95
# Parameters are saved in pickle file
# epochs: 300, Loss: 1.693e-03, Time: 30.50
# Parameters are saved in pickle file
# epochs: 310, Loss: 1.214e-02, Time: 30.33
# Parameters are saved in pickle file
# epochs: 320, Loss: 4.994e-03, Time: 29.66
# Parameters are saved in pickle file
# epochs: 330, Loss: 3.103e-03, Time: 29.77
# Parameters are saved in pickle file
# epochs: 340, Loss: 4.117e-03, Time: 30.86
# Parameters are saved in pickle file
# epochs: 350, Loss: 2.816e-03, Time: 30.69
# Parameters are saved in pickle file
# epochs: 360, Loss: 3.168e-03, Time: 30.19
# Parameters are saved in pickle file
# epochs: 370, Loss: 2.762e-03, Time: 30.15
# Parameters are saved in pickle file
# epochs: 380, Loss: 2.603e-03, Time: 28.67
# Parameters are saved in pickle file
# epochs: 390, Loss: 3.917e-03, Time: 28.71
# Parameters are saved in pickle file
# epochs: 400, Loss: 1.949e-03, Time: 30.03
# Parameters are saved in pickle file
# epochs: 410, Loss: 3.281e-03, Time: 30.93
# Parameters are saved in pickle file
# epochs: 420, Loss: 1.920e-03, Time: 30.61
# Parameters are saved in pickle file
# epochs: 430, Loss: 3.587e-03, Time: 30.30
# Parameters are saved in pickle file
# epochs: 440, Loss: 1.401e-03, Time: 30.57
# Parameters are saved in pickle file
# epochs: 450, Loss: 1.625e-03, Time: 29.54
# Parameters are saved in pickle file
# epochs: 460, Loss: 1.575e-03, Time: 30.19
# Parameters are saved in pickle file
# epochs: 470, Loss: 2.428e-03, Time: 30.52
# Parameters are saved in pickle file
# epochs: 480, Loss: 2.753e-03, Time: 30.82
# Parameters are saved in pickle file
# epochs: 490, Loss: 3.488e-03, Time: 30.84
# Parameters are saved in pickle file
# epochs: 500, Loss: 1.729e-03, Time: 30.57
# Parameters are saved in pickle file
# epochs: 510, Loss: 8.869e-03, Time: 30.53
# Parameters are saved in pickle file
# epochs: 520, Loss: 3.025e-03, Time: 29.32
# Parameters are saved in pickle file
# epochs: 530, Loss: 2.817e-03, Time: 30.35
# Parameters are saved in pickle file
# epochs: 540, Loss: 1.995e-03, Time: 30.47
# Parameters are saved in pickle file
# epochs: 550, Loss: 1.464e-03, Time: 30.74
# Parameters are saved in pickle file
# epochs: 560, Loss: 1.365e-03, Time: 30.54
# Parameters are saved in pickle file
# epochs: 570, Loss: 3.866e-03, Time: 30.16
# Parameters are saved in pickle file
# epochs: 580, Loss: 1.379e-03, Time: 29.96
# Parameters are saved in pickle file
# epochs: 590, Loss: 3.091e-03, Time: 30.09
# Parameters are saved in pickle file
# epochs: 600, Loss: 1.715e-03, Time: 30.55
# Parameters are saved in pickle file
# epochs: 610, Loss: 3.361e-03, Time: 30.79
# Parameters are saved in pickle file
# epochs: 620, Loss: 1.364e-03, Time: 30.45
# Parameters are saved in pickle file
# epochs: 630, Loss: 1.523e-03, Time: 30.43
# Parameters are saved in pickle file
# epochs: 640, Loss: 2.584e-03, Time: 29.46
# Parameters are saved in pickle file
# epochs: 650, Loss: 2.028e-03, Time: 29.87
# Parameters are saved in pickle file
# epochs: 660, Loss: 1.473e-03, Time: 30.53
# Parameters are saved in pickle file
# epochs: 670, Loss: 2.208e-03, Time: 30.19
# Parameters are saved in pickle file
# epochs: 680, Loss: 3.641e-03, Time: 30.18
# Parameters are saved in pickle file
# epochs: 690, Loss: 1.382e-03, Time: 31.05
# Parameters are saved in pickle file
# epochs: 700, Loss: 2.468e-03, Time: 30.22
# Parameters are saved in pickle file
# epochs: 710, Loss: 2.340e-03, Time: 29.44
# Parameters are saved in pickle file
# epochs: 720, Loss: 2.511e-03, Time: 29.74
# Parameters are saved in pickle file
# epochs: 730, Loss: 2.747e-03, Time: 30.68
# Parameters are saved in pickle file
# epochs: 740, Loss: 1.584e-03, Time: 30.21
# Parameters are saved in pickle file
# epochs: 750, Loss: 2.011e-03, Time: 30.49
# Parameters are saved in pickle file
# epochs: 760, Loss: 1.445e-03, Time: 30.79
# Parameters are saved in pickle file
# epochs: 770, Loss: 2.189e-03, Time: 29.65
# Parameters are saved in pickle file
# epochs: 780, Loss: 3.715e-02, Time: 30.47
# Parameters are saved in pickle file
# epochs: 790, Loss: 5.697e-03, Time: 30.45
# Parameters are saved in pickle file
# epochs: 800, Loss: 4.240e-03, Time: 30.37
# Parameters are saved in pickle file
# epochs: 810, Loss: 3.409e-03, Time: 30.05
# Parameters are saved in pickle file
# epochs: 820, Loss: 3.719e-03, Time: 30.23
# Parameters are saved in pickle file
# epochs: 830, Loss: 3.200e-03, Time: 30.71
# Parameters are saved in pickle file
# epochs: 840, Loss: 2.850e-03, Time: 29.43
# Parameters are saved in pickle file
# epochs: 850, Loss: 2.909e-03, Time: 30.62
# Parameters are saved in pickle file
# epochs: 860, Loss: 1.862e-03, Time: 30.19
# Parameters are saved in pickle file
# epochs: 870, Loss: 2.483e-03, Time: 30.99
# Parameters are saved in pickle file
# epochs: 880, Loss: 2.399e-03, Time: 30.81
# Parameters are saved in pickle file
# epochs: 890, Loss: 1.866e-03, Time: 30.69
# Parameters are saved in pickle file
# epochs: 900, Loss: 2.885e-03, Time: 29.93
# Parameters are saved in pickle file
# epochs: 910, Loss: 1.375e-03, Time: 30.03
# Parameters are saved in pickle file
# epochs: 920, Loss: 1.565e-03, Time: 30.79
# Parameters are saved in pickle file
# epochs: 930, Loss: 2.964e-03, Time: 30.49
# Parameters are saved in pickle file
# epochs: 940, Loss: 1.691e-03, Time: 30.40
# Parameters are saved in pickle file
# epochs: 950, Loss: 2.288e-03, Time: 30.77
# Parameters are saved in pickle file
# epochs: 960, Loss: 2.408e-03, Time: 30.10
# Parameters are saved in pickle file
# epochs: 970, Loss: 1.673e-03, Time: 30.07
# Parameters are saved in pickle file
# epochs: 980, Loss: 2.025e-03, Time: 30.40
# Parameters are saved in pickle file
# epochs: 990, Loss: 2.880e-03, Time: 30.84
# Parameters are saved in pickle file
# epochs: 0, Loss: 9.146e-04, Time: 3.18
# epochs: 10, Loss: 7.584e-04, Time: 30.56
# Parameters are saved in pickle file
# epochs: 20, Loss: 7.191e-04, Time: 30.69
# Parameters are saved in pickle file
# epochs: 30, Loss: 7.069e-04, Time: 29.56
# Parameters are saved in pickle file
# epochs: 40, Loss: 7.188e-04, Time: 31.15
# Parameters are saved in pickle file
# epochs: 50, Loss: 7.734e-04, Time: 29.93
# Parameters are saved in pickle file
# epochs: 60, Loss: 7.092e-04, Time: 30.33
# Parameters are saved in pickle file
# epochs: 70, Loss: 6.677e-04, Time: 30.23
# Parameters are saved in pickle file
# epochs: 80, Loss: 6.600e-04, Time: 30.31
# Parameters are saved in pickle file
# epochs: 90, Loss: 7.733e-04, Time: 29.90
# Parameters are saved in pickle file
# epochs: 100, Loss: 6.295e-04, Time: 30.07
# Parameters are saved in pickle file
# epochs: 110, Loss: 6.923e-04, Time: 30.08
# Parameters are saved in pickle file
# epochs: 120, Loss: 6.268e-04, Time: 30.32
# Parameters are saved in pickle file
# epochs: 130, Loss: 6.892e-04, Time: 30.55
# Parameters are saved in pickle file
# epochs: 140, Loss: 7.029e-04, Time: 30.42
# Parameters are saved in pickle file
# epochs: 150, Loss: 6.527e-04, Time: 30.20
# Parameters are saved in pickle file
# epochs: 160, Loss: 7.168e-04, Time: 29.61
# Parameters are saved in pickle file
# epochs: 170, Loss: 7.475e-04, Time: 30.67
# Parameters are saved in pickle file
# epochs: 180, Loss: 6.598e-04, Time: 30.40
# Parameters are saved in pickle file
# epochs: 190, Loss: 6.905e-04, Time: 30.83
# Parameters are saved in pickle file
# epochs: 200, Loss: 6.857e-04, Time: 31.27
# Parameters are saved in pickle file
# epochs: 210, Loss: 6.099e-04, Time: 30.58
# Parameters are saved in pickle file
# epochs: 220, Loss: 6.874e-04, Time: 29.50
# Parameters are saved in pickle file
# epochs: 230, Loss: 7.526e-04, Time: 30.26
# Parameters are saved in pickle file
# epochs: 240, Loss: 6.788e-04, Time: 30.73
# Parameters are saved in pickle file
# epochs: 250, Loss: 6.871e-04, Time: 30.92
# Parameters are saved in pickle file
# epochs: 260, Loss: 5.865e-04, Time: 29.95
# Parameters are saved in pickle file
# epochs: 270, Loss: 6.286e-04, Time: 31.01
# Parameters are saved in pickle file
# epochs: 280, Loss: 6.487e-04, Time: 29.88
# Parameters are saved in pickle file
# epochs: 290, Loss: 5.972e-04, Time: 30.34
# Parameters are saved in pickle file
# epochs: 300, Loss: 5.988e-04, Time: 30.47
# Parameters are saved in pickle file
# epochs: 310, Loss: 5.912e-04, Time: 30.66
# Parameters are saved in pickle file
# epochs: 320, Loss: 5.375e-04, Time: 30.88
# Parameters are saved in pickle file
# epochs: 330, Loss: 5.746e-04, Time: 30.81
# Parameters are saved in pickle file
# epochs: 340, Loss: 5.789e-04, Time: 30.27
# Parameters are saved in pickle file
# epochs: 350, Loss: 5.827e-04, Time: 29.71
# Parameters are saved in pickle file
# epochs: 360, Loss: 6.002e-04, Time: 30.08
# Parameters are saved in pickle file
# epochs: 370, Loss: 5.855e-04, Time: 30.12
# Parameters are saved in pickle file
# epochs: 380, Loss: 5.463e-04, Time: 30.09
# Parameters are saved in pickle file
# epochs: 390, Loss: 5.387e-04, Time: 30.71
# Parameters are saved in pickle file
# epochs: 400, Loss: 5.631e-04, Time: 30.34
# Parameters are saved in pickle file
# epochs: 410, Loss: 5.412e-04, Time: 29.90
# Parameters are saved in pickle file
# epochs: 420, Loss: 5.860e-04, Time: 30.07
# Parameters are saved in pickle file
# epochs: 430, Loss: 5.854e-04, Time: 31.18
# Parameters are saved in pickle file
# epochs: 440, Loss: 5.305e-04, Time: 30.39
# Parameters are saved in pickle file
# epochs: 450, Loss: 5.124e-04, Time: 30.18
# Parameters are saved in pickle file
# epochs: 460, Loss: 5.382e-04, Time: 30.68
# Parameters are saved in pickle file
# epochs: 470, Loss: 5.351e-04, Time: 29.92
# Parameters are saved in pickle file
# epochs: 480, Loss: 5.227e-04, Time: 30.28
# Parameters are saved in pickle file
# epochs: 490, Loss: 5.096e-04, Time: 30.07
# Parameters are saved in pickle file
# epochs: 500, Loss: 5.310e-04, Time: 30.69
# Parameters are saved in pickle file
# epochs: 510, Loss: 4.793e-04, Time: 30.27
# Parameters are saved in pickle file
# epochs: 520, Loss: 5.094e-04, Time: 30.30
# Parameters are saved in pickle file
# epochs: 530, Loss: 5.826e-04, Time: 30.78
# Parameters are saved in pickle file
# epochs: 540, Loss: 5.218e-04, Time: 29.48
# Parameters are saved in pickle file
# epochs: 550, Loss: 5.192e-04, Time: 30.09
# Parameters are saved in pickle file
# epochs: 560, Loss: 5.498e-04, Time: 30.23
# Parameters are saved in pickle file
# epochs: 570, Loss: 5.206e-04, Time: 30.72
# Parameters are saved in pickle file
# epochs: 580, Loss: 4.735e-04, Time: 30.00
# Parameters are saved in pickle file
# epochs: 590, Loss: 5.277e-04, Time: 30.33
# Parameters are saved in pickle file
# epochs: 600, Loss: 5.314e-04, Time: 29.62
# Parameters are saved in pickle file
# epochs: 610, Loss: 4.661e-04, Time: 30.41
# Parameters are saved in pickle file
# epochs: 620, Loss: 4.899e-04, Time: 30.72
# Parameters are saved in pickle file
# epochs: 630, Loss: 5.122e-04, Time: 30.29
# Parameters are saved in pickle file
# epochs: 640, Loss: 4.954e-04, Time: 30.74
# Parameters are saved in pickle file
# epochs: 650, Loss: 4.980e-04, Time: 30.46
# Parameters are saved in pickle file
# epochs: 660, Loss: 5.428e-04, Time: 29.68
# Parameters are saved in pickle file
# epochs: 670, Loss: 5.123e-04, Time: 28.58
# Parameters are saved in pickle file
# epochs: 680, Loss: 5.233e-04, Time: 30.05
# Parameters are saved in pickle file
# epochs: 690, Loss: 4.574e-04, Time: 30.52
# Parameters are saved in pickle file
# epochs: 700, Loss: 4.897e-04, Time: 30.13
# Parameters are saved in pickle file
# epochs: 710, Loss: 5.288e-04, Time: 30.33
# Parameters are saved in pickle file
# epochs: 720, Loss: 4.682e-04, Time: 29.98
# Parameters are saved in pickle file
# epochs: 730, Loss: 4.528e-04, Time: 30.28
# Parameters are saved in pickle file
# epochs: 740, Loss: 4.478e-04, Time: 29.74
# Parameters are saved in pickle file
# epochs: 750, Loss: 5.167e-04, Time: 30.62
# Parameters are saved in pickle file
# epochs: 760, Loss: 5.123e-04, Time: 30.50
# Parameters are saved in pickle file
# epochs: 770, Loss: 4.686e-04, Time: 30.02
# Parameters are saved in pickle file
# epochs: 780, Loss: 5.064e-04, Time: 31.09
# Parameters are saved in pickle file
# epochs: 790, Loss: 4.695e-04, Time: 30.71
# Parameters are saved in pickle file
# epochs: 800, Loss: 5.010e-04, Time: 29.42
# Parameters are saved in pickle file
# epochs: 810, Loss: 4.921e-04, Time: 30.32
# Parameters are saved in pickle file
# epochs: 820, Loss: 5.100e-04, Time: 30.76
# Parameters are saved in pickle file
# epochs: 830, Loss: 4.835e-04, Time: 30.39
# Parameters are saved in pickle file
# epochs: 840, Loss: 4.856e-04, Time: 30.19
# Parameters are saved in pickle file
# epochs: 850, Loss: 4.854e-04, Time: 30.91
# Parameters are saved in pickle file
# epochs: 860, Loss: 4.554e-04, Time: 29.80
# Parameters are saved in pickle file
# epochs: 870, Loss: 4.716e-04, Time: 30.16
# Parameters are saved in pickle file
# epochs: 880, Loss: 4.613e-04, Time: 30.41
# Parameters are saved in pickle file
# epochs: 890, Loss: 5.001e-04, Time: 30.68
# Parameters are saved in pickle file
# epochs: 900, Loss: 4.607e-04, Time: 30.47
# Parameters are saved in pickle file
# epochs: 910, Loss: 4.869e-04, Time: 29.96
# Parameters are saved in pickle file
# epochs: 920, Loss: 4.793e-04, Time: 30.55
# Parameters are saved in pickle file
# epochs: 930, Loss: 4.653e-04, Time: 29.49
# Parameters are saved in pickle file
# epochs: 940, Loss: 4.274e-04, Time: 30.87
# Parameters are saved in pickle file
# epochs: 950, Loss: 4.851e-04, Time: 29.94
# Parameters are saved in pickle file
# epochs: 960, Loss: 4.556e-04, Time: 30.58
# Parameters are saved in pickle file
# epochs: 970, Loss: 4.872e-04, Time: 31.03
# Parameters are saved in pickle file
# epochs: 980, Loss: 4.929e-04, Time: 29.60
# Parameters are saved in pickle file
# epochs: 990, Loss: 4.567e-04, Time: 29.86
# Parameters are saved in pickle file
# Saving the predictions for time step: [3.]
# Predictions are saved in pickle file
# Previous predictions are loaded from pickle file
# Previous predictions are saved in pickle file
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>▄▂▂▂▁▁█▂▁▁▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Data_loss</td><td>▃▂▂▂▁▂█▂▁▁▂▁▁▁▁▁▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>█▂▂▂▂▂▂▂▃▁▅▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Previous_loss</td><td>█▅▂▂▁▂▁▁▃▁▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>▃▂▃▂▃▃▄▂▂▂█▂▃▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>▇▄▃▂▃▃█▂▃▂▆▂▃▂▂▂▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>█▅▂▂▂▂▂▂▄▂▂▁▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 2</td><td>█▄▂▂▂▂▃▂▃▂▂▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 3</td><td>▃▃▂▂▂▂█▃▂▂▃▂▂▂▂▁▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 4</td><td>▄▄▆▇▇▇▂▂▆████▇▇▆▁▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>time step 5</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 6</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 7</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>0.00013</td></tr><tr><td>Data_loss</td><td>0.00021</td></tr><tr><td>Initial_loss</td><td>0.0</td></tr><tr><td>Previous_loss</td><td>5e-05</td></tr><tr><td>Residual_loss</td><td>6e-05</td></tr><tr><td>Total_loss</td><td>0.00046</td></tr><tr><td>time step 1</td><td>0.01579</td></tr><tr><td>time step 2</td><td>0.01517</td></tr><tr><td>time step 3</td><td>0.0148</td></tr><tr><td>time step 4</td><td>0.21997</td></tr><tr><td>time step 5</td><td>0.244</td></tr><tr><td>time step 6</td><td>1.11972</td></tr><tr><td>time step 7</td><td>5.51505</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">smart-monkey-8</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/2blt9zrr" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/2blt9zrr</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220917_050030-2blt9zrr\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.03333369890848795, max=1.0)…
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20220917_064425-26psicsj</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/26psicsj" target="_blank">visionary-bird-9</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 3 4 ]
# ===============================================================================================
# epochs: 0, Loss: 1.258e-01, Time: 26.69
# epochs: 10, Loss: 1.114e-02, Time: 31.42
# Parameters are saved in pickle file
# epochs: 20, Loss: 6.532e-03, Time: 34.40
# Parameters are saved in pickle file
# epochs: 30, Loss: 5.879e-03, Time: 31.92
# Parameters are saved in pickle file
# epochs: 40, Loss: 5.876e-03, Time: 31.42
# Parameters are saved in pickle file
# epochs: 50, Loss: 4.845e-03, Time: 30.58
# Parameters are saved in pickle file
# epochs: 60, Loss: 4.058e-03, Time: 31.37
# Parameters are saved in pickle file
# epochs: 70, Loss: 3.242e-03, Time: 32.11
# Parameters are saved in pickle file
# epochs: 80, Loss: 5.634e-03, Time: 32.08
# Parameters are saved in pickle file
# epochs: 90, Loss: 3.554e-03, Time: 32.03
# Parameters are saved in pickle file
# epochs: 100, Loss: 3.269e-03, Time: 30.66
# Parameters are saved in pickle file
# epochs: 110, Loss: 3.168e-03, Time: 31.10
# Parameters are saved in pickle file
# epochs: 120, Loss: 3.464e-03, Time: 31.79
# Parameters are saved in pickle file
# epochs: 130, Loss: 2.990e-03, Time: 31.69
# Parameters are saved in pickle file
# epochs: 140, Loss: 3.468e-03, Time: 31.30
# Parameters are saved in pickle file
# epochs: 150, Loss: 3.180e-03, Time: 31.89
# Parameters are saved in pickle file
# epochs: 160, Loss: 3.033e-03, Time: 30.94
# Parameters are saved in pickle file
# epochs: 170, Loss: 2.704e-03, Time: 31.18
# Parameters are saved in pickle file
# epochs: 180, Loss: 3.556e-03, Time: 31.56
# Parameters are saved in pickle file
# epochs: 190, Loss: 3.113e-03, Time: 31.43
# Parameters are saved in pickle file
# epochs: 200, Loss: 4.060e-03, Time: 30.97
# Parameters are saved in pickle file
# epochs: 210, Loss: 1.634e-03, Time: 31.40
# Parameters are saved in pickle file
# epochs: 220, Loss: 2.059e-03, Time: 31.13
# Parameters are saved in pickle file
# epochs: 230, Loss: 2.470e-03, Time: 31.12
# Parameters are saved in pickle file
# epochs: 240, Loss: 2.964e-03, Time: 31.84
# Parameters are saved in pickle file
# epochs: 250, Loss: 2.174e-03, Time: 31.90
# Parameters are saved in pickle file
# epochs: 260, Loss: 2.121e-03, Time: 31.18
# Parameters are saved in pickle file
# epochs: 270, Loss: 4.659e-02, Time: 30.95
# Parameters are saved in pickle file
# epochs: 280, Loss: 9.237e-03, Time: 30.94
# Parameters are saved in pickle file
# epochs: 290, Loss: 6.778e-03, Time: 30.57
# Parameters are saved in pickle file
# epochs: 300, Loss: 6.386e-03, Time: 32.00
# Parameters are saved in pickle file
# epochs: 310, Loss: 5.166e-03, Time: 32.02
# Parameters are saved in pickle file
# epochs: 320, Loss: 5.257e-03, Time: 31.83
# Parameters are saved in pickle file
# epochs: 330, Loss: 4.238e-03, Time: 31.91
# Parameters are saved in pickle file
# epochs: 340, Loss: 6.017e-03, Time: 30.79
# Parameters are saved in pickle file
# epochs: 350, Loss: 3.943e-03, Time: 31.54
# Parameters are saved in pickle file
# epochs: 360, Loss: 4.527e-03, Time: 31.61
# Parameters are saved in pickle file
# epochs: 370, Loss: 4.914e-03, Time: 31.90
# Parameters are saved in pickle file
# epochs: 380, Loss: 3.796e-03, Time: 31.89
# Parameters are saved in pickle file
# epochs: 390, Loss: 3.797e-03, Time: 31.62
# Parameters are saved in pickle file
# epochs: 400, Loss: 4.860e-03, Time: 30.40
# Parameters are saved in pickle file
# epochs: 410, Loss: 4.481e-03, Time: 31.92
# Parameters are saved in pickle file
# epochs: 420, Loss: 4.683e-03, Time: 31.44
# Parameters are saved in pickle file
# epochs: 430, Loss: 3.081e-03, Time: 31.64
# Parameters are saved in pickle file
# epochs: 440, Loss: 3.361e-03, Time: 31.95
# Parameters are saved in pickle file
# epochs: 450, Loss: 2.998e-03, Time: 31.59
# Parameters are saved in pickle file
# epochs: 460, Loss: 2.175e-03, Time: 30.96
# Parameters are saved in pickle file
# epochs: 470, Loss: 3.492e-03, Time: 31.84
# Parameters are saved in pickle file
# epochs: 480, Loss: 2.400e-03, Time: 31.75
# Parameters are saved in pickle file
# epochs: 490, Loss: 4.495e-03, Time: 32.34
# Parameters are saved in pickle file
# epochs: 500, Loss: 2.985e-03, Time: 31.78
# Parameters are saved in pickle file
# epochs: 510, Loss: 2.114e-03, Time: 30.61
# Parameters are saved in pickle file
# epochs: 520, Loss: 2.385e-03, Time: 31.14
# Parameters are saved in pickle file
# epochs: 530, Loss: 3.116e-03, Time: 31.38
# Parameters are saved in pickle file
# epochs: 540, Loss: 2.329e-03, Time: 30.87
# Parameters are saved in pickle file
# epochs: 550, Loss: 3.891e-03, Time: 31.95
# ...
# epochs: 110, Loss: 6.322e-04, Time: 31.29
# Parameters are saved in pickle file
# epochs: 120, Loss: 6.453e-04, Time: 31.22
# Parameters are saved in pickle file
# epochs: 130, Loss: 5.785e-04, Time: 31.91
# Parameters are saved in pickle file
# epochs: 140, Loss: 6.270e-04, Time: 31.48
# Parameters are saved in pickle file
# epochs: 150, Loss: 6.149e-04, Time: 31.82
# Parameters are saved in pickle file
# epochs: 160, Loss: 6.533e-04, Time: 30.86
# Parameters are saved in pickle file
# epochs: 170, Loss: 6.653e-04, Time: 31.46
# Parameters are saved in pickle file
# epochs: 180, Loss: 5.543e-04, Time: 31.97
# Parameters are saved in pickle file
# epochs: 190, Loss: 5.796e-04, Time: 31.84
# Parameters are saved in pickle file
# epochs: 200, Loss: 6.158e-04, Time: 31.21
# Parameters are saved in pickle file
# epochs: 210, Loss: 5.653e-04, Time: 31.36
# Parameters are saved in pickle file
# epochs: 220, Loss: 5.830e-04, Time: 31.10
# Parameters are saved in pickle file
# epochs: 230, Loss: 5.901e-04, Time: 31.42
# Parameters are saved in pickle file
# epochs: 240, Loss: 6.110e-04, Time: 31.90
# Parameters are saved in pickle file
# epochs: 250, Loss: 6.072e-04, Time: 31.59
# Parameters are saved in pickle file
# epochs: 260, Loss: 5.483e-04, Time: 31.23
# Parameters are saved in pickle file
# epochs: 270, Loss: 6.166e-04, Time: 31.27
# Parameters are saved in pickle file
# epochs: 280, Loss: 5.908e-04, Time: 31.11
# Parameters are saved in pickle file
# epochs: 290, Loss: 5.924e-04, Time: 30.97
# Parameters are saved in pickle file
# epochs: 300, Loss: 5.882e-04, Time: 31.63
# Parameters are saved in pickle file
# epochs: 310, Loss: 5.479e-04, Time: 31.91
# Parameters are saved in pickle file
# epochs: 320, Loss: 5.712e-04, Time: 31.14
# Parameters are saved in pickle file
# epochs: 330, Loss: 5.521e-04, Time: 31.22
# Parameters are saved in pickle file
# epochs: 340, Loss: 5.649e-04, Time: 31.15
# Parameters are saved in pickle file
# epochs: 350, Loss: 5.848e-04, Time: 31.58
# Parameters are saved in pickle file
# epochs: 360, Loss: 5.660e-04, Time: 31.55
# Parameters are saved in pickle file
# epochs: 370, Loss: 5.586e-04, Time: 32.25
# Parameters are saved in pickle file
# epochs: 380, Loss: 5.663e-04, Time: 31.96
# Parameters are saved in pickle file
# epochs: 390, Loss: 5.386e-04, Time: 31.08
# Parameters are saved in pickle file
# epochs: 400, Loss: 5.343e-04, Time: 30.35
# Parameters are saved in pickle file
# epochs: 410, Loss: 5.856e-04, Time: 31.16
# Parameters are saved in pickle file
# epochs: 420, Loss: 5.154e-04, Time: 31.17
# Parameters are saved in pickle file
# epochs: 430, Loss: 5.554e-04, Time: 31.38
# Parameters are saved in pickle file
# epochs: 440, Loss: 5.385e-04, Time: 31.39
# Parameters are saved in pickle file
# epochs: 450, Loss: 5.465e-04, Time: 31.34
# Parameters are saved in pickle file
# epochs: 460, Loss: 5.438e-04, Time: 30.23
# Parameters are saved in pickle file
# epochs: 470, Loss: 5.112e-04, Time: 31.96
# Parameters are saved in pickle file
# epochs: 480, Loss: 5.396e-04, Time: 31.69
# Parameters are saved in pickle file
# epochs: 490, Loss: 5.043e-04, Time: 31.56
# Parameters are saved in pickle file
# epochs: 500, Loss: 4.894e-04, Time: 31.55
# Parameters are saved in pickle file
# epochs: 510, Loss: 5.313e-04, Time: 31.72
# Parameters are saved in pickle file
# epochs: 520, Loss: 5.477e-04, Time: 30.41
# Parameters are saved in pickle file
# epochs: 530, Loss: 5.206e-04, Time: 31.85
# Parameters are saved in pickle file
# epochs: 540, Loss: 5.318e-04, Time: 31.86
# Parameters are saved in pickle file
# epochs: 550, Loss: 5.029e-04, Time: 31.82
# Parameters are saved in pickle file
# epochs: 560, Loss: 4.903e-04, Time: 31.98
# Parameters are saved in pickle file
# epochs: 570, Loss: 5.088e-04, Time: 31.07
# Parameters are saved in pickle file
# epochs: 580, Loss: 4.537e-04, Time: 30.71
# Parameters are saved in pickle file
# epochs: 590, Loss: 4.769e-04, Time: 31.65
# Parameters are saved in pickle file
# epochs: 600, Loss: 5.390e-04, Time: 31.58
# Parameters are saved in pickle file
# epochs: 610, Loss: 4.785e-04, Time: 31.85
# Parameters are saved in pickle file
# epochs: 620, Loss: 5.135e-04, Time: 32.30
# Parameters are saved in pickle file
# epochs: 630, Loss: 5.229e-04, Time: 30.77
# Parameters are saved in pickle file
# epochs: 640, Loss: 5.230e-04, Time: 31.48
# Parameters are saved in pickle file
# epochs: 650, Loss: 4.996e-04, Time: 31.80
# Parameters are saved in pickle file
# epochs: 660, Loss: 4.801e-04, Time: 31.24
# Parameters are saved in pickle file
# epochs: 670, Loss: 5.272e-04, Time: 31.28
# Parameters are saved in pickle file
# epochs: 680, Loss: 4.803e-04, Time: 31.96
# Parameters are saved in pickle file
# epochs: 690, Loss: 4.700e-04, Time: 30.72
# Parameters are saved in pickle file
# epochs: 700, Loss: 4.849e-04, Time: 31.17
# Parameters are saved in pickle file
# epochs: 710, Loss: 5.380e-04, Time: 31.79
# Parameters are saved in pickle file
# epochs: 720, Loss: 4.793e-04, Time: 31.40
# Parameters are saved in pickle file
# epochs: 730, Loss: 5.081e-04, Time: 31.33
# Parameters are saved in pickle file
# epochs: 740, Loss: 4.919e-04, Time: 31.65
# Parameters are saved in pickle file
# epochs: 750, Loss: 5.069e-04, Time: 30.71
# Parameters are saved in pickle file
# epochs: 760, Loss: 4.669e-04, Time: 30.87
# Parameters are saved in pickle file
# epochs: 770, Loss: 4.897e-04, Time: 32.46
# Parameters are saved in pickle file
# epochs: 780, Loss: 4.813e-04, Time: 32.18
# Parameters are saved in pickle file
# epochs: 790, Loss: 5.391e-04, Time: 31.65
# Parameters are saved in pickle file
# epochs: 800, Loss: 4.580e-04, Time: 31.74
# Parameters are saved in pickle file
# epochs: 810, Loss: 5.332e-04, Time: 30.34
# Parameters are saved in pickle file
# epochs: 820, Loss: 4.655e-04, Time: 31.42
# Parameters are saved in pickle file
# epochs: 830, Loss: 4.726e-04, Time: 31.72
# Parameters are saved in pickle file
# epochs: 840, Loss: 4.616e-04, Time: 31.75
# Parameters are saved in pickle file
# epochs: 850, Loss: 4.673e-04, Time: 31.77
# Parameters are saved in pickle file
# epochs: 860, Loss: 4.504e-04, Time: 31.55
# Parameters are saved in pickle file
# epochs: 870, Loss: 4.767e-04, Time: 30.26
# Parameters are saved in pickle file
# epochs: 880, Loss: 4.504e-04, Time: 32.01
# Parameters are saved in pickle file
# epochs: 890, Loss: 5.346e-04, Time: 32.12
# Parameters are saved in pickle file
# epochs: 900, Loss: 4.562e-04, Time: 31.33
# Parameters are saved in pickle file
# epochs: 910, Loss: 5.058e-04, Time: 31.13
# Parameters are saved in pickle file
# epochs: 920, Loss: 4.336e-04, Time: 31.44
# Parameters are saved in pickle file
# epochs: 930, Loss: 4.463e-04, Time: 30.31
# Parameters are saved in pickle file
# epochs: 940, Loss: 4.480e-04, Time: 31.71
# Parameters are saved in pickle file
# epochs: 950, Loss: 4.510e-04, Time: 32.25
# Parameters are saved in pickle file
# epochs: 960, Loss: 4.851e-04, Time: 31.96
# Parameters are saved in pickle file
# epochs: 970, Loss: 4.488e-04, Time: 31.24
# Parameters are saved in pickle file
# epochs: 980, Loss: 4.546e-04, Time: 30.16
# Parameters are saved in pickle file
# epochs: 990, Loss: 4.319e-04, Time: 29.66
# Parameters are saved in pickle file
# Saving the predictions for time step: [4.]
# Predictions are saved in pickle file
# Previous predictions are loaded from pickle file
# Previous predictions are saved in pickle file
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>█▃▂▂▂▂▆▄▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Data_loss</td><td>▆▃▂▃▂▂█▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Initial_loss</td><td>█▃▂▂▁▂▂▂▂▂▂▃▂▂▂▁▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Previous_loss</td><td>█▃▂▂▂▂▂▂▂▁▁▁▂▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Residual_loss</td><td>█▆▅▅▂▃▄▅▆▅▃▇▆▃▆▃▇▅▄▅▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Total_loss</td><td>█▄▃▃▂▂▄▃▄▃▂▃▃▂▃▂▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 1</td><td>█▅▂▃▂▂▂▂▂▂▂▁▂▁▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 2</td><td>█▄▃▃▂▃▃▂▃▂▂▂▃▁▁▁▂▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 3</td><td>█▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 4</td><td>▅▃▂▂▂▂█▆▅▄▃▄▃▃▃▃▃▂▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time step 5</td><td>▅▄▄▄▄▅▁▃▆▇▇▆▆▆▇█▇▇▆▆▆▆▆▆▅▅▅▅▄▄▄▄▄▄▄▄▃▃▃▃</td></tr><tr><td>time step 6</td><td>▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▄▅▅▇███▇▇▇▇▇▇▆▇▇▇▆▆▇▇▇▇▇</td></tr><tr><td>time step 7</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▁▁▄▅▅▅▆███▇▇▇▇▆▆▆▆▆▆▆▆▇▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Boundary_loss</td><td>0.00013</td></tr><tr><td>Data_loss</td><td>0.00017</td></tr><tr><td>Initial_loss</td><td>0.0</td></tr><tr><td>Previous_loss</td><td>8e-05</td></tr><tr><td>Residual_loss</td><td>6e-05</td></tr><tr><td>Total_loss</td><td>0.00043</td></tr><tr><td>time step 1</td><td>0.01626</td></tr><tr><td>time step 2</td><td>0.01482</td></tr><tr><td>time step 3</td><td>0.01476</td></tr><tr><td>time step 4</td><td>0.01407</td></tr><tr><td>time step 5</td><td>0.21902</td></tr><tr><td>time step 6</td><td>3.87827</td></tr><tr><td>time step 7</td><td>14.60532</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">visionary-bird-9</strong>: <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/26psicsj" target="_blank">https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/26psicsj</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220917_064425-26psicsj\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.03351078828175862, max=1.0)…
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>C:\Users\user1\Downloads\Vamsi_oe20s302\Research work\Re100_experiments\Novel method\wandb\run-20220917_083217-17lvcg28</code>
# Syncing run <strong><a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training/runs/17lvcg28" target="_blank">comfy-monkey-10</a></strong> to <a href="https://wandb.ai/vamsi_malineni6/bc_pinn_ltd_1data_longer_training" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6
#
# ===============================================================================================
# Commencing training for the timesegment:( 4 5 ]
# ===============================================================================================
# epochs: 0, Loss: 1.035e-01, Time: 27.07
# epochs: 10, Loss: 1.338e-02, Time: 32.76
# Parameters are saved in pickle file
# epochs: 20, Loss: 6.963e-03, Time: 36.18
# Parameters are saved in pickle file
# epochs: 30, Loss: 5.769e-03, Time: 32.77
# Parameters are saved in pickle file
# epochs: 40, Loss: 5.584e-03, Time: 31.86
# Parameters are saved in pickle file
# epochs: 50, Loss: 5.076e-03, Time: 32.72
# Parameters are saved in pickle file
# epochs: 60, Loss: 5.161e-03, Time: 32.60
# Parameters are saved in pickle file
# epochs: 70, Loss: 2.893e-03, Time: 32.50
# Parameters are saved in pickle file
# epochs: 80, Loss: 4.856e-03, Time: 32.75
# Parameters are saved in pickle file
# epochs: 90, Loss: 3.050e-03, Time: 32.21
# Parameters are saved in pickle file
# epochs: 100, Loss: 3.666e-03, Time: 32.38
# Parameters are saved in pickle file
# epochs: 110, Loss: 2.414e-03, Time: 32.42
# Parameters are saved in pickle file
# epochs: 120, Loss: 4.484e-03, Time: 32.10
# Parameters are saved in pickle file
# epochs: 130, Loss: 3.105e-03, Time: 31.93
# Parameters are saved in pickle file
# epochs: 140, Loss: 2.326e-03, Time: 32.33
# Parameters are saved in pickle file
# epochs: 150, Loss: 2.401e-03, Time: 32.47
# Parameters are saved in pickle file
# epochs: 160, Loss: 3.823e-03, Time: 32.14
# Parameters are saved in pickle file
# epochs: 170, Loss: 2.411e-03, Time: 33.28
# Parameters are saved in pickle file
# epochs: 180, Loss: 4.216e-03, Time: 33.05
# Parameters are saved in pickle file
# epochs: 190, Loss: 2.748e-03, Time: 32.81
# Parameters are saved in pickle file
# epochs: 200, Loss: 2.606e-03, Time: 32.64
# Parameters are saved in pickle file
# epochs: 210, Loss: 1.998e-03, Time: 32.32
# Parameters are saved in pickle file
# epochs: 220, Loss: 2.793e-03, Time: 32.99
# Parameters are saved in pickle file
# epochs: 230, Loss: 4.898e-03, Time: 32.79
# Parameters are saved in pickle file
# epochs: 240, Loss: 5.445e-03, Time: 32.28
# Parameters are saved in pickle file
# epochs: 250, Loss: 2.330e-03, Time: 33.17
# Parameters are saved in pickle file
# epochs: 260, Loss: 3.112e-03, Time: 31.24
# Parameters are saved in pickle file
# epochs: 270, Loss: 2.063e-03, Time: 32.82
# Parameters are saved in pickle file
# epochs: 280, Loss: 4.281e-03, Time: 32.66
# Parameters are saved in pickle file
# epochs: 290, Loss: 2.977e-03, Time: 32.85
# Parameters are saved in pickle file
# epochs: 300, Loss: 1.764e-03, Time: 32.64
# Parameters are saved in pickle file
# epochs: 310, Loss: 2.031e-03, Time: 31.65
# Parameters are saved in pickle file
# epochs: 320, Loss: 3.111e-03, Time: 32.37
# Parameters are saved in pickle file
# epochs: 330, Loss: 3.551e-03, Time: 32.70
# Parameters are saved in pickle file
# epochs: 340, Loss: 2.527e-03, Time: 32.68
# Parameters are saved in pickle file
# epochs: 350, Loss: 1.654e-03, Time: 32.92
# Parameters are saved in pickle file
# epochs: 360, Loss: 2.953e-03, Time: 32.08
# Parameters are saved in pickle file
# epochs: 370, Loss: 1.661e-03, Time: 31.41
# Parameters are saved in pickle file
# epochs: 380, Loss: 2.447e-03, Time: 32.78
# Parameters are saved in pickle file
# epochs: 390, Loss: 1.540e-03, Time: 32.54
# Parameters are saved in pickle file
# epochs: 400, Loss: 3.350e-03, Time: 32.49
# Parameters are saved in pickle file
# epochs: 410, Loss: 4.904e-03, Time: 32.43
# Parameters are saved in pickle file
# epochs: 420, Loss: 1.621e-03, Time: 31.90
# Parameters are saved in pickle file
# epochs: 430, Loss: 2.013e-03, Time: 32.32
# Parameters are saved in pickle file
# epochs: 440, Loss: 2.044e-03, Time: 33.11
# Parameters are saved in pickle file
# epochs: 450, Loss: 2.264e-03, Time: 33.27
# Parameters are saved in pickle file
# epochs: 460, Loss: 3.683e-03, Time: 32.85
# Parameters are saved in pickle file
# epochs: 470, Loss: 1.201e-02, Time: 33.57
# Parameters are saved in pickle file
# epochs: 480, Loss: 5.146e-03, Time: 31.46
# Parameters are saved in pickle file
# epochs: 490, Loss: 4.023e-03, Time: 33.08
# Parameters are saved in pickle file
# epochs: 500, Loss: 3.542e-03, Time: 33.29
# Parameters are saved in pickle file
# epochs: 510, Loss: 2.979e-03, Time: 33.05
# Parameters are saved in pickle file
# epochs: 520, Loss: 3.662e-03, Time: 33.49
# Parameters are saved in pickle file
# epochs: 530, Loss: 3.175e-03, Time: 31.78
# Parameters are saved in pickle file
# epochs: 540, Loss: 3.668e-03, Time: 32.56
# Parameters are saved in pickle file
# epochs: 550, Loss: 3.042e-03, Time: 32.97
# Parameters are saved in pickle file
# epochs: 560, Loss: 2.937e-03, Time: 32.89
# Parameters are saved in pickle file
# epochs: 570, Loss: 2.867e-03, Time: 32.81
# Parameters are saved in pickle file
# epochs: 580, Loss: 2.726e-03, Time: 32.50
# Parameters are saved in pickle file
# epochs: 590, Loss: 2.707e-03, Time: 32.21
# Parameters are saved in pickle file
# epochs: 600, Loss: 3.993e-03, Time: 32.73
# Parameters are saved in pickle file
# epochs: 610, Loss: 2.422e-03, Time: 33.24
# Parameters are saved in pickle file

# %% [markdown]
# # Run this code snippet to load the model

# %%
'''
This code snippet loads the bc pinn model, for some reason its not predicting well for time t=0 ?
'''

if __name__ == "__main__":

    
    N_train = 25000
    batch_size=1000
    Reynolds = 100
    layers = [3]+10*[100]+[3]
    
    # Enter the latest timestep for which the model has be previous trained on.
    time_step_test = 7

    # Loading the initial and the boundary conditions for the next timestep
    domain, initial, boundary,domain_data = load_data(time_step_test)
    datalist=load_complete_data()


    # Loading the predictions of the final timestep of the first timesegment as the initial conditions of this time segment
    prediction_file='uv_preds_lts_exp20'
    u,v,t=read_uv_values(prediction_file)

    # Initial condition guided learning
    # Altering the initial conditions data, only uvt values are changed pressure values are untouched.
    initial[:,2]=t[:,0]
    initial[:,3]=u[:,0]
    initial[:,4]=v[:,0]

    # Loading the previous timesegment data
    prev_name='prev_data_predictions_lts_exp20'
    prevtimedata=read_prev_data(prev_name)

    # Enter the names of the files :
    '''
    params_name : name of the file where you want to save the weights and biases, LOAD THE MODEL EVERYTIME, SINCE ITS THE SAME
                  MODEL THAT IS BEING TRAINED OVER DIFFERNT TIMESEGMENTS, WITH FOCUS ON PREV TIME SEGMENTS                  
    loss_name   : name of the file where you want to save the loss components
    prev_name   : name of the file where you want to save the predictions of each time step in the segment
    '''

    params_name = 'params_exp20'
    loss_name   = 'Loss_re100_truly_sparse'

    # Start the Training process
    with tf.device('/gpu:0'):

        bc_pinn_model_test = bc_pinn_t (domain,initial,boundary,domain_data,prevtimedata,datalist,
                                       N_train,batch_size,
                                       layers,re=Reynolds,
                                       load_model=True,filedr=params_name,
                                       freeze = 5,timestep=time_step_test,
                                       savewandb=params_name,saveloss=loss_name)
# Out:
# Predictions are loaded
# Previous predictions are loaded from pickle file
# Parameters are loaded succesffuly
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6

# %% [markdown]
# # Run this code snippet for checking

# %%
# Run this for Prediction for a network of 3 10*100 3 
def test_check_predictions(test_time_step,model,plot=False):
    '''
    This code works for specific time steps like 0,1,2,.... and not for intermediate timesteps like 0.1,0.2,0.3......
    '''

    X_star,Y_star=load_testdata(test_time_step)
    u_pred, v_pred, p_pred = model.predict(X_star[0],X_star[1],X_star[2])

    # # Error
    error_u = np.linalg.norm(Y_star[0] - u_pred, 2) / np.linalg.norm(Y_star[0], 2)
    error_v = np.linalg.norm(Y_star[1] - v_pred, 2) / np.linalg.norm(Y_star[1], 2)

    # Mean corrected pressure error
    p_predm=p_pred-np.mean(p_pred)
    p_truem=Y_star[2]-np.mean(Y_star[2])

    error_p = np.linalg.norm(p_truem - p_predm, 2) / np.linalg.norm(p_truem, 2)

    print("Errors at timestep:", np.unique(X_star[2]))
    print("------------------------------------------------")
    print('Error u: %e' % error_u)
    print('Error v: %e' % error_v)
    print('Error p: %e' % error_p)
    
    if plot == True:
        uplot=np.reshape(v_pred,(100,100))
        plt.imshow(uplot)
        plt.title("Predicted v_velocity")
        plt.colorbar()
        plt.savefig('pred'+str(test_time_step))
        plt.show()

        upl=np.reshape(Y_star[1],(100,100))
        plt.imshow(upl)
        plt.title("Actual v_velocity")
        plt.colorbar()
        plt.savefig('actual'+str(test_time_step))
        plt.show()
    return error_u,error_v

# %%
eu=[]
ev=[]
for i in np.arange(0,8,1):
    eua,eva=test_check_predictions(round(i,3),bc_pinn_model_test,plot=True)
    eu.append(eua)
    ev.append(eva)
# Out:
# Errors at timestep: [0.]
# ------------------------------------------------
# Error u: 1.347203e-02
# Error v: 5.959370e-02
# Error p: 3.209532e+00
# Errors at timestep: [1.]
# ------------------------------------------------
# Error u: 1.909367e-02
# Error v: 8.071755e-02
# Error p: 2.899308e+00
# Errors at timestep: [2.]
# ------------------------------------------------
# Error u: 1.711176e-02
# Error v: 7.752481e-02
# Error p: 5.641785e+00
# Errors at timestep: [3.]
# ------------------------------------------------
# Error u: 1.708689e-02
# Error v: 7.471022e-02
# Error p: 2.272302e+00
# Errors at timestep: [4.]
# ------------------------------------------------
# Error u: 1.521060e-02
# Error v: 6.058200e-02
# Error p: 2.752390e+00
# Errors at timestep: [5.]
# ------------------------------------------------
# Error u: 1.460097e-02
# Error v: 5.308062e-02
# Error p: 1.505694e+00
# Errors at timestep: [6.]
# ------------------------------------------------
# Error u: 1.453251e-02
# Error v: 6.637325e-02
# Error p: 3.234035e-01
# Errors at timestep: [7.]
# ------------------------------------------------
# Error u: 1.446415e-02
# Error v: 4.851704e-02
# Error p: 2.055610e-01

# %%
X_star,Y_star=load_testdata(6)
u_pred, v_pred, p_pred = bc_pinn_model_test.predict(X_star[0],X_star[1],X_star[2])
err=u_pred-Y_star[0]
err=np.reshape(err,(100,100))

plt.imshow(err)
plt.colorbar()

# %%
from scipy.interpolate import make_interp_spline as mis

nsfdata=pd.read_csv(r"C:\Users\user1\Desktop\NSFNET_basic.csv").to_numpy()
nsfdata2=pd.read_csv(r"C:\Users\user1\Desktop\NSFNET_dynamic.csv").to_numpy()
for i in range(nsfdata.shape[1]):
    nsfdata[i,0]=round(nsfdata[i,0],3)
    
for i in range(nsfdata2.shape[1]):
    nsfdata2[i,0]=round(nsfdata2[i,0],3)

t_nsf=nsfdata[:,0]
eu_nsf=nsfdata[:,1]
eu_nsf2=nsfdata2[:,1]

# Basic 
xyspline=mis(t_nsf,eu_nsf)
x=np.linspace(t_nsf.min(),t_nsf.max(),500)
y=xyspline(x)
plt.plot(x,y)
# Dynamic weights
xyspline3=mis(t_nsf,eu_nsf2)
y3=xyspline3(x)
plt.plot(x,y3)

# MY model
t=[i for i in np.arange(0,8,1)]
xyspline2=mis(t,eu)
y2=xyspline2(x)
plt.plot(x,y2)

plt.legend(['NSFNET Basic','NSFNET Dynamic','seq2seq model with 1% data from inside domain'])
plt.title("Comparison of relative l2 errors with NSFNET paper")
plt.xlabel("Time steps")
plt.ylabel("Relative l2 error")
plt.show()

# %%
from scipy.interpolate import make_interp_spline as mis

nsfdatav=pd.read_csv(r"C:\Users\user1\Desktop\vvel_basic.csv").to_numpy()
nsfdatav2=pd.read_csv(r"C:\Users\user1\Desktop\vvel_dynamic.csv").to_numpy()
for i in range(nsfdatav.shape[1]):
    nsfdatav[i,0]=round(nsfdatav[i,0],3)
    
for i in range(nsfdatav2.shape[1]):
    nsfdatav2[i,0]=round(nsfdatav2[i,0],3)

t_nsf=nsfdatav[:,0]
eu_nsf=nsfdatav[:,1]
eu_nsf2=nsfdatav2[:,1]

# Basic 
xyspline=mis(t_nsf,eu_nsf)
x=np.linspace(t_nsf.min(),t_nsf.max(),500)
y=xyspline(x)
plt.plot(x,y)
# Dynamic weights
xyspline3=mis(t_nsf,eu_nsf2)
y3=xyspline3(x)
plt.plot(x,y3)

# MY model
t=[i for i in np.arange(0,8,1)]
xyspline2=mis(t,ev)
y2=xyspline2(x)
plt.plot(x,y2)

plt.legend(['NSFNET no weights','NSFNET Dynamic weights','seq2seq model with 1% data from inside domain'])
plt.title("Comparison of v velocity relative l2 errors with NSFNET paper")
plt.xlabel("Time steps")
plt.ylabel("Relative l2 error")
plt.show()

# %% [markdown]
# # Run this code segment to save the errors

# %%
def save_error_data(file_name,eu):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\RE100_mts_results\novel_method")
    my_path=root_path/file_name

    with open(my_path,'wb') as f:
        pickle.dump(eu,f)
        print("Errors are saved in pickle file")

# %%
def load_error_data(file_name):
    root_path=Path(r"E:\Vamsi_oe20s302\Vamsi\seq2seq learning\Re100_mts_results\novel_method")
    my_path=root_path/file_name

    # returns the weights and biases of the network as np array
    with open(my_path,'rb') as f:
        eu_load=pickle.load(f)
    return eu_load

# %% [markdown]
# # Saving the errors

# %%
save_error_data('1data_long_training',eu)
# Out:
# Errors are saved in pickle file

# %% [markdown]
# # Comparing the reduced data models

# %%
eu10=load_error_data('10data')
euwd=load_error_data('withoutdata')
eu50=load_error_data('50data')
eu1=load_error_data('1data')

# %%
t=[i for i in np.arange(0,8,1)]

xyspline10=mis(t,eu10)
y10=xyspline10(x)
plt.plot(x,y10)

xyspline50=mis(t,eu50)
y50=xyspline50(x)
plt.plot(x,y50)

xyspline10re=mis(t,eu1)
y10re=xyspline10re(x)
plt.plot(x,y10re)

xysplinewd=mis(t,euwd)
ywd=xysplinewd(x)
plt.plot(x,ywd)

plt.legend(['10% data','50% data','1% data','withoutdata'])
plt.title("Comparison of relative l2 errors ")
plt.xlabel("Time steps")
plt.ylabel("Relative l2 error")
plt.show()

# %%
t=[i for i in np.arange(0,8,1)]

xyspline10=mis(t,eu10)
y10=xyspline10(x)
plt.plot(x,y10)

xyspline50=mis(t,eu50)
y50=xyspline50(x)
plt.plot(x,y50)

xysplinewd=mis(t,euwd)
ywd=xysplinewd(x)
plt.plot(x,ywd)

plt.legend(['10% data','50% data','withoutdata'])
plt.title("Comparison of relative l2 errors ")
plt.xlabel("Time steps")
plt.ylabel("Relative l2 error")
plt.show()
